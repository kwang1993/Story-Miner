# %%
# %run init.py
# %run main_functions.py
# %run utility_functions.py

'''
CONFIGURATION SETUP
'''
DATA_SET = "sentence_only"
MAX_ITERATION = -1
NODE_SELECTION = False
SAVE_GEFX = True
SAVE_PAIRWISE_RELS = True
SAVE_ALL_RELS = True

#input_file_loc = "../../data/Vaccination/mothering_contexts/religousInst_medicalProf.csv"
#input_file_loc = "../../data/Vaccination/hoffman_output/exp_3_clean_sep/res_all_cat_clean.csv"
input_file_loc = "../../data/Tweets/tweets_textOnly_relations_-1.csv"
output_dir = "../../data/Tweets/aggregation_results/"

file_input_name = 'all'#'relig_med'

df_rels = read_data(input_file_loc,DATA_SET,",")

# %%
df_rels
# Out:
#                                              sentence  \
# 0   Why Samsung Pay could gain an early lead in mo...
# 1   Why Samsung Pay could gain an early lead in mo...
# 2   Why Samsung Pay could gain an early lead in mo...
# 3   Why Samsung Pay could gain an early lead in mo...
# 4   Why Samsung Pay could gain an early lead in mo...
# 5   Why Samsung Pay could gain an early lead in mo...
# 6   Why Samsung Pay could gain an early lead in mo...
# 7   Why Samsung Pay could gain an early lead in mo...
# 8   Why Samsung Pay could gain an early lead in mo...
# 9   Going out for some Mexican Food! Happy Hour Ti...
# 10  Why Samsung Pay could gain an early lead in mo...
# 11  Why Samsung Pay could gain an early lead in mo...
# 12  Why Samsung Pay could gain an early lead in mo...
# 13  Why Samsung Pay could gain an early lead in mo...
# 14  Never will I own a contactless card. Not makin...
# 15  Why Samsung Pay could gain an early lead in mo...
# 16  Why Samsung Pay could gain an early lead in mo...
# 17  Why Samsung Pay could gain an early lead in mo...
# 18  Why Samsung Pay could gain an early lead in mo...
# 19  Today Kenya leads the way in mobile payment pr...
# 20  Why Samsung Pay could gain an early lead in mo...
# 21  Why Samsung Pay could gain an early lead in mo...
# 22  Why Samsung Pay could gain an early lead in mo...
# 23  Why Samsung Pay could gain an early lead in mo...
# 24  Why Samsung Pay could gain an early lead in mo...
# 25  Never will I own a contactless card. Not makin...
# 26  Fake Twitter verification profiles trick victi...
# 27  Why Samsung Pay could gain an early lead in mo...
# 28  Cale + Apple Pay! Visit us at booth 361 at IPI...
# 29  Why Samsung Pay could gain an early lead in mo...
# ..                                                ...
# 31  Someone should invent a cryptocurrency that di...
# 32  Silicone Mobile Wallet If you have a cell then...
# 33  Silicone Mobile Wallet If you have a cell then...
# 34  Silicone Mobile Wallet If you have a cell then...
# 35  Silicone Mobile Wallet If you have a cell then...
# 36  Silicone Mobile Wallet If you have a cell then...
# 37  Silicone Mobile Wallet If you have a cell then...
# 38  Why Samsung Pay could gain an early lead in mo...
# 39  Why Samsung Pay could gain an early lead in mo...
# 40  Fake Twitter verification profiles trick victi...
# 41  Everything You Need To Know About Apple Pay In...
# 42  Why Samsung Pay could gain an early lead in mo...
# 43  Fake Twitter verification profiles trick victi...
# 44  Why Samsung Pay could gain an early lead in mo...
# 45  Why Samsung Pay could gain an early lead in mo...
# 46  Tampa parking kiosk subsidiary caleamerica rev...
# 47  true, though sometimes Apple has better luck p...
# 48  consider using Apple Pay for donations. I'm gu...
# 49  everyone comments how awesome apple pay is whe...
# 50  everyone comments how awesome apple pay is whe...
# 51                    i believe you use Google wallet
# 52  Today Kenya leads the way in mobile payment pr...
# 53  Fake Twitter verification profiles trick victi...
# 54        once I get a paypal/Google wallet I will ;3
# 55  Who's attending MWCS15? Visit the SD Associati...
# 56  Fake Twitter verification profiles trick victi...
# 57  Forget Apple Pay on your Apple Watch, First We...
# 58  Forget Apple Pay on your Apple Watch, First We...
# 59  Barclays Bank in the UK is developing its own ...
# 60  Hey, simple, trying to get my card approved fo...
#
#                                             arg1                   rel  \
# 0                                  Samsung {Pay}      Why could {gain}
# 1                                  Samsung {Pay}      Why could {gain}
# 2                                  Samsung {Pay}      Why could {gain}
# 3                                  Samsung {Pay}      Why could {gain}
# 4                                  Samsung {Pay}      Why could {gain}
# 5                                  Samsung {Pay}      Why could {gain}
# 6                                  Samsung {Pay}      Why could {gain}
# 7                                  Samsung {Pay}      Why could {gain}
# 8                                  Samsung {Pay}      Why could {gain}
# 9                                      {someone}     should {buy} here
# 10                                 Samsung {Pay}      Why could {gain}
# 11                                 Samsung {Pay}      Why could {gain}
# 12                                 Samsung {Pay}      Why could {gain}
# 13                                 Samsung {Pay}      Why could {gain}
# 14                                           {I}      Never will {own}
# 15                                 Samsung {Pay}      Why could {gain}
# 16                                 Samsung {Pay}      Why could {gain}
# 17                                 Samsung {Pay}      Why could {gain}
# 18                                 Samsung {Pay}      Why could {gain}
# 19                                     the {way}           will {take}
# 20                                 Samsung {Pay}      Why could {gain}
# 21                                 Samsung {Pay}      Why could {gain}
# 22                                 Samsung {Pay}      Why could {gain}
# 23                                 Samsung {Pay}      Why could {gain}
# 24                                 Samsung {Pay}      Why could {gain}
# 25                                           {I}      Never will {own}
# 26          Fake Twitter verification {profiles}               {trick}
# 27                                 Samsung {Pay}      Why could {gain}
# 28                              Cale Apple {Pay}               {Visit}
# 29                                 Samsung {Pay}      Why could {gain}
# ..                                           ...                   ...
# 31                            a {cryptocurrency}         {distributes}
# 32                                         {you}                {have}
# 33                      Silicone Mobile {Wallet}           then {need}
# 34                                         {you}           then {need}
# 35                                         {you}                {have}
# 36                      Silicone Mobile {Wallet}           then {need}
# 37                                         {you}           then {need}
# 38                                 Samsung {Pay}      Why could {gain}
# 39                                 Samsung {Pay}      Why could {gain}
# 40          Fake Twitter verification {profiles}               {trick}
# 41                                         {You}                {Need}
# 42                                 Samsung {Pay}      Why could {gain}
# 43          Fake Twitter verification {profiles}               {trick}
# 44                                 Samsung {Pay}      Why could {gain}
# 45                                 Samsung {Pay}      Why could {gain}
# 46  Tampa parking kiosk subsidiary {caleamerica}             {reveals}
# 47                                       {Apple}  true sometimes {has}
# 48                                           {I}         'm {guessing}
# 49                                           {i}         when do {lol}
# 50                                           {i}         when do {lol}
# 51                                         {you}                 {use}
# 52                                     the {way}           will {take}
# 53          Fake Twitter verification {profiles}               {trick}
# 54                                           {I}            once {get}
# 55                                         {Who}            's {Visit}
# 56          Fake Twitter verification {profiles}               {trick}
# 57                                   Apple {Pay}                 {has}
# 58                     First West Credit {Union}                 {has}
# 59                               Barclays {Bank}       is {developing}
# 60                                           {I}            {fill} out
#
#                            arg2 type              pattern  \
# 0               an early {lead}  SVO  (nsubj, verb, dobj)
# 1               an early {lead}  SVO  (nsubj, verb, dobj)
# 2               an early {lead}  SVO  (nsubj, verb, dobj)
# 3               an early {lead}  SVO  (nsubj, verb, dobj)
# 4               an early {lead}  SVO  (nsubj, verb, dobj)
# 5               an early {lead}  SVO  (nsubj, verb, dobj)
# 6               an early {lead}  SVO  (nsubj, verb, dobj)
# 7               an early {lead}  SVO  (nsubj, verb, dobj)
# 8               an early {lead}  SVO  (nsubj, verb, dobj)
# 9                     a {drink}  SVO  (nsubj, verb, dobj)
# 10              an early {lead}  SVO  (nsubj, verb, dobj)
# 11              an early {lead}  SVO  (nsubj, verb, dobj)
# 12              an early {lead}  SVO  (nsubj, verb, dobj)
# 13              an early {lead}  SVO  (nsubj, verb, dobj)
# 14         a contactless {card}  SVO  (nsubj, verb, dobj)
# 15              an early {lead}  SVO  (nsubj, verb, dobj)
# 16              an early {lead}  SVO  (nsubj, verb, dobj)
# 17              an early {lead}  SVO  (nsubj, verb, dobj)
# 18              an early {lead}  SVO  (nsubj, verb, dobj)
# 19                the {rest} us  SVO  (nsubj, verb, dobj)
# 20              an early {lead}  SVO  (nsubj, verb, dobj)
# 21              an early {lead}  SVO  (nsubj, verb, dobj)
# 22              an early {lead}  SVO  (nsubj, verb, dobj)
# 23              an early {lead}  SVO  (nsubj, verb, dobj)
# 24              an early {lead}  SVO  (nsubj, verb, dobj)
# 25         a contactless {card}  SVO  (nsubj, verb, dobj)
# 26                    {victims}  SVO  (nsubj, verb, dobj)
# 27              an early {lead}  SVO  (nsubj, verb, dobj)
# 28                         {us}  SVO  (nsubj, verb, dobj)
# 29              an early {lead}  SVO  (nsubj, verb, dobj)
# ..                          ...  ...                  ...
# 31               the {currency}  SVO  (nsubj, verb, dobj)
# 32                     a {cell}  SVO  (nsubj, verb, dobj)
# 33                       {this}  SVO  (nsubj, verb, dobj)
# 34                       {this}  SVO  (nsubj, verb, dobj)
# 35                     a {cell}  SVO  (nsubj, verb, dobj)
# 36                       {this}  SVO  (nsubj, verb, dobj)
# 37                       {this}  SVO  (nsubj, verb, dobj)
# 38              an early {lead}  SVO  (nsubj, verb, dobj)
# 39              an early {lead}  SVO  (nsubj, verb, dobj)
# 40                    {victims}  SVO  (nsubj, verb, dobj)
# 41                 {Everything}  SVO  (nsubj, verb, dobj)
# 42              an early {lead}  SVO  (nsubj, verb, dobj)
# 43                    {victims}  SVO  (nsubj, verb, dobj)
# 44              an early {lead}  SVO  (nsubj, verb, dobj)
# 45              an early {lead}  SVO  (nsubj, verb, dobj)
# 46            ApplePay {reader}  SVO  (nsubj, verb, dobj)
# 47        better {luck} pushing  SVO  (nsubj, verb, dobj)
# 48                     % {lift}  SVO  (nsubj, verb, dobj)
# 49                          {i}  SVO  (nsubj, verb, dobj)
# 50                         {it}  SVO  (nsubj, verb, dobj)
# 51              Google {wallet}  SVO  (nsubj, verb, dobj)
# 52                the {rest} us  SVO  (nsubj, verb, dobj)
# 53                    {victims}  SVO  (nsubj, verb, dobj)
# 54                   a {paypal}  SVO  (nsubj, verb, dobj)
# 55   the SD Association {booth}  SVO  (nsubj, verb, dobj)
# 56                    {victims}  SVO  (nsubj, verb, dobj)
# 57    the Dashband CU {Insight}  SVO  (nsubj, verb, dobj)
# 58    the Dashband CU {Insight}  SVO  (nsubj, verb, dobj)
# 59  own mobile payment {device}  SVO  (nsubj, verb, dobj)
# 60                       {form}  SVO  (nsubj, verb, dobj)
#
#                                         arg1_with_pos  \
# 0                             Samsung-NNP-2 Pay-NNP-3
# 1                             Samsung-NNP-2 Pay-NNP-3
# 2                             Samsung-NNP-2 Pay-NNP-3
# 3                             Samsung-NNP-2 Pay-NNP-3
# 4                             Samsung-NNP-2 Pay-NNP-3
# 5                             Samsung-NNP-2 Pay-NNP-3
# 6                             Samsung-NNP-2 Pay-NNP-3
# 7                             Samsung-NNP-2 Pay-NNP-3
# 8                             Samsung-NNP-2 Pay-NNP-3
# 9                                       someone-NN-12
# 10                            Samsung-NNP-2 Pay-NNP-3
# 11                            Samsung-NNP-2 Pay-NNP-3
# 12                            Samsung-NNP-2 Pay-NNP-3
# 13                            Samsung-NNP-2 Pay-NNP-3
# 14                                            I-PRP-3
# 15                            Samsung-NNP-2 Pay-NNP-3
# 16                            Samsung-NNP-2 Pay-NNP-3
# 17                            Samsung-NNP-2 Pay-NNP-3
# 18                            Samsung-NNP-2 Pay-NNP-3
# 19                                  the-DT-4 way-NN-5
# 20                            Samsung-NNP-2 Pay-NNP-3
# 21                            Samsung-NNP-2 Pay-NNP-3
# 22                            Samsung-NNP-2 Pay-NNP-3
# 23                            Samsung-NNP-2 Pay-NNP-3
# 24                            Samsung-NNP-2 Pay-NNP-3
# 25                                            I-PRP-3
# 26  Fake-JJ-1 Twitter-NNP-2 verification-NN-3 prof...
# 27                            Samsung-NNP-2 Pay-NNP-3
# 28                   Cale-NNP-1 Apple-NNP-3 Pay-NNP-4
# 29                            Samsung-NNP-2 Pay-NNP-3
# ..                                                ...
# 31                         a-DT-4 cryptocurrency-NN-5
# 32                                          you-PRP-5
# 33            Silicone-NNP-1 Mobile-NNP-2 Wallet-NN-3
# 34                                         you-PRP-10
# 35                                          you-PRP-5
# 36            Silicone-NNP-1 Mobile-NNP-2 Wallet-NN-3
# 37                                         you-PRP-10
# 38                            Samsung-NNP-2 Pay-NNP-3
# 39                            Samsung-NNP-2 Pay-NNP-3
# 40  Fake-JJ-1 Twitter-NNP-2 verification-NN-3 prof...
# 41                                          You-PRP-2
# 42                            Samsung-NNP-2 Pay-NNP-3
# 43  Fake-JJ-1 Twitter-NNP-2 verification-NN-3 prof...
# 44                            Samsung-NNP-2 Pay-NNP-3
# 45                            Samsung-NNP-2 Pay-NNP-3
# 46  Tampa-NNP-1 parking-NN-2 kiosk-NN-3 subsidiary...
# 47                                        Apple-NNP-5
# 48                                            I-PRP-8
# 49                                            i-PRP-9
# 50                                            i-PRP-9
# 51                                          you-PRP-3
# 52                                  the-DT-4 way-NN-5
# 53  Fake-JJ-1 Twitter-NNP-2 verification-NN-3 prof...
# 54                                            I-PRP-2
# 55                                           Who-WP-1
# 56  Fake-JJ-1 Twitter-NNP-2 verification-NN-3 prof...
# 57                              Apple-NNP-2 Pay-NNP-3
# 58  First-NNP-9 West-NNP-10 Credit-NNP-11 Union-NN...
# 59                          Barclays-NNP-1 Bank-NNP-2
# 60                                           I-PRP-18
#
#                           rel_with_pos  \
# 0       Why-WRB-1 could-MD-4 gain-VB-5
# 1       Why-WRB-1 could-MD-4 gain-VB-5
# 2       Why-WRB-1 could-MD-4 gain-VB-5
# 3       Why-WRB-1 could-MD-4 gain-VB-5
# 4       Why-WRB-1 could-MD-4 gain-VB-5
# 5       Why-WRB-1 could-MD-4 gain-VB-5
# 6       Why-WRB-1 could-MD-4 gain-VB-5
# 7       Why-WRB-1 could-MD-4 gain-VB-5
# 8       Why-WRB-1 could-MD-4 gain-VB-5
# 9    should-MD-13 buy-VB-14 here-RB-21
# 10      Why-WRB-1 could-MD-4 gain-VB-5
# 11      Why-WRB-1 could-MD-4 gain-VB-5
# 12      Why-WRB-1 could-MD-4 gain-VB-5
# 13      Why-WRB-1 could-MD-4 gain-VB-5
# 14       Never-RB-1 will-MD-2 own-VB-4
# 15      Why-WRB-1 could-MD-4 gain-VB-5
# 16      Why-WRB-1 could-MD-4 gain-VB-5
# 17      Why-WRB-1 could-MD-4 gain-VB-5
# 18      Why-WRB-1 could-MD-4 gain-VB-5
# 19               will-MD-13 take-VB-14
# 20      Why-WRB-1 could-MD-4 gain-VB-5
# 21      Why-WRB-1 could-MD-4 gain-VB-5
# 22      Why-WRB-1 could-MD-4 gain-VB-5
# 23      Why-WRB-1 could-MD-4 gain-VB-5
# 24      Why-WRB-1 could-MD-4 gain-VB-5
# 25       Never-RB-1 will-MD-2 own-VB-4
# 26                         trick-VBP-5
# 27      Why-WRB-1 could-MD-4 gain-VB-5
# 28                          Visit-VB-6
# 29      Why-WRB-1 could-MD-4 gain-VB-5
# ..                                 ...
# 31                   distributes-VBZ-7
# 32                          have-VBP-6
# 33               then-RB-9 need-VBP-11
# 34               then-RB-9 need-VBP-11
# 35                          have-VBP-6
# 36               then-RB-9 need-VBP-11
# 37               then-RB-9 need-VBP-11
# 38      Why-WRB-1 could-MD-4 gain-VB-5
# 39      Why-WRB-1 could-MD-4 gain-VB-5
# 40                         trick-VBP-5
# 41                          Need-VBP-3
# 42      Why-WRB-1 could-MD-4 gain-VB-5
# 43                         trick-VBP-5
# 44      Why-WRB-1 could-MD-4 gain-VB-5
# 45      Why-WRB-1 could-MD-4 gain-VB-5
# 46                       reveals-VBZ-6
# 47  true-JJ-1 sometimes-RB-4 has-VBZ-6
# 48            'm-VBP-9 guessing-VBG-10
# 49      when-WRB-8 do-VBP-10 lol-VB-12
# 50      when-WRB-8 do-VBP-10 lol-VB-12
# 51                           use-VBP-4
# 52               will-MD-13 take-VB-14
# 53                         trick-VBP-5
# 54                 once-RB-1 get-VBP-3
# 55                 's-VBZ-2 Visit-VB-6
# 56                         trick-VBP-5
# 57                          has-VBZ-13
# 58                          has-VBZ-13
# 59           is-VBZ-6 developing-VBG-7
# 60               fill-VBP-19 out-RP-20
#
#                                         arg2_with_pos  \
# 0                        an-DT-6 early-JJ-7 lead-NN-8
# 1                        an-DT-6 early-JJ-7 lead-NN-8
# 2                        an-DT-6 early-JJ-7 lead-NN-8
# 3                        an-DT-6 early-JJ-7 lead-NN-8
# 4                        an-DT-6 early-JJ-7 lead-NN-8
# 5                        an-DT-6 early-JJ-7 lead-NN-8
# 6                        an-DT-6 early-JJ-7 lead-NN-8
# 7                        an-DT-6 early-JJ-7 lead-NN-8
# 8                        an-DT-6 early-JJ-7 lead-NN-8
# 9                                 a-DT-16 drink-NN-17
# 10                       an-DT-6 early-JJ-7 lead-NN-8
# 11                       an-DT-6 early-JJ-7 lead-NN-8
# 12                       an-DT-6 early-JJ-7 lead-NN-8
# 13                       an-DT-6 early-JJ-7 lead-NN-8
# 14                  a-DT-5 contactless-JJ-6 card-NN-7
# 15                       an-DT-6 early-JJ-7 lead-NN-8
# 16                       an-DT-6 early-JJ-7 lead-NN-8
# 17                       an-DT-6 early-JJ-7 lead-NN-8
# 18                       an-DT-6 early-JJ-7 lead-NN-8
# 19                     the-DT-15 rest-NN-16 us-PRP-18
# 20                       an-DT-6 early-JJ-7 lead-NN-8
# 21                       an-DT-6 early-JJ-7 lead-NN-8
# 22                       an-DT-6 early-JJ-7 lead-NN-8
# 23                       an-DT-6 early-JJ-7 lead-NN-8
# 24                       an-DT-6 early-JJ-7 lead-NN-8
# 25                  a-DT-5 contactless-JJ-6 card-NN-7
# 26                                      victims-NNS-6
# 27                       an-DT-6 early-JJ-7 lead-NN-8
# 28                                           us-PRP-7
# 29                       an-DT-6 early-JJ-7 lead-NN-8
# ..                                                ...
# 31                             the-DT-8 currency-NN-9
# 32                                   a-DT-7 cell-NN-8
# 33                                         this-DT-12
# 34                                         this-DT-12
# 35                                   a-DT-7 cell-NN-8
# 36                                         this-DT-12
# 37                                         this-DT-12
# 38                       an-DT-6 early-JJ-7 lead-NN-8
# 39                       an-DT-6 early-JJ-7 lead-NN-8
# 40                                      victims-NNS-6
# 41                                    Everything-NN-1
# 42                       an-DT-6 early-JJ-7 lead-NN-8
# 43                                      victims-NNS-6
# 44                       an-DT-6 early-JJ-7 lead-NN-8
# 45                       an-DT-6 early-JJ-7 lead-NN-8
# 46                         ApplePay-NNP-7 reader-NN-8
# 47               better-JJR-7 luck-NN-8 pushing-VBG-9
# 48                                 %-NN-12 lift-NN-13
# 49                                           i-PRP-13
# 50                                          it-PRP-11
# 51                           Google-NNP-5 wallet-NN-6
# 52                     the-DT-15 rest-NN-16 us-PRP-18
# 53                                      victims-NNS-6
# 54                                 a-DT-4 paypal-NN-5
# 55    the-DT-7 SD-NNP-8 Association-NNP-9 booth-NN-10
# 56                                      victims-NNS-6
# 57  the-DT-14 Dashband-NNP-15 CU-NNP-16 Insight-NN...
# 58  the-DT-14 Dashband-NNP-15 CU-NNP-16 Insight-NN...
# 59   own-JJ-9 mobile-JJ-10 payment-NN-11 device-NN-12
# 60                                         form-NN-21
#
#                                     arg1_prepositions  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19  REASON: prep_in TEXT: mobile payment processin...
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# ..                                                ...
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51                                                NaN
# 52  REASON: prep_in TEXT: mobile payment processin...
# 53                                                NaN
# 54                                                NaN
# 55                                                NaN
# 56                                                NaN
# 57                                                NaN
# 58                                                NaN
# 59                 REASON: prep_in TEXT: the {UK} --
# 60                                                NaN
#
#                                      rel_prepositions  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                     REASON: prep_in TEXT: {lt} --
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28  REASON: prep_at TEXT: {booth} 361 -- REASON: p...
# 29                                                NaN
# ..                                                ...
# 31    REASON: prep_in TEXT: each digital {wallet} --
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43           REASON: prep_for TEXT: more {detail} --
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51                                                NaN
# 52                     REASON: prep_in TEXT: {lt} --
# 53                                                NaN
# 54                                                NaN
# 55                                                NaN
# 56                                                NaN
# 57            REASON: prep_on TEXT: Apple {Watch} --
# 58            REASON: prep_on TEXT: Apple {Watch} --
# 59                                                NaN
# 60                                                NaN
#
#                               arg2_prepositions
# 0   REASON: prep_in TEXT: mobile {payments} --
# 1   REASON: prep_in TEXT: mobile {payments} --
# 2   REASON: prep_in TEXT: mobile {payments} --
# 3   REASON: prep_in TEXT: mobile {payments} --
# 4   REASON: prep_in TEXT: mobile {payments} --
# 5   REASON: prep_in TEXT: mobile {payments} --
# 6   REASON: prep_in TEXT: mobile {payments} --
# 7   REASON: prep_in TEXT: mobile {payments} --
# 8   REASON: prep_in TEXT: mobile {payments} --
# 9                                           NaN
# 10  REASON: prep_in TEXT: mobile {payments} --
# 11  REASON: prep_in TEXT: mobile {payments} --
# 12  REASON: prep_in TEXT: mobile {payments} --
# 13  REASON: prep_in TEXT: mobile {payments} --
# 14                                          NaN
# 15  REASON: prep_in TEXT: mobile {payments} --
# 16  REASON: prep_in TEXT: mobile {payments} --
# 17  REASON: prep_in TEXT: mobile {payments} --
# 18  REASON: prep_in TEXT: mobile {payments} --
# 19                                          NaN
# 20  REASON: prep_in TEXT: mobile {payments} --
# 21  REASON: prep_in TEXT: mobile {payments} --
# 22  REASON: prep_in TEXT: mobile {payments} --
# 23  REASON: prep_in TEXT: mobile {payments} --
# 24  REASON: prep_in TEXT: mobile {payments} --
# 25                                          NaN
# 26                                          NaN
# 27  REASON: prep_in TEXT: mobile {payments} --
# 28                                          NaN
# 29  REASON: prep_in TEXT: mobile {payments} --
# ..                                          ...
# 31                                          NaN
# 32                                          NaN
# 33                                          NaN
# 34                                          NaN
# 35                                          NaN
# 36                                          NaN
# 37                                          NaN
# 38  REASON: prep_in TEXT: mobile {payments} --
# 39  REASON: prep_in TEXT: mobile {payments} --
# 40                                          NaN
# 41                                          NaN
# 42  REASON: prep_in TEXT: mobile {payments} --
# 43                                          NaN
# 44  REASON: prep_in TEXT: mobile {payments} --
# 45  REASON: prep_in TEXT: mobile {payments} --
# 46          REASON: prep_at TEXT: {IPIConf} --
# 47                                          NaN
# 48       REASON: prep_in TEXT: {conversion} --
# 49                                          NaN
# 50                                          NaN
# 51                                          NaN
# 52                                          NaN
# 53                                          NaN
# 54                                          NaN
# 55                                          NaN
# 56                                          NaN
# 57                                          NaN
# 58                                          NaN
# 59                                          NaN
# 60                                          NaN
#
# [61 rows x 12 columns]

# %%
#'''
if NODE_SELECTION:
    # get the list of different versions of an entity. Example : parents,parent,i,we -> parents
    entity_versions = get_entity_versions(DATA_SET)    
    df_simp = get_simp_df(df_rels.copy(),entity_versions)  
    selected_nodes = entity_versions.keys()
    df_rels_selected = filter_nodes(df_simp.copy(),source='arg1',target='arg2',selected_nodes = selected_nodes)
    g_arg = create_argument_multiGraph(df_rels_selected.copy(),source='arg1',target='arg2',edge_attr = 'rel')
    if SAVE_GEFX:
        nx.write_gexf(g_arg, output_dir + file_input_name + "_" + "g_arg_selected_"+str(MAX_ITERATION)+"_"+str(time.time())+".gexf")
    #plot_argument_graph(g_arg)
    if SAVE_PAIRWISE_RELS:
        file_loc = output_dir + file_input_name + "_" + "pairwise_rels_selected_"+str(MAX_ITERATION)+"_"+DATA_SET+".txt"
        save_pairwise_rels(file_loc,g_arg,print_option=True)      

g_arg = create_argument_multiGraph(df_rels.copy(),source='arg1',target='arg2',edge_attr = 'rel')
if SAVE_GEFX:
    nx.write_gexf(g_arg, output_dir + file_input_name + "_" + "g_arg_"+str(MAX_ITERATION)+"_"+str(time.time())+".gexf")
#plot_argument_graph(g_arg)
if SAVE_PAIRWISE_RELS:
    file_loc = output_dir + file_input_name + "_"  + "pairwise_rels_"+str(MAX_ITERATION)+"_"+DATA_SET+".txt"
    save_pairwise_rels(file_loc,g_arg,print_option=True)    
    
#if __name__ == "__main__":
#    main(sys.argv[1:])
#'''
# Out:
# the {way} the {rest} us {0: {'label': 'will {take}-2'}}
# Cale Apple {Pay} {us} {0: {'label': '{Visit}-1'}}
# {I} a {paypal} {0: {'label': 'once {get}-1'}}
# {I} a contactless {card} {0: {'label': 'Never will {own}-2'}}
# {I} {form} {0: {'label': '{fill} out-1'}}
# {I} % {lift} {0: {'label': "'m {guessing}-1"}}
# {Who} the SD Association {booth} {0: {'label': "'s {Visit}-1"}}
# Fake Twitter verification {profiles} {victims} {0: {'label': '{trick}-5'}}
# {you} a {cell} {0: {'label': '{have}-2'}}
# {you} {this} {0: {'label': 'then {need}-2'}}
# {you} Google {wallet} {0: {'label': '{use}-1'}}
# Tampa parking kiosk subsidiary {caleamerica} ApplePay {reader} {0: {'label': '{reveals}-1'}}
# {someone} a {drink} {0: {'label': 'should {buy} here-1'}}
# Apple {Pay} the Dashband CU {Insight} {0: {'label': '{has}-1'}}
# Silicone Mobile {Wallet} {this} {0: {'label': 'then {need}-2'}}
# {Someone} a {cryptocurrency} {0: {'label': 'should {invent}-1'}}
# First West Credit {Union} the Dashband CU {Insight} {0: {'label': '{has}-1'}}
# {You} {Everything} {0: {'label': '{Need}-1'}}
# {Apple} better {luck} pushing {0: {'label': 'true sometimes {has}-1'}}
# Samsung {Pay} an early {lead} {0: {'label': 'Why could {gain}-29'}}
# a {cryptocurrency} the {currency} {0: {'label': '{distributes}-1'}}
# Barclays {Bank} own mobile payment {device} {0: {'label': 'is {developing}-1'}}
# {i} {it} {0: {'label': 'when do {lol}-1'}}

# %%
2+2
