# %%
import pandas as pd
from collections import defaultdict
import re
import numpy as np

# %run -i 'parameters'
# %run -i 'main_functions'
# %run -i 'utility_functions'


def read_df_rel():
    based_dir = '../data/'
    file_input_name = 'output_relations_child_exemption_svo.csv'
    file_input = based_dir + file_input_name    
    ff = open(file_input)
    delim=","
    df = pd.read_csv(file_input,delimiter=delim,header=0)        
    return df

df_rels = read_df_rel()
entity_versions = get_entity_versions("mothering")
#df_simp = get_simp_df(df_rels.copy(),entity_versions)
ent_medicals = entity_versions['medical prof']

for entity in entity_versions:
    print "-------------------------"
    print "       ", entity
    print "-------------------------"    
    for ent_one_version in entity_versions[entity]:
        print "\n\n**** ", ent_one_version, " ****"
        df_all_versions = defaultdict(list)
        df_one_version = df_rels[np.logical_or(df_rels['arg1'].str.contains(ent_one_version),df_rels['arg2'].str.contains(ent_one_version))]
        list_one_version = df_one_version['rel'].tolist()
        print_top_relations(list_one_version,top_num=-1) 
        #print df_med_version['rel']
# Out:
# -------------------------
#         VPDs
# -------------------------
#
#
# ****  varicella  ****
# Frequent relations:
# now {requires} :  5
# has already {had} :  2
#
#
# ****  chickenpox  ****
# Frequent relations:
#
#
# ****  flu  ****
# Frequent relations:
# does n't {have} :  5
# just {vaxing} :  3
# {getting} :  2
# {mandated} :  1
#
#
# ****  whooping cough  ****
# Frequent relations:
#
#
# ****  tetanus  ****
# Frequent relations:
#
#
# ****  pertussis  ****
# Frequent relations:
# {caused} :  1
#
#
# ****  hepatitis  ****
# Frequent relations:
#
#
# ****  polio  ****
# Frequent relations:
#
#
# ****  mumps  ****
# Frequent relations:
#
#
# ****  measles  ****
# Frequent relations:
#
#
# ****  diphtheria  ****
# Frequent relations:
# -------------------------
#         medical prof
# -------------------------
#
#
# ****  doctor  ****
# Frequent relations:
# would {find} :  16
# can {fire} :  5
# {recommends} :  5
# to {sign} :  3
# {used} :  3
# does {have} :  3
# wo n't {find} :  3
# Apparently {spent} :  2
# how {got} :  2
# ca n't {rat} out :  2
# {filled} out :  1
# can {pull} :  1
# Do n't {have} :  1
# must {state} :  1
#
#
# ****  doctors  ****
# Frequent relations:
# can {fire} :  5
#
#
# ****  pediatrician  ****
# Frequent relations:
# are {giving} out :  10
# wo n't {sign} :  6
# are having {getting} :  6
# is {giving} :  4
# has {signed} :  2
#
#
# ****  pediatricians  ****
# Frequent relations:
# are {giving} out :  10
#
#
# ****  nurse  ****
# Frequent relations:
# do n't {inform} :  4
# must {inform} :  4
# {asked} :  4
# {hit} :  3
# {knew} :  3
# {told} :  2
#
#
# ****  nurses  ****
# Frequent relations:
#
#
# ****  ped  ****
# Frequent relations:
# {switched} not now :  60
# are {giving} out :  10
# are having {getting} :  6
# wo n't {sign} :  6
# {supports} :  4
# {told} :  4
# {need} :  4
# is {giving} :  4
# {asking} :  4
# {uses} :  2
# has {signed} :  2
# 've {told} :  1
#
#
# ****  md  ****
# Frequent relations:
#
#
# ****  dr  ****
# Frequent relations:
# {have} :  22
# have {received} :  20
# has always {taken} :  16
# {accept} :  14
# {unschool} :  11
# however {need} eventually :  10
# have {attended} :  9
# can not {attend} :  8
# have {had} :  8
# must {have} :  6
# does n't {vax} :  6
# {has} :  6
# however {have} :  6
# have never {had} previously :  5
# to {exempt} :  5
# {recommends} :  5
# do n't {have} :  4
# can {exempt} :  4
# {had} :  4
# have {sent} :  4
# Now can not {deny} :  4
# {using} :  3
# MIGHT {protect} :  3
# {decides} :  3
# had already {attended} :  3
# to {have} :  3
# can legally {exempt} :  3
# {accepted} :  3
# do not {have} :  3
# will {send} :  3
# to {love} :  3
# {notarized} when not :  3
# have not {received} :  3
# will {take} :  3
# have partially {vaccinated} :  3
# {receive} :  2
# {violates} :  2
# to {attend} :  2
# {play} :  2
# {notarized} :  2
# {gave} :  2
# ca n't legally {go} back :  2
# has {enrolled} :  2
# must {meet} " :  2
# to {vaccinate} :  2
# has {received} :  2
# {enroll} anyway :  2
# does not {vaccinate} :  2
# how {suspended} :  2
# {homeschool} :  2
# can {protect} :  1
# are not {attending} :  1
# will likely {enroll} in :  1
# will {have} :  1
# {knew} :  1
# {prohibit} :  1
# have never {had} :  1
# would {have} :  1
# {have} at :  1
# can {attend} :  1
# {needing} :  1
# just {needed} :  1
# -------------------------
#         government
# -------------------------
#
#
# ****  government  ****
# Frequent relations:
# {told} :  4
#
#
# ****  cdc  ****
# Frequent relations:
#
#
# ****  federal  ****
# Frequent relations:
#
#
# ****  feds  ****
# Frequent relations:
#
#
# ****  center for disease control  ****
# Frequent relations:
#
#
# ****  officials  ****
# Frequent relations:
#
#
# ****  politician  ****
# Frequent relations:
#
#
# ****  official  ****
# Frequent relations:
# {looks} :  4
# {use} :  2
#
#
# ****  law  ****
# Frequent relations:
# would {bring} in :  11
# {requires} :  9
# actually here have {changed} :  8
# {see} :  7
# to {attend} :  6
# always {took} :  6
# must {vaccinate} :  5
# may {open} up :  4
# {mandates} :  3
# would be {breaking} :  3
# should {read} :  3
# {says} :  3
# have {followed} :  2
# ca n't {afford} :  2
# {included} :  2
# are {breaking} :  2
# {enacts} :  2
# {have} :  2
# then can not {ignore} :  2
# do n't {know} specifically :  2
# {looked} up :  1
# calmly {provides} :  1
# {stretch} :  1
# No 's {breaking} :  1
# -------------------------
#         religous inst
# -------------------------
#
#
# ****  faith  ****
# Frequent relations:
# {accept} :  12
#
#
# ****  religion  ****
# Frequent relations:
# therefore to {use} :  10
# {forbids} :  9
# ca n't {join} now :  6
# does n't {change} :  5
# {require} :  4
#
#
# ****  pastor  ****
# Frequent relations:
#
#
# ****  pastors  ****
# Frequent relations:
#
#
# ****  parish  ****
# Frequent relations:
#
#
# ****  parishes  ****
# Frequent relations:
#
#
# ****  church  ****
# Frequent relations:
# have {attended} :  2
#
#
# ****  churches  ****
# Frequent relations:
#
#
# ****  congregation  ****
# Frequent relations:
#
#
# ****  congregations  ****
# Frequent relations:
#
#
# ****  clergy  ****
# Frequent relations:
# have to {get} :  6
# -------------------------
#         vaccines
# -------------------------
#
#
# ****  vaccines  ****
# Frequent relations:
# did n't {get} :  18
# has {received} :  10
# therefore {giving} :  9
# {forbids} :  9
# should not {get} :  8
# only {requires} :  6
# {had} :  6
# to {check} off :  6
# are {opting} out :  6
# have never {had} previously :  5
# would {exempt} :  5
# would simply {sign} off :  4
# have {had} :  4
# had {gotten} :  4
# {mandates} :  3
# just has {received} :  3
# when {refused} :  3
# so {enrolled} :  3
# even have {had} :  3
# has {chosen} :  3
# {think} :  3
# have not {received} :  3
# do n't {want} :  3
# {receive} :  2
# can {refuse} :  2
# {opposes} :  2
# will {inject} :  2
# do not {need} :  2
# {gave} :  1
# do n't {have} :  1
# did n't {receive} :  1
# {received} :  1
# {carry} :  1
# has already {received} :  1
# {inject} :  1
#
#
# ****  vax  ****
# Frequent relations:
# {have} :  28
# can {attend} :  21
# {brought} up :  15
# {has} :  11
# " {need} :  10
# ca n't {have} obviously :  10
# {didnt} :  9
# was {getting} :  8
# {had} :  8
# {signed} :  7
# As {having} :  6
# does n't {need} :  6
# would have " {recieved} :  6
# have {had} :  5
# {passed} :  5
# do n't {want} :  5
# have {gotten} :  4
# can {exempt} :  4
# has {had} :  4
# already {received} :  4
# do n't {get} :  4
# then can {submit} :  4
# {listed} :  4
# then ca n't ever {get} again :  4
# may {open} up :  4
# {submitted} :  3
# {attend} :  3
# {discuss} frequently :  3
# do not {want} :  3
# {accepts} :  3
# can still {claim} :  3
# {delay} :  3
# {manage} :  3
# would otherwise {require} :  3
# never {reveal} :  2
# {fill} out :  2
# can {submit} :  2
# even {did} :  2
# just to {figure} :  2
# {enroll} :  2
# {decides} :  2
# are {requesting} :  2
# when had {received} :  2
# Also can {send} :  2
# do n't {know} deeply :  2
# When were {enrolling} :  2
# just {left} :  2
# 'd better {get} :  2
# would never be {discussing} :  2
# would {qualify} :  2
# so {had} :  1
# can always {give} later :  1
# {needing} :  1
# should not {receive} :  1
# must {have} :  1
# when {signs} :  1
# when {asked} :  1
#
#
# ****  vaccine  ****
# Frequent relations:
# did n't {get} :  18
# should not {get} :  13
# has {received} :  10
# {contracting} :  10
# therefore {giving} :  9
# {forbids} :  9
# {have} :  8
# {hits} :  8
# only {requires} :  6
# to {check} off :  6
# {had} :  6
# to {force} :  6
# {choose} :  6
# are {opting} out :  6
# have never {had} previously :  5
# does n't {change} :  5
# {has} :  5
# would {exempt} :  5
# to {give} :  5
# {wanted} :  4
# would simply {sign} off :  4
# have {had} :  4
# had {gotten} :  4
# even {wanted} :  4
# must {have} :  3
# {mandates} :  3
# when {refused} :  3
# just {vaxing} :  3
# just has {received} :  3
# did not {have} :  3
# so {enrolled} :  3
# even have {had} :  3
# has {chosen} :  3
# {think} :  3
# have not {received} :  3
# do n't {want} :  3
# {receive} :  2
# to {sign} :  2
# can {refuse} :  2
# {opposes} :  2
# {care} :  2
# will {inject} :  2
# had {risked} :  2
# do not {need} :  2
# {need} :  2
# has already {received} :  1
# {gave} :  1
# do n't {have} :  1
# did n't {receive} :  1
# {received} :  1
# {carry} :  1
# {inject} :  1
#
#
# ****  vaccination  ****
# Frequent relations:
# {has} :  9
# does n't {have} :  4
# had already {received} :  4
# must {have} :  3
# {receive} :  2
# {signed} :  2
# 're {stopping} :  2
# {want} :  2
# {have} :  2
# would not {submit} :  2
# {had} :  2
# 've been {researching} :  2
# must {meet} " :  2
# to {receive} :  1
# even {has} :  1
# {have} at :  1
# could {cause} :  1
# have never {had} :  1
#
#
# ****  vaccinations  ****
# Frequent relations:
# does n't {have} :  4
# had already {received} :  4
# must {have} :  3
# {has} :  3
# {receive} :  2
# {have} :  2
# {had} :  2
# to {receive} :  1
# {have} at :  1
# could {cause} :  1
# have never {had} :  1
#
#
# ****  shots  ****
# Frequent relations:
# did n't {have} :  18
# has {gotten} :  16
# will {need} :  6
# {require} :  4
# did n't {get} :  4
# does n't {have} :  3
# {do} :  2
# how {got} :  2
# did {receive} up :  2
# {give} :  2
# {calling} :  2
# already {has} :  1
#
#
# ****  shot  ****
# Frequent relations:
# did n't {have} :  18
# has {gotten} :  16
# does n't {have} :  8
# will {need} :  6
# {require} :  4
# did n't {get} :  4
# {wants} :  4
# will not be {updating} :  2
# how {got} :  2
# {do} :  2
# is NOT {getting} :  2
# would {keep} :  2
# did {receive} up :  2
# yes {require} :  2
# {give} :  2
# {calling} :  2
# already {has} :  1
#
#
# ****  vaxed  ****
# Frequent relations:
# can {attend} :  21
# {have} :  20
# As {having} :  6
# {passed} :  5
# do n't {get} :  4
# can {exempt} :  4
# {accepts} :  3
# {attend} :  3
# 'd better {get} :  2
# Also can {send} :  2
# {enroll} :  2
#
#
# ****  unvax  ****
# Frequent relations:
# can {attend} :  15
# {attend} :  3
# 'd better {get} :  2
# {enroll} :  2
#
#
# ****  unvaxed  ****
# Frequent relations:
# can {attend} :  15
# {attend} :  3
# 'd better {get} :  2
# {enroll} :  2
#
#
# ****  nonvaxed  ****
# Frequent relations:
#
#
# ****  vaccinate  ****
# Frequent relations:
# ca n't {refuse} :  4
# Not then can {keep} :  2
# do n't {take} :  2
# to {delay} :  2
# {get} :  2
# would {have} :  1
# to {get} :  1
#
#
# ****  vaccinated  ****
# Frequent relations:
# ca n't {refuse} :  4
# Not then can {keep} :  2
# do n't {take} :  2
# {get} :  2
# would {have} :  1
# to {get} :  1
#
#
# ****  vaxes  ****
# Frequent relations:
# " {need} :  10
# {had} :  8
# was {getting} :  8
# would have " {recieved} :  6
# {listed} :  4
# has {had} :  4
# then ca n't ever {get} again :  4
# have {gotten} :  4
# have {had} :  3
# {discuss} frequently :  3
# would otherwise {require} :  3
# do not {want} :  3
# can still {claim} :  3
# {has} :  2
# just to {figure} :  2
# {needing} :  1
#
#
# ****  vaxing  ****
# Frequent relations:
# when had {received} :  2
# When were {enrolling} :  2
# are {requesting} :  2
#
#
# ****  vaccinating  ****
# Frequent relations:
# {start} now :  6
# {recommends} :  5
#
#
# ****  substances  ****
# Frequent relations:
#
#
# ****  ingredients  ****
# Frequent relations:
# {have} :  8
# -------------------------
#         parents
# -------------------------
#
#
# ****  parents  ****
# Frequent relations:
# did n't {get} :  18
# {have} :  11
# can {tell} :  6
# then will just {give} up :  6
# do n't {vax} :  6
# just {took} :  6
# Even {told} :  5
# often {give} how :  4
# did NOT {file} :  3
# {claim} :  3
# to {claim} :  3
# when {submit} :  2
# to {vaccinate} :  2
# have {claimed} :  2
# solely did n't {belong} :  2
# to {get} :  1
# shall {object} :  1
# can {use} :  1
# can {protect} :  1
# {begin} :  1
# {sign} :  1
# {have} at :  1
#
#
# ****  parent  ****
# Frequent relations:
# did n't {get} :  18
# {have} :  11
# can {tell} :  6
# then will just {give} up :  6
# do n't {vax} :  6
# just {took} :  6
# Even {told} :  5
# often {give} how :  4
# can {submit} :  3
# then can {file} :  3
# may {claim} :  3
# did NOT {file} :  3
# {claim} :  3
# has {chosen} :  3
# to {claim} :  3
# must {sign} :  2
# {authorizes} :  2
# When {claims} :  2
# {opposes} :  2
# does not {vaccinate} :  2
# when {submit} :  2
# to {vaccinate} :  2
# can {write} :  2
# have {claimed} :  2
# must {furnish} :  2
# solely did n't {belong} :  2
# {filing} :  2
# to {get} :  1
# shall {object} :  1
# can {use} :  1
# just {submits} :  1
# can {protect} :  1
# {saw} :  1
# {begin} :  1
# {sign} :  1
# can can {submit} :  1
# {provides} :  1
# {have} at :  1
# when {signs} :  1
# {used} :  1
#
#
# ****  i  ****
# Frequent relations:
# {have} :  441
# {has} :  126
# {had} :  82
# {file} :  40
# do n't {have} :  40
# do n't {need} :  37
# {claim} :  35
# {told} :  35
# do {have} :  32
# how will {have} :  32
# {switched} not now :  30
# {vax} :  28
# can {attend} :  27
# to {attend} :  27
# {got} :  26
# {submitted} :  25
# {started} :  25
# do n't {vax} :  24
# must {have} :  24
# {use} :  23
# can {claim} :  23
# has {received} :  23
# {filed} :  22
# {get} :  21
# did n't {get} :  21
# {submit} :  21
# {need} :  20
# therefore to {use} :  20
# have {received} :  20
# have {attended} :  19
# {requires} :  18
# do not {need} :  18
# never can {get} :  18
# {used} :  18
# does not {accept} :  18
# have {had} :  17
# So technically {using} :  16
# has always {taken} :  16
# would {find} :  16
# do n't {see} :  16
# {accept} :  16
# does {have} :  15
# {gives} :  15
# n't already {has} :  15
# {brought} up :  15
# {notarized} when not :  15
# must {accept} :  15
# {sign} :  14
# {know} :  14
# should n't {have} :  14
# can {submit} :  14
# does n't {have} :  14
# can {file} :  14
# when {enroll} :  13
# {claimed} :  13
# should not {get} :  13
# {understand} :  13
# {found} :  13
# often {give} how :  12
# so {enrolled} :  12
# then will just {give} up :  12
# may be {entering} :  12
# When {enters} :  12
# then may {have} :  12
# may {use} :  12
# {gave} :  12
# {want} :  12
# are having {getting} :  12
# just {forwarded} :  12
# can not {attend} :  12
# have {read} :  11
# will be {using} :  11
# {sent} :  11
# {signed} :  11
# {needed} :  11
# would {bring} in :  11
# {unschool} :  11
# does not {need} :  11
# 'd {have} :  10
# to {get} :  10
# are {giving} out :  10
# will {file} :  10
# ca n't {have} obviously :  10
# {contracting} :  10
# {gets} :  10
# already {have} :  10
# 'll be {filing} :  10
# however {need} eventually :  10
# {conflicts} :  10
# just {submitted} :  10
# would {need} :  10
# how will {take} how how up together :  10
# {forbids} :  9
# are {claiming} :  9
# would {submit} :  9
# {accepted} :  9
# does n't {vax} :  9
# therefore {giving} :  9
# can {use} :  9
# can {enroll} :  9
# is {attending} :  9
# Fortunately does not {have} :  9
# did not {have} :  9
# {says} :  9
# will {need} :  9
# would not {constitute} :  9
# would have {died} :  9
# wo n't {accept} .. :  8
# then can {have} :  8
# have been {biting} :  8
# even will selectively {vax} :  8
# {hits} :  8
# do n't {want} :  8
# Can {have} :  8
# .It much {rattled} :  8
# must {enroll} :  8
# {wondered} :  8
# {fill} out :  8
# {replied} :  8
# might not {accept} :  8
# {claimed} .... :  8
# are falsely {taking} :  8
# well 'll just {skip} :  8
# never even {checked} :  8
# will {use} :  8
# can {do} :  8
# would {fire} :  8
# has {recommended} :  8
# {turned} :  8
# can {exempt} :  8
# when {enters} :  8
# 'm {sharing} :  8
# When {submit} :  8
# have {enrolled} :  8
# will likely not be {using} anymore :  8
# 've just {used} :  8
# was {getting} :  8
# when {submitted} :  8
# {declare} :  8
# Also do n't {need} :  8
# how can {use} :  8
# {resent} :  8
# {see} :  7
# would {do} :  7
# {did} :  7
# JUST DO N'T {SIGN} :  7
# {took} :  7
# 'm definitely not {signing} :  7
# {received} :  7
# now {have} :  7
# has {had} :  7
# 'm {putting} :  7
# just ca n't {claim} :  7
# {take} :  7
# can {get} :  7
# {accepts} :  7
# {allows} :  7
# would n't {take} :  7
# {provided} :  7
# to {have} :  7
# ca n't {have} :  7
# {required} :  7
# {fits} :  7
# can not {deny} :  7
# {passed} :  7
# {do} :  6
# {think} :  6
# just {emailed} not :  6
# {receive} :  6
# however not {claim} :  6
# when will not {cause} :  6
# {debate} :  6
# would just {sign} :  6
# ca n't {join} now :  6
# will then {lose} :  6
# currently {claim} :  6
# am {Thank} :  6
# are {enrolling} :  6
# could probably {submit} :  6
# {form} :  6
# 'll {give} :  6
# Should {pick} :  6
# to {check} off :  6
# {have} then :  6
# have {decided} :  6
# when {contain} :  6
# have always {used} :  6
# to {submit} :  6
# will not be {attending} :  6
# will {accept} :  6
# {wanted} :  6
# {deny} :  6
# to {force} :  6
# {takes} :  6
# have n't {needed} yet :  6
# again yes {have} :  6
# {start} now :  6
# to {turn} in :  6
# {guess} :  6
# As {having} :  6
# are {opting} out :  6
# {meet} :  6
# would {share} :  6
# {showed} :  6
# {give} :  6
# would have " {recieved} :  6
# How can still {use} :  6
# {needs} :  6
# would be {signing} :  6
# {require} :  6
# {bring} :  6
# only {requires} :  6
# have n't {vaxed} :  6
# requires {sign} :  6
# {respect} :  6
# why do not {have} :  6
# ca n't {use} :  6
# to is {keeping} :  6
# does n't {want} :  6
# would n't be {exempting} :  6
# {feel} better :  6
# wo n't {sign} :  6
# does n't {need} :  6
# why have {delayed} far :  6
# should really {say} :  6
# So fully {vax} :  6
# only {need} :  6
# really {want} :  6
# would only {exempt} :  6
# simply {stated} " :  6
# so 'm {guessing} :  6
# does n't {state} :  6
# would not have {vaxed} at :  6
# did n't {need} :  6
# may selectively {vaccinate} :  6
# {choose} :  6
# have {taken} :  6
# {send} :  6
# when is {sign} :  6
# {using} now :  6
# to {sign} :  6
# {exempts} :  6
# should {perform} :  6
# even will {vaccinate} :  6
# when {read} :  6
# then {needed} :  6
# however {have} :  6
# {stating} :  6
# {feel} :  6
# now {requires} :  5
# could {get} :  5
# 're {claiming} :  5
# would {have} :  5
# can {fire} :  5
# could {use} :  5
# only {allow} :  5
# {prohibit} :  5
# too will {have} :  5
# {allow} :  5
# CAN {attend} :  5
# {features} :  5
# {saved} :  5
# Can {file} :  5
# to {enroll} :  5
# has ever {had} :  5
# why {have} :  5
# would just {submit} :  5
# {bet} :  5
# must {vaccinate} :  5
# to {give} :  5
# do not {give} :  5
# {offers} :  5
# have {filed} :  5
# would {exempt} :  5
# {filled} out :  5
# Even {told} :  5
# {recieved} :  5
# are {giving} :  5
# 'd not {accept} :  5
# to {vax} :  5
# 've {filed} :  5
# {surround} :  5
# does not {have} :  5
# to {exempt} :  5
# still would n't {grant} :  5
# {attend} :  5
# does n't {change} :  5
# {play} :  5
# {left} :  5
# {put} :  5
# only {allows} :  5
# wo n't {need} :  5
# either do n't {have} :  5
# obviously {know} :  5
# are not {claiming} :  5
# should also probably not {mention} :  5
# have never {had} previously :  5
# {recommends} :  5
# did indeed {have} :  5
# 'd rather not {have} :  4
# could not {come} back :  4
# {sidestep} :  4
# have n't {filed} yet :  4
# just {filed} :  4
# where do not {allow} :  4
# can also {use} :  4
# " just {need} :  4
# has {enrolled} :  4
# is {entering} :  4
# {states} :  4
# do n't {inform} :  4
# can {refuse} :  4
# have {gotten} :  4
# can {have} :  4
# {getting} :  4
# {encompases} :  4
# {enter} :  4
# Even {filed} :  4
# would not {apply} :  4
# {vaccinated} :  4
# have never {filled} out :  4
# 've {written} :  4
# just to {claim} :  4
# do not {accept} :  4
# ca n't {do} :  4
# ca n't {answer} :  4
# {had} here :  4
# do n't {know} :  4
# then would {pull} out :  4
# had already {received} :  4
# 're {using} :  4
# do {need} :  4
# {cuz} :  4
# especially have {used} :  4
# not to {vax} :  4
# would {hurt} :  4
# {asking} :  4
# 'll {fill} out :  4
# have {cited} :  4
# when {begins} :  4
# {begins} :  4
# will {issue} :  4
# to {pick} up :  4
# Does {have} :  4
# would {count} :  4
# do {take} well :  4
# will {write} :  4
# have {found} :  4
# {figure} :  4
# just {sign} :  4
# really {have} :  4
# {write} :  4
# will be {filing} :  4
# ca n't {refuse} :  4
# were {exempting} :  4
# 'm {using} :  4
# do not {hold} :  4
# then down {filed} :  4
# {said} :  4
# will {compromise} :  4
# have {sent} :  4
# {attended} :  4
# can {find} :  4
# {denies} :  4
# eg {keep} :  4
# would {sign} :  4
# can not {enter} :  4
# {comes} up :  4
# shall {document} :  4
# not {get} :  4
# just {filling} out not now probably :  4
# must {claim} :  4
# {change} :  4
# simply will be {using} :  4
# would simply {sign} off :  4
# just {check} :  4
# can {fill} out :  4
# can {write} :  4
# are {using} :  4
# would {thrive} :  4
# may {open} up :  4
# had {filed} :  4
# {called} :  4
# out " not {vaxing} :  4
# actually {has} :  4
# 've {lived} :  4
# do just not {fill} out :  4
# could even {get} long :  4
# {have} now :  4
# even {wanted} :  4
# Now can not {deny} :  4
# {hold} :  4
# {supports} :  4
# certainly {gets} off :  4
# however do not {have} :  4
# have recently {gotten} :  4
# can religiously {exempt} :  4
# no {had} :  4
# Even 're {getting} :  4
# will {keep} :  4
# will {file} too :  4
# vaxed {get} :  4
# {make} :  4
# maybe should {rewrite} :  4
# 'd {enroll} :  4
# so {got} :  4
# {reaches} :  4
# will {deem} :  4
# is {giving} :  4
# {included} :  4
# have since {obtained} :  4
# just {have} :  4
# would {send} back :  4
# {reminds} :  4
# hopefully 'll {accept} :  4
# do n't {vaccinate} :  4
# 've never {registered} :  4
# when {request} :  4
# where are {submitting} :  4
# where can only {submit} :  4
# then {changed} again :  4
# already {received} :  4
# {looks} :  4
# {wants} :  4
# had {gotten} :  4
# unfortunately ca n't {exempt} :  3
# even {filled} out :  3
# has {claimed} :  3
# {using} :  3
# do not {have} :  3
# even have {had} :  3
# 'll {have} :  3
# {started} have :  3
# {putting} :  3
# {run} :  3
# could even {use} :  3
# do n't {file} :  3
# When {reaches} :  3
# already {has} :  3
# also {used} :  3
# Regardless never {needed} :  3
# could {have} :  3
# {happened} :  3
# to {love} :  3
# can still {claim} :  3
# {typed} out :  3
# can {sign} :  3
# will {help} :  3
# wo n't {override} :  3
# would just {write} :  3
# {insert} :  3
# to {claim} :  3
# {mandates} :  3
# will longer be {vaccinating} :  3
# would {negate} :  3
# {quotes} :  3
# do n't {need} now :  3
# was {fill} out :  3
# have not {received} :  3
# {opted} :  3
# when {got} :  3
# wo n't {find} :  3
# is {interpreting} :  3
# {simplifies} anyway :  3
# certainly can {reject} :  3
# has {chosen} :  3
# {allowed} :  3
# {find} :  3
# do n't {need} right :  3
# then can {file} :  3
# had already {attended} :  3
# should {have} :  3
# wo n't {let} :  3
# {say} :  3
# even {has} :  3
# simply {signed} :  3
# may just {have} :  3
# to {school} :  3
# can {send} :  3
# have {seen} :  3
# will {take} :  3
# {vaccinate} :  3
# am {submitting} :  3
# {did} up :  3
# am {seeking} :  3
# how {needs} :  3
# is {requesting} :  3
# only to {have} :  3
# just {vaxing} :  3
# have ever {seen} :  3
# will not {accept} :  3
# {delay} :  3
# MIGHT {protect} :  3
# {discuss} frequently :  3
# be {taking} did :  3
# then {claimed} :  3
# may {reissue} :  3
# When {came} :  3
# Usually {has} :  3
# are {submitting} :  3
# just has {received} :  3
# once {submit} can :  3
# However must {file} :  3
# do n't {think} :  3
# 've already {given} :  3
# {covers} :  3
# {Tell} :  3
# when {had} :  3
# have partially {vaccinated} :  3
# how could {receive} :  3
# are not {vaxing} :  3
# can {print} out :  3
# {flustered} :  3
# will not {alow} :  3
# even {have} .. :  3
# when {refused} :  3
# would be {breaking} :  3
# {keep} :  3
# {decides} :  3
# So do n't {need} :  3
# did NOT {file} :  3
# can legally {exempt} :  3
# when recently {submitted} :  3
# can even {exempt} :  3
# {decided} :  3
# may {claim} :  3
# 've {used} :  3
# would {tell} :  3
# ca n't {obtain} :  3
# will not {allow} :  3
# {have} unfortunately :  3
# actually {filed} :  3
# just {wrote} :  3
# {presents} :  3
# would {cast} :  2
# Just 've successfully {filed} :  2
# {denied} :  2
# could possibly {enroll} :  2
# when {submit} :  2
# will {claim} :  2
# are not even {exempting} :  2
# could n't {release} :  2
# would n't {submit} :  2
# {need} too :  2
# {recieve} :  2
# when {start} :  2
# does not {vaccinate} :  2
# already {had} :  2
# how would {acquire} :  2
# {carries} :  2
# {entered} :  2
# {have} already :  2
# do n't {need} at :  2
# do n't {hear} :  2
# could still {get} :  2
# Also can {challenge} :  2
# will {inject} :  2
# {knows} :  2
# ca n't {file} :  2
# could {hire} :  2
# {put} down :  2
# {requiring} :  2
# {opened} :  2
# still {hate} :  2
# can always {file} :  2
# should just {submit} not :  2
# could {bust} :  2
# can not {withhold} :  2
# just {turned} ago :  2
# can just {use} :  2
# {include} :  2
# 've {had} :  2
# can not {discount} :  2
# was .. {go} :  2
# can {change} afterward :  2
# has already {had} :  2
# so can {enroll} :  2
# 'd better {get} :  2
# will not be {vaccinating} :  2
# would never be {discussing} :  2
# would be {attending} :  2
# even {have} :  2
# must {sign} :  2
# yes {require} :  2
# {has} already :  2
# {noticed} :  2
# 'll {honor} :  2
# 'll {retract} :  2
# {waste} :  2
# {attends} :  2
# {challenges} :  2
# has {filed} :  2
# just {signed} :  2
# is {provide} :  2
# 're {stopping} :  2
# simply {checked} :  2
# are {filing} :  2
# will not be {initiating} :  2
# to {start} :  2
# must {meet} " :  2
# first can {exclude} :  2
# {brought} in :  2
# also do not {need} :  2
# Also can {send} :  2
# Here ca n't {get} :  2
# However 'm selectively {vaccinating} :  2
# has {signed} :  2
# when {vaccinated} :  2
# where {said} :  2
# have {claimed} :  2
# now {need} :  2
# can {get} so :  2
# could n't {use} :  2
# can {participate} in :  2
# why 'd {need} :  2
# can longer {vax} :  2
# {meets} :  2
# can still {use} :  2
# {wish} :  2
# when had {received} :  2
# just {enrolled} :  2
# never {had} :  2
# {supercedes} :  2
# {claims} :  2
# would {cross} :  2
# {pisses} off too :  2
# {enacts} :  2
# will be {putting} together :  2
# {provide} :  2
# how can probably {get} :  2
# Additionally can {submit} :  2
# {have} " :  2
# had {checked} off :  2
# Thus {claim} :  2
# how {suspended} :  2
# 've never {said} :  2
# {started} scholl :  2
# {enters} :  2
# only {accept} :  2
# so can {claim} :  2
# should not {vaccinate} :  2
# when must {submit} :  2
# did {have} :  2
# can also {get} :  2
# {informed} up :  2
# Obviously will {have} :  2
# {opposes} :  2
# when {filled} out :  2
# ca n't {get} here :  2
# {excepted} :  2
# should {include} well :  2
# when {started} :  2
# Has ever {submitted} :  2
# only {has} :  2
# will {give} :  2
# {filled} :  2
# Also can still {claim} :  2
# {mailed} back :  2
# {afforded} :  2
# {went} :  2
# Simply {puts} :  2
# 'd {bring} :  2
# never ever {take} :  2
# am {taking} :  2
# always nicely {present} :  2
# never {felt} :  2
# {filing} :  2
# do {pick} then :  2
# would {qualify} :  2
# can ever {get} :  2
# was {harming} :  2
# {violates} :  2
# Now {thought} :  2
# When {claims} :  2
# {suffers} :  2
# are {requesting} :  2
# ca n't legally {go} back :  2
# just {left} :  2
# {vaxed} COMPLETELY :  2
# how can {get} :  2
# have not {enacted} :  2
# can not {claim} :  2
# {homeschool} :  2
# do n't {need} anyway :  2
# did n't even {mention} :  2
# do n't {take} :  2
# too have {had} :  2
# is {blowing} off :  2
# had {risked} :  2
# {uses} :  2
# 'd {need} :  2
# how {got} :  2
# was {thinking} about :  2
# actually can still {claim} :  2
# ever {had} :  2
# then can not {ignore} :  2
# {taking} :  2
# {enroll} anyway :  2
# {involving} :  2
# {exclude} :  2
# would {use} :  2
# must {obtain} :  2
# does n't even {need} :  2
# will always {use} :  2
# {had} ago :  2
# should not {receive} :  2
# could really be {putting} :  2
# is not to {give} :  2
# 'll {deny} :  2
# should {write} up anyway :  2
# ca n't {pick} up :  2
# could not {get} :  2
# {have} too :  2
# are {using} just :  2
# 've been {researching} :  2
# So {have} :  2
# did n't {have} :  2
# {put} off :  2
# can not {do} :  2
# {renewed} :  2
# even {did} :  2
# to {do} :  2
# Actually just {get} :  2
# can certainly {vax} selectively :  2
# can also {exempt} :  2
# then {submitted} later :  2
# {care} :  2
# to {vaccinate} :  2
# did not even {question} :  2
# only once {starts} :  2
# must also {offer} :  2
# could {submit} :  2
# was {going} :  2
# solely did n't {belong} :  2
# also {has} :  2
# {prove} :  2
# {made} :  2
# vaguely {defines} :  2
# to {receive} :  2
# {notarized} :  2
# {starts} :  2
# {send} though :  2
# can {get} then :  2
# So do not {need} :  2
# would not {submit} :  2
# when {registered} :  2
# just {filled} out :  2
# would simply {fill} out :  2
# have up {indicating} :  2
# {submits} :  2
# up so would only {need} :  2
# {bring} up :  2
# will {accept} especially :  2
# {tells} :  2
# ca n't {keep} long :  2
# do not accidentally {mess} up :  2
# when {starts} :  2
# cant {keep} :  2
# {hope} :  2
# can not {exclude} :  2
# {authorizes} :  2
# then must {get} :  2
# actually {covers} :  2
# when {fill} out :  2
# Well {handed} in :  2
# {need} now :  2
# only {have} :  2
# Not then can {keep} :  2
# could {kick} :  2
# when {signing} :  2
# Apparently {spent} :  2
# {enroll} :  2
# once {have} :  2
# {sent} in :  2
# to {delay} :  2
# When were {enrolling} :  2
# would {affect} :  2
# must {furnish} :  2
# was {denying} :  2
# will {deliver} :  2
# must {offer} :  1
# {prevents} :  1
# {schooled} :  1
# will likely {enroll} in :  1
# {have} partially :  1
# could {attend} :  1
# does not {count} :  1
# {have} because :  1
# Do n't {have} :  1
# So must {get} :  1
# just {submits} :  1
# is when {using} :  1
# {inform} :  1
# {links} :  1
# has not {had} :  1
# will {respect} :  1
# Why would {have} :  1
# {checked} :  1
# still {needs} :  1
# Could {get} :  1
# are {getting} :  1
# are {having} :  1
# do {yank} :  1
# could {cause} :  1
# just {received} :  1
# did n't {receive} :  1
# are not {attending} :  1
# were {entering} :  1
# {jabbed} :  1
# {thank} :  1
# are {missing} :  1
# {go} :  1
# still {claim} :  1
# {obtain} :  1
# {knew} :  1
# {carry} :  1
# calmly {provides} :  1
# are {putting} :  1
# when does {enter} :  1
# re {read} :  1
# {includes} :  1
# {provides} :  1
# will simply {state} :  1
# do n't {word} right :  1
# always {took} :  1
# can not {force} :  1
# here just {signed} :  1
# would just {do} :  1
# {caused} :  1
# later {got} :  1
# {checking} :  1
# has {documented} :  1
# Even does n't {have} :  1
# must {maintain} :  1
# have {adopted} :  1
# {inject} :  1
# should {use} :  1
# {pigging} :  1
# can easily {get} :  1
# why ca n't {get} :  1
# {mandated} :  1
# would {come} up :  1
# must {know} specifically :  1
# personally would n't {want} :  1
# can {protect} :  1
# so {do} :  1
# will just {prevent} :  1
# sincerely {hold} :  1
# have not {VAXD} :  1
# can {request} :  1
# has {used} :  1
# have never {had} :  1
# to {require} :  1
# will {have} :  1
# was {using} :  1
# did NOT {have} :  1
# 've never {had} always :  1
# is {fill} out :  1
# could {send} :  1
# can never ever {take} back :  1
# {ignored} :  1
# No {attend} :  1
# how do discreetly {find} out :  1
# why {used} :  1
# {live} :  1
# {have} at :  1
# has already {received} :  1
# when {signs} :  1
# {shows} :  1
# can {forgo} :  1
# can {put} :  1
# can can {submit} :  1
# {lists} :  1
# {looked} up :  1
# {stretch} :  1
# {needing} :  1
# {use} here :  1
# quietly {offers} :  1
# will {love} more :  1
# must {state} :  1
# just {needed} :  1
# shall {object} :  1
# will be {entering} :  1
# {vaccinates} :  1
# No 's {breaking} :  1
# are {touting} :  1
#
#
# ****  we  ****
# Frequent relations:
# {have} :  30
# do {have} :  24
# {submitted} :  19
# would certainly {take} in :  16
# {file} :  9
# {didnt} :  9
# even will selectively {vax} :  8
# will likely not be {using} anymore :  8
# just {submitted} :  7
# {claimed} :  7
# will {prob} :  7
# {need} :  7
# {used} :  7
# have always {used} :  6
# currently {claim} :  6
# did not {get} :  6
# do n't {vax} :  6
# why do not {have} :  6
# even will {vaccinate} :  6
# have {registered} :  5
# {know} :  5
# are {giving} :  5
# 've {lived} :  4
# do not {want} :  4
# {cuz} :  4
# then ca n't ever {get} again :  4
# would {sign} :  4
# were {exempting} :  4
# when {submitted} :  4
# then would {pull} out :  4
# have {done} :  4
# are {claiming} :  3
# will {help} :  3
# {submit} :  3
# then {claimed} :  3
# when recently {submitted} :  3
# {lament} :  3
# can still {claim} :  3
# {made} :  2
# are {filing} :  2
# {hit} often :  2
# when {filled} out :  2
# 've {had} :  2
# {did} :  2
# will {homeschool} :  2
# {recieve} :  2
# {claim} :  2
# have never {had} :  2
# how can probably {get} :  2
# {have} too :  2
# {bring} :  2
# 'll {give} :  1
# {use} here :  1
# later {got} :  1
# {had} :  1
# so {do} :  1
# {get} :  1
# will likely {enroll} in :  1
#
#
# ****  us  ****
# Frequent relations:
# {have} :  100
# {has} :  32
# do {have} :  30
# {claim} :  18
# So technically {using} :  16
# {submitted} :  15
# {had} :  14
# can {claim} :  13
# {file} :  13
# can {submit} :  12
# {need} :  12
# {claimed} :  11
# {used} :  11
# {use} :  10
# {gets} :  10
# will {file} :  10
# would not {constitute} :  9
# wo n't {accept} .. :  8
# then can {have} :  8
# when {submitted} :  8
# even will selectively {vax} :  8
# do n't {have} :  8
# already {have} :  8
# might not {accept} :  8
# Also do n't {need} :  8
# how can {use} :  8
# Can {have} :  8
# {claimed} .... :  8
# are falsely {taking} :  8
# now {have} :  7
# {took} :  7
# just ca n't {claim} :  7
# can {use} :  7
# just {submitted} :  7
# currently {claim} :  6
# How can still {use} :  6
# {accept} :  6
# would be {signing} :  6
# {requires} :  6
# however not {claim} :  6
# {forbids} :  6
# {debate} :  6
# to {submit} :  6
# {fill} out :  6
# will be {using} :  6
# {filed} :  6
# {switched} not now :  6
# 've {filed} :  5
# can {file} :  5
# to further {harm} :  5
# {prohibit} :  5
# must {accept} :  5
# have {filed} :  5
# would {exempt} :  5
# {provided} :  5
# 'll be {filing} :  5
# did indeed {have} :  5
# have recently {gotten} :  4
# shall {document} :  4
# 've {written} :  4
# no {had} :  4
# just {filed} :  4
# must {claim} :  4
# do n't {need} :  4
# have {cited} :  4
# {accepted} :  4
# would {count} :  4
# so {got} :  4
# simply will be {using} :  4
# have since {obtained} :  4
# will be {filing} :  4
# vaxed {get} :  4
# 'm {using} :  4
# do not {hold} :  4
# does {leave} :  4
# {bring} :  4
# then down {filed} :  4
# {started} :  4
# where can only {submit} :  4
# will {compromise} :  4
# {hold} :  4
# then would {pull} out :  4
# 're {using} :  4
# can {exempt} :  3
# has {claimed} :  3
# will not {accept} :  3
# {typed} out :  3
# does {have} :  3
# could {get} :  3
# certainly can {reject} :  3
# {wanted} :  3
# ca n't {obtain} :  3
# {tell} :  3
# {allows} :  3
# then {claimed} :  3
# when recently {submitted} :  3
# {manage} :  3
# {play} :  3
# then can {file} :  3
# {needed} :  3
# may {claim} :  3
# also {used} :  3
# are {submitting} :  3
# how {needs} :  3
# have {seen} :  3
# {have} unfortunately :  3
# can {sign} :  3
# does n't {have} :  3
# can {get} :  3
# how could {receive} :  3
# am {submitting} :  3
# wo n't {override} :  3
# Also can still {claim} :  2
# simply {checked} :  2
# would {cast} :  2
# {see} :  2
# {meets} :  2
# would {submit} :  2
# {sent} in :  2
# where {said} :  2
# {using} :  2
# {care} :  2
# when {filled} out :  2
# did not even {question} :  2
# must also {offer} :  2
# will not be {initiating} :  2
# have {claimed} :  2
# {make} :  2
# can still {use} :  2
# would n't {submit} :  2
# do n't {know} deeply :  2
# would simply {fill} out :  2
# can not {claim} :  2
# 'd {need} :  2
# has {received} :  2
# {submits} :  2
# Actually just {get} :  2
# {states} :  2
# can always {file} :  2
# never {reveal} :  2
# {included} :  2
# will {accept} :  2
# would {use} :  2
# Additionally can {submit} :  2
# {notarized} :  2
# {have} " :  2
# Thus {claim} :  2
# Well {handed} in :  2
# {filing} :  2
# actually can still {claim} :  2
# will always {use} :  2
# only {accept} :  2
# so can {claim} :  2
# {excepted} :  2
# {informed} up :  2
# are {requesting} :  2
# to {delay} :  2
# Has ever {submitted} :  2
# when {enroll} :  2
# only {has} :  2
# how would {acquire} :  2
# would never be {discussing} :  2
# Obviously will {have} :  2
# has {filed} :  2
# {filled} :  2
# should {use} :  1
# {sign} :  1
# {knew} :  1
# {have} partially :  1
# calmly {provides} :  1
# has {had} :  1
# {mandated} :  1
# {stretch} :  1
# {carry} :  1
# sincerely {hold} :  1
# would {have} :  1
# why {used} :  1
# just {received} :  1
# here just {signed} :  1
# would just {do} :  1
# {caused} :  1
# will {have} :  1
# is {requesting} :  1
# later {got} :  1
# did NOT {have} :  1
# are {touting} :  1
# {checking} :  1
# will simply {state} :  1
# {go} :  1
#
#
# ****  you  ****
# Frequent relations:
# {have} :  159
# {file} :  31
# {want} :  27
# do n't {need} :  17
# 'd {have} :  16
# will not be {vaccinating} anymore :  16
# {get} :  14
# {had} :  13
# 'd {do} :  12
# though just {signed} just just :  12
# do n't {want} :  12
# then may {have} :  12
# do n't {have} :  11
# {give} :  11
# {submit} :  11
# can {file} :  11
# So have n't {turned} in :  10
# do not {need} :  10
# must {vaccinate} :  10
# " {need} :  10
# when do {need} :  9
# simply {tell} :  9
# When {submit} :  8
# have {enrolled} :  8
# just {sign} :  8
# Also do n't {need} :  8
# {talk} :  8
# can {use} :  8
# {claimed} .... :  8
# are falsely {taking} :  8
# Can {have} :  8
# well 'll just {skip} :  8
# can {exempt} :  7
# are n't {neglecting} :  7
# have just {made} :  7
# {brings} :  7
# can {request} :  7
# {take} :  7
# just ca n't {claim} :  7
# {sign} :  6
# Should {pick} :  6
# can {claim} :  6
# will longer be {vaccinating} :  6
# then {needed} :  6
# when are {facing} :  6
# may selectively {vaccinate} :  6
# however not {claim} :  6
# {have} then :  6
# {send} :  6
# when {read} :  6
# to {submit} :  6
# have to {get} :  6
# have n't {vaxed} :  6
# only {need} :  6
# can {do} :  6
# will then {lose} :  6
# again yes {have} :  6
# are {opting} out :  6
# really {want} :  6
# are {enrolling} :  6
# ca n't {join} now :  6
# to {check} off :  6
# would n't be {exempting} :  6
# never can {get} :  6
# are {applying} :  6
# could probably {submit} :  6
# when {enroll} :  6
# to {turn} in :  6
# would {submit} :  5
# obviously {know} :  5
# can {fire} :  5
# are {putting} :  5
# now {have} :  5
# to {vax} :  5
# Can {file} :  5
# 're {claiming} :  5
# do not {give} :  5
# {want} privately :  5
# wo n't {need} :  5
# are not {claiming} :  5
# 'll be {filing} :  5
# ca n't {get} :  5
# should also probably not {mention} :  5
# how did {decide} out :  5
# would {do} :  5
# do n't {find} :  5
# ca n't {rat} out :  4
# {vax} :  4
# do not {hold} :  4
# will {need} :  4
# do n't {inform} :  4
# especially have {used} :  4
# {claim} :  4
# would {need} :  4
# Simply {puts} :  4
# can religiously {exempt} :  4
# 're {using} :  4
# Even 're {getting} :  4
# would {hurt} :  4
# must {claim} :  4
# {asking} :  4
# {wanted} :  4
# {sidestep} :  4
# could {sue} :  4
# can also {use} :  4
# would simply {sign} off :  4
# {instill} :  4
# {need} :  4
# {put} :  4
# can {fill} out :  4
# {choose} :  4
# {listed} :  4
# would {have} :  4
# {suits} better :  4
# do not {choose} :  4
# Also could always {skip} :  4
# {getting} :  4
# have {sent} :  4
# {vaccinated} :  4
# 're {saying} :  4
# do {get} :  4
# do not {tell} :  4
# where can only {submit} :  4
# are {using} :  4
# do just not {fill} out :  4
# {hold} :  4
# had {gotten} :  4
# 'll {provide} :  4
# unfortunately ca n't {exempt} :  3
# {do} :  3
# {think} :  3
# {live} :  3
# {delay} :  3
# {play} :  3
# could even {use} :  3
# can {provide} :  3
# ca n't {obtain} :  3
# do not {want} :  3
# just {check} :  3
# when {got} :  3
# {tell} :  3
# can legally {exempt} :  3
# do n't {file} :  3
# even {filled} out :  3
# {did} :  3
# 'll {have} :  3
# are not {vaxing} :  3
# just will not {tell} :  3
# are {suggesting} :  3
# Regardless never {needed} :  3
# once {submit} can :  3
# However must {file} :  3
# {vaccinate} :  3
# can {sign} :  3
# will {help} :  3
# can {get} :  3
# Also can still {claim} :  2
# can absolutely {guarantee} :  2
# {put} off :  2
# 're {stopping} :  2
# can not {do} :  2
# {sent} :  2
# {has} :  2
# Just 've successfully {filed} :  2
# {open} :  2
# will {ask} :  2
# never ever {take} :  2
# also do n't {seem} :  2
# could possibly {enroll} :  2
# Here ca n't {get} :  2
# do not {have} :  2
# may {give} :  2
# when {vaccinated} :  2
# do n't {hear} :  2
# {need} too :  2
# can {get} so :  2
# so can {claim} :  2
# {write} :  2
# why 'd {need} :  2
# can {get} then :  2
# So do not {need} :  2
# can still {use} :  2
# {require} :  2
# do n't {need} at :  2
# actually can still {claim} :  2
# when {send} :  2
# {put} down :  2
# {requiring} :  2
# ca n't {pick} up :  2
# up so would only {need} :  2
# can certainly {vax} selectively :  2
# can {refuse} :  2
# {prove} :  2
# will surely {ask} :  2
# {provide} :  2
# can not {claim} :  2
# 'd {need} :  2
# {check} :  2
# just do n't {notify} :  2
# {authorizes} :  2
# will not be {updating} :  2
# can longer {vax} :  2
# Additionally can {submit} :  2
# {bet} :  2
# {need} now :  2
# so can {enroll} :  2
# 'd better {get} :  2
# will not be {vaccinating} :  2
# must {enroll} :  2
# can certainly {write} :  2
# must {supply} :  2
# {fill} out :  2
# should not {vaccinate} :  2
# {enroll} :  2
# once {have} :  2
# simply 'll {provide} :  2
# could really be {putting} :  2
# Actually just {get} :  2
# will {inject} :  2
# Also can {send} :  2
# {waste} :  2
# can {find} :  2
# So {have} :  2
# {obtain} :  1
# can always {give} later :  1
# 've {told} :  1
# Could {get} :  1
# do {advise} :  1
# are {talking} :  1
# can {put} :  1
# do n't {word} right :  1
# {like} :  1
# can never ever {take} back :  1
# can not {force} :  1
# must {know} specifically :  1
# might {get} :  1
# do {yank} :  1
# why ca n't {get} :  1
# {saw} :  1
# do {think} :  1
# could {send} :  1
# {thank} :  1
# {know} :  1
# {go} :  1
# -------------------------
#         adverse effects
# -------------------------
#
#
# ****  autism  ****
# Frequent relations:
#
#
# ****  autistic  ****
# Frequent relations:
#
#
# ****  fever  ****
# Frequent relations:
#
#
# ****  fevers  ****
# Frequent relations:
#
#
# ****  reaction  ****
# Frequent relations:
# {gets} :  10
# {has} :  6
# {had} :  4
# is {blowing} off :  2
# would {qualify} :  2
# 've {had} :  1
# has {had} :  1
# {caused} :  1
# ca n't {have} :  1
#
#
# ****  reactions  ****
# Frequent relations:
# {had} :  2
#
#
# ****  infection  ****
# Frequent relations:
#
#
# ****  infections  ****
# Frequent relations:
#
#
# ****  inflammation  ****
# Frequent relations:
#
#
# ****  inflammations  ****
# Frequent relations:
#
#
# ****  pain  ****
# Frequent relations:
#
#
# ****  pains  ****
# Frequent relations:
#
#
# ****  bleeding  ****
# Frequent relations:
#
#
# ****  bruising  ****
# Frequent relations:
#
#
# ****  diarrhea  ****
# Frequent relations:
#
#
# ****  diarrhoea  ****
# Frequent relations:
# -------------------------
#         schools
# -------------------------
#
#
# ****  teacher  ****
# Frequent relations:
# {asked} :  4
#
#
# ****  teachers  ****
# Frequent relations:
#
#
# ****  preschools  ****
# Frequent relations:
# {called} :  4
# have {attended} :  2
# however do not {have} :  2
#
#
# ****  preschool  ****
# Frequent relations:
# 've {asked} :  6
# will be {attending} :  6
# {called} :  4
# {run} :  3
# however do not {have} :  2
# {enter} :  2
# {go} there :  2
# have {attended} :  2
# {attends} :  2
#
#
# ****  school  ****
# Frequent relations:
# can {attend} :  27
# to {attend} :  23
# does not {accept} :  18
# may be {entering} :  12
# have {attended} :  11
# {have} :  10
# is {attending} :  9
# can not {attend} :  9
# will {tell} :  8
# must {accept} :  8
# can not {deny} :  7
# {attend} :  6
# 've {asked} :  6
# will not be {attending} :  6
# had already {attended} :  6
# can {request} :  6
# do not {need} :  6
# When {enters} :  6
# will be {attending} :  6
# {look} :  5
# CAN {attend} :  5
# {called} :  5
# to {enroll} :  5
# must {enroll} :  5
# does {constitute} " :  5
# must {inform} :  4
# do n't {inform} :  4
# when {enters} :  4
# can not {enter} :  4
# {asked} :  4
# is {entering} :  4
# {want} :  4
# when {begins} :  4
# do n't {have} :  4
# {reaches} :  4
# {deny} :  4
# does {start} :  4
# {attended} :  4
# So technically {using} :  4
# {knew} :  3
# has {admitted} :  3
# when {entered} :  3
# would be {breaking} :  3
# would otherwise {require} :  3
# {run} :  3
# certainly can {reject} :  3
# When {reaches} :  3
# must {have} :  3
# {freaking} :  3
# {gave} :  3
# to {have} :  3
# still {attend} :  3
# however do not {have} :  2
# {afforded} :  2
# has been {attending} there :  2
# only once {starts} :  2
# will {keep} :  2
# when {start} :  2
# {begins} :  2
# {entered} :  2
# have up {indicating} :  2
# just do n't {notify} :  2
# will {accept} especially :  2
# when {starts} :  2
# {enter} :  2
# can not {discount} :  2
# then must {get} :  2
# how {suspended} :  2
# {enters} :  2
# {told} :  2
# {starts} :  2
# does n't even {need} :  2
# is not to {give} :  2
# {accept} :  2
# must {furnish} :  2
# {attends} :  2
# {challenges} :  2
# {go} there :  2
# will {start} :  2
# did n't {bat} :  1
# to {get} :  1
# So must {get} :  1
# is when {using} :  1
# can not {force} :  1
# just {check} :  1
# No {attend} :  1
#
#
# ****  schools  ****
# Frequent relations:
# have {attended} :  11
# must {accept} :  7
# will not be {attending} :  6
# do not {need} :  6
# do n't {inform} :  4
# {deny} :  4
# can not {deny} :  4
# {called} :  4
# would be {breaking} :  3
# {accept} :  2
# will {accept} especially :  2
# {have} :  2
# {attended} :  2
# however do not {have} :  2
# is when {using} :  1
# did n't {bat} :  1
#
#
# ****  class  ****
# Frequent relations:
# do {take} well :  4
# to {attend} :  4
# can {attend} at :  3
# can not {attend} :  3
#
#
# ****  daycare  ****
# Frequent relations:
# to {attend} :  7
# will be {attending} :  6
# does {constitute} " :  5
# {enter} :  4
# do n't {need} now :  3
# be {taking} did :  3
# {started} :  2
# {enters} :  2
# to {start} :  2
#
#
# ****  daycares  ****
# Frequent relations:
#
#
# ****  classes  ****
# Frequent relations:
# can not {attend} :  3
# -------------------------
#         children
# -------------------------
#
#
# ****  child  ****
# Frequent relations:
# {has} :  27
# {have} :  27
# to {attend} :  23
# have {received} :  20
# has always {taken} :  16
# {accept} :  14
# must {have} :  13
# When {enters} :  12
# {unschool} :  11
# does not {need} :  11
# has {received} :  10
# however {need} eventually :  10
# is {attending} :  9
# have {attended} :  9
# can not {attend} :  9
# would have {died} :  9
# can {exempt} :  8
# was {getting} :  8
# must {enroll} :  8
# have {had} :  8
# {had} :  8
# {received} :  7
# 'm {putting} :  7
# can not {deny} :  7
# to {have} :  7
# does n't {vax} :  6
# would only {exempt} :  6
# {exempts} :  6
# has {had} :  6
# would have " {recieved} :  6
# would not have {vaxed} at :  6
# may selectively {vaccinate} :  6
# {get} :  6
# will not be {attending} :  6
# are {enrolling} :  6
# does n't {want} :  6
# would n't be {exempting} :  6
# does n't {need} :  6
# however {have} :  6
# when {enroll} :  6
# CAN {attend} :  5
# have never {had} previously :  5
# to {vax} :  5
# should not {get} :  5
# to {enroll} :  5
# to {exempt} :  5
# could {use} :  5
# must {vaccinate} :  5
# {recommends} :  5
# {allow} :  5
# {denies} :  4
# eg {keep} :  4
# will {need} :  4
# when {enters} :  4
# can not {enter} :  4
# would {need} :  4
# can religiously {exempt} :  4
# {receive} :  4
# to {get} :  4
# {needs} :  4
# {accepts} :  4
# 'd {enroll} :  4
# has {enrolled} :  4
# {put} :  4
# will {deem} :  4
# {reaches} :  4
# {enter} :  4
# {vaccinated} :  4
# do n't {vaccinate} :  4
# were {exempting} :  4
# 've never {registered} :  4
# must {accept} :  4
# already {received} :  4
# could even {get} long :  4
# Now can not {deny} :  4
# have {sent} :  4
# do n't {have} :  4
# unfortunately ca n't {exempt} :  3
# once {submit} can :  3
# {using} :  3
# have ever {seen} :  3
# will longer be {vaccinating} :  3
# {quotes} :  3
# MIGHT {protect} :  3
# can {send} :  3
# can {attend} :  3
# have not {received} :  3
# {decides} :  3
# {accepted} :  3
# {putting} :  3
# can legally {exempt} :  3
# When {reaches} :  3
# {notarized} when not :  3
# have partially {vaccinated} :  3
# are not {vaxing} :  3
# Usually {has} :  3
# {decided} :  3
# had already {attended} :  3
# may {claim} :  3
# even {has} :  3
# just has {received} :  3
# {happened} :  3
# to {love} :  3
# will not {allow} :  3
# will {take} :  3
# do n't {want} :  3
# {presents} :  3
# how could {receive} :  3
# did n't {have} :  2
# will not be {vaccinating} :  2
# {use} :  2
# can also {exempt} :  2
# never ever {take} :  2
# does not {vaccinate} :  2
# could possibly {enroll} :  2
# must {meet} " :  2
# first can {exclude} :  2
# to {vaccinate} :  2
# are not even {exempting} :  2
# only once {starts} :  2
# However 'm selectively {vaccinating} :  2
# when {vaccinated} :  2
# is {entering} :  2
# {homeschool} :  2
# can {participate} in :  2
# {violates} :  2
# {notarized} :  2
# {starts} :  2
# can longer {vax} :  2
# ca n't legally {go} back :  2
# was {harming} :  2
# {requires} :  2
# when had {received} :  2
# {submits} :  2
# {requiring} :  2
# Also can {send} :  2
# {claims} :  2
# would {have} :  2
# {send} :  2
# have {found} :  2
# {enters} :  2
# will {accept} especially :  2
# {play} :  2
# when {starts} :  2
# already {had} :  2
# {taking} :  2
# has already {had} :  2
# had {checked} off :  2
# {enroll} anyway :  2
# so can {enroll} :  2
# how {suspended} :  2
# would be {attending} :  2
# {wish} :  2
# {exclude} :  2
# {gave} :  2
# should not {vaccinate} :  2
# yes {require} :  2
# can not {exclude} :  2
# should not {receive} :  2
# {begins} :  2
# could really be {putting} :  2
# ca n't {do} :  2
# to {receive} :  2
# {attended} :  2
# So {have} :  2
# have never {had} :  1
# {knew} :  1
# will likely {enroll} in :  1
# already {has} :  1
# {have} because :  1
# has already {received} :  1
# {have} at :  1
# when does {enter} :  1
# personally would n't {want} :  1
# just {submits} :  1
# can {forgo} :  1
# was {using} :  1
# will just {prevent} :  1
# {lists} :  1
# Why would {have} :  1
# {needing} :  1
# can {have} :  1
# can {protect} :  1
# still {needs} :  1
# will {love} more :  1
# {prohibit} :  1
# just {needed} :  1
# will {have} :  1
# shall {object} :  1
# ca n't {have} :  1
# are not {attending} :  1
# were {entering} :  1
# could {send} :  1
#
#
# ****  kid  ****
# Frequent relations:
# {have} :  47
# {vax} :  28
# do n't {vax} :  24
# then will just {give} up :  12
# have {attended} :  10
# {gets} :  10
# can {attend} :  9
# {wondered} :  8
# have {enrolled} :  8
# have been {biting} :  8
# As {having} :  6
# {start} now :  6
# {had} :  6
# even will {vaccinate} :  6
# {takes} :  6
# have n't {vaxed} :  6
# So fully {vax} :  6
# {attend} :  5
# have {had} :  5
# {passed} :  5
# vaxed {get} :  4
# could not {come} back :  4
# have {gotten} :  4
# ca n't {refuse} :  4
# {cuz} :  4
# {sidestep} :  4
# out " not {vaxing} :  4
# {send} :  4
# not to {vax} :  4
# do n't {need} :  4
# to {attend} :  3
# {vaccinate} :  3
# do n't {need} now :  3
# wo n't {let} :  3
# just {vaxing} :  3
# only to {have} :  3
# does {have} :  3
# {covers} :  3
# does n't {have} :  3
# does n't {vax} :  3
# even have {had} :  3
# {accepts} :  3
# can even {exempt} :  3
# {send} though :  2
# {enroll} :  2
# cant {keep} :  2
# {see} :  2
# {want} :  2
# {denied} :  2
# can certainly {vax} selectively :  2
# do n't {take} :  2
# to {start} :  2
# 'd better {get} :  2
# {get} :  2
# do {pick} then :  2
# Not then can {keep} :  2
# {attended} :  2
# ca n't {keep} long :  2
# when {start} :  2
# did {have} :  1
# would {have} :  1
# {has} :  1
# did NOT {have} :  1
# {pigging} :  1
# {jabbed} :  1
# {vaccinates} :  1
# No {attend} :  1
# are {having} :  1
#
#
# ****  kids  ****
# Frequent relations:
# {have} :  47
# {vax} :  28
# do n't {vax} :  24
# then will just {give} up :  12
# have {attended} :  10
# can {attend} :  9
# ...
# When were {enrolling} :  2
# {denied} :  2
# will not be {providing} :  2
# do not {need} :  2
# do n't {take} :  2
# to {start} :  2
# {get} :  2
# will {deliver} :  2
# do {pick} then :  2
# {attended} :  2
# also {had} right :  2
# {bring} :  2
# when {start} :  2
# did NOT {have} :  1
# would {have} :  1
# {schooled} :  1
# has {used} :  1
# {vaccinates} :  1
# No {attend} :  1
# are {having} :  1
# -------------------------
#         exemptions
# -------------------------
#
#
# ****  exemption  ****
# Frequent relations:
# {have} :  239
# {has} :  73
# {file} :  40
# {claim} :  33
# do {have} :  24
# can {claim} :  23
# do n't {need} :  23
# {submitted} :  23
# {filed} :  22
# {use} :  21
# {had} :  21
# have {received} :  20
# never can {get} :  18
# {submit} :  18
# So technically {using} :  16
# {used} :  16
# n't already {has} :  15
# {need} :  14
# can {file} :  14
# do n't {have} :  14
# {claimed} :  13
# does {have} :  12
# may be {entering} :  12
# can {submit} :  12
# may {use} :  12
# just {forwarded} :  12
# has {received} :  11
# {signed} :  11
# will {file} :  10
# just {submitted} :  10
# already {have} :  10
# do not {need} :  10
# to {get} :  9
# will be {using} :  9
# are {claiming} :  9
# would {submit} :  9
# therefore {giving} :  9
# can {use} :  9
# Fortunately does not {have} :  9
# will {need} :  9
# wo n't {accept} .. :  8
# then can {have} :  8
# {sign} :  8
# Can {have} :  8
# {fill} out :  8
# {claimed} .... :  8
# will {use} :  8
# are falsely {taking} :  8
# might not {accept} :  8
# even will selectively {vax} :  8
# When {submit} :  8
# 've just {used} :  8
# when {submitted} :  8
# {want} :  8
# Also do n't {need} :  8
# how can {use} :  8
# must {accept} :  8
# now {have} :  7
# {took} :  7
# just ca n't {claim} :  7
# would n't {take} :  7
# {provided} :  7
# does n't {have} :  7
# {required} :  7
# {fits} :  7
# {debate} :  6
# would just {sign} :  6
# have always {used} :  6
# will then {lose} :  6
# could probably {submit} :  6
# Should {pick} :  6
# {know} :  6
# to {submit} :  6
# will {accept} :  6
# again yes {have} :  6
# have n't {needed} yet :  6
# When {enters} :  6
# ca n't {have} :  6
# {switched} not now :  6
# to {turn} in :  6
# when will not {cause} :  6
# currently {claim} :  6
# How can still {use} :  6
# would be {signing} :  6
# did not {have} :  6
# ca n't {use} :  6
# wo n't {sign} :  6
# {exempts} :  6
# would {need} :  6
# did n't {need} :  6
# however not {claim} :  6
# when is {sign} :  6
# to {sign} :  6
# only {need} :  6
# really {want} :  6
# then {needed} :  6
# {see} :  5
# could {get} :  5
# 're {claiming} :  5
# wo n't {need} :  5
# too will {have} :  5
# Can {file} :  5
# 'll be {filing} :  5
# would just {submit} :  5
# {offers} :  5
# have {filed} :  5
# would {exempt} :  5
# {filled} out :  5
# {give} :  5
# 'd not {accept} :  5
# 've {filed} :  5
# still would n't {grant} :  5
# only {allows} :  5
# either do n't {have} :  5
# {needed} :  5
# are not {claiming} :  5
# should also probably not {mention} :  5
# only {allow} :  5
# 're {using} :  4
# have n't {filed} yet :  4
# just {filed} :  4
# can also {use} :  4
# {getting} :  4
# Even {filed} :  4
# where do not {allow} :  4
# have never {filled} out :  4
# 've {written} :  4
# {had} here :  4
# must {claim} :  4
# do {need} :  4
# then would {pull} out :  4
# would not {apply} :  4
# especially have {used} :  4
# {accepted} :  4
# would {hurt} :  4
# 'll {fill} out :  4
# have {cited} :  4
# would {count} :  4
# will be {filing} :  4
# 'm {using} :  4
# {bring} :  4
# would {send} back :  4
# can {get} :  4
# {wants} :  4
# just {sign} :  4
# would {sign} :  4
# shall {document} :  4
# hopefully 'll {accept} :  4
# just {filling} out not now probably :  4
# {vax} :  4
# simply will be {using} :  4
# may {open} up :  4
# had {filed} :  4
# actually {has} :  4
# 've {lived} :  4
# then down {filed} :  4
# {have} now :  4
# {supports} :  4
# have recently {gotten} :  4
# no {had} :  4
# Even 're {getting} :  4
# will {file} too :  4
# vaxed {get} :  4
# maybe should {rewrite} :  4
# so {got} :  4
# have since {obtained} :  4
# just {have} :  4
# when {request} :  4
# where are {submitting} :  4
# where can only {submit} :  4
# {started} :  4
# is {giving} :  4
# {using} :  3
# even {filled} out :  3
# has {claimed} :  3
# do not {have} :  3
# could even {use} :  3
# do n't {file} :  3
# also {used} :  3
# Regardless never {needed} :  3
# can still {claim} :  3
# can {sign} :  3
# {insert} :  3
# to {claim} :  3
# would {negate} :  3
# {quotes} :  3
# when {got} :  3
# {allowed} :  3
# do n't {need} right :  3
# then can {file} :  3
# should {have} :  3
# {simplifies} anyway :  3
# simply {signed} :  3
# have {seen} :  3
# am {submitting} :  3
# am {seeking} :  3
# was {fill} out :  3
# is {requesting} :  3
# will not {accept} :  3
# 'll {have} :  3
# just {check} :  3
# {allows} :  3
# {notarized} when not :  3
# does not {have} :  3
# Usually {has} :  3
# are {submitting} :  3
# However must {file} :  3
# could {have} :  3
# 've already {given} :  3
# {covers} :  3
# when {had} :  3
# how could {receive} :  3
# did n't {get} :  3
# even {have} .. :  3
# ca n't {obtain} :  3
# So do n't {need} :  3
# did NOT {file} :  3
# when recently {submitted} :  3
# may {claim} :  3
# 've {used} :  3
# how {needs} :  3
# {have} unfortunately :  3
# actually {filed} :  3
# {presents} :  3
# Just 've successfully {filed} :  2
# when {submit} :  2
# will {claim} :  2
# {mailed} back :  2
# {have} already :  2
# do n't {need} at :  2
# ca n't {file} :  2
# {states} :  2
# can always {file} :  2
# already {has} :  2
# {prove} :  2
# can not {withhold} :  2
# actually can still {claim} :  2
# {has} already :  2
# {noticed} :  2
# 'll {honor} :  2
# 'll {retract} :  2
# {challenges} :  2
# is {provide} :  2
# simply {checked} :  2
# When {claims} :  2
# are {filing} :  2
# {brought} in :  2
# also do not {need} :  2
# Here ca n't {get} :  2
# {renewed} :  2
# has {signed} :  2
# where {said} :  2
# have {claimed} :  2
# now {need} :  2
# can {get} so :  2
# could n't {use} :  2
# can longer {vax} :  2
# {meets} :  2
# can still {use} :  2
# Also can {challenge} :  2
# {claims} :  2
# {pisses} off too :  2
# {provide} :  2
# how can probably {get} :  2
# Additionally can {submit} :  2
# {have} " :  2
# Thus {claim} :  2
# only {accept} :  2
# so can {claim} :  2
# when must {submit} :  2
# can also {get} :  2
# when {filled} out :  2
# has {filed} :  2
# ca n't {get} here :  2
# {excepted} :  2
# Has ever {submitted} :  2
# will {give} :  2
# {filled} :  2
# Also can still {claim} :  2
# Simply {puts} :  2
# am {taking} :  2
# always nicely {present} :  2
# {showed} :  2
# just {signed} :  2
# {needs} :  2
# are {requesting} :  2
# {vaxed} COMPLETELY :  2
# how can {get} :  2
# {require} :  2
# can {fill} out :  2
# can not {claim} :  2
# can {write} :  2
# do n't {need} anyway :  2
# too have {had} :  2
# must {have} :  2
# 'd {need} :  2
# can just {use} :  2
# then can not {ignore} :  2
# would {use} :  2
# must {obtain} :  2
# does n't even {need} :  2
# will always {use} :  2
# {take} :  2
# 'll {deny} :  2
# should {write} up anyway :  2
# ca n't {pick} up :  2
# how would {acquire} :  2
# {have} too :  2
# however do not {have} :  2
# {sent} in :  2
# then {submitted} later :  2
# {care} :  2
# did not even {question} :  2
# must also {offer} :  2
# could {submit} :  2
# solely did n't {belong} :  2
# will {keep} :  2
# {notarized} :  2
# {make} :  2
# can {get} then :  2
# So do not {need} :  2
# would n't {submit} :  2
# just {filled} out :  2
# {submits} :  2
# up so would only {need} :  2
# should just {submit} not :  2
# {included} :  2
# do not accidentally {mess} up :  2
# why 'd {need} :  2
# then must {get} :  2
# only {has} :  2
# when {fill} out :  2
# {need} now :  2
# only {have} :  2
# {filing} :  2
# when {signing} :  2
# once {have} :  2
# Actually just {get} :  2
# would simply {fill} out :  2
# would {affect} :  2
# was {denying} :  2
# Obviously will {have} :  2
# must {offer} :  1
# {have} partially :  1
# {have} because :  1
# So must {get} :  1
# just {submits} :  1
# {requires} :  1
# {got} :  1
# why {used} :  1
# just {received} :  1
# will {respect} :  1
# Why would {have} :  1
# can {have} :  1
# Could {get} :  1
# are {getting} :  1
# do {yank} :  1
# {go} :  1
# still {claim} :  1
# to {attend} :  1
# {obtain} :  1
# calmly {provides} :  1
# re {read} :  1
# will simply {state} :  1
# always {took} :  1
# {wanted} :  1
# here just {signed} :  1
# would just {do} :  1
# did {have} :  1
# later {got} :  1
# {checking} :  1
# has {documented} :  1
# must {maintain} :  1
# why ca n't {get} :  1
# {mandated} :  1
# would {come} up :  1
# {stretch} :  1
# can easily {get} :  1
# {get} :  1
# can {request} :  1
# {says} :  1
# will {have} :  1
# was {using} :  1
# did NOT {have} :  1
# is {fill} out :  1
# {ignored} :  1
# {live} :  1
# when {signs} :  1
# can can {submit} :  1
# {looked} up :  1
# {use} here :  1
#
#
# ****  exempt  ****
# Frequent relations:
# {have} :  239
# {has} :  73
# {file} :  40
# {claim} :  33
# do {have} :  24
# can {claim} :  23
# do n't {need} :  23
# {submitted} :  23
# {filed} :  22
# {use} :  21
# {had} :  21
# have {received} :  20
# never can {get} :  18
# {submit} :  18
# So technically {using} :  16
# {used} :  16
# n't already {has} :  15
# {need} :  14
# can {file} :  14
# do n't {have} :  14
# {claimed} :  13
# does {have} :  12
# may be {entering} :  12
# can {submit} :  12
# may {use} :  12
# just {forwarded} :  12
# has {received} :  11
# {signed} :  11
# will {file} :  10
# just {submitted} :  10
# already {have} :  10
# do not {need} :  10
# to {get} :  9
# will be {using} :  9
# are {claiming} :  9
# would {submit} :  9
# therefore {giving} :  9
# can {use} :  9
# Fortunately does not {have} :  9
# will {need} :  9
# wo n't {accept} .. :  8
# then can {have} :  8
# {sign} :  8
# Can {have} :  8
# {fill} out :  8
# {claimed} .... :  8
# will {use} :  8
# are falsely {taking} :  8
# might not {accept} :  8
# even will selectively {vax} :  8
# When {submit} :  8
# 've just {used} :  8
# when {submitted} :  8
# {want} :  8
# Also do n't {need} :  8
# how can {use} :  8
# must {accept} :  8
# now {have} :  7
# {took} :  7
# just ca n't {claim} :  7
# would n't {take} :  7
# {provided} :  7
# does n't {have} :  7
# {required} :  7
# {fits} :  7
# {debate} :  6
# would just {sign} :  6
# have always {used} :  6
# will then {lose} :  6
# could probably {submit} :  6
# Should {pick} :  6
# {know} :  6
# to {submit} :  6
# will {accept} :  6
# again yes {have} :  6
# though just {signed} just just :  6
# have n't {needed} yet :  6
# When {enters} :  6
# ca n't {have} :  6
# {switched} not now :  6
# to {turn} in :  6
# when will not {cause} :  6
# currently {claim} :  6
# How can still {use} :  6
# would be {signing} :  6
# did not {have} :  6
# ca n't {use} :  6
# wo n't {sign} :  6
# {exempts} :  6
# would {need} :  6
# did n't {need} :  6
# however not {claim} :  6
# when is {sign} :  6
# to {sign} :  6
# only {need} :  6
# really {want} :  6
# then {needed} :  6
# {see} :  5
# could {get} :  5
# 're {claiming} :  5
# wo n't {need} :  5
# too will {have} :  5
# Can {file} :  5
# 'll be {filing} :  5
# would just {submit} :  5
# {offers} :  5
# have {filed} :  5
# would {exempt} :  5
# {filled} out :  5
# {give} :  5
# 'd not {accept} :  5
# 've {filed} :  5
# still would n't {grant} :  5
# only {allows} :  5
# either do n't {have} :  5
# {needed} :  5
# are not {claiming} :  5
# should also probably not {mention} :  5
# only {allow} :  5
# 're {using} :  4
# have n't {filed} yet :  4
# just {filed} :  4
# can also {use} :  4
# {getting} :  4
# Even {filed} :  4
# where do not {allow} :  4
# have never {filled} out :  4
# 've {written} :  4
# {had} here :  4
# must {claim} :  4
# do {need} :  4
# then would {pull} out :  4
# would not {apply} :  4
# especially have {used} :  4
# {accepted} :  4
# would {hurt} :  4
# 'll {fill} out :  4
# have {cited} :  4
# would {count} :  4
# will be {filing} :  4
# 'm {using} :  4
# {bring} :  4
# would {send} back :  4
# can {get} :  4
# {wants} :  4
# just {sign} :  4
# would {sign} :  4
# shall {document} :  4
# hopefully 'll {accept} :  4
# just {filling} out not now probably :  4
# {vax} :  4
# simply will be {using} :  4
# may {open} up :  4
# had {filed} :  4
# actually {has} :  4
# 've {lived} :  4
# then down {filed} :  4
# {have} now :  4
# {supports} :  4
# have recently {gotten} :  4
# no {had} :  4
# Even 're {getting} :  4
# will {file} too :  4
# vaxed {get} :  4
# maybe should {rewrite} :  4
# so {got} :  4
# have since {obtained} :  4
# just {have} :  4
# when {request} :  4
# where are {submitting} :  4
# where can only {submit} :  4
# {started} :  4
# is {giving} :  4
# {using} :  3
# even {filled} out :  3
# has {claimed} :  3
# do not {have} :  3
# could even {use} :  3
# do n't {file} :  3
# also {used} :  3
# Regardless never {needed} :  3
# can still {claim} :  3
# can {sign} :  3
# {insert} :  3
# to {claim} :  3
# would {negate} :  3
# {quotes} :  3
# when {got} :  3
# {allowed} :  3
# do n't {need} right :  3
# then can {file} :  3
# should {have} :  3
# {simplifies} anyway :  3
# simply {signed} :  3
# have {seen} :  3
# am {submitting} :  3
# am {seeking} :  3
# was {fill} out :  3
# is {requesting} :  3
# will not {accept} :  3
# 'll {have} :  3
# just {check} :  3
# {allows} :  3
# {notarized} when not :  3
# does not {have} :  3
# Usually {has} :  3
# are {submitting} :  3
# However must {file} :  3
# could {have} :  3
# 've already {given} :  3
# {covers} :  3
# when {had} :  3
# how could {receive} :  3
# did n't {get} :  3
# even {have} .. :  3
# ca n't {obtain} :  3
# So do n't {need} :  3
# did NOT {file} :  3
# when recently {submitted} :  3
# may {claim} :  3
# 've {used} :  3
# how {needs} :  3
# {have} unfortunately :  3
# actually {filed} :  3
# {presents} :  3
# Just 've successfully {filed} :  2
# when {submit} :  2
# will {claim} :  2
# {mailed} back :  2
# {have} already :  2
# do n't {need} at :  2
# ca n't {file} :  2
# {requiring} :  2
# {states} :  2
# can always {file} :  2
# already {has} :  2
# {prove} :  2
# can not {withhold} :  2
# actually can still {claim} :  2
# {has} already :  2
# {noticed} :  2
# 'll {honor} :  2
# 'll {retract} :  2
# {challenges} :  2
# is {provide} :  2
# simply {checked} :  2
# When {claims} :  2
# are {filing} :  2
# {brought} in :  2
# also do not {need} :  2
# Here ca n't {get} :  2
# {renewed} :  2
# has {signed} :  2
# where {said} :  2
# have {claimed} :  2
# now {need} :  2
# can {get} so :  2
# could n't {use} :  2
# can longer {vax} :  2
# {meets} :  2
# can still {use} :  2
# Also can {challenge} :  2
# {claims} :  2
# {pisses} off too :  2
# {provide} :  2
# how can probably {get} :  2
# Additionally can {submit} :  2
# {have} " :  2
# Thus {claim} :  2
# only {accept} :  2
# so can {claim} :  2
# when must {submit} :  2
# can also {get} :  2
# when {filled} out :  2
# has {filed} :  2
# ca n't {get} here :  2
# {excepted} :  2
# Has ever {submitted} :  2
# will {give} :  2
# {filled} :  2
# Also can still {claim} :  2
# Simply {puts} :  2
# am {taking} :  2
# always nicely {present} :  2
# {showed} :  2
# just {signed} :  2
# {needs} :  2
# are {requesting} :  2
# {vaxed} COMPLETELY :  2
# how can {get} :  2
# {require} :  2
# can {fill} out :  2
# can not {claim} :  2
# can {write} :  2
# do n't {need} anyway :  2
# too have {had} :  2
# must {have} :  2
# 'd {need} :  2
# can just {use} :  2
# then can not {ignore} :  2
# would {use} :  2
# must {obtain} :  2
# does n't even {need} :  2
# will always {use} :  2
# {take} :  2
# 'll {deny} :  2
# should {write} up anyway :  2
# ca n't {pick} up :  2
# how would {acquire} :  2
# {have} too :  2
# however do not {have} :  2
# {sent} in :  2
# then {submitted} later :  2
# {care} :  2
# did not even {question} :  2
# must also {offer} :  2
# could {submit} :  2
# solely did n't {belong} :  2
# will {keep} :  2
# {notarized} :  2
# {make} :  2
# can {get} then :  2
# So do not {need} :  2
# would n't {submit} :  2
# just {filled} out :  2
# {submits} :  2
# up so would only {need} :  2
# should just {submit} not :  2
# {included} :  2
# do not accidentally {mess} up :  2
# why 'd {need} :  2
# then must {get} :  2
# only {has} :  2
# when {fill} out :  2
# {need} now :  2
# only {have} :  2
# {filing} :  2
# when {signing} :  2
# once {have} :  2
# Actually just {get} :  2
# would simply {fill} out :  2
# would {affect} :  2
# was {denying} :  2
# Obviously will {have} :  2
# must {offer} :  1
# {have} partially :  1
# {have} because :  1
# So must {get} :  1
# just {submits} :  1
# {requires} :  1
# {got} :  1
# why {used} :  1
# just {received} :  1
# will {respect} :  1
# Why would {have} :  1
# can {have} :  1
# Could {get} :  1
# are {getting} :  1
# do {yank} :  1
# {go} :  1
# still {claim} :  1
# to {attend} :  1
# {obtain} :  1
# calmly {provides} :  1
# re {read} :  1
# will simply {state} :  1
# always {took} :  1
# {wanted} :  1
# here just {signed} :  1
# would just {do} :  1
# did {have} :  1
# later {got} :  1
# {checking} :  1
# has {documented} :  1
# must {maintain} :  1
# why ca n't {get} :  1
# {mandated} :  1
# would {come} up :  1
# {stretch} :  1
# can easily {get} :  1
# {get} :  1
# can {request} :  1
# {says} :  1
# will {have} :  1
# was {using} :  1
# did NOT {have} :  1
# is {fill} out :  1
# {ignored} :  1
# {live} :  1
# when {signs} :  1
# can can {submit} :  1
# {looked} up :  1
# {use} here :  1

# %%
ent_one_version = "vaccines"
df_tmp = df_rels[np.logical_or(df_rels['arg1'].str.contains(ent_one_version),df_rels['arg2'].str.contains(ent_one_version))]
df_tmp
# Out:
#       Unnamed: 0                                      original_text  \
# 2              2  Even if the Church told all Catholic parents n...
# 133          133  Even if the Church told all Catholic parents n...
# 171          171  Your best bet , with partially vaccinated chil...
# 356          356  Even if the Church told all Catholic parents n...
# 361          361  I have 3 children , and all have had the minim...
# 487          487  In Canada only Ontario requires vaccines and i...
# 492          492  So if a dr refuses to put in writting that our...
# 570          570  So if a dr refuses to put in writting that our...
# 702          702  as far as i know , there is no law that mandat...
# 823          823  When my 3rd child was 4 , I decided no more va...
# 913          913  When my 3rd child was 4 , I decided no more va...
# 941          941  Just go in and tell her point blank that you '...
# 1040        1040  I would try to file an ethical exemption based...
# 1042        1042  I would try to file an ethical exemption based...
# 1079        1079  Just go in and tell her point blank that you '...
# 1163        1163  I would try to file an ethical exemption based...
# 1213        1213  I would be dishonest signing the religious exe...
# 1239        1239  The ped we used to see agreed that our daughte...
# 1249        1249  Â  I would imagine , in the case of selective ...
# 1277        1277  In any case , you can sign the religious exemp...
# 1294        1294  When the child enters school they have a very ...
# 1324        1324  So if a dr refuses to put in writting that our...
# 1365        1365  I would be dishonest signing the religious exe...
# 1373        1373  The ped we used to see agreed that our daughte...
# 1381        1381  Â  I would imagine , in the case of selective ...
# 1398        1398  In any case , you can sign the religious exemp...
# 1413        1413  When the child enters school they have a very ...
# 1448        1448  So if a dr refuses to put in writting that our...
# 1466        1466  I am not sure on that one but most people who ...
# 1468        1468  I am not sure on that one but most people who ...
# ...          ...                                                ...
# 5637        5637  Â  I would imagine , in the case of selective ...
# 5692        5692  When the child enters school they have a very ...
# 5702        5702  She can just use an exemption as thought the c...
# 5731        5731  ; q = 242070 Keep in mind that if there are an...
# 5745        5745  Even if the Church told all Catholic parents n...
# 5807        5807  Just go in and tell her point blank that you '...
# 5826        5826  However , if you find that in your state you m...
# 5844        5844  So , just because your child has received a fe...
# 5874        5874  I would be dishonest signing the religious exe...
# 5929        5929  The ped we used to see agreed that our daughte...
# 5945        5945  I 'm worried about the same thing . lord peopl...
# 5946        5946  I 'm worried about the same thing . lord peopl...
# 6036        6036  The only way parents can protect their childre...
# 6178        6178  In Canada only Ontario requires vaccines and i...
# 6227        6227  as far as i know , there is no law that mandat...
# 6228        6228  So if a dr refuses to put in writting that our...
# 6229        6229  So if a dr refuses to put in writting that our...
# 6230        6230  So if a dr refuses to put in writting that our...
# 6347        6347  Just go in and tell her point blank that you '...
# 6355        6355  However , if you find that in your state you m...
# 6375        6375  I would be dishonest signing the religious exe...
# 6399        6399  The ped we used to see agreed that our daughte...
# 6411        6411  I 'm worried about the same thing . lord peopl...
# 6412        6412  I 'm worried about the same thing . lord peopl...
# 6547        6547  In Canada only Ontario requires vaccines and i...
# 6567        6567  So if a dr refuses to put in writting that our...
# 6568        6568  So if a dr refuses to put in writting that our...
# 6657        6657  as far as i know , there is no law that mandat...
# 6664        6664  The great thing about the exemption here is th...
# 6687        6687  The great thing about the exemption here is th...
#
#                                                sentence  \
# 2     Even if the Church told all Catholic parents n...
# 133   Even if the Church told all Catholic parents n...
# 171   Your best bet , with partially vaccinated chil...
# 356   Even if the Church told all Catholic parents n...
# 361   I have 3 children , and all have had the minim...
# 487   In Canada only Ontario requires vaccines and i...
# 492   So if a dr refuses to put in writting that our...
# 570   So if a dr refuses to put in writting that our...
# 702   as far as i know , there is no law that mandat...
# 823   When my 3rd child was 4 , I decided no more va...
# 913   When my 3rd child was 4 , I decided no more va...
# 941   Just go in and tell her point blank that you '...
# 1040  I would try to file an ethical exemption based...
# 1042  I would try to file an ethical exemption based...
# 1079  Just go in and tell her point blank that you '...
# 1163  I would try to file an ethical exemption based...
# 1213  I would be dishonest signing the religious exe...
# 1239  The ped we used to see agreed that our daughte...
# 1249  Â  I would imagine , in the case of selective ...
# 1277  In any case , you can sign the religious exemp...
# 1294  When the child enters school they have a very ...
# 1324  So if a dr refuses to put in writting that our...
# 1365  I would be dishonest signing the religious exe...
# 1373  The ped we used to see agreed that our daughte...
# 1381  Â  I would imagine , in the case of selective ...
# 1398  In any case , you can sign the religious exemp...
# 1413  When the child enters school they have a very ...
# 1448  So if a dr refuses to put in writting that our...
# 1466  I am not sure on that one but most people who ...
# 1468  I am not sure on that one but most people who ...
# ...                                                 ...
# 5637  Â  I would imagine , in the case of selective ...
# 5692  When the child enters school they have a very ...
# 5702  She can just use an exemption as thought the c...
# 5731  ; q = 242070 Keep in mind that if there are an...
# 5745  Even if the Church told all Catholic parents n...
# 5807  Just go in and tell her point blank that you '...
# 5826  However , if you find that in your state you m...
# 5844  So , just because your child has received a fe...
# 5874  I would be dishonest signing the religious exe...
# 5929  The ped we used to see agreed that our daughte...
# 5945  lord people need to be educated I was just tal...
# 5946  lord people need to be educated I was just tal...
# 6036  The only way parents can protect their childre...
# 6178  In Canada only Ontario requires vaccines and i...
# 6227  as far as i know , there is no law that mandat...
# 6228  So if a dr refuses to put in writting that our...
# 6229  So if a dr refuses to put in writting that our...
# 6230  So if a dr refuses to put in writting that our...
# 6347  Just go in and tell her point blank that you '...
# 6355  However , if you find that in your state you m...
# 6375  I would be dishonest signing the religious exe...
# 6399  The ped we used to see agreed that our daughte...
# 6411  lord people need to be educated I was just tal...
# 6412  lord people need to be educated I was just tal...
# 6547  In Canada only Ontario requires vaccines and i...
# 6567  So if a dr refuses to put in writting that our...
# 6568  So if a dr refuses to put in writting that our...
# 6657  as far as i know , there is no law that mandat...
# 6664  The great thing about the exemption here is th...
# 6687  The great thing about the exemption here is th...
#
#                         arg1                          rel  \
# 2     a religous {exemption}               would {exempt}
# 133   a religous {exemption}               would {exempt}
# 171              the {child}                   {received}
# 356   a religous {exemption}               would {exempt}
# 361                    {all}                   have {had}
# 487                {Ontario}              only {requires}
# 492         these {vaccines}           therefore {giving}
# 570         these {vaccines}           therefore {giving}
# 702                 no {law}                   {mandates}
# 823       no more {vaccines}                so {enrolled}
# 913       no more {vaccines}                so {enrolled}
# 941               {children}  have never {had} previously
# 1040              {religion}                    {forbids}
# 1042              {religion}                    {forbids}
# 1079              {children}  have never {had} previously
# 1163              {religion}                    {forbids}
# 1213            a {religion}                    {forbids}
# 1239              {daughter}             should not {get}
# 1249                   {you}      would simply {sign} off
# 1277                  {kids}              even have {had}
# 1294                   {you}             are {opting} out
# 1324        these {vaccines}           therefore {giving}
# 1365            a {religion}                    {forbids}
# 1373              {daughter}             should not {get}
# 1381                   {you}      would simply {sign} off
# 1398                  {kids}              even have {had}
# 1413                   {you}             are {opting} out
# 1448        these {vaccines}           therefore {giving}
# 1466           most {people}                     {inject}
# 1468                  {they}                       {gave}
# ...                      ...                          ...
# 5637                   {you}      would simply {sign} off
# 5692                   {you}             are {opting} out
# 5702             the {child}                        {had}
# 5731                   {you}                do n't {want}
# 5745  a religous {exemption}               would {exempt}
# 5807              {children}  have never {had} previously
# 5826                 {child}               has {received}
# 5844                 {child}          just has {received}
# 5874            a {religion}                    {forbids}
# 5929              {daughter}             should not {get}
# 5945               {parents}                did n't {get}
# 5946               {parents}                did n't {get}
# 6036              {vaccines}                      {carry}
# 6178               {Ontario}              only {requires}
# 6227                no {law}                   {mandates}
# 6228        these {vaccines}           therefore {giving}
# 6229        these {vaccines}           therefore {giving}
# 6230        these {vaccines}           therefore {giving}
# 6347              {children}  have never {had} previously
# 6355                 {child}               has {received}
# 6375            a {religion}                    {forbids}
# 6399              {daughter}             should not {get}
# 6411               {parents}                did n't {get}
# 6412               {parents}                did n't {get}
# 6547               {Ontario}              only {requires}
# 6567        these {vaccines}           therefore {giving}
# 6568        these {vaccines}           therefore {giving}
# 6657                no {law}                   {mandates}
# 6664                   {you}               to {check} off
# 6687                   {you}               to {check} off
#
#                                  arg2 type              pattern  \
# 2                      all {vaccines}  SVO  (nsubj, verb, dobj)
# 133                    all {vaccines}  SVO  (nsubj, verb, dobj)
# 171                the few {vaccines}  SVO  (nsubj, verb, dobj)
# 356                    all {vaccines}  SVO  (nsubj, verb, dobj)
# 361   the minimum {vaccines} required  SVO  (nsubj, verb, dobj)
# 487                        {vaccines}  SVO  (nsubj, verb, dobj)
# 492             a medical {exemption}  SVO  (nsubj, verb, dobj)
# 570             a medical {exemption}  SVO  (nsubj, verb, dobj)
# 702                        {vaccines}  SVO  (nsubj, verb, dobj)
# 823                             {him}  SVO  (nsubj, verb, dobj)
# 913                             {him}  SVO  (nsubj, verb, dobj)
# 941                    any {vaccines}  SVO  (nsubj, verb, dobj)
# 1040                       {vaccines}  SVO  (nsubj, verb, dobj)
# 1042                       {vaccines}  SVO  (nsubj, verb, dobj)
# 1079                   any {vaccines}  SVO  (nsubj, verb, dobj)
# 1163                       {vaccines}  SVO  (nsubj, verb, dobj)
# 1213               the {use} vaccines  SVO  (nsubj, verb, dobj)
# 1239         the scheduled {vaccines}  SVO  (nsubj, verb, dobj)
# 1249                 those {vaccines}  SVO  (nsubj, verb, dobj)
# 1277                       {vaccines}  SVO  (nsubj, verb, dobj)
# 1294                       {vaccines}  SVO  (nsubj, verb, dobj)
# 1324            a medical {exemption}  SVO  (nsubj, verb, dobj)
# 1365               the {use} vaccines  SVO  (nsubj, verb, dobj)
# 1373         the scheduled {vaccines}  SVO  (nsubj, verb, dobj)
# 1381                 those {vaccines}  SVO  (nsubj, verb, dobj)
# 1398                       {vaccines}  SVO  (nsubj, verb, dobj)
# 1413                       {vaccines}  SVO  (nsubj, verb, dobj)
# 1448            a medical {exemption}  SVO  (nsubj, verb, dobj)
# 1466                  some {vaccines}  SVO  (nsubj, verb, dobj)
# 1468                   the {vaccines}  SVO  (nsubj, verb, dobj)
# ...                               ...  ...                  ...
# 5637                 those {vaccines}  SVO  (nsubj, verb, dobj)
# 5692                       {vaccines}  SVO  (nsubj, verb, dobj)
# 5702                    no {vaccines}  SVO  (nsubj, verb, dobj)
# 5731             any vaccines {doses}  SVO  (nsubj, verb, dobj)
# 5745                   all {vaccines}  SVO  (nsubj, verb, dobj)
# 5807                   any {vaccines}  SVO  (nsubj, verb, dobj)
# 5826                  some {vaccines}  SVO  (nsubj, verb, dobj)
# 5844                 a few {vaccines}  SVO  (nsubj, verb, dobj)
# 5874               the {use} vaccines  SVO  (nsubj, verb, dobj)
# 5929         the scheduled {vaccines}  SVO  (nsubj, verb, dobj)
# 5945                       {vaccines}  SVO  (nsubj, verb, dobj)
# 5946                       {vaccines}  SVO  (nsubj, verb, dobj)
# 6036                  serious {risks}  SVO  (nsubj, verb, dobj)
# 6178                       {vaccines}  SVO  (nsubj, verb, dobj)
# 6227                       {vaccines}  SVO  (nsubj, verb, dobj)
# 6228            a medical {exemption}  SVO  (nsubj, verb, dobj)
# 6229            a medical {exemption}  SVO  (nsubj, verb, dobj)
# 6230            a medical {exemption}  SVO  (nsubj, verb, dobj)
# 6347                   any {vaccines}  SVO  (nsubj, verb, dobj)
# 6355                  some {vaccines}  SVO  (nsubj, verb, dobj)
# 6375               the {use} vaccines  SVO  (nsubj, verb, dobj)
# 6399         the scheduled {vaccines}  SVO  (nsubj, verb, dobj)
# 6411                       {vaccines}  SVO  (nsubj, verb, dobj)
# 6412                       {vaccines}  SVO  (nsubj, verb, dobj)
# 6547                       {vaccines}  SVO  (nsubj, verb, dobj)
# 6567            a medical {exemption}  SVO  (nsubj, verb, dobj)
# 6568            a medical {exemption}  SVO  (nsubj, verb, dobj)
# 6657                       {vaccines}  SVO  (nsubj, verb, dobj)
# 6664                   the {vaccines}  SVO  (nsubj, verb, dobj)
# 6687                   the {vaccines}  SVO  (nsubj, verb, dobj)
#
#                                arg1_with_pos  \
# 2     a-DT-30 religous-JJ-31 exemption-NN-32
# 133   a-DT-30 religous-JJ-31 exemption-NN-32
# 171                    the-DT-25 child-NN-26
# 356   a-DT-30 religous-JJ-31 exemption-NN-32
# 361                                 all-DT-7
# 487                            Ontario-NNP-4
# 492              these-DT-36 vaccines-NNS-37
# 570              these-DT-36 vaccines-NNS-37
# 702                        no-DT-9 law-NN-10
# 823     no-DT-10 more-JJR-11 vaccines-NNS-12
# 913     no-DT-10 more-JJR-11 vaccines-NNS-12
# 941                          children-NNS-21
# 1040                          religion-NN-51
# 1042                          religion-NN-51
# 1079                         children-NNS-21
# 1163                          religion-NN-51
# 1213                  a-DT-16 religion-NN-17
# 1239                          daughter-NN-10
# 1249                              you-PRP-13
# 1277                             kids-NNS-14
# 1294                              you-PRP-25
# 1324             these-DT-36 vaccines-NNS-37
# 1365                  a-DT-16 religion-NN-17
# 1373                          daughter-NN-10
# 1381                              you-PRP-13
# 1398                             kids-NNS-14
# 1413                              you-PRP-25
# 1448             these-DT-36 vaccines-NNS-37
# 1466                most-JJS-9 people-NNS-10
# 1468                             they-PRP-30
# ...                                      ...
# 5637                              you-PRP-13
# 5692                              you-PRP-25
# 5702                    the-DT-9 child-NN-10
# 5731                              you-PRP-17
# 5745  a-DT-30 religous-JJ-31 exemption-NN-32
# 5807                         children-NNS-21
# 5826                             child-NN-28
# 5844                              child-NN-6
# 5874                  a-DT-16 religion-NN-17
# 5929                          daughter-NN-10
# 5945                          parents-NNS-81
# 5946                          parents-NNS-81
# 6036                         vaccines-NNS-14
# 6178                           Ontario-NNP-4
# 6227                       no-DT-9 law-NN-10
# 6228             these-DT-36 vaccines-NNS-37
# 6229             these-DT-36 vaccines-NNS-37
# 6230             these-DT-36 vaccines-NNS-37
# 6347                         children-NNS-21
# 6355                             child-NN-28
# 6375                  a-DT-16 religion-NN-17
# 6399                          daughter-NN-10
# 6411                          parents-NNS-81
# 6412                          parents-NNS-81
# 6547                           Ontario-NNP-4
# 6567             these-DT-36 vaccines-NNS-37
# 6568             these-DT-36 vaccines-NNS-37
# 6657                       no-DT-9 law-NN-10
# 6664                              you-PRP-13
# 6687                              you-PRP-13
#
#                                            rel_with_pos
# 2                              would-MD-34 exempt-VB-35
# 133                            would-MD-34 exempt-VB-35
# 171                                     received-VBD-27
# 356                            would-MD-34 exempt-VB-35
# 361                                have-VBP-8 had-VBN-9
# 487                            only-RB-3 requires-VBZ-5
# 492                       therefore-RB-38 giving-VBG-39
# 570                       therefore-RB-38 giving-VBG-39
# 702                                     mandates-VBZ-12
# 823                            so-RB-14 enrolled-VBD-31
# 913                            so-RB-14 enrolled-VBD-31
# 941   have-VBP-22 never-RB-23 had-VBD-24 previously-...
# 1040                                     forbids-VBZ-52
# 1042                                     forbids-VBZ-52
# 1079  have-VBP-22 never-RB-23 had-VBD-24 previously-...
# 1163                                     forbids-VBZ-52
# 1213                                     forbids-VBZ-19
# 1239                   should-MD-11 not-RB-12 get-VB-13
# 1249      would-MD-14 simply-RB-15 sign-VB-16 off-RP-17
# 1277                  even-RB-11 have-VBP-15 had-VBN-16
# 1294                 are-VBP-26 opting-VBG-27 out-IN-28
# 1324                      therefore-RB-38 giving-VBG-39
# 1365                                     forbids-VBZ-19
# 1373                   should-MD-11 not-RB-12 get-VB-13
# 1381      would-MD-14 simply-RB-15 sign-VB-16 off-RP-17
# 1398                  even-RB-11 have-VBP-15 had-VBN-16
# 1413                 are-VBP-26 opting-VBG-27 out-IN-28
# 1448                      therefore-RB-38 giving-VBG-39
# 1466                                      inject-VBP-12
# 1468                                        gave-VBD-31
# ...                                                 ...
# 5637      would-MD-14 simply-RB-15 sign-VB-16 off-RP-17
# 5692                 are-VBP-26 opting-VBG-27 out-IN-28
# 5702                                         had-VBD-11
# 5731                     do-VBP-18 n't-RB-19 want-VB-20
# 5745                           would-MD-34 exempt-VB-35
# 5807  have-VBP-22 never-RB-23 had-VBD-24 previously-...
# 5826                         has-VBZ-29 received-VBN-30
# 5844                 just-RB-3 has-VBZ-7 received-VBN-8
# 5874                                     forbids-VBZ-19
# 5929                   should-MD-11 not-RB-12 get-VB-13
# 5945                     did-VBD-83 n't-RB-84 get-VB-85
# 5946                     did-VBD-83 n't-RB-84 get-VB-85
# 6036                                       carry-VBP-16
# 6178                           only-RB-3 requires-VBZ-5
# 6227                                    mandates-VBZ-12
# 6228                      therefore-RB-38 giving-VBG-39
# 6229                      therefore-RB-38 giving-VBG-39
# 6230                      therefore-RB-38 giving-VBG-39
# 6347  have-VBP-22 never-RB-23 had-VBD-24 previously-...
# 6355                         has-VBZ-29 received-VBN-30
# 6375                                     forbids-VBZ-19
# 6399                   should-MD-11 not-RB-12 get-VB-13
# 6411                     did-VBD-83 n't-RB-84 get-VB-85
# 6412                     did-VBD-83 n't-RB-84 get-VB-85
# 6547                           only-RB-3 requires-VBZ-5
# 6567                      therefore-RB-38 giving-VBG-39
# 6568                      therefore-RB-38 giving-VBG-39
# 6657                                    mandates-VBZ-12
# 6664                     to-TO-14 check-VB-15 off-RP-16
# 6687                     to-TO-14 check-VB-15 off-RP-16
#
# [144 rows x 10 columns]
