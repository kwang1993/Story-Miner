# %%
# %matplotlib inline 

import pandas as pd
from collections import defaultdict
import re
import numpy as np
import sys
import seaborn as sns
import matplotlib.pyplot as plt

pal = sns.color_palette()


sys.path.insert(0, '../../base_codes')
sys.path.insert(0, '../../data_specific_codes')
sys.path.insert(0, '../../utility_codes')


from RE_init import *
from main_functions import *
from utility_functions import *

def read_df_rel():
    #based_dir = '../../../../data/GoodReads/'
    based_dir = '../../../../data/Tweets/all_tweets_with_extractions_from_spade/'
    file_input_name = 'merged_relations_-1.csv'
    file_input = based_dir + file_input_name    
    ff = open(file_input)
    delim=","
    df = pd.read_csv(file_input,delimiter=delim,header=0)        
    return df

df_rels = read_df_rel()
# Out:
# /Library/Python/2.7/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %%
df_text = pd.Series(df_rels["text"].tolist()).astype(str)
#pd.Series(df_train['question1'].tolist() + df_train['question2'].tolist()).astype(str)

# %%
df_text_sample = df_text.sample(100)

# %%
#sns.palplot(sns.color_palette("GnBu_d"))
#blue_orange = sns.palplot(sns.diverging_palette(220, 20, n=7))

#sns.set_palette(blue_orange)


current_palette_4 = sns.color_palette("Blues_r", 4)
sns.set_palette(current_palette_4)

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
cloud = WordCloud(width=1440, height=1080).generate(" ".join(df_text_sample.astype(str)))
plt.figure(figsize=(20, 15))
plt.imshow(cloud)
plt.axis('off')
# Out:
# (-0.5, 1439.5, 1079.5, -0.5)

# %%
print_full(df_text_sample.iloc[4:10])
# Out:
# 125931    14 things you should know SamsungPay!!.. INFO ...
# 67634     SamsungPay Gets Korea and US Launch Date; Comi...
# 118999    SamsungPay now open to all supported devices i...
# 15174     how understanding would HSBC be if I delayed m...
# 136023    Chinese hackers may have stolen the technology...
# 19785     Can someone explain this? You can use ApplePay...
# dtype: object

# %%
pd.set_option('display.max_colwidth', -1)
print(df_text_sample)
pd.reset_option('display.max_colwidth')
# Out:
# 94028     $HJOE These are cashless take ApplePay,google pay,you can buy a shot with your smart phone and they have socialmedia and theyare billboards
# 110959    googlewallet for iOS makes it easier to send money to your friends
# 43643     Lost my wallet. Looks like I will only be going to Starbucks and places that accept ApplePay.. So..... basically it does not _
# 128605    hi do you know what date Barclays will start accepting ApplePay? Thanks
# 125931    14 things you should know SamsungPay!!.. INFO ====&gt;
# 67634     SamsungPay Gets Korea and US Launch Date; Coming to UK, Spain, and China Later: Samsung says its mobile payment_
# 118999    SamsungPay now open to all supported devices in the U.S. check out all of our coverage!: After _
# 15174     how understanding would HSBC be if I delayed my payment to them by 2weeks.perhaps then they can see how customers feel re ApplePay fail
# ...
