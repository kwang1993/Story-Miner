# %%
import pandas as pd
from collections import defaultdict
import re
import numpy as np
import sys
sys.path.insert(0, '../../base_codes')
sys.path.insert(0, '../../data_specific_codes')
sys.path.insert(0, '../../utility_codes')


from RE_init import *
from main_functions import *
from utility_functions import *

def read_df_rel():
    #based_dir = '../../../../data/GoodReads/'
    based_dir = '../../../../data/Tweets/all_tweets_with_extractions_from_spade/'
    file_input_name = 'merged_relations_-1.csv'
    file_input = based_dir + file_input_name    
    ff = open(file_input)
    delim=","
    df = pd.read_csv(file_input,delimiter=delim,header=0)        
    return df

df_rels = read_df_rel()

# %%
df_rels
# Out:
#                        tweet_id         tweet_posted_time   tweet_author_id  \
# 0       2005:616033582348374016  2015-07-01T00:00:26.000Z          20562637
# 1       2005:616033586781814785  2015-07-01T00:00:27.000Z           8841372
# 2       2005:616033610773041152  2015-07-01T00:00:32.000Z        1891949672
# 3       2005:616033653701890048  2015-07-01T00:00:43.000Z          36204878
# 4       2005:616033660068761600  2015-07-01T00:00:44.000Z          63201802
# 5       2005:616033679169687552  2015-07-01T00:00:49.000Z        2805624278
# 6       2005:616033691786084352  2015-07-01T00:00:52.000Z        2720373876
# 7       2005:616033710895407104  2015-07-01T00:00:56.000Z        3299992401
# 8       2005:616034001741082624  2015-07-01T00:02:06.000Z         199620260
# 9       2005:616034053255360512  2015-07-01T00:02:18.000Z        2794526676
# 10      2005:616034180732850176  2015-07-01T00:02:48.000Z        2186649973
# 11      2005:616034304355778560  2015-07-01T00:03:18.000Z          46356750
# 12      2005:616034543590576128  2015-07-01T00:04:15.000Z        2591566082
# 13      2005:616034960831553536  2015-07-01T00:05:54.000Z        2888729354
# 14      2005:616034992385314817  2015-07-01T00:06:02.000Z          19065008
# 15      2005:616035029966262273  2015-07-01T00:06:11.000Z        3254212509
# 16      2005:616035098303987712  2015-07-01T00:06:27.000Z         145652346
# 17      2005:616035413250195456  2015-07-01T00:07:42.000Z         103246788
# 18      2005:616035810148659200  2015-07-01T00:09:17.000Z         115893653
# 19      2005:616035874040446977  2015-07-01T00:09:32.000Z          32718488
# 20      2005:616035874040446977  2015-07-01T00:09:32.000Z          32718488
# 21      2005:616036110708441089  2015-07-01T00:10:28.000Z         233759329
# 22      2005:616036395992248321  2015-07-01T00:11:36.000Z         257184857
# 23      2005:616036409669894144  2015-07-01T00:11:40.000Z          73320704
# 24      2005:616036491358244864  2015-07-01T00:11:59.000Z          29217093
# 25      2005:616038134971809792  2015-07-01T00:18:31.000Z         554506383
# 26      2005:616039105286246400  2015-07-01T00:22:22.000Z        2696054760
# 27      2005:616040766805118976  2015-07-01T00:28:58.000Z         145727348
# 28      2005:616040786279419904  2015-07-01T00:29:03.000Z         145479560
# 29      2005:616040786279419904  2015-07-01T00:29:03.000Z         145479560
# ...                         ...                       ...               ...
# 153831  2005:654430772514783232  2015-10-14T22:57:09.000Z        3033531574
# 153832  2005:654430773706014720  2015-10-14T22:57:09.000Z        2896850638
# 153833  2005:654430779766779904  2015-10-14T22:57:11.000Z        2273108791
# 153834  2005:654430781633224704  2015-10-14T22:57:11.000Z        3035556394
# 153835  2005:654430780865679364  2015-10-14T22:57:11.000Z        2273012568
# 153836  2005:654430781624860672  2015-10-14T22:57:11.000Z        2804715352
# 153837  2005:654430785739452416  2015-10-14T22:57:12.000Z        3033803560
# 153838  2005:654430811450507264  2015-10-14T22:57:18.000Z        3033732837
# 153839  2005:654430829662212096  2015-10-14T22:57:23.000Z        3034890100
# 153840  2005:654430874591563776  2015-10-14T22:57:33.000Z        2588623208
# 153841  2005:654430885060608001  2015-10-14T22:57:36.000Z        2798616144
# 153842  2005:654431097573535744  2015-10-14T22:58:27.000Z        3302651328
# 153843  2005:654431509592444928  2015-10-14T23:00:05.000Z        2533737332
# 153844  2005:654431532766097410  2015-10-14T23:00:10.000Z        3212982333
# 153845  2005:654431657227890688  2015-10-14T23:00:40.000Z        3846701692
# 153846  2005:654432512073056256  2015-10-14T23:04:04.000Z         361879882
# 153847  2005:654432526123950080  2015-10-14T23:04:07.000Z         389606426
# 153848  2005:654432767900561408  2015-10-14T23:05:05.000Z        2572348748
# 153849  2005:654432815849697280  2015-10-14T23:05:16.000Z        3819789853
# 153850  2005:654432818471301120  2015-10-14T23:05:17.000Z        2756893400
# 153851  2005:654433595117961216  2015-10-14T23:08:22.000Z        2247413024
# 153852  2005:654433595117961216  2015-10-14T23:08:22.000Z        2247413024
# 153853  2005:654434792172183552  2015-10-14T23:13:07.000Z        2234609616
# 153854  2005:654435046695243776  2015-10-14T23:14:08.000Z         286421557
# 153855  2005:654435381908275200  2015-10-14T23:15:28.000Z          78617337
# 153856  2005:654435526259417088  2015-10-14T23:16:02.000Z        2961909107
# 153857  2005:654436304420081664  2015-10-14T23:19:08.000Z         157937378
# 153858  2005:654436556015599616  2015-10-14T23:20:08.000Z        3212982333
# 153859  2005:654436615532748800  2015-10-14T23:20:22.000Z        2887004286
# 153860  2005:654436615532748800  2015-10-14T23:20:22.000Z        2887004286
#
#               tweet_author_location   tweet_country      city  tweet_lang  \
# 0                      New York, NY             NaN       NaN          en
# 1                      New York, NY             NaN       NaN          en
# 2                               NaN             NaN       NaN          en
# 3                      Marietta, GA             NaN       NaN          en
# 4                       Mxico, D.F.             NaN       NaN          en
# 5                      Florida, USA             NaN       NaN          en
# 6                   Los Angeles, CA             NaN       NaN          en
# 7               Manchester, England             NaN       NaN          en
# 8          Santarcangelo di Romagna             NaN       NaN          en
# 9                             Texas             NaN       NaN          en
# 10                              NaN             NaN       NaN          en
# 11                              NaN             NaN       NaN          en
# 12                            South             NaN       NaN          en
# 13                              NaN             NaN       NaN          en
# 14                  Los Angeles, CA             NaN       NaN          en
# 15                    United States             NaN       NaN          en
# 16                            Mxico             NaN       NaN          en
# 17                               :)             NaN       NaN          en
# 18                        Abu Dhabi             NaN       NaN          en
# 19                    San Francisco             NaN       NaN          en
# 20                    San Francisco             NaN       NaN          en
# 21                     Bluffton, SC             NaN       NaN          en
# 22                              NaN             NaN       NaN          en
# 23                              NaN             NaN       NaN          en
# 24                   Chennai, India             NaN       NaN          en
# 25               Massachusetts, USA             NaN       NaN          en
# 26                         La Plata             NaN       NaN          en
# 27                    Campbell, CA              NaN       NaN          en
# 28          Houghton Lake, Michigan             NaN       NaN          en
# 29          Houghton Lake, Michigan             NaN       NaN          en
# ...                             ...             ...       ...         ...
# 153831     Chapeltown,Rotherham, UK             NaN       NaN          en
# 153832                        Idaho             NaN       NaN          en
# 153833                      Schweiz             NaN       NaN          en
# 153834                          USA             NaN       NaN          en
# 153835      Buenos Aires, Argentina             NaN       NaN          en
# 153836                 Pennsylvania             NaN       NaN          en
# 153837                          NaN             NaN       NaN          en
# 153838                     Miami,FL             NaN       NaN          en
# 153839                    Miami, FL             NaN       NaN          en
# 153840               Salt Lake City             NaN       NaN          en
# 153841                     Maryland             NaN       NaN          en
# 153842                        India             NaN       NaN          en
# 153843                         Ty H             NaN       NaN          en
# 153844                          NaN             NaN       NaN          en
# 153845                   Takip Club             NaN       NaN          en
# 153846                  eLinda Info             NaN       NaN          en
# 153847                          NaN             NaN       NaN          en
# 153848  Vancouver, British Columbia             NaN       NaN          en
# 153849       DKI Jakarta, Indonesia             NaN       NaN          en
# 153850                          NaN             NaN       NaN          en
# 153851                          NaN             NaN       NaN          en
# 153852                          NaN             NaN       NaN          en
# 153853                Cupertino, CA             NaN       NaN          en
# 153854               West Yorkshire  United Kingdom  Bradford          en
# 153855                          NYC             NaN       NaN          en
# 153856                          NaN             NaN       NaN          en
# 153857                          NaN             NaN       NaN          en
# 153858                          NaN             NaN       NaN          en
# 153859                       Hawaii             NaN       NaN          en
# 153860                       Hawaii             NaN       NaN          en
#
#         lat  lon    ALTLAT                        ...                          \
# 0       NaN  NaN       NaN                        ...
# 1       NaN  NaN       NaN                        ...
# 2       NaN  NaN       NaN                        ...
# 3       NaN  NaN       NaN                        ...
# 4       NaN  NaN       NaN                        ...
# 5       NaN  NaN       NaN                        ...
# 6       NaN  NaN       NaN                        ...
# 7       NaN  NaN       NaN                        ...
# 8       NaN  NaN       NaN                        ...
# 9       NaN  NaN       NaN                        ...
# 10      NaN  NaN       NaN                        ...
# 11      NaN  NaN       NaN                        ...
# 12      NaN  NaN       NaN                        ...
# 13      NaN  NaN       NaN                        ...
# 14      NaN  NaN       NaN                        ...
# 15      NaN  NaN       NaN                        ...
# 16      NaN  NaN       NaN                        ...
# 17      NaN  NaN       NaN                        ...
# 18      NaN  NaN       NaN                        ...
# 19      NaN  NaN       NaN                        ...
# 20      NaN  NaN       NaN                        ...
# 21      NaN  NaN       NaN                        ...
# 22      NaN  NaN       NaN                        ...
# 23      NaN  NaN       NaN                        ...
# 24      NaN  NaN       NaN                        ...
# 25      NaN  NaN       NaN                        ...
# 26      NaN  NaN       NaN                        ...
# 27      NaN  NaN       NaN                        ...
# 28      NaN  NaN       NaN                        ...
# 29      NaN  NaN       NaN                        ...
# ...     ...  ...       ...                        ...
# 153831  NaN  NaN       NaN                        ...
# 153832  NaN  NaN       NaN                        ...
# 153833  NaN  NaN       NaN                        ...
# 153834  NaN  NaN       NaN                        ...
# 153835  NaN  NaN       NaN                        ...
# 153836  NaN  NaN       NaN                        ...
# 153837  NaN  NaN       NaN                        ...
# 153838  NaN  NaN       NaN                        ...
# 153839  NaN  NaN       NaN                        ...
# 153840  NaN  NaN       NaN                        ...
# 153841  NaN  NaN       NaN                        ...
# 153842  NaN  NaN       NaN                        ...
# 153843  NaN  NaN       NaN                        ...
# 153844  NaN  NaN       NaN                        ...
# 153845  NaN  NaN       NaN                        ...
# 153846  NaN  NaN       NaN                        ...
# 153847  NaN  NaN       NaN                        ...
# 153848  NaN  NaN       NaN                        ...
# 153849  NaN  NaN       NaN                        ...
# 153850  NaN  NaN       NaN                        ...
# 153851  NaN  NaN       NaN                        ...
# 153852  NaN  NaN       NaN                        ...
# 153853  NaN  NaN       NaN                        ...
# 153854  NaN  NaN -1.837304                        ...
# 153855  NaN  NaN       NaN                        ...
# 153856  NaN  NaN       NaN                        ...
# 153857  NaN  NaN       NaN                        ...
# 153858  NaN  NaN       NaN                        ...
# 153859  NaN  NaN       NaN                        ...
# 153860  NaN  NaN       NaN                        ...
#
#                               arg2 type              pattern  \
# 0                  an early {lead}  SVO  (nsubj, verb, dobj)
# 1                  an early {lead}  SVO  (nsubj, verb, dobj)
# 2                  an early {lead}  SVO  (nsubj, verb, dobj)
# 3                  an early {lead}  SVO  (nsubj, verb, dobj)
# 4                  an early {lead}  SVO  (nsubj, verb, dobj)
# 5                  an early {lead}  SVO  (nsubj, verb, dobj)
# 6                  an early {lead}  SVO  (nsubj, verb, dobj)
# 7                  an early {lead}  SVO  (nsubj, verb, dobj)
# 8                  an early {lead}  SVO  (nsubj, verb, dobj)
# 9                        a {drink}  SVO  (nsubj, verb, dobj)
# 10                 an early {lead}  SVO  (nsubj, verb, dobj)
# 11                 an early {lead}  SVO  (nsubj, verb, dobj)
# 12                 an early {lead}  SVO  (nsubj, verb, dobj)
# 13                 an early {lead}  SVO  (nsubj, verb, dobj)
# 14                 an early {lead}  SVO  (nsubj, verb, dobj)
# 15                 an early {lead}  SVO  (nsubj, verb, dobj)
# 16                 an early {lead}  SVO  (nsubj, verb, dobj)
# 17                 an early {lead}  SVO  (nsubj, verb, dobj)
# 18                 an early {lead}  SVO  (nsubj, verb, dobj)
# 19                       the {way}  SVO  (nsubj, verb, dobj)
# 20                   the {rest} us  SVO  (nsubj, verb, dobj)
# 21                 an early {lead}  SVO  (nsubj, verb, dobj)
# 22                 an early {lead}  SVO  (nsubj, verb, dobj)
# 23                 an early {lead}  SVO  (nsubj, verb, dobj)
# 24                 an early {lead}  SVO  (nsubj, verb, dobj)
# 25                       {victims}  SVO  (nsubj, verb, dobj)
# 26                 an early {lead}  SVO  (nsubj, verb, dobj)
# 27                 an early {lead}  SVO  (nsubj, verb, dobj)
# 28                        a {cell}  SVO  (nsubj, verb, dobj)
# 29                          {this}  SVO  (nsubj, verb, dobj)
# ...                            ...  ...                  ...
# 153831                      {$} 2.  SVO  (nsubj, verb, dobj)
# 153832                      {$} 2.  SVO  (nsubj, verb, dobj)
# 153833                      {$} 2.  SVO  (nsubj, verb, dobj)
# 153834                      {$} 2.  SVO  (nsubj, verb, dobj)
# 153835                      {$} 2.  SVO  (nsubj, verb, dobj)
# 153836                      {$} 2.  SVO  (nsubj, verb, dobj)
# 153837                      {$} 2.  SVO  (nsubj, verb, dobj)
# 153838                      {$} 2.  SVO  (nsubj, verb, dobj)
# 153839                      {$} 2.  SVO  (nsubj, verb, dobj)
# 153840                      {$} 2.  SVO  (nsubj, verb, dobj)
# 153841                      {$} 2.  SVO  (nsubj, verb, dobj)
# 153842            a payment {card}  SVO  (nsubj, verb, dobj)
# 153843                      {$} 2.  SVO  (nsubj, verb, dobj)
# 153844                     {money}  SVO  (nsubj, verb, dobj)
# 153845            a payment {card}  SVO  (nsubj, verb, dobj)
# 153846                     {money}  SVO  (nsubj, verb, dobj)
# 153847  upcoming ApplePay {launch}  SVO  (nsubj, verb, dobj)
# 153848                Slow {Start}  SVO  (nsubj, verb, dobj)
# 153849            a payment {card}  SVO  (nsubj, verb, dobj)
# 153850            a payment {card}  SVO  (nsubj, verb, dobj)
# 153851                    {people}  SVO  (nsubj, verb, dobj)
# 153852              about {15,000}  SVO  (nsubj, verb, dobj)
# 153853                      {$} 2.  SVO  (nsubj, verb, dobj)
# 153854                  {ApplePay}  SVO  (nsubj, verb, dobj)
# 153855                leverage {w}  SVO  (nsubj, verb, dobj)
# 153856               Android {Pay}  SVO  (nsubj, verb, dobj)
# 153857         NFC payment {watch}  SVO  (nsubj, verb, dobj)
# 153858                     {money}  SVO  (nsubj, verb, dobj)
# 153859            a shopkeep {POS}  SVO  (nsubj, verb, dobj)
# 153860                {AndroidPay}  SVO  (nsubj, verb, dobj)
#
#                                             arg1_with_pos  \
# 0                                        SamsungPay-NNP-2
# 1                                        SamsungPay-NNP-2
# 2                                        SamsungPay-NNP-2
# 3                                        SamsungPay-NNP-2
# 4                                        SamsungPay-NNP-2
# 5                                        SamsungPay-NNP-2
# 6                                        SamsungPay-NNP-2
# 7                                        SamsungPay-NNP-2
# 8                                        SamsungPay-NNP-2
# 9                                            someone-NN-5
# 10                                       SamsungPay-NNP-2
# 11                                       SamsungPay-NNP-2
# 12                                       SamsungPay-NNP-2
# 13                                       SamsungPay-NNP-2
# 14                                       SamsungPay-NNP-2
# 15                                       SamsungPay-NNP-2
# 16                                       SamsungPay-NNP-2
# 17                                       SamsungPay-NNP-2
# 18                                       SamsungPay-NNP-2
# 19                                             Today-NN-1
# 20                                Block-NN-1 chains-NNS-2
# 21                                       SamsungPay-NNP-2
# 22                                       SamsungPay-NNP-2
# 23                                       SamsungPay-NNP-2
# 24                                       SamsungPay-NNP-2
# 25      Fake-JJ-1 twitter-NN-2 verification-NN-3 profi...
# 26                                       SamsungPay-NNP-2
# 27                                       SamsungPay-NNP-2
# 28                                              you-PRP-5
# 29               Silicone-NNP-1 TMobile-NNP-2 Wallet-NN-3
# ...                                                   ...
# 153831                              Cards-NNS-2 Pro-NNP-3
# 153832                              Cards-NNS-2 Pro-NNP-3
# 153833                              Cards-NNS-2 Pro-NNP-3
# 153834                              Cards-NNS-2 Pro-NNP-3
# 153835                              Cards-NNS-2 Pro-NNP-3
# 153836                              Cards-NNS-2 Pro-NNP-3
# 153837                              Cards-NNS-2 Pro-NNP-3
# 153838                              Cards-NNS-2 Pro-NNP-3
# 153839                              Cards-NNS-2 Pro-NNP-3
# 153840                              Cards-NNS-2 Pro-NNP-3
# 153841                              Cards-NNS-2 Pro-NNP-3
# 153842                                          you-PRP-2
# 153843                              Cards-NNS-2 Pro-NNP-3
# 153844                                           it-PRP-9
# 153845                                          you-PRP-2
# 153846                                           it-PRP-9
# 153847                            Bank-NNP-1 website-NN-2
# 153848               6-CD-1 Reasons-NNPS-2 ApplePay-NNP-3
# 153849                                          you-PRP-2
# 153850                                          you-PRP-2
# 153851                                         they-PRP-2
# 153852                                       people-NNS-5
# 153853                              Cards-NNS-2 Pro-NNP-3
# 153854                                          you-PRP-3
# 153855                                    Starbucks-NNP-1
# 153856                                        google-NN-1
# 153857                                       Swatch-NNP-1
# 153858                                           it-PRP-9
# 153859                                    assassins-NNS-3
# 153860                     a-DT-5 shopkeep-JJ-6 POS-NNP-7
#
#                                       rel_with_pos  \
# 0                   Why-WRB-1 could-MD-3 gain-VB-4
# 1                   Why-WRB-1 could-MD-3 gain-VB-4
# 2                   Why-WRB-1 could-MD-3 gain-VB-4
# 3                   Why-WRB-1 could-MD-3 gain-VB-4
# 4                   Why-WRB-1 could-MD-3 gain-VB-4
# 5                   Why-WRB-1 could-MD-3 gain-VB-4
# 6                   Why-WRB-1 could-MD-3 gain-VB-4
# 7                   Why-WRB-1 could-MD-3 gain-VB-4
# 8                   Why-WRB-1 could-MD-3 gain-VB-4
# 9                             should-MD-6 buy-VB-7
# 10                  Why-WRB-1 could-MD-3 gain-VB-4
# 11                  Why-WRB-1 could-MD-3 gain-VB-4
# 12                  Why-WRB-1 could-MD-3 gain-VB-4
# 13                  Why-WRB-1 could-MD-3 gain-VB-4
# 14                  Why-WRB-1 could-MD-3 gain-VB-4
# 15                  Why-WRB-1 could-MD-3 gain-VB-4
# 16                  Why-WRB-1 could-MD-3 gain-VB-4
# 17                  Why-WRB-1 could-MD-3 gain-VB-4
# 18                  Why-WRB-1 could-MD-3 gain-VB-4
# 19                                     leads-VBZ-3
# 20                  will-MD-3 take-VB-4 there-RB-9
# 21                  Why-WRB-1 could-MD-3 gain-VB-4
# 22                  Why-WRB-1 could-MD-3 gain-VB-4
# 23                  Why-WRB-1 could-MD-3 gain-VB-4
# 24                  Why-WRB-1 could-MD-3 gain-VB-4
# 25                                     trick-VBP-5
# 26                  Why-WRB-1 could-MD-3 gain-VB-4
# 27                  Why-WRB-1 could-MD-3 gain-VB-4
# 28                                      have-VBP-6
# 29                           then-RB-9 need-VBP-11
# ...                                            ...
# 153831                                *****-VBP-11
# 153832                                *****-VBP-11
# 153833                                *****-VBP-11
# 153834                                *****-VBP-11
# 153835                                *****-VBP-11
# 153836                                *****-VBP-11
# 153837                                *****-VBP-11
# 153838                                *****-VBP-11
# 153839                                *****-VBP-11
# 153840                                *****-VBP-11
# 153841                                *****-VBP-11
# 153842          Have-VB-1 already-RB-3 added-VBD-4
# 153843                                *****-VBP-11
# 153844                      how-WRB-8 makes-VBZ-10
# 153845          Have-VB-1 already-RB-3 added-VBD-4
# 153846                      how-WRB-8 makes-VBZ-10
# 153847              accidentally-RB-3 teases-VBZ-4
# 153848                     Will-MD-4 Overcome-VB-5
# 153849          Have-VB-1 already-RB-3 added-VBD-4
# 153850          Have-VB-1 already-RB-3 added-VBD-4
# 153851     Meanwhile-RB-1 're-VBP-3 charging-VBG-4
# 153852                                  make-VBP-7
# 153853                                *****-VBP-11
# 153854  when-WRB-1 are-VBP-2 setting-VBG-4 up-RP-5
# 153855                                   had-VBD-2
# 153856                              Launches-VBZ-2
# 153857                              launches-VBZ-2
# 153858                      how-WRB-8 makes-VBZ-10
# 153859                                   got-VBD-4
# 153860                               accepts-VBZ-9
#
#                                    arg2_with_pos  \
# 0                   an-DT-5 early-JJ-6 lead-NN-7
# 1                   an-DT-5 early-JJ-6 lead-NN-7
# 2                   an-DT-5 early-JJ-6 lead-NN-7
# 3                   an-DT-5 early-JJ-6 lead-NN-7
# 4                   an-DT-5 early-JJ-6 lead-NN-7
# 5                   an-DT-5 early-JJ-6 lead-NN-7
# 6                   an-DT-5 early-JJ-6 lead-NN-7
# 7                   an-DT-5 early-JJ-6 lead-NN-7
# 8                   an-DT-5 early-JJ-6 lead-NN-7
# 9                             a-DT-9 drink-NN-10
# 10                  an-DT-5 early-JJ-6 lead-NN-7
# 11                  an-DT-5 early-JJ-6 lead-NN-7
# 12                  an-DT-5 early-JJ-6 lead-NN-7
# 13                  an-DT-5 early-JJ-6 lead-NN-7
# 14                  an-DT-5 early-JJ-6 lead-NN-7
# 15                  an-DT-5 early-JJ-6 lead-NN-7
# 16                  an-DT-5 early-JJ-6 lead-NN-7
# 17                  an-DT-5 early-JJ-6 lead-NN-7
# 18                  an-DT-5 early-JJ-6 lead-NN-7
# 19                             the-DT-4 way-NN-5
# 20                   the-DT-5 rest-NN-6 us-PRP-8
# 21                  an-DT-5 early-JJ-6 lead-NN-7
# 22                  an-DT-5 early-JJ-6 lead-NN-7
# 23                  an-DT-5 early-JJ-6 lead-NN-7
# 24                  an-DT-5 early-JJ-6 lead-NN-7
# 25                                 victims-NNS-6
# 26                  an-DT-5 early-JJ-6 lead-NN-7
# 27                  an-DT-5 early-JJ-6 lead-NN-7
# 28                              a-DT-7 cell-NN-8
# 29                                    this-DT-12
# ...                                          ...
# 153831                           $-$-12 2.-CD-13
# 153832                           $-$-12 2.-CD-13
# 153833                           $-$-12 2.-CD-13
# 153834                           $-$-12 2.-CD-13
# 153835                           $-$-12 2.-CD-13
# 153836                           $-$-12 2.-CD-13
# 153837                           $-$-12 2.-CD-13
# 153838                           $-$-12 2.-CD-13
# 153839                           $-$-12 2.-CD-13
# 153840                           $-$-12 2.-CD-13
# 153841                           $-$-12 2.-CD-13
# 153842             a-DT-5 payment-NN-6 card-NN-7
# 153843                           $-$-12 2.-CD-13
# 153844                               money-NN-11
# 153845             a-DT-5 payment-NN-6 card-NN-7
# 153846                               money-NN-11
# 153847  upcoming-JJ-5 ApplePay-NNP-6 launch-NN-7
# 153848                    Slow-NNP-6 Start-NNP-7
# 153849             a-DT-5 payment-NN-6 card-NN-7
# 153850             a-DT-5 payment-NN-6 card-NN-7
# 153851                              people-NNS-5
# 153852                    about-RB-8 15,000-CD-9
# 153853                           $-$-12 2.-CD-13
# 153854                            ApplePay-NNP-6
# 153855                      leverage-NN-3 w-NN-4
# 153856                   Android-NNP-3 Pay-NNP-4
# 153857         NFC-NNP-3 payment-NN-4 watch-NN-5
# 153858                               money-NN-11
# 153859            a-DT-5 shopkeep-JJ-6 POS-NNP-7
# 153860                         AndroidPay-NNP-10
#
#                          arg1_prepositions  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# 5                                      NaN
# 6                                      NaN
# 7                                      NaN
# 8                                      NaN
# 9                                      NaN
# 10                                     NaN
# 11                                     NaN
# 12                                     NaN
# 13                                     NaN
# 14                                     NaN
# 15                                     NaN
# 16                                     NaN
# 17                                     NaN
# 18                                     NaN
# 19                                     NaN
# 20                                     NaN
# 21                                     NaN
# 22                                     NaN
# 23                                     NaN
# 24                                     NaN
# 25                                     NaN
# 26                                     NaN
# 27                                     NaN
# 28                                     NaN
# 29                                     NaN
# ...                                    ...
# 153831                                 NaN
# 153832                                 NaN
# 153833                                 NaN
# 153834                                 NaN
# 153835                                 NaN
# 153836                                 NaN
# 153837                                 NaN
# 153838                                 NaN
# 153839                                 NaN
# 153840                                 NaN
# 153841                                 NaN
# 153842                                 NaN
# 153843                                 NaN
# 153844                                 NaN
# 153845                                 NaN
# 153846                                 NaN
# 153847                                 NaN
# 153848                                 NaN
# 153849                                 NaN
# 153850                                 NaN
# 153851                                 NaN
# 153852  REASON: prep_for TEXT: {water} --
# 153853                                 NaN
# 153854                                 NaN
# 153855                                 NaN
# 153856                                 NaN
# 153857                                 NaN
# 153858                                 NaN
# 153859                                 NaN
# 153860                                 NaN
#
#                                          rel_prepositions  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# 5                                                     NaN
# 6                                                     NaN
# 7                                                     NaN
# 8                                                     NaN
# 9                                                     NaN
# 10                                                    NaN
# 11                                                    NaN
# 12                                                    NaN
# 13                                                    NaN
# 14                                                    NaN
# 15                                                    NaN
# 16                                                    NaN
# 17                                                    NaN
# 18                                                    NaN
# 19      REASON: prep_in TEXT: mobile payment {processi...
# 20                         REASON: prep_in TEXT: {lt} --
# 21                                                    NaN
# 22                                                    NaN
# 23                                                    NaN
# 24                                                    NaN
# 25                                                    NaN
# 26                                                    NaN
# 27                                                    NaN
# 28                                                    NaN
# 29                                                    NaN
# ...                                                   ...
# 153831                                                NaN
# 153832                                                NaN
# 153833                                                NaN
# 153834                                                NaN
# 153835                                                NaN
# 153836                                                NaN
# 153837                                                NaN
# 153838                                                NaN
# 153839                                                NaN
# 153840                                                NaN
# 153841                                                NaN
# 153842                                                NaN
# 153843                                                NaN
# 153844                                                NaN
# 153845                                                NaN
# 153846                                                NaN
# 153847                                                NaN
# 153848                                                NaN
# 153849                                                NaN
# 153850                                                NaN
# 153851                                                NaN
# 153852            REASON: prep_before TEXT: {tax} 300 --
# 153853                                                NaN
# 153854                                                NaN
# 153855                                                NaN
# 153856                                                NaN
# 153857                                                NaN
# 153858                                                NaN
# 153859                                                NaN
# 153860                                                NaN
#
#                                   arg2_prepositions  \
# 0       REASON: prep_in TEXT: mobile {payments} --
# 1       REASON: prep_in TEXT: mobile {payments} --
# 2       REASON: prep_in TEXT: mobile {payments} --
# 3       REASON: prep_in TEXT: mobile {payments} --
# 4       REASON: prep_in TEXT: mobile {payments} --
# 5       REASON: prep_in TEXT: mobile {payments} --
# 6       REASON: prep_in TEXT: mobile {payments} --
# 7       REASON: prep_in TEXT: mobile {payments} --
# 8       REASON: prep_in TEXT: mobile {payments} --
# 9                                               NaN
# 10      REASON: prep_in TEXT: mobile {payments} --
# 11      REASON: prep_in TEXT: mobile {payments} --
# 12      REASON: prep_in TEXT: mobile {payments} --
# 13      REASON: prep_in TEXT: mobile {payments} --
# 14      REASON: prep_in TEXT: mobile {payments} --
# 15      REASON: prep_in TEXT: mobile {payments} --
# 16      REASON: prep_in TEXT: mobile {payments} --
# 17      REASON: prep_in TEXT: mobile {payments} --
# 18      REASON: prep_in TEXT: mobile {payments} --
# 19                                              NaN
# 20                                              NaN
# 21      REASON: prep_in TEXT: mobile {payments} --
# 22      REASON: prep_in TEXT: mobile {payments} --
# 23      REASON: prep_in TEXT: mobile {payments} --
# 24      REASON: prep_in TEXT: mobile {payments} --
# 25                                              NaN
# 26      REASON: prep_in TEXT: mobile {payments} --
# 27      REASON: prep_in TEXT: mobile {payments} --
# 28                                              NaN
# 29                                              NaN
# ...                                             ...
# 153831                                          NaN
# 153832                                          NaN
# 153833                                          NaN
# 153834                                          NaN
# 153835                                          NaN
# 153836                                          NaN
# 153837                                          NaN
# 153838                                          NaN
# 153839                                          NaN
# 153840                                          NaN
# 153841                                          NaN
# 153842                                          NaN
# 153843                                          NaN
# 153844                                          NaN
# 153845                                          NaN
# 153846                                          NaN
# 153847           REASON: prep_in TEXT: {Canada} --
# 153848                                          NaN
# 153849                                          NaN
# 153850                                          NaN
# 153851           REASON: prep_for TEXT: {water} --
# 153852                                          NaN
# 153853                                          NaN
# 153854                                          NaN
# 153855                                          NaN
# 153856                                          NaN
# 153857            REASON: prep_in TEXT: {China} --
# 153858                                          NaN
# 153859                                          NaN
# 153860                                          NaN
#
#                                                annotation
# 0       {'dep_parse': 'advmod(gain-4, Why-1)\nnsubj(ga...
# 1       {'dep_parse': 'advmod(gain-4, Why-1)\nnsubj(ga...
# 2       {'dep_parse': 'advmod(gain-4, Why-1)\nnsubj(ga...
# 3       {'dep_parse': 'advmod(gain-4, Why-1)\nnsubj(ga...
# 4       {'dep_parse': 'advmod(gain-4, Why-1)\nnsubj(ga...
# 5       {'dep_parse': 'advmod(gain-4, Why-1)\nnsubj(ga...
# 6       {'dep_parse': 'advmod(gain-4, Why-1)\nnsubj(ga...
# 7       {'dep_parse': 'advmod(gain-4, Why-1)\nnsubj(ga...
# 8       {'dep_parse': 'advmod(gain-4, Why-1)\nnsubj(ga...
# 9       {'dep_parse': 'amod(Time-3, Happy-1)\nnn(Time-...
# 10      {'dep_parse': 'advmod(gain-4, Why-1)\nnsubj(ga...
# 11      {'dep_parse': 'advmod(gain-4, Why-1)\nnsubj(ga...
# 12      {'dep_parse': 'advmod(gain-4, Why-1)\nnsubj(ga...
# 13      {'dep_parse': 'advmod(gain-4, Why-1)\nnsubj(ga...
# 14      {'dep_parse': 'advmod(gain-4, Why-1)\nnsubj(ga...
# 15      {'dep_parse': 'advmod(gain-4, Why-1)\nnsubj(ga...
# 16      {'dep_parse': 'advmod(gain-4, Why-1)\nnsubj(ga...
# 17      {'dep_parse': 'advmod(gain-4, Why-1)\nnsubj(ga...
# 18      {'dep_parse': 'advmod(gain-4, Why-1)\nnsubj(ga...
# 19      {'dep_parse': 'nsubj(leads-3, Today-1)\ndep(To...
# 20      {'dep_parse': 'nn(chains-2, Block-1)\nnsubj(ta...
# 21      {'dep_parse': 'advmod(gain-4, Why-1)\nnsubj(ga...
# 22      {'dep_parse': 'advmod(gain-4, Why-1)\nnsubj(ga...
# 23      {'dep_parse': 'advmod(gain-4, Why-1)\nnsubj(ga...
# 24      {'dep_parse': 'advmod(gain-4, Why-1)\nnsubj(ga...
# 25      {'dep_parse': 'amod(profiles-4, Fake-1)\nnn(pr...
# 26      {'dep_parse': 'advmod(gain-4, Why-1)\nnsubj(ga...
# 27      {'dep_parse': 'advmod(gain-4, Why-1)\nnsubj(ga...
# 28      {'dep_parse': 'nn(Wallet-3, Silicone-1)\nnn(Wa...
# 29      {'dep_parse': 'nn(Wallet-3, Silicone-1)\nnn(Wa...
# ...                                                   ...
# 153831  {'dep_parse': 'poss(Pro-3, My-1)\nnn(Pro-3, Ca...
# 153832  {'dep_parse': 'poss(Pro-3, My-1)\nnn(Pro-3, Ca...
# 153833  {'dep_parse': 'poss(Pro-3, My-1)\nnn(Pro-3, Ca...
# 153834  {'dep_parse': 'poss(Pro-3, My-1)\nnn(Pro-3, Ca...
# 153835  {'dep_parse': 'poss(Pro-3, My-1)\nnn(Pro-3, Ca...
# 153836  {'dep_parse': 'poss(Pro-3, My-1)\nnn(Pro-3, Ca...
# 153837  {'dep_parse': 'poss(Pro-3, My-1)\nnn(Pro-3, Ca...
# 153838  {'dep_parse': 'poss(Pro-3, My-1)\nnn(Pro-3, Ca...
# 153839  {'dep_parse': 'poss(Pro-3, My-1)\nnn(Pro-3, Ca...
# 153840  {'dep_parse': 'poss(Pro-3, My-1)\nnn(Pro-3, Ca...
# 153841  {'dep_parse': 'poss(Pro-3, My-1)\nnn(Pro-3, Ca...
# 153842  {'dep_parse': 'aux(added-4, Have-1)\nnsubj(add...
# 153843  {'dep_parse': 'poss(Pro-3, My-1)\nnn(Pro-3, Ca...
# 153844  {'dep_parse': 'advmod(company-4, How-1)\namod(...
# 153845  {'dep_parse': 'aux(added-4, Have-1)\nnsubj(add...
# 153846  {'dep_parse': 'advmod(company-4, How-1)\namod(...
# 153847  {'dep_parse': 'nn(website-2, Bank-1)\nnsubj(te...
# 153848  {'dep_parse': 'num(ApplePay-3, 6-1)\nnn(AppleP...
# 153849  {'dep_parse': 'aux(added-4, Have-1)\nnsubj(add...
# 153850  {'dep_parse': 'aux(added-4, Have-1)\nnsubj(add...
# 153851  {'dep_parse': "advmod(charging-4, Meanwhile-1)...
# 153852  {'dep_parse': "advmod(charging-4, Meanwhile-1)...
# 153853  {'dep_parse': 'poss(Pro-3, My-1)\nnn(Pro-3, Ca...
# 153854  {'dep_parse': 'advmod(setting-4, when-1)\naux(...
# 153855  {'dep_parse': "nsubj(had-2, Starbucks-1)\nroot...
# 153856  {'dep_parse': 'nsubj(Launches-2, google-1)\nxs...
# 153857  {'dep_parse': 'nsubj(launches-2, Swatch-1)\nro...
# 153858  {'dep_parse': 'advmod(company-4, How-1)\namod(...
# 153859  {'dep_parse': 'dep(assassins-3, ahi-1)\npunct(...
# 153860  {'dep_parse': 'dep(assassins-3, ahi-1)\npunct(...
#
# [153861 rows x 36 columns]

# %%
#'''
if NODE_SELECTION:
    # get the list of different versions of an entity. Example : parents,parent,i,we -> parents
    entity_versions = get_entity_versions(DATA_SET)    
    df_simp = get_simp_df(df_rels.copy(),entity_versions)  
    selected_nodes = entity_versions.keys()
    df_rels_selected = filter_nodes_OR(df_simp.copy(),source='arg1',target='arg2',selected_nodes = selected_nodes)
    g_arg = create_argument_multiGraph(df_rels_selected.copy(),source='arg1',target='arg2',edge_attr = 'rel')
    if SAVE_GEFX:
        nx.write_gexf(g_arg, output_dir + file_input_name + "_" + "g_arg_selected_"+str(MAX_ITERATION)+"_"+str(time.time())+".gexf")
    #plot_argument_graph(g_arg)
    if SAVE_PAIRWISE_RELS:
        file_loc = output_dir + file_input_name + "_" + "pairwise_rels_selected_"+str(MAX_ITERATION)+"_"+DATA_SET+".txt"
        save_pairwise_rels(file_loc,g_arg,print_option=True)      

g_arg = create_argument_multiGraph(df_rels.copy(),source='arg1',target='arg2',edge_attr = 'rel')
if SAVE_GEFX:
    nx.write_gexf(g_arg, output_dir + file_input_name + "_" + "g_arg_"+str(MAX_ITERATION)+"_"+str(time.time())+".gexf")
#plot_argument_graph(g_arg)
if SAVE_PAIRWISE_RELS:
    file_loc = output_dir + file_input_name + "_"  + "pairwise_rels_"+str(MAX_ITERATION)+"_"+DATA_SET+".txt"
    save_pairwise_rels(file_loc,g_arg,print_option=True)    
    
#if __name__ == "__main__":
#    main(sys.argv[1:])
#'''
# Out:
# PayPal {$} {0: {'label': '{sends}-1'}}
# PayPal own custom {video} {0: {'label': '{get}-2'}}
# PayPal similar {terms} {0: {'label': '{has}-1'}}
# PayPal war {chest} {0: {'label': '{putting}-1'}}
# PayPal {$} 35 {0: {'label': '{charge}-1'}}
# PayPal the mobile wallet {game} thrones {0: {'label': 'still {winning}-2'}}
# PayPal {_} {0: {'label': 'currently {welcome}-1'}}
# PayPal the {merchant} {0: {'label': 'Essentially has {created}-1'}}
# PayPal {$} 35 crazy {0: {'label': '{charge}-1'}}
# PayPal tributes {pigs} {0: {'label': '{needs}-2'}}
# PayPal nude selfie {scandal} {0: {'label': '{uses}-1'}}
# PayPal million new {accounts} {0: {'label': '{added}-1'}}
# PayPal mobile payment {apps} {0: {'label': 'Just when off could {kill} off-5'}}
# {it} PayPal {0: {'label': '{Fill} up-4'}}
# maybe {apple} PayPal {0: {'label': '{adds}-2'}}
# apple {music} HSBC {0: {'label': '{enters}-43'}}
# Amex payments {sys} {0: {'label': '{hopes}-2'}}
# Amex new {mobile} {0: {'label': '{hopes}-1'}}
# Amex new mobile {payments} {0: {'label': '{hopes}-4'}}
# Amex apple {pay} {0: {'label': '{updates}-13'}, 1: {'label': '{supports}-1'}}
# Amex fast digital {checkouts} {0: {'label': '{launches}-54'}}
# Amex new mobile {payment} {0: {'label': '{hopes}-2'}}
# Amex {sys} {0: {'label': '{hopes}-4'}}
# Amex new mobile {pa.} {0: {'label': '{hopes}-1'}}
# Amex {express} {0: {'label': 'just {launched}-2'}}
# Amex new mobile {pay} {0: {'label': '{hopes}-1'}}
# a {book} PayPal {0: {'label': '{takes}-2'}, 1: {'label': '{allows}-1'}}
# Starbucks apple {pay} {0: {'label': '{praises}-1'}}
# Starbucks the insecure mobile {payment} {0: {'label': 'seriously {has}-1'}}
# {i} PayPal {0: {'label': '{got}-5'}, 1: {'label': 'can {do}-1'}, 2: {'label': "'ll {take}-1"}, 3: {'label': 'once {get}-1'}, 4: {'label': '{accept}-1'}, 5: {'label': '{have}-1'}}
# {i} Starbucks {0: {'label': 'really {wanted}-1'}, 1: {'label': '{need}-1'}}
# {you} Barclays {0: {'label': '{mean}-1'}}
# apple {pay} PayPal {0: {'label': 'is {beating}-1'}}
# apple {pay} HSBC {0: {'label': '{enters}-43'}}
# HSBC {what} {0: {'label': '{TOLD}-1'}}
# HSBC {me} {0: {'label': '{TOLD}-1'}}
# Barclays three bpay {devices} {0: {'label': '{announces}-2'}}
# Barclays {'t} one partners {0: {'label': '{aren}-1'}}
# Barclays bpay {solution} {0: {'label': 'are {flogging}-1'}}
# Barclays {it} {0: {'label': '{going} alone-1'}, 1: {'label': 'to {support}-1'}}
# Barclays {zapp} not {0: {'label': '{joins}-1'}}
# Barclays good {reasons} do {0: {'label': '{have}-1'}}
# Barclays {zapp} {0: {'label': '{joins}-81'}, 1: {'label': '{uses}-1'}}
# Barclays applepay {wallet} {0: {'label': 'to {support}-1'}}
# Barclays {brand} {0: {'label': '{screwed} up-3'}}
# Barclays 2 key {entrants} {0: {'label': '{joins}-1'}}
# Barclays {_} {0: {'label': 'will {get} applepay now-2'}}
# Barclays the {battle} {0: {'label': 'have {lost}-1'}}
# Barclays {apple} {0: {'label': '{support}-1'}}
# Barclays apple {pay} {0: {'label': 'to {support}-32'}, 1: {'label': 'are not {doing}-12'}, 2: {'label': '{shuns}-10'}, 3: {'label': '{attacks}-9'}, 4: {'label': '{delays}-6'}, 5: {'label': '{support}-2'}, 6: {'label': 'Is {Delaying}-2'}, 7: {'label': 'not {supporting}-1'}, 8: {'label': 'do not {support}-1'}, 9: {'label': 'are not {implementing}-1'}, 10: {'label': '{supporting}-1'}, 11: {'label': '{shun}-1'}, 12: {'label': 'how {supports}-1'}, 13: {'label': 'not to {join}-1'}}
# Barclays contactless {solution} {0: {'label': '{launches}-1'}}
# Barclays a {deal} {0: {'label': 'has {signed}-2'}}
# Barclays standard nfc payments {tech} {0: {'label': 'to {adopt}-1'}}
# Barclays {pingit} {0: {'label': '{uses}-1'}}
# Barclays various innovative digital smart {pay} {0: {'label': '{introduces}-1'}}
# Barclays {applepay} {0: {'label': '{attacks}-3'}, 1: {'label': 'just {want}-1'}, 2: {'label': 'now hopefully will {have}-1'}}
# Barclays the {decision} support {0: {'label': 'when will {review}-1'}}
# Barclays {it.} {0: {'label': 'are not {supporting}-2'}}
# Barclays new {ways} {0: {'label': '{offers}-2'}}
# Barclays {customers} {0: {'label': 'should be {giving}-1'}}
# Barclays the {rank} {0: {'label': 'has {joined}-4'}}
# E4i The {Future} Payments {Fingerprint} {0: {'label': '{Awaits}-1'}}
# International mobile payment {service.} the {team} {0: {'label': '{Join} too-1'}}
# MTN {Swaziland} Ericsson Mobile {Wallet} {0: {'label': '{Deploys}-1'}}
# Aaaaaand {ncsecu} Apple {Pay} {0: {'label': 'still {using}-1'}}
# HiTestElbert {Capitol} world {applepay} {0: {'label': 'can {accept}-1'}}
# {Stickers} {shit} {0: {'label': '{put} together-1'}}
# P2P {payments} {all} {0: {'label': '{rolls} out-9'}}
# SBT {Capital} $ {Funding} {0: {'label': '{Leads}-1'}}
# 10 {tips} {thoughts} {0: {'label': 'will {reaffirm}-1'}}
# Hi {Samuel} {you} {0: {'label': '{thank}-1'}}
# Naked Security ] Trump Hotel {chain} potential payment card {breach} {0: {'label': '{investigates}-1'}}
# {terminals} Apple {pay} {0: {'label': '{support}-1'}}
# An Apple Pay {Peer} to {Disaster} {0: {'label': 'May {Spell}-11'}}
# Trump Hotel {chain} potential payment card {breach} {0: {'label': '{investigates}-26'}}
# Hi {Gabe} Pin payment {technologies} {0: {'label': 'will {allow}-1'}}
# {10.5.} {Venmo} {0: {'label': 'Will {sell}-2'}}
# losse {kaartjes} korting zijn niet {verkrijgbaar} {0: {'label': '{met}-1'}}
# Twitter verification {profiles} {victims} {0: {'label': '{trick}-1'}}
# SCMagazine ] Trump Hotel {Collection} potential payment card {breach} {0: {'label': '{investigating}-1'}}
# blog team member {Brandon} first {experience} {0: {'label': '{shared}-1'}}
# The {Future} Payments {Fingerprint} {0: {'label': '{Awaits}-85'}}
# {That} Venmo P2P {payments} {0: {'label': '{Forget}-1'}}
# {That} {Brits} {0: {'label': '{gives}-10'}}
# {That} no payment card {usage} {0: {'label': '{means}-2'}}
# {That} {iPhone} {0: {'label': '{Turns}-1'}}
# {That} {some} confusion {0: {'label': '{clears} up-1'}}
# Most {places} apple {pay} {0: {'label': '{has}-1'}}
# Not {everyone} a {device} {0: {'label': 'will {have} not-1'}}
# 70 {percent} consumers an {offer} {0: {'label': 'will {save}-2'}}
# New {Point} Sale card {information} {0: {'label': '{steals}-1'}}
# largest high street {banks} digital payment {services} {0: {'label': 'are {launching}-1'}}
# Apple Pay UK release {date} {online} {0: {'label': '{LEAKED}-31'}}
# No {point} a {petition} {0: {'label': '{having}-1'}}
# Banks {Gearing} {Everything} {0: {'label': '{Hate}-1'}}
# {consumers} the {speed} {0: {'label': '{love}-1'}}
# {GO} the {switch} {0: {'label': '{flip}-2'}}
# Mobile wallet app {Yoyo} {expansion} {0: {'label': '{eyes}-1'}}
# APPLE {PAY} SPENDING {SPIRAL} {0: {'label': 'WILL {MAKE}-2'}}
# APPLE {PAY} {LIFE} {0: {'label': '{SAVED}-1'}}
# {US} {watch} {0: {'label': '{messes} up-1'}}
# Apple haven {'t} the best {job} communicating {0: {'label': '{done}-1'}}
# Apple haven {'t} app {update} {0: {'label': '{approved}-1'}}
# Apple haven {'t} {YOU} {0: {'label': 'even {told}-1'}}
# iPhone {User} {Petition} Convince {0: {'label': '{Starts}-1'}}
# the social {team} a new {line.} {0: {'label': '{needs}-2'}}
# {mgr} {hoq} {0: {'label': '{told}-1'}}
# Clover {Mini} a wide {variety} payments {0: {'label': '{accepts}-1'}}
# Si Apple {Pay} a entonces si me compro el {relojito} {0: {'label': '{llega}-1'}}
# more US {banks} Apple {Pay} {0: {'label': '{add}-7'}}
# {ours} {whatever} that {0: {'label': "can {'t}-1"}}
# {Customers} {Car} {0: {'label': 'to {Register}-1'}}
# {Customers} {applepay} {0: {'label': '{want}-1'}}
# {Customers} contactless {card} authenticate {0: {'label': '{tap}-1'}}
# {Customers} {_} {0: {'label': 'to {Register}-9'}}
# {Customers} {Cards} {0: {'label': 'to {Register}-228'}}
# {Customers} {Ca.} {0: {'label': 'to {Register}-1'}}
# Google {News} Biometric Payment {Card} {0: {'label': 'to {Develop}-1'}}
# Sally {Beauty} {reports} activity {0: {'label': '{probes}-1'}}
# 14. {Apple} {_} {0: {'label': '{has}-1'}}
# {employees} {business} {0: {'label': 'How will {affect} Will-1'}}
# {8.4} {haha} {0: {'label': '{took}-1'}}
# {8.4} Apple {Pay} {0: {'label': '{took}-1'}}
# {8.4} {applepay} {0: {'label': '{brought}-1'}}
# {Yo} apple pay {wtf} {0: {'label': '{want}-1'}}
# {you} any {writers} interested {0: {'label': 'Do {have}-1'}}
# {you} more {details} {0: {'label': '{know}-1'}}
# {you} {all} them {0: {'label': 'can {get}-1'}}
# {you} release {date} " {0: {'label': 'Surely {know}-1'}}
# {you} Payment Card {Policy} {0: {'label': 'Are {using}-1'}}
# {you} the {time} {0: {'label': '{get} around-1'}}
# {you} {that} {0: {'label': '{take}-1'}}
# {you} {sausages} {0: {'label': 'Did {miss}-1'}}
# {you} 1/ {3} {0: {'label': 'have {used}-1'}}
# {you} this {bullshit} {0: {'label': 'to {tweet}-19'}}
# {you} {item} {0: {'label': '{return}-1'}}
# {you} {haves} {0: {'label': '{know}-3'}, 1: {'label': 'Do {know}-1'}}
# {you} a {try} {0: {'label': '{give}-2'}}
# {you} the new contactless {card} {0: {'label': 'have simply {received}-1'}}
# {you} the NFC {reader} {0: {'label': 'when {have}-1'}}
# {you} {Everything} {0: {'label': '{need}-139'}}
# {you} True Blue direct debit {card} {0: {'label': 'Have {linked} yet-2'}}
# {you} the {locale} set {0: {'label': 'Do {have}-1'}}
# {you} baes Apple {pay} {0: {'label': 'When {have}-1'}}
# {you} {banks} {0: {'label': '{switching}-1'}}
# {you} {us} {0: {'label': 'Would {like}-1'}}
# {you} {mobile} {0: {'label': 'Have ever {used} Is-1'}}
# {you} a {reader} {0: {'label': 'can {get}-2'}}
# {you} the apple {pay} {0: {'label': 'did {start} yet-1'}}
# {you} odd bpay _ {uk} {0: {'label': 'only {reply}-1'}}
# {you} an oyster {card} {0: {'label': 'either {need}-1'}}
# {you} {iMessages} {0: {'label': '{delete}-1'}}
# {you} 't support {ApplePay} {0: {'label': 'when {don}-1'}}
# {you} a {light} {0: {'label': 'when would {see}-1'}}
# {you} Apple {pay} {0: {'label': 'Will be {using}-1'}, 1: {'label': 'still {use}-1'}, 2: {'label': 'could {use}-1'}, 3: {'label': 'when will {support} don-1'}, 4: {'label': 'when will be {joining}-1'}, 5: {'label': 'be {supporting}-1'}, 6: {'label': '{see}-1'}, 7: {'label': '{use} ..-1'}, 8: {'label': 'when will be {accepting}-1'}}
# {you} {cash} {0: {'label': 'do {mean}-1'}}
# {you} {them} {0: {'label': '{embraced}-8'}, 1: {'label': 'could {collect}-1'}}
# {you} {toknow} {0: {'label': '{need}-3'}}
# {you} reward {points} {0: {'label': 'can {get}-4'}}
# {you} any {updates} {0: {'label': 'do {have}-1'}}
# {you} any {documentation} {0: {'label': '{find}-1'}}
# {you} {http} {0: {'label': '{think}-1'}}
# {you} {money} {0: {'label': 'to {load}-2'}, 1: {'label': 'now can {send}-1'}, 2: {'label': "'ll {send}-1"}}
# {you} own {devices} {0: {'label': 'to {use}-8'}}
# {you} this new Apple Pay {thing} {0: {'label': "'re {launching}-1"}}
# {you} an Apple {Pay} {0: {'label': '{have}-1'}}
# {you} {cashback} {0: {'label': 'when can {earn}-1'}}
# {you} {all} {0: {'label': '{need}-3'}}
# {you} payment card {PINs} {0: {'label': 'Have considered already {issuing}-1'}}
# {you} a quick {errand} {0: {'label': '{run}-2'}}
# {you} a dal voordeel {abonnement} {0: {'label': '{mean}-1'}}
# {you} 8 {reasons} {0: {'label': 'might {want}-2'}}
# {you} single {purchases} {0: {'label': '{allow}-1'}}
# {you} the {service} {0: {'label': 'Will {use}-2'}}
# {you} any {update} {0: {'label': 'Do {have}-1'}}
# {you} ONE {item} {0: {'label': 'to {buy}-1'}}
# {you} apple {pay} {0: {'label': 'do {support}-2'}, 1: {'label': '{use}-2'}, 2: {'label': 'could just {flick}-2'}, 3: {'label': 'Will {support}-2'}, 4: {'label': '{have}-2'}, 5: {'label': 'really {use}-1'}, 6: {'label': 'when {use}-1'}, 7: {'label': 'do {have}-1'}}
# {you} grocery {shopping} {0: {'label': 'whenever {go}-1'}}
# {you} {music} {0: {'label': '{buy}-1'}}
# {you} {credit} {0: {'label': 'to {store}-8'}}
# {you} {guys} {0: {'label': 'Basically now {got}-1'}}
# {you} a {discount} {0: {'label': 'actually can {get}-1'}}
# {you} an expensive {coffee} {0: {'label': '{buy}-1'}}
# {you} {card} {0: {'label': '{forget}-1'}}
# {you} a concrete release {date} {0: {'label': 'Do {have} yet-1'}}
# {you} Apple {Pay} {0: {'label': 'Where can {use}-3'}, 1: {'label': '{use}-2'}, 2: {'label': 'how did {use} How-2'}, 3: {'label': 'Do {take}-1'}, 4: {'label': 'Do {accept}-1'}, 5: {'label': 'will be {accepting}-1'}, 6: {'label': 'where can {use}-1'}, 7: {'label': 'Are {using}-1'}, 8: {'label': 'do not {get}-1'}, 9: {'label': 'Will {use}-1'}, 10: {'label': "why 't {support} yet-1"}, 11: {'label': 'would {support} ago-1'}, 12: {'label': "'re {supporting}-1"}, 13: {'label': 'When will {support}-1'}, 14: {'label': '{support}-1'}, 15: {'label': 'Will be {supporting}-1'}, 16: {'label': '{adopt}-1'}, 17: {'label': "now 're not {getting}-1"}, 18: {'label': 'when are {launching}-1'}, 19: {'label': 'Walks up do {accept}-1'}, 20: {'label': "'re not {supporting}-1"}, 21: {'label': 'Now can {use}-1'}, 22: {'label': 'when will be {supporting}-1'}, 23: {'label': 'when are {getting}-1'}, 24: {'label': 'how do {have}-1'}, 25: {'label': 'can {use}-1'}, 26: {'label': 'could {launch}-1'}}
# {you} {'t} {0: {'label': 'when {don}-8'}, 1: {'label': 'Why {shouldn}-5'}, 2: {'label': '{want}-1'}}
# {you} the {button} release {0: {'label': 'could just {press}-1'}}
# {you} contactless payment {card} {0: {'label': 'can {use}-1'}}
# {you} the last 4 {digits} birth {0: {'label': 'Can {follow}-1'}}
# {you} Integrate Google {Wallet} {0: {'label': 'how can {get}-1'}}
# {you} {wrist} check {0: {'label': 'could just {flick}-2'}}
# {you} the wrist {space} {0: {'label': "'ve {got}-4"}}
# {you} {me} {0: {'label': '{want}-2'}, 1: {'label': 'Can {tell} more-2'}, 2: {'label': '{saved} now-1'}, 3: {'label': 'Are {kidding} Exactly-1'}, 4: {'label': '{forwarded}-1'}, 5: {'label': 'Did {miss}-1'}}
# {you} additional {questions} {0: {'label': '{have}-1'}}
# {you} PhoneBank {team} {0: {'label': '{call}-1'}}
# {you} this {solution} {0: {'label': 'Are {using}-1'}}
# {you} a new {number} {0: {'label': 'yeah are {reissuing}-1'}}
# {you} {returns} {0: {'label': 'how {process}-1'}}
# {you} {5650} {0: {'label': '{call}-1'}}
# {you} a 25 wrist {band} {0: {'label': 'to {buy}-1'}}
# {you} {funds} {0: {'label': 'can {deposit} directly-1'}, 1: {'label': 'can {send} directly-1'}}
# {you} {the} {0: {'label': "'ve {got}-1"}}
# {you} {tickets} {0: {'label': 'when {collect}-1'}}
# {you} some {announcements} make {0: {'label': "'ve {got}-1"}}
# {you} {applepay} {0: {'label': 'should {consider}-1'}}
# {you} all 13 {videos} {0: {'label': '{want}-1'}}
# {you} a pizza {joint} {0: {'label': '{had}-1'}}
# {you} Google {Wallet} {0: {'label': 'Is still {take}-1'}, 1: {'label': '{use}-1'}, 2: {'label': 'can {use}-1'}}
# {you} some {attention} {0: {'label': 'can {get}-1'}}
# {you} the normal {transaction} {0: {'label': '{do}-1'}}
# {you} {ApplePay} {0: {'label': 'to {have}-3'}, 1: {'label': 'could be {using}-1'}, 2: {'label': 'can not {use}-1'}, 3: {'label': "where 've {used}-1"}, 4: {'label': 'will be {supporting}-1'}, 5: {'label': 'do {take}-1'}, 6: {'label': '{know}-1'}, 7: {'label': 'why {accept}-1'}, 8: {'label': '{want}-1'}, 9: {'label': 'could just {support}-1'}, 10: {'label': '{support}-1'}, 11: {'label': 'Have {used}-1'}, 12: {'label': 'Will be {supporting}-1'}, 13: {'label': '{get} sooner-1'}, 14: {'label': 'can {use}-1'}}
# {you} the {cost} {0: {'label': '{refund}-1'}}
# {you} a Disney Store {sign} {0: {'label': 'When {misread}-1'}}
# {you} {NFC} {0: {'label': '{advertise}-1'}}
# {you} {this} {0: {'label': 'then {need}-31'}, 1: {'label': 'actually {believe}-1'}, 2: {'label': '{drop}-1'}, 3: {'label': 'may have {answered} already-1'}, 4: {'label': 'Why are {doing}-1'}}
# {you} {Cmon} {0: {'label': 'must {know}-1'}}
# {you} {date} birth {0: {'label': 'Can {send}-1'}}
# {you} an {iPhone} 6 {0: {'label': '{have}-1'}}
# {you} {gt} {0: {'label': 'Will be {using}-1'}}
# {you} a launch {date} {0: {'label': 'do {have}-1'}}
# {you} mobile {payments} {0: {'label': 'when {accept}-1'}}
# {you} a {book} {0: {'label': "'re {find}-1"}}
# {you} {everything} {0: {'label': '{need}-25'}, 1: {'label': '{know}-1'}}
# {you} the {road} {0: {'label': '{pave}-1'}}
# {you} {surprises} {0: {'label': 'Also will {get}-1'}, 1: {'label': 'will {get}-1'}}
# {you} Apple Pays {UK} {0: {'label': 'anxiously {awaiting}-1'}}
# {you} the {card} {0: {'label': 'should {get}-1'}}
# {you} fill {Queenblossom01gmail} {0: {'label': 'will {get}-1'}}
# {you} an iOS point {release} {0: {'label': 'Will {need}-1'}}
# {you} a {time} {0: {'label': 'to {buy}-1'}}
# {you} {Brewers} {0: {'label': "'ve been {looking}-1"}}
# {you} the official {date} {0: {'label': '{know}-1'}}
# {you} an inferior {product} {0: {'label': '{BUY}-1'}}
# {you} country {settings} {0: {'label': '{have}-1'}}
# {you} {Cash} {0: {'label': 'Can {get}-1'}}
# {you} {stuff} {0: {'label': 'can {buy}-1'}}
# {you} {support} {0: {'label': 'will {have}-1'}}
# {you} the customer service {department} {0: {'label': 'when {close}-1'}}
# {you} {findom} {0: {'label': '{need}-1'}}
# {you} payment {card} {0: {'label': 'Did {change}-1'}, 1: {'label': '{do}-1'}}
# {you} ApplePay {AskLloydsBank} {0: {'label': 'When will be {launching}-1'}}
# {you} the last four {digits} card {0: {'label': 'Can {send}-1'}}
# {you} 6 letter booking {reference} {0: {'label': "'ll just {need}-1"}}
# {you} real {MVP} {0: {'label': '{da}-1'}}
# {you} a new {CEO} {0: {'label': '{need}-2'}}
# {you} {MasterCard} {0: {'label': "'re {using}-1"}}
# {you} favorite {artist} {0: {'label': 'should {find}-1'}}
# {you} a contactless {card} {0: {'label': 'to {send}-1'}}
# {you} an apple pay {notification} {0: {'label': '{sent}-1'}}
# {you} any {stores} {0: {'label': '{know}-1'}}
# {you} a {quiz} {0: {'label': 'Then how do {fail}-1'}}
# {you} the {rest} us {0: {'label': 'when will be {joining}-1'}}
# {you} the wrist space {Tech} {0: {'label': "'ve {got}-1"}}
# {you} {whatever} {0: {'label': 'will {use}-1'}}
# {you} the {payment} {0: {'label': 'to {authorise}-1'}}
# {you} {What} {0: {'label': 'do {think}-2'}, 1: {'label': 'are {doing}-1'}, 2: {'label': 'should {know}-1'}}
# {you} a {way} transfer {0: {'label': '{have}-1'}}
# {you} {regions} {0: {'label': '{switch}-1'}}
# {you} a credit card {number} {0: {'label': 'when {cancel}-8'}}
# {you} _ _ {TuhhYouWishHoe} {0: {'label': '{get}-1'}}
# {you} Google {wallet} {0: {'label': '{accept}-1'}, 1: {'label': 'do {accept} only-1'}, 2: {'label': '{use}-1'}}
# {you} google {wallet} {0: {'label': '{use} Also how-1'}, 1: {'label': 'can {fill} up up-1'}, 2: {'label': 'maybe could {try}-1'}, 3: {'label': '{accept}-1'}}
# {you} {America} {0: {'label': '{love}-1'}}
# {you} a {selfie} {0: {'label': 'to {take}-2'}}
# {you} whipped {cream} {0: {'label': '{like}-1'}}
# {you} whole {trip} using {0: {'label': 'can {book}-1'}}
# {you} {more} 2 {0: {'label': '{spend}-1'}}
# {you} {Barclays} {0: {'label': '{mean}-1'}}
# {you} {phone} {0: {'label': '{use}-1'}}
# {you} stminfo {fares} {0: {'label': 'to {load}-2'}}
# {you} a free everyday banking {account} {0: {'label': 'Do {offer}-1'}}
# {you} {it} {0: {'label': 'have {used}-5'}, 1: {'label': 'Will be {using}-5'}, 2: {'label': 'Just {have}-4'}, 3: {'label': 'where can {use}-3'}, 4: {'label': '{missed}-2'}, 5: {'label': 'soon will {see} here first Then-2'}, 6: {'label': '{take}-1'}, 7: {'label': 'can {access}-1'}, 8: {'label': '{use}-1'}, 9: {'label': 'Now can {use}-1'}, 10: {'label': 'could {use} ..-1'}, 11: {'label': 'will be {using}-1'}, 12: {'label': 'will {use}-1'}, 13: {'label': 'Would {use}-1'}, 14: {'label': '{missed} here-1'}, 15: {'label': 'must {know}-1'}, 16: {'label': 'can {purchase}-1'}, 17: {'label': '{supporting}-1'}, 18: {'label': '{getting}-1'}, 19: {'label': '{own}-1'}}
# {you} a {date} {0: {'label': 'Do {have}-1'}, 1: {'label': 'do {have}-1'}}
# {you} an Apple Pay {update} {0: {'label': 'do {have}-1'}}
# {you} yer {money} {0: {'label': 'can {get} out-1'}}
# {you} {mpayments} {0: {'label': '{expected}-1'}}
# {you} {Passbook} {0: {'label': 'Did {mean}-1'}}
# {you} contactless {payments} {0: {'label': 'were {rolling} out-1'}}
# {you} the {use} debit {0: {'label': '{govern}-1'}}
# {you} credit {card} {0: {'label': '{link}-1'}}
# {you} {customers} {0: {'label': 'are {loosing}-1'}}
# {you} {needs} {0: {'label': 'really {understand}-1'}}
# {you} {snapchat} {0: {'label': 'can {get}-1'}}
# {you} Wallet {card} {0: {'label': '{using}-2'}}
# {you} the {fold} {0: {'label': 'never {leave}-1'}}
# {you} a different {way} {0: {'label': "'re {going}-1"}}
# {you} {All} {0: {'label': '{had}-1'}, 1: {'label': '{need}-1'}}
# {you} account beecause payment {card} {0: {'label': 'have {suspended}-2'}}
# {you} DTH {recharges} {0: {'label': 'can also {do}-1'}}
# {you} a Contactless {card} {0: {'label': 'should {receive}-1'}}
# {you} an {ETA} {0: {'label': 'do {have}-1'}}
# {you} {someone} wielding {0: {'label': 'Can {imagine}-1'}}
# {you} {tweets} {0: {'label': '{see}-3'}}
# {you} this {petition} {0: {'label': 'Can {please}-485'}}
# {you} 40 {cents} {0: {'label': '{have}-2'}}
# {you} card {info} {0: {'label': '{put}-1'}}
# {you} {someone} {0: {'label': 'can {walk}-1'}}
# {you} the branded payment {card} {0: {'label': '{bring} up-1'}}
# {you} {_} {0: {'label': '{send}-14'}, 1: {'label': '{have}-1'}, 2: {'label': '{forgot}-1'}, 3: {'label': 'how {disclose}-1'}}
# {you} {anybody} {0: {'label': '{know}-3'}}
# {you} a {store} {0: {'label': 'When {realize}-2'}}
# {you} {amp} {0: {'label': 'where can {tap}-1'}}
# {you} {Zip} {0: {'label': "'d {discover}-1"}}
# {you} the {security} {0: {'label': '{trust}-41'}}
# {you} a digital {wallet} {0: {'label': 'Are {adopting}-2'}, 1: {'label': 'Do {have}-1'}}
# {you} a {microchip} {0: {'label': '{put}-1'}}
# {you} {rock} {0: {'label': '{guys}-5'}}
# {you} {purchases} {0: {'label': 'to {make}-1'}}
# {you} {payment} {0: {'label': 'Can {accept} also-1'}}
# {you} latest {blog} {0: {'label': '{missed}-1'}}
# {you} chip {cards} {0: {'label': 'when will {issue}-1'}}
# {you} a {world} {0: {'label': '{imagine}-1'}}
# {you} {theres} {0: {'label': 'can {buy}-1'}}
# {you} an apple {watch} {0: {'label': 'have {bought} yet-1'}}
# {you} any {integrations} {0: {'label': 'Do {offer}-1'}}
# {you} {war} {0: {'label': "'ve already {lost}-2"}}
# {you} a {giftrocket} {0: {'label': 'can {send}-1'}}
# {you} 1/2 ^ {JL} {0: {'label': '{bank}-1'}}
# {you} not {something} {0: {'label': '{plan} overnight-1'}}
# {you} another payment {card} {0: {'label': 'do {have}-1'}}
# {you} a free everyday bank {account} {0: {'label': '{offer}-1'}}
# {you} a radio {show} {0: {'label': '{missed}-1'}}
# {you} this new {service} {0: {'label': 'Will {use}-1'}}
# {you} Apple Pay all other {banks} {0: {'label': 'be {supporting}-1'}}
# {you} a $ OPUS card {reader} {0: {'label': 'only {buy}-1'}}
# {you} any {idea} go {0: {'label': 'Do {have}-1'}}
# {you} {something} {0: {'label': 'would {do} again-1'}, 1: {'label': 'when {buy}-1'}}
# {you} a new gas payment {card} {0: {'label': '{send} out-1'}}
# {you} PayPal {card} {0: {'label': 'only {add}-1'}}
# {you} any {clue} {0: {'label': 'do {have}-1'}}
# {you} {what} {0: {'label': '{think}-2'}, 1: {'label': '{get}-2'}, 2: {'label': '{love}-2'}, 3: {'label': 'may have {read}-1'}, 4: {'label': '{do}-1'}, 5: {'label': "'re {trying}-1"}, 6: {'label': "'ve {done}-1"}}
# {you} {wallet} {0: {'label': 'when {leave}-1'}, 1: {'label': 'Will be {dumping}-1'}, 2: {'label': '{lost}-1'}, 3: {'label': '{forget}-1'}}
# {you} the {details} issue {0: {'label': '{email}-1'}}
# {you} {wow} {0: {'label': '{go}-1'}, 1: {'label': "'d {think}-1"}}
# {you} the {end} " {0: {'label': '{missed}-1'}}
# {you} a modern {POS} {0: {'label': '{wanted}-1'}}
# {you} {one} {0: {'label': '{have}-1'}}
# {you} contactless {card} {0: {'label': 'once {activate}-1'}}
# {you} {18} {0: {'label': 'when do {hit}-1'}}
# {you} some other NFC {technology} {0: {'label': 'Have {used}-1'}}
# {you} {Whatever} {0: {'label': 'snapcash {got}-1'}}
# {you} this {rubbish} {0: {'label': 'bit when {switch} off when how-1'}, 1: {'label': 'when {switch} off-1'}}
# {you} an {easy} {0: {'label': 'Here {have}-1'}}
# {you} a {cell} {0: {'label': '{have}-31'}}
# {you} security {checks} {0: {'label': 'are {conducting}-1'}}
# {you} {confirmation} {0: {'label': "'ll {receive}-1"}}
# {you} {Thanks} {0: {'label': 'Now can {use}-1'}}
# {you} {vote} go {0: {'label': '{want}-2'}}
# {you} a good {experience} {0: {'label': '{had}-1'}}
# {you} {advantage} developing {0: {'label': 'Are {taking}-1'}}
# {you} digital {wallet} {0: {'label': 'when {use}-1'}, 1: {'label': 'could {replace}-1'}}
# {you} a exact {date} {0: {'label': 'Do {have}-1'}}
# {you} the {devil} {0: {'label': 'just {walking} around-1'}}
# First West Credit {Union} the Dashband CU {Insight} {0: {'label': '{has}-1'}}
# First West Credit {Union} the {Dashband} {0: {'label': '{has}-1'}}
# {AskLloydsBank} a contactless {card} {0: {'label': 'Why do never {send}-1'}}
# any {news} contactless {payments} {0: {'label': 'will {accept}-1'}}
# Leaked Waitrose {memo} imminent release {date} {0: {'label': '{reveals}-2'}}
# A {guy} this {petition} get {0: {'label': 'is {doing}-1'}}
# Novo recurso {pode} a {tran} {0: {'label': '{permitir}-2'}}
# Novo recurso {pode} a {transfer} {0: {'label': '{permitir}-9'}}
# {They} {July} bad {0: {'label': 'do {say}-1'}}
# {They} {that} {0: {'label': "'re {changing}-1"}}
# {They} no {plans} support {0: {'label': '{have}-1'}}
# {They} a really good Apple {Watch} {0: {'label': 'are {developing}-1'}}
# {They} {everything} {0: {'label': '{have}-1'}}
# {They} no {innovation} {0: {'label': '{have}-1'}}
# {They} not secure {enuf} {0: {'label': '{say}-1'}}
# {They} none standard {bPay} {0: {'label': '{want}-1'}}
# {Payments} financial {information} {0: {'label': 'will {handle}-1'}}
# a {bank} apple {pay} {0: {'label': '{supports}-3'}}
# a {bank} Apple {Pay} {0: {'label': '{accepts}-1'}, 1: {'label': '{supports}-1'}}
# a {bank} {applepay} {0: {'label': 'does {support}-1'}}
# a {bank} {ApplePay} {0: {'label': '{supports}-1'}}
# a {bank} {itself} {0: {'label': '{promotes}-1'}}
# Google {Payments} financial {information} {0: {'label': 'will {handle}-5'}}
# Google {Payments} financial {info} {0: {'label': 'will {handle}-1'}}
# QR {Codes} Apple {Pay} {0: {'label': '{Smashes}-2'}}
# doesn 't {matter} Apple {Pay} {0: {'label': "now 're not {getting}-1"}}
# {that} some {hands} {0: {'label': "'d definitely {free} up-1"}}
# {that} {You} {0: {'label': '{Allows}-1'}}
# {that} mobile payment {apps} {0: {'label': 'could {kill} off-2'}}
# {that} {What} {0: {'label': 'Will {work}-1'}}
# {that} * {hugs} * {0: {'label': '{sucks}-1'}}
# {that} mobile {payment} {0: {'label': 'are {creating}-2'}}
# {partners} {Apple} {0: {'label': 'Were {love}-2'}}
# PIN contactless transaction {limit} {_} {0: {'label': 'does {apply}-1'}}
# Apple Watch {UI} the Apple Pay high {ground} {0: {'label': 'has {gained}-1'}}
# mobile payment {technology} {Fingerprint} {0: {'label': '{means}-34'}}
# The Bilderberg Cashless Society {Proposal} Cashless Payment {System} {0: {'label': '{Supported}-1'}}
# {Hares} {6} {0: {'label': '{sz}-12'}}
# {online} Apple Pay {wil} {0: {'label': '{suggests}-1'}}
# {online} {A...} {0: {'label': '{suggests}-1'}}
# {Woo} One {way} {0: {'label': 'now {has}-1'}}
# {Woo} Apple {Pay} {0: {'label': 'now {has}-1'}}
# {McDonald} KFC {teams} {0: {'label': '{ordering}-1'}}
# {McDonald} pilot {program} {0: {'label': '{ordering}-1'}}
# {McDonald} mobile {payment} {0: {'label': 'to {start}-36'}}
# Hershey {Park} Possible Payment Card {Breach} {0: {'label': '{Investigating}-3'}}
# {Anybody} Google {wallet} {0: {'label': '{have}-2'}}
# {Yay} {it} {0: {'label': '{love} too forward-1'}}
# Heres Why {Barclays} Apple {Pay} {0: {'label': 'Is {Delaying}-2'}}
# this Apple Pay UK {bs} {everyone} {0: {'label': 'Where {chill}-1'}}
# {Waitrose} Apple {Pay} _ {0: {'label': 'is {getting}-1'}}
# {Waitrose} the {beans} {0: {'label': '{spills}-1'}}
# Marty McFly didn {'t} {this} coming {0: {'label': '{see}-1'}}
# E {Wallets} {banks} {0: {'label': 'are {pushing}-1'}}
# {LancParkAuth} mobile payment {option} {0: {'label': 'to {offer}-1'}}
# Latest TUAW News Apple {Pay} the {UK} {0: {'label': 'reportedly {reaches}-1'}}
# {Experts} huge mobile payment adoption {wave} {0: {'label': '{predict}-2'}}
# the {offer} Google {Wallet} {0: {'label': 'Is still {take}-1'}}
# AskNationwide haven {'t} a contactless debit {card} {0: {'label': '{given}-1'}}
# the new iOS {update} Apple {Pay} {0: {'label': '{took} off-5'}}
# Hope Santander don {'t} {applepayuk} {0: {'label': '{disable}-1'}}
# Nigerias Access {Bank} the {envelope} {0: {'label': 'is {pushing}-5'}}
# {yesterday} a {yank} {0: {'label': '{try}-1'}}
# TUAW Apple {Pay} the {UK} {0: {'label': 'reportedly {reaches}-1'}}
# 90 {%} readers the same default {passcode} {0: {'label': '{use}-2'}}
# UK bank {Barclays} Apple {Pay} {0: {'label': '{delays}-6'}}
# $ google {wallet} {$} 15 {0: {'label': '{end}-1'}}
# {skrill} {yourself} {0: {'label': '{give}-1'}}
# Apple Pay {UK} live {14} {0: {'label': '{go}-1'}}
# Apple Pay {UK} A Launch {Date} {0: {'label': '{Gets}-10'}}
# Apple Pay {UK} {_} {0: {'label': '{launch}-8'}}
# {Oyster} tube {congestion} {0: {'label': '{affects}-1'}}
# barclaycard bpay _ uk utter utter {rubbish} the {battle} {0: {'label': "'ve {lost}-1"}}
# connected {car} {programs} {0: {'label': '{rewards}-1'}}
# Apples latest patent {filing} {person} {0: {'label': '{reveals}-8'}}
# the {way} the {rest} us {0: {'label': 'will {take}-3'}}
# the {way} {Visa} {0: {'label': '{says}-1'}}
# {eBay} mobile payment {apps} {0: {'label': 'Just when off could {kill} off-5'}}
# Gas {pumps} Apple {Pay} {0: {'label': '{need}-1'}}
# 1 {year} bPay {devices} {0: {'label': '{withdraws}-2'}}
# {entry} ApplePay these {numbers} {0: {'label': 'how will {affect}-1'}}
# nog {toegang} {OV} {0: {'label': '{met}-2'}}
# {BlackBerry} Mobile Payment {Capabilities} {0: {'label': '{Enhances}-1'}}
# {BlackBerry} {Indonesia} {0: {'label': 'Why {prioritises}-4'}}
# Apple Pay {U.K.} {July14th} {0: {'label': 'to {launch}-2'}}
# a {point} {sense} {0: {'label': 'back so {makes}-1'}}
# 13 {%} owners a mobile {wallet} {0: {'label': '{have}-1'}}
# {HSE} {me} {0: {'label': '{tells}-1'}}
# Starbucks doesn {'t} {ApplePay} {0: {'label': '{take}-1'}}
# {business} {these} {0: {'label': 'Does {accept}-2'}}
# u {gotta} {it} {0: {'label': '{use}-1'}}
# u {gotta} the {shit} {0: {'label': '{use}-1'}}
# Mobile {wallet} {R1m} {0: {'label': '{wins}-4'}}
# Google Wallet {support} {me} {0: {'label': '{directed}-1'}}
# every {time} {you} {0: {'label': 'vibrate {tweet}-1'}}
# iPhone 6s Logic {Board} 16GB Base {Model} {0: {'label': '{Suggests}-1'}}
# New payment {service} launched 100 new local {jobs} {0: {'label': 'also {creating}-1'}}
# {she} {you} {0: {'label': 'will {spoil} back-3'}}
# {she} {60} {0: {'label': '{paid}-1'}}
# {she} no {idea} {0: {'label': '{had}-1'}}
# Korean credit card firm Samsung {Card} beta {testers} {0: {'label': 'is {recruiting}-2'}}
# smartphone {payments} payment {card} {0: {'label': 'will {replace}-2'}}
# {homedepot} {customers} {0: {'label': 'will {respect}-2'}}
# a drive thru staff member {Duncraig} {card} {0: {'label': 'just {take}-1'}}
# a bpay _ uk {wearable} {integration} {0: {'label': '{want}-1'}}
# {Tanner} {Hey} {0: {'label': '{say} "-1'}}
# Payment {security} a {revolution} {0: {'label': 'is {undergoing}-1'}}
# 5 Ways Mobile {Wallet} The {Way} {0: {'label': 'Can {Change}-1'}}
# {hi} {you} {0: {'label': 'can {please}-79'}}
# " Spin {Games} Sightline mobile payment {solution} {0: {'label': 'to {integrate} "-1'}}
# AppleWatch {Watch} {http} {0: {'label': 'Why {tells}-1'}}
# {'Ali} {9.0'} {0: {'label': '{pay}-1'}}
# didn {'t} {money} {0: {'label': '{have}-1'}}
# didn {'t} {it} {0: {'label': '{make}-1'}}
# didn {'t} {wallet} {0: {'label': '{need}-1'}}
# {PMSL} {these} {0: {'label': 'will {BUY}-1'}}
# Three San Diego {hotels} a payment {card} {0: {'label': 'have {identified}-2'}}
# Three San Diego {hotels} a payment card security {breach} {0: {'label': 'have {identified}-1'}}
# {Everything} {toknow} {0: {'label': '{need}-3'}}
# {Everything} {ApplePay} {0: {'label': 'is {coming} up-1'}}
# {Everything} nytvideo {shares} {0: {'label': 'is {coming} up-1'}}
# Barclays ain {'t} Apple {Pay} {0: {'label': '{supporting}-1'}}
# {Mastercard} {payment} {0: {'label': 'are now {testing}-1'}}
# {Mastercard} ApplePay private {label} {0: {'label': 'how is {enabling}-6'}}
# {suretapwallet} mobile wallet {apps} {0: {'label': '{upgraded}-1'}}
# " selfies " {initiative} payment card {fraud} {0: {'label': '{reduce}-4'}}
# contactless card doesn {'t} two {people} {0: {'label': '{cover}-1'}}
# some {folks} {that} {0: {'label': 'greatly {prefer}-1'}}
# {Walgreens} Apple {Pay} {0: {'label': 'however happily {accepts}-1'}}
# GLOBAL PAYMENT CARD {GDV} {$} 3533B {0: {'label': 'to {post}-1'}}
# The {UK} {diary} {0: {'label': '{marks}-2'}}
# The {UK} {Europe} {0: {'label': 'is {leading}-1'}}
# Samsung {Pay} NFC {World} {0: {'label': '{enters}-3'}}
# Samsung {Pay} beta {testing} {0: {'label': '{enters}-9'}}
# Samsung {Pay} an early {lead} {0: {'label': 'Why could {gain}-58'}, 1: {'label': 'could {gain}-1'}}
# Samsung {Pay} {teams} {0: {'label': '{enters}-1'}}
# Samsung {Pay} some interesting technical {features} {0: {'label': 'does {have}-1'}}
# Samsung {Pay} {_} {0: {'label': 'to {address}-1'}}
# Samsung {Pay} final {testing} {0: {'label': '{enters}-26'}}
# Samsung {Pay} final testing {rounds} {0: {'label': '{enters}-23'}}
# Samsung {Pay} {ANDROIDNEWS} {0: {'label': 'to {address}-1'}}
# Samsung {Pay} live beta {testing} {0: {'label': '{enters}-4'}}
# ValueCard {Partnership} Mobile Payment {Solutions} {0: {'label': '{Brings}-1'}}
# {Pingit} the ApplePay {Wave} {0: {'label': '{Survive}-2'}}
# {Pingit} the " ApplePay " {Wave} {0: {'label': '{Survive}-1'}}
# {Pingit} the " Apple Pay " {Wave} {0: {'label': '{Survive}-3'}}
# iPhone {Plus} {compensation} {0: {'label': '{explodes}-30'}}
# 76 {%} 't {it.} {0: {'label': '{use}-1'}}
# {everyone} Apple Pay Cul de {sac} {0: {'label': 'will {use}-1'}}
# {everyone} {banks} {0: {'label': 'Yes will {switch}-1'}}
# {everyone} Apple {Pay} {0: {'label': 'else {use}-1'}}
# {everyone} {ApplePay} {0: {'label': 'when {does}-1'}}
# {everyone} {What} {0: {'label': 'does {think}-1'}}
# {everyone} {apple} {0: {'label': '{has}-1'}}
# {everyone} applepay _ Mr. {Pocket} {0: {'label': '{takes}-1'}}
# {everyone} the {money} {0: {'label': 'not {has}-1'}}
# the {public} {c.} {0: {'label': 'to {understand}-1'}}
# new {feature} mobile payment {apps} {0: {'label': 'could {kill} off-1'}}
# new {patent} mobile payment {apps} {0: {'label': 'could {kill} off-1'}}
# new {patent} NFC {use} {0: {'label': 'to {expand}-1'}}
# {date} Apple Pay {launch} sure {0: {'label': '{does}-1'}}
# {date} {What} {0: {'label': 'is {pay} out-1'}}
# Google wallet {tributes} a special {reward} {0: {'label': 'might {get}-1'}}
# {munnii} the first {Bitcoin} {0: {'label': '{created}-1'}}
# A leaked {memo} {online} {0: {'label': 'has {surfaced}-6'}}
# 100 {signatures} Apple {Pay} {0: {'label': 'not {supporting}-2'}}
# the bPay _ UK {sticker} a sticky {residue} {0: {'label': 'will {leave}-1'}}
# {banks} {consortium} deal {0: {'label': '{form}-1'}}
# {banks} {deals} {0: {'label': '{sign}-1'}}
# {banks} apple {pay} {0: {'label': 'all {support}-1'}}
# {banks} Apple {Pay} {0: {'label': '{add}-8'}, 1: {'label': '{support}-1'}}
# {banks} {ApplePay} {0: {'label': '{blame}-1'}, 1: {'label': '{offering}-1'}}
# {banks} Apple Pay {Apple} {0: {'label': '{add}-2'}}
# {banks} Apple Pay NFC {World} {0: {'label': '{add}-2'}}
# Your {Time} {"} {0: {'label': 'has {Come}-1'}}
# Your {Time} {I} {0: {'label': 'has {Come}-1'}}
# First {Direct} no Apple {Pay} {0: {'label': '{confirming}-3'}}
# Doesn 't {ApplePay} this {kind} unnecessary {0: {'label': '{make}-1'}}
# technology Apple {Pay} {t} {0: {'label': '{tipped}-1'}}
# Every grocery {store} a {lot} influence {0: {'label': '{have}-1'}}
# Mobile wallet {operators} small {trades} generating {0: {'label': '{eye}-1'}}
# {us} {tonight} {0: {'label': '{get}-1'}}
# {us} {interest} {0: {'label': '{know}-1'}}
# {us} {_} {0: {'label': 'soon {ba}-2'}}
# {us} clunky ugly {bpay} {0: {'label': 'to {use}-2'}}
# {us} 15$ + {tx} {0: {'label': 'to {pay}-1'}}
# Apple {Inc.} No Payment {Cap} {0: {'label': '{Confirms}-1'}}
# Apple {Inc.} 20+ More {Banks} {0: {'label': '{Adds}-9'}}
# Petition {Barclays} Apple {Pay} {0: {'label': 'to {support}-1'}}
# any {news} regarding the {UK} {0: {'label': 'will {hit}-1'}}
# {MBNA} Apple {Pay} {0: {'label': '{getting} kinda-1'}}
# {MBNA} Apple Pay {page} {0: {'label': 'has {launched}-2'}}
# {Cale} the parking payment {industry} {0: {'label': '{shifts}-2'}}
# {Humanity} {ApplePay} {0: {'label': 'now {has}-2'}}
# {Grocers} Apple {Pay} {0: {'label': '{gobble} up-2'}}
# {iphone} the secret {_} {0: {'label': 'would up .. {found}-1'}}
# dm u cause u {didnt} {me.} {0: {'label': '{follow}-1'}}
# Nuovi Gadget Apple {Pay} the {UK} {0: {'label': 'reportedly {reaches}-1'}}
# {Retailers} nation {note} {0: {'label': '{take}-1'}}
# The Citadele {Bank} innovative payment {card} {0: {'label': 'is {offering}-1'}}
# that {mag} online {banking} {0: {'label': '{protected}-1'}}
# {AskNationwide} an {email} saying {0: {'label': 'have {sent}-1'}}
# {AskNationwide} {ApplePay} {0: {'label': 'are {introducing}-1'}}
# {AskNationwide} the UK {way} {0: {'label': 'are {leading}-1'}}
# Stupid {decision} Apple {Pay} {0: {'label': 'not to {support}-2'}}
# Mobile Payment {Index} record {growth} {0: {'label': '{exhibits}-1'}}
# Apple {pay} thru {clutch} {0: {'label': '{came} again always-1'}}
# Apple {pay} good {tbh} {0: {'label': '{looks}-1'}}
# Apple {pay} {lol} {0: {'label': '{came} again always-1'}}
# Apple {pay} live 14th {July} {0: {'label': '{goes}-1'}}
# Apple {pay} the {uk} {0: {'label': 'reportedly {reaches}-1'}}
# Apple {pay} {it} {0: {'label': 'too {find}-1'}}
# Apple {pay} a {matter} weeks {0: {'label': 'when is {launching} in-1'}}
# Apple {pay} One {week} {0: {'label': '{comes} out-1'}}
# Apple {pay} {Whatever} {0: {'label': 'snapcash {got}-1'}}
# Apple {pay} a software {update} {0: {'label': 'why {requires}-1'}}
# {id} barclay {credit} {0: {'label': 'yeah {use}-1'}}
# Will Credit Card {Companies} The {Benefits} Market {0: {'label': '{Reap}-5'}}
# {Reports} {launch} {0: {'label': '{suggest}-1'}}
# mobile wallet text marketing {feature} live audience {participation} {0: {'label': 'can {engage}-1'}}
# {mix} next level profit {margins} {0: {'label': 'might have just {unlocked}-1'}}
# {BradHeat} {me} {0: {'label': '{introduced}-1'}}
# Denis {Ill} {bank} {0: {'label': 'be {evaluating} soon-1'}}
# {U} the {memo} {0: {'label': '{get}-1'}}
# more {businesses} Apple {Pay} {0: {'label': '{supported}-1'}}
# {them} {their} {0: {'label': '{complete}-1'}}
# {them} apple {pay} {0: {'label': 'to {adopt}-1'}}
# {them} {more} {0: {'label': '{spend}-1'}}
# {them} {it} {0: {'label': '{phase} out-1'}}
# Jawbone UP4 fitness {tracker} contactless {payments} {0: {'label': '{gets}-35'}}
# Jawbone UP4 fitness {tracker} contactless {payments} take {0: {'label': '{gets}-49'}}
# The U.S. {Saw} {sense} {0: {'label': 'back so {makes}-1'}}
# the {experts} {What} {0: {'label': 'do {make}-1'}}
# {Australia} Apple {Pay} {0: {'label': 'when will {get}-1'}, 1: {'label': '{deserves} more-1'}}
# {Australia} 20+ {transactions} {0: {'label': '{expected}-1'}}
# {mcuban} {them} {0: {'label': '{puts}-1'}}
# {2} {4} {0: {'label': '{give} back-1'}}
# {2} Touch {ID} {0: {'label': '{get}-1'}}
# {Dinner} {$} 45 {0: {'label': '{send}-2'}}
# Facebook Messenger {payments} {ApplePay} {0: {'label': '{challenge}-5'}}
# {wearables} mobile {payment} {0: {'label': 'will {facilitate}-1'}}
# {deals} {website} {0: {'label': '{Visit}-1'}}
# {BECU} Apple {Pay} {0: {'label': 'Does {support}-1'}}
# Matt {Stringer} Wearhouse the Mobile {Wallet} {0: {'label': '{Discusses}-7'}}
# {LovelyCorrine} {Airbitz} {0: {'label': 'only {recommends}-3'}}
# {Android} google {wallet} {0: {'label': '{has}-1'}}
# This New Apple Wallet Patent Means {Brands} Mobile Wallet {Marketing} {0: {'label': 'Why Can Longer {Ignore}-3'}}
# hotel {chain} a payment {card} {0: {'label': 'has {suffered}-1'}}
# digital {journey} Apple {Pay} {0: {'label': '{include} though-1'}}
# the Google Wallet Merchant {Center} email {address} {0: {'label': 'seemingly longer {displays}-1'}}
# AMEX CEO Ken Chenault Talks {Bitcoin} {much} {0: {'label': '{know}-1'}}
# CTO Carlos {Morgado} {http} {0: {'label': 'Why {tells}-1'}}
# {it.} this {space} {0: {'label': '{Watch}-2'}}
# {it.} {Thanks} {0: {'label': '{Watch}-1'}}
# isn {'t} Apple {Pay} {0: {'label': 'still {using}-1'}}
# Apple {staff} {nothing} {0: {'label': 'here {know}-1'}}
# {digitalspy} the {details} {0: {'label': '{gives}-1'}}
# {Amex} {Express} {0: {'label': 'just {launched}-2'}}
# {Amex} new mobile {pay} {0: {'label': '{hopes}-1'}}
# {Amex} fast digital {checkouts} {0: {'label': '{launches}-54'}}
# {Amex} Apple {pay} {0: {'label': '{supports}-1'}}
# {Amex} new mobile {payments} {0: {'label': '{hopes}-4'}}
# {Amex} new mobile {payment} {0: {'label': '{hopes}-2'}}
# {Amex} new {mobile} {0: {'label': '{hopes}-1'}}
# {Amex} payments {sys} {0: {'label': '{hopes}-2'}}
# {Amex} new mobile {pa.} {0: {'label': '{hopes}-1'}}
# {Amex} {sys} {0: {'label': '{hopes}-4'}}
# " {Canadians} Greater Customer {Experience} {0: {'label': '{Seek}-1'}}
# {FirehouseSubs} {ApplePay} {0: {'label': '{accepts}-1'}}
# {One} banks Apple {Pay} {0: {'label': 'has {snubbed}-2'}}
# NFCWorld News {Koreans} Apple Pay {talks} {0: {'label': '{claim}-2'}}
# {ACH} a Digital {Wallet} {0: {'label': '{Have}-1'}}
# based {Nearex} mobile {payment} {0: {'label': '{brings}-4'}}
# stupid {pigs} {you} {0: {'label': 'better {start}-1'}}
# {much} {you} {0: {'label': 'how do {pay}-1'}}
# {much} {LADBible} {0: {'label': 'do {pay}-1'}}
# {much} {apple} {0: {'label': 'how do {pay}-1'}, 1: {'label': 'do {pay}-1'}}
# thanks {Dev} {some} confusion {0: {'label': '{clears} up-1'}}
# {money} _ _ _ Google {wallet} {0: {'label': '{looks} better-1'}}
# " {woah} all {fancy} {0: {'label': '{getting}-1'}}
# {Canada} Apple {Pay} {0: {'label': '{get}-2'}}
# a senior {citizen} Apple {Pay} {0: {'label': '{use}-1'}}
# Leaked {documents} UK release {date} {0: {'label': '{reveal}-10'}}
# Deze {week} chipkaart accepteert maar wel {strippenkaarten} {0: {'label': '{die}-1'}}
# {Data} {Vi.} {0: {'label': '{shows}-2'}}
# Londoners {auto} contactless {payments} net {0: {'label': '{donate} 30,000-1'}}
# {AllyBank} an ATM fee reimbursement {limit} {0: {'label': 'oh {announced}-3'}}
# iPhone payments {service} set imminent {release} {0: {'label': '{reveals}-1'}}
# Leading mobile wallet {MobiKwik} {hands} {0: {'label': '{joins}-14'}}
# {i} a {card} {0: {'label': 'can {imply}-1'}}
# {i} {it} more {0: {'label': 'will {adopt}-2'}}
# {i} Apple {pay} {0: {'label': '{got}-1'}}
# {i} {it.} {0: {'label': '{love}-3'}, 1: {'label': 'when {get}-1'}}
# {i} {money} {0: {'label': 'barely {have}-1'}}
# {i} {all} {0: {'label': '{want}-2'}}
# {i} contactless {card} work {0: {'label': 'could never {get}-1'}}
# {i} apple {pay} {0: {'label': '{love}-1'}, 1: {'label': 'just {used}-1'}}
# {i} {girls} {0: {'label': '{see}-1'}}
# {i} * {card} {0: {'label': '{forget}-1'}}
# {i} {address} {0: {'label': '{changed}-1'}}
# {i} {her} {0: {'label': '{asked}-1'}}
# {i} {applepay} {0: {'label': 'really {want}-1'}}
# {i} {naprawd} {0: {'label': '{dziaa}-1'}}
# {i} apple {pay} buy {0: {'label': 'at {have}-1'}}
# {i} a contactless {card} {0: {'label': 'Only would {get}-1'}}
# {i} {settings} {0: {'label': '{changed}-2'}}
# {i} Google {wallet} {0: {'label': 'Apparently {have}-1'}}
# {i} {it} {0: {'label': '{want}-1'}, 1: {'label': 'when do {lol}-1'}}
# {i} {ahh} {0: {'label': '{see} well-1'}}
# {i} {u} {0: {'label': '{followed}-1'}}
# {i} an {iphone} 6 purely {0: {'label': '{need}-2'}}
# {i} the {person} {0: {'label': '{spoke}-1'}}
# {i} the payment {card} {0: {'label': '{bring} so can-2'}}
# doesn 't Pollo {Tropical} Apple {pay} {0: {'label': 'Why {take}-1'}}
# Mobile Wallet {Users} {Cash} {0: {'label': '{Get}-4'}}
# {Apples} {July} 14 {0: {'label': '{lands}-1'}}
# ApplePay isn 't {P2P} {it} {0: {'label': 'will {love}-1'}}
# No house building {program} Apple pay {taxes} {0: {'label': '{likes}-4'}}
# a new {patent} {people} send {0: {'label': 'would {allow}-1'}}
# UK release {date} {online} {0: {'label': '{LEAKED}-1'}}
# UK release {date} Apple Pay {expectation} high {0: {'label': '{revealed}-2'}}
# James {Bond} Apple {Pay} {0: {'label': '{using}-1'}}
# AAPL Another 23 financial {institutions} {support} {0: {'label': '{add}-1'}}
# Credit {Union} ApplePay {way} {0: {'label': '{having}-1'}}
# haven {'t} {http} {0: {'label': '{had}-1'}}
# haven {'t} Apple {Pay} {0: {'label': '{used} once-1'}}
# haven {'t} replacement {card} {0: {'label': '{received}-5'}}
# haven {'t} payment {card} {0: {'label': '{received} yet-1'}}
# {Ugh} the insecure mobile {payment} {0: {'label': 'seriously {has}-1'}}
# {yall} Apple {pay} {0: {'label': 'Have {used} yet-1'}}
# {yall} Apple {Pay} {0: {'label': 'Do {use}-1'}}
# {yall} {Apple} {0: {'label': 'Do {use}-1'}}
# {Help} Apple {Pay} {0: {'label': 'still does not {support}-1'}}
# {barclaycardus} Apple {Pay} {0: {'label': '{supports}-2'}}
# about {time} {ApplePay} {0: {'label': '{do}-1'}}
# Cale Apple {Pay} {us} {0: {'label': '{Visit}-1'}}
# tenuous {heatwave} received those precious extra {minutes} {0: {'label': 'can {give}-1'}}
# {$} 24 google {wallet} {0: {'label': '{sent}-1'}}
# 23 {US} an additional 23 {banks} {0: {'label': 'has {added}-2'}}
# {complaining} {everyone} {0: {'label': '{supports}-1'}}
# {Revel} integrated mobile payment {solution} {0: {'label': 'to {dish} up-6'}}
# trader {joes} apple {pay} {0: {'label': 'now {accepts}-1'}}
# Independent Apple {pay} {way} {0: {'label': '{coming}-1'}}
# {BSNL} an open ended mobile wallet {DigitalIndia} {0: {'label': '{launches}-1'}}
# {BSNL} mobile {wallet} {0: {'label': '{launches}-178'}, 1: {'label': '{rolls} out-1'}, 2: {'label': 'Now {launches}-1'}}
# {BSNL} SpeedPay mobile {wallet} {0: {'label': '{launches}-1'}}
# {BSNL} Pay mobile {wallet} {0: {'label': '{launches}-18'}}
# {BSNL} Speedy Pay mobile wallet {service} {0: {'label': '{rolls} out-2'}}
# {BSNL} {Times} India {0: {'label': '{launches}-2'}}
# {BSNL} Economic {Times} {0: {'label': '{launches}-4'}}
# {BSNL} The Economic {Times} {0: {'label': '{launches}-3'}}
# {BSNL} mobile wallet {SpeedPay} {0: {'label': '{launched}-1'}}
# {BSNL} mobile wallet service Speed {Pay} {0: {'label': '{launches}-2'}}
# a {patent} mobile payment {apps} {0: {'label': 'could {kill} off-21'}, 1: {'label': 'could {kill}-1'}}
# a {patent} mobile {payment} {0: {'label': 'could {kill} off-3'}}
# {This} more {options} {0: {'label': 'would {give}-1'}}
# {This} {nothing} do {0: {'label': '{has}-1'}}
# {This} {me} {0: {'label': '{reminds}-1'}}
# {This} {shit} {0: {'label': "'ll {do}-1"}}
# mobile {wallet} the {ranks} Airte {0: {'label': '{joins}-1'}}
# mobile {wallet} million monthly active {users} {0: {'label': '{has}-3'}}
# mobile {wallet} the {ranks} Ai {0: {'label': '{joins}-2'}}
# mobile {wallet} the {ranks} A... {0: {'label': '{joins}-1'}}
# mobile {wallet} the {ranks} Mone {0: {'label': '{joins}-35'}}
# mobile {wallet} the {ranks} {0: {'label': '{joins}-1'}}
# mobile {wallet} the {ranks} Money {0: {'label': '{joins}-1'}}
# INSTANT {transfers} {choice} {0: {'label': '{leggo}-1'}}
# {WTF} Touch {ID} {0: {'label': '{have}-1'}}
# {Dungarees} Clothing {website} {0: {'label': '{hacked}-1'}}
# App News Apple {Pay} the {UK} {0: {'label': 'reportedly {reaches}-1'}}
# Tim {Cook} {2015} {0: {'label': '{named}-6'}}
# Tim {Cook} Apple {Pay} {0: {'label': '{replaying}-1'}}
# {all} Bloody {hell} {0: {'label': 'is {charge}-1'}}
# {all} Apple {Pay} {0: {'label': 'Where can {use}-3'}}
# {all} {ApplePay} {0: {'label': '{accept}-1'}}
# NFC {technology} mobile {payments} {0: {'label': '{powers}-17'}}
# the {Watch} {pros} {0: {'label': '{has}-1'}}
# the {Watch} more {sense} {0: {'label': '{making}-1'}}
# Singapore mobile payment startup {Nearex} {funds} {0: {'label': '{gets}-2'}}
# Wonderful {insights} high {Samavesh2015} {0: {'label': 'is {going}-8'}}
# {patreon} {me} {0: {'label': '{charged} correctly-1'}}
# {V} paper {money} {0: {'label': 'should {remove}-1'}}
# favorite {Dierbergs} One {way} {0: {'label': 'now {has}-1'}}
# favorite {Dierbergs} Apple {Pay} {0: {'label': 'now {has}-1'}}
# a great {stance} {bank} {0: {'label': 'be {evaluating} soon-1'}}
# the {kind} thing Apple {Pay} {0: {'label': 'should {shun}-1'}}
# Doesn {'t} {that} {0: {'label': '{do} anyway-1'}}
# the {shop} isn 't {BP} {0: {'label': 'where {connected}-1'}}
# {$} 5 more {video} {0: {'label': '{gets}-3'}}
# the {service} the retail {industry} {0: {'label': 'Could {revolutionise}-1'}}
# the {service} live {DW} {0: {'label': 'when {goes}-2'}}
# No {paypal} {$} 35 {0: {'label': '{charge}-1'}}
# No {paypal} {$} 35 crazy {0: {'label': '{charge}-1'}}
# {peers} similar {products} {0: {'label': '{offering}-2'}}
# this {one} {Apple} {0: {'label': '{using}-1'}}
# Blij m. openbaar {vervoer} {OV} {0: {'label': '{met}-2'}}
# don {'t} that {shit} {0: {'label': '{use}-1'}}
# don {'t} a permanent {address} {0: {'label': '{have} yet-1'}}
# don {'t} {iphone} {0: {'label': '{lose}-1'}}
# don {'t} p2p {payments} {0: {'label': '{bother}-1'}}
# don {'t} apple {pay} {0: {'label': '{use}-1'}}
# don {'t} {plastic} {0: {'label': '{accept}-1'}}
# don {'t} {ApplePay} {0: {'label': '{offer}-1'}}
# don {'t} a designed {app} {0: {'label': '{adopt}-1'}}
# ...
# {what} {me} {0: {'label': '{prompted}-1'}}
# {what} {users} {0: {'label': 'do {want}-2'}}
# {what} {_} {0: {'label': '{use} does-2'}}
# {hoo} Apple {Pay} {0: {'label': 'is {doing}-1'}}
# {wallet} {god} {0: {'label': '{Thank}-1'}}
# {wallet} a {wallet} {0: {'label': '{needs}-1'}}
# 30 {%} donors contactless {card} {0: {'label': '{use}-1'}}
# {Coin} {these} {0: {'label': 'Does {accept}-2'}}
# {Providers} Payment Card {Terminals} {0: {'label': 'to {Upgrade}-1'}}
# {FYI} the {UK} {0: {'label': 'reportedly {reaches}-2'}}
# The fuel {stations} charging a {disservice} {0: {'label': 'are {doing}-4'}}
# Dang gas station didn {'t} Apple {Pay} {0: {'label': '{take}-1'}}
# {Please} payment {card} {0: {'label': '{have}-1'}}
# {Please} {amp} {0: {'label': '{sign}-2'}}
# {Lucy} {you} {0: {'label': 'can {please}-1'}}
# many online {vendors} Google {Wallet} tired {0: {'label': '{accept}-1'}}
# Lewis {Center} Apple Pay {transaction} {0: {'label': '{declined} twice-1'}}
# a {service} the most {freedom} {0: {'label': '{gives}-2'}}
# {one} {I} {0: {'label': 'should {get}-1'}}
# {one} tidal {pay} {0: {'label': 'should {get}-1'}}
# {one} {1} {0: {'label': 'allowed {Had}-1'}}
# Fake Twitter verification {profiles} {victims} {0: {'label': '{trick}-39'}}
# contactless {card} {them} {0: {'label': '{confuses}-1'}}
# New Zealand mobile {wallet} {SembleNZ} {0: {'label': 'now {works}-4'}}
# {YAY} Touch {ID} {0: {'label': '{have}-1'}}
# {People} dissing Apple {Pay} {0: {'label': '{use}-1'}}
# Use {caution} {cash} {0: {'label': 'when {prefer}-2'}}
# latest {paper} the {journey} introducing {0: {'label': '{describes}-5'}}
# {AppleInsider} early {signs} support {0: {'label': '{sees}-1'}}
# {clients} {fees} online {0: {'label': 'to {settle}-1'}}
# {Attackers} payment card {information} {0: {'label': 'reportedly {stole}-1'}}
# {STM} OPUS {card} {0: {'label': '{introduces}-20'}}
# {STM} {readers} {0: {'label': '{introduces}-1'}}
# a white {girl} apple {pay} {0: {'label': '{use}-2'}}
# Online {recharge} 700M {GTV} {0: {'label': '{targets}-3'}}
# {Nrgarner} {Thursday} {0: {'label': '{talks}-1'}}
# zijn {niet} chipkaart kan hij wel gebruik 1/ {2} {0: {'label': '{met}-2'}}
# Google wallet doesn {'t} Indian Debit {cards} {0: {'label': '{take}-1'}}
# not {perfect} One {CC} {0: {'label': '{using}-1'}}
# not {perfect} {it} {0: {'label': '{using}-1'}}
# {KFC} digital {payment} {0: {'label': 'to {add}-1'}}
# {Garner} {Proxama} {0: {'label': '{puts}-1'}}
# {3D} {toothbrushes} {0: {'label': '{printed}-1'}}
# {one} retailers Apple {Pay} {0: {'label': 'to {offer}-1'}}
# no {making} Apple pay {taxes} {0: {'label': '{likes}-4'}}
# 13 {%} Owners a Digital {Wallet} {0: {'label': '{Have}-3'}}
# 13 {%} Owners Wallet % {'t} {0: {'label': '{Have}-9'}}
# the only {reason} {headlines} {0: {'label': 'has {made}-1'}}
# A Mobile {Wallet} {Users} {0: {'label': 'Will {Allow}-20'}}
# a {cryptocurrency} the {currency} {0: {'label': '{distributes}-1'}}
# the only major uk {bank} {applepay} {0: {'label': '{supporting}-1'}}
# NZ digital wallet {Semble} Many {use} {0: {'label': '{adds}-1'}}
# NZ digital wallet {Semble} transit {payments} {0: {'label': '{adds}-4'}}
# a new {feature} a... mobile payment {apps} {0: {'label': 'could {kill} off-1'}}
# {Nobody} {How} {0: {'label': '{cares}-1'}}
# {Nobody} {these} {0: {'label': 'will {BUY}-2'}}
# files {patent} mobile payment {apps} {0: {'label': 'may {overtake}-2'}, 1: {'label': 'could {kill} off-1'}}
# the {battery} {more} {0: {'label': 'when {lasts}-1'}}
# new mobile payment {platform} {UK} {0: {'label': 'to {reach}-2'}}
# {payworks} NFC {payments} {0: {'label': '{bring}-6'}}
# No {One} the {Battle} {0: {'label': 'Is {Winning}-7'}}
# No {One} the Digital Wallet {Battle} {0: {'label': 'Why Is {Winning}-4'}}
# haha {man} much {hassle} {0: {'label': 'cant {switch}-1'}}
# {RideScout} {GlobeSherpa} {0: {'label': '{Acquires}-4'}, 1: {'label': '{acquires}-2'}}
# Missing Price {Tags} Machine PayPass {result} {0: {'label': 'does not {accept}-2'}}
# a {grand} Apple {Pay} Priceless {0: {'label': 'to {use}-2'}}
# {'s} google {wallet} http {0: {'label': '{play}-8'}}
# {'s} {this} {0: {'label': '{do}-1'}}
# {'s} {walls} {0: {'label': '{hopping}-1'}}
# {'s} the {RTgame} {0: {'label': '{play}-8'}}
# {birthday} 24 more {days} {0: {'label': 'so {get}-1'}}
# {Amazon} corp. {taxes} {0: {'label': '{pay}-1'}}
# {thanks} Apple {Pay} {0: {'label': "now 're not {getting}-1"}}
# No Apple {Pay} {me} {0: {'label': 'will {keep}-1'}}
# {he} {Waitrose} {0: {'label': '{fluffed}-1'}}
# {he} Apple Pay {YAY} {0: {'label': '{fluffed}-1'}}
# {he} apple {pay} {0: {'label': '{uses}-1'}}
# {he} Apple {Pay} {0: {'label': '{accepts}-1'}}
# {he} {me} {0: {'label': 'when {introduced}-1'}}
# {he} a bank {account} {0: {'label': 'even does not {have}-1'}}
# {he} a pre payment {card} {0: {'label': '{had}-1'}}
# {Thanks} {you} {0: {'label': '{love} too-1'}}
# {Thanks} Apple {Pay} {0: {'label': 'now {supports}-3'}}
# {Thanks} {me} {0: {'label': '{showed}-1'}}
# {Thanks} {it} {0: {'label': 'Now {take} further-1'}}
# the new {service} high {street} {0: {'label': 'may {hit}-1'}}
# First Canadian {bank} implement credit card {business} {0: {'label': '{gets}-4'}}
# White {Castle} apple {pay} {0: {'label': '{has}-1'}}
# {ScotiabankJM} the next {step} {0: {'label': 'is {making}-1'}}
# {youve} {t} {0: {'label': '{got}-1'}}
# {youve} the {w} {0: {'label': '{got}-2'}}
# {youve} the wrist space {digital} {0: {'label': '{got}-1'}}
# {youve} a contactless credit {card} {0: {'label': '{got}-1'}}
# {youve} the wrist {space} {0: {'label': '{got}-282'}}
# {youve} the {wr} {0: {'label': '{got}-2'}}
# {youve} Convenient contactless {payments} {0: {'label': '{got}-1'}}
# {youve} the wrist space {WearableTech} {0: {'label': '{got}-1'}}
# {youve} the {wrist} {0: {'label': '{got}-2'}}
# {youve} the {wristspace} {0: {'label': '{got}-3'}}
# {youve} {_} {0: {'label': '{got}-2'}}
# {youve} the wrist space {TheNextWoods} {0: {'label': '{got}-1'}}
# {youve} the {wri} {0: {'label': '{got}-1'}}
# {youve} the wrist {spa} {0: {'label': '{got}-1'}}
# wish {everyone} else early {adopter} ApplePay {0: {'label': 'would {get}-2'}}
# Thanks {God} Apple {pay} {0: {'label': '{got}-1'}}
# {ah} that doesn {think} {0: {'label': '{did}-1'}}
# {Semble} {Snapper} {0: {'label': '{adds}-5'}}
# {Semble} a public transport {op.} {0: {'label': 'has {added}-3'}}
# {Semble} public transport {cards} {0: {'label': '{adds}-1'}}
# {Semble} public transport {card} {0: {'label': '{adds}-1'}}
# {Semble} Snapper New Zealand public transport {payments} {0: {'label': '{adds}-3'}}
# {Semble} public {transport} {0: {'label': '{adds}-1'}}
# {Semble} Snapper public transport {payments} {0: {'label': '{adds}-10'}}
# Iphone 6 {Case} Italian Oil Leather Genuine Brown Apple {Wallet} {0: {'label': '{Cover}-1'}}
# live beta {testing} a live {beta} {0: {'label': 'has {launched}-1'}}
# {Samsung} {progress} {0: {'label': 'slowly {making}-1'}}
# {Samsung} Samsung {Pay} {0: {'label': '{testing}-48'}}
# {Samsung} {dedicat} {0: {'label': '{announced}-2'}}
# {Samsung} beta {testing} Pay {0: {'label': '{begins}-3'}}
# {Samsung} beta {testing} Experts {0: {'label': '{begins}-3'}}
# {Samsung} fingerprint mobile {paymentservice} {0: {'label': 'to {launch}-3'}}
# {Samsung} a short beta {program} {0: {'label': 'has {launched}-1'}}
# {Samsung} {its} dedicated {0: {'label': '{announced}-1'}}
# {Samsung} {good} {0: {'label': '{pay}-3'}}
# {Samsung} a live beta {test} payments {0: {'label': 'has {launched}-1'}}
# Hi {Mike} the {memo} {0: {'label': 'did {get}-2'}}
# {Apple} {mob} {0: {'label': '{told}-1'}}
# {Apple} 4 {iPhone} 6 {0: {'label': '{pay}-1'}}
# {Apple} {23..} {0: {'label': '{added}-1'}}
# {Apple} shit {money} ffs {0: {'label': '{pay}-1'}}
# {Apple} {you} {0: {'label': 'Did {pay}-1'}}
# {Apple} {meetings} {0: {'label': 'has reportedly {held}-4'}}
# {Apple} a {bank} {0: {'label': 'will {launch}-1'}}
# {Apple} {that} {0: {'label': '{doing}-1'}}
# {Apple} a patent {fthat} {0: {'label': 'has {filed} off-1'}}
# {Apple} the mobile {money} {0: {'label': '{follow}-1'}}
# {Apple} {retail} {0: {'label': 'has apparently {informed}-2'}}
# {Apple} {23} {0: {'label': '{added}-1'}}
# {Apple} production {Touch} {0: {'label': '{revving} up-1'}}
# {Apple} _ _ {toni04734630} {0: {'label': '{pay}-1'}}
# {Apple} {us} {0: {'label': '{told}-22'}}
# {Apple} {focus} {0: {'label': '{increase}-4'}}
# {Apple} {themselves} {0: {'label': 'are now {setting} up-1'}}
# {Apple} 23 {m.} {0: {'label': '{added}-2'}}
# {Apple} a new music streaming {service} {0: {'label': '{reveals}-16'}}
# {Apple} trivial {patent} {0: {'label': '{files}-7'}}
# {Apple} full {speed} {0: {'label': 'are {rushing}-2'}}
# {Apple} {Canada} {0: {'label': 'Could Be {Targeting}-1'}}
# {Apple} 23 {com} {0: {'label': '{added}-13'}}
# {Apple} the {number} stores accepting {0: {'label': 'has {tripled}-5'}}
# {Apple} a new {patent} {0: {'label': 'has {filed}-2'}}
# {Apple} {patents} {0: {'label': '{seeks}-2'}}
# {Apple} a {patent} {0: {'label': 'has {filed}-283'}, 1: {'label': '{filed}-8'}, 2: {'label': '{files}-2'}, 3: {'label': '{files} presumably-1'}}
# {Apple} {'What} {0: {'label': '{enabling}-1'}}
# {Apple} {UBS} {0: {'label': '{adds}-1'}}
# {Apple} a new {colors} {0: {'label': 'will {release}-1'}}
# {Apple} iOS {Passbook} {0: {'label': 'is {hiring}-1'}}
# {Apple} better {luck} pushing {0: {'label': 'true sometimes {has}-1'}}
# {Apple} {more} {0: {'label': '{pay}-1'}}
# {Apple} the mobile payment {competition} {0: {'label': 'is {killing} off-2'}}
# {Apple} an additional 23 {banks} {0: {'label': 'has {added}-5'}}
# {Apple} {work} {0: {'label': 'will {pay} is-1'}}
# {Apple} {its} {0: {'label': 'is not {disrupting}-1'}}
# {Apple} a {Meeting} {0: {'label': 'Recently {Held}-3'}}
# {Apple} {UK} {0: {'label': '{pay}-1'}}
# {Apple} Apple {Pay} {0: {'label': 'when {enable}-1'}, 1: {'label': 'Could {Launch}-1'}, 2: {'label': 'to {launch}-1'}}
# {Apple} a butt {load} money {0: {'label': 'ONLY {pay}-1'}}
# {Apple} {repo} {0: {'label': '{willannounce}-1'}}
# {Apple} {Pairs} {0: {'label': '{continues}-1'}}
# {Apple} {me} {0: {'label': 'should {hire}-1'}}
# {Apple} a Capital One {exec} {0: {'label': '{hired}-5'}}
# {Apple} mobile payment {service} {0: {'label': '{unveils}-8'}}
# {Apple} {headlines} {0: {'label': 'has {made}-1'}}
# {Apple} the {same} {0: {'label': 'Does {pay}-1'}}
# {Apple} {too} {0: {'label': '{pay}-1'}}
# {Apple} Google {Wallet} {0: {'label': '{getting} outta here-1'}, 1: {'label': '{ripped} off-1'}}
# {Apple} {ApplePay} {0: {'label': '{unveils}-1'}}
# {Apple} {person} {0: {'label': '{exploring}-12'}}
# {Apple} {$} {0: {'label': 'should {withdraw}-1'}}
# {Apple} the {artists} {0: {'label': '{pay}-1'}, 1: {'label': 'So how Does {pay}-1'}}
# {Apple} {efforts} add {0: {'label': 'is {continuing}-1'}}
# {Apple} mobile {payments} {0: {'label': '{told}-4'}}
# {Apple} the {date} {0: {'label': 'has {moved} up-1'}}
# {Apple} new {webpage} {0: {'label': '{launches}-1'}}
# {Apple} {friends} {0: {'label': '{Pay}-3'}}
# {Apple} this {dick} {0: {'label': '{pay}-2'}}
# {Apple} {Contactless} {0: {'label': 'whats already {got} Is-1'}}
# {Apple} {Person} {0: {'label': 'May {Allow}-5'}}
# {Apple} braintree {Head} Operations {0: {'label': '{poached}-4'}}
# {Apple} a {Patent} {0: {'label': '{Filed}-1'}}
# {Apple} that mobile payment {system} {0: {'label': '{said}-8'}}
# {Apple} mobile payment {apps} {0: {'label': 'Just when off could {kill} off-5'}}
# {Apple} corp. {taxes} {0: {'label': '{pay}-1'}}
# {Apple} {What} {0: {'label': 'is {pay} out-1'}, 1: {'label': 'do {have}-1'}}
# {Apple} Apple Pay {expansion} {0: {'label': '{eyes}-32'}}
# {Apple} P2P {patent} {0: {'label': '{files}-2'}}
# {Apple} the {plot} {0: {'label': 'Have {lost}-1'}}
# {Apple} {gos} {0: {'label': 'when {pay}-1'}}
# {Apple} the new the {standard} {0: {'label': 'Once again will {set}-1'}}
# {Apple} {iPhone} {0: {'label': '{invents}-4'}}
# {Apple} iPad {Mini} 4 {0: {'label': 'To {Release}-57'}}
# {Apple} the {roll} {0: {'label': 'is {continuing}-8'}}
# {Apple} {Passbook} {0: {'label': '{renames}-1'}}
# {Apple} a {pa.} {0: {'label': '{files}-1'}}
# {Apple} contactless {payments} {0: {'label': 'Is {taking}-2'}}
# {Apple} the {Head} Operations {0: {'label': '{hired}-5'}}
# {Apple} starving {artists} {0: {'label': '{pay}-2'}}
# {Apple} mobile payments {system} {0: {'label': '{told}-1'}}
# {Apple} the {launch} Pay {0: {'label': '{willannounce}-11'}}
# {Apple} leccy {Bill} {0: {'label': '{pay}-1'}}
# {Apple} a private {meeting} {0: {'label': 'recently {had}-3'}}
# {Apple} the first {time} {0: {'label': '{pay}-1'}}
# {Apple} a patent new {feature} {0: {'label': '{filed}-1'}}
# {Apple} mobile {paym} {0: {'label': '{told}-1'}}
# {Apple} a smaller {iPhone} {0: {'label': '{does}-1'}}
# {Apple} million {tax} {0: {'label': '{pay}-49'}}
# {Apple} Complete {Rasputin} {0: {'label': 'Why Is Not {Offering}-1'}}
# {Apple} {shit} {0: {'label': '{pay}-1'}}
# {Apple} Apple Pay {Window} {0: {'label': 'Now {Providing}-1'}}
# {Apple} new Apple Watch biometric ID {system} {0: {'label': '{invents}-1'}}
# {Apple} {_} {0: {'label': '{pay}-1'}}
# {Apple} {some} features {0: {'label': '{introduced}-1'}}
# {Apple} {Greece} {0: {'label': '{bail} out-1'}}
# {Apple} mobile {paymen} {0: {'label': '{told}-1'}}
# {Apple} 23 {companies} {0: {'label': '{added}-10'}}
# {Apple} {sys} {0: {'label': '{told}-1'}}
# {Apple} mobile payments {system.} {0: {'label': '{told}-1'}}
# {Apple} the Greek {debt} {0: {'label': '{pay} off-37'}}
# {Apple} the digital {wallet} {0: {'label': 'How {killed}-1'}}
# {Apple} different {clerks} couldn {0: {'label': '{pay}-3'}}
# {Apple} mobile payments system {wou} {0: {'label': '{told}-1'}}
# {Apple} {attention} {0: {'label': '{pay}-1'}}
# {Apple} a similar {product} called {0: {'label': '{introducing}-1'}}
# {Apple} Apple {Wallet} {0: {'label': '{getting} outta here-1'}}
# {Apple} OS X El {Capitan} {0: {'label': '{unveils}-1'}}
# {Apple} {_} _ {0: {'label': '{pay}-1'}}
# {Apple} any {time} {0: {'label': '{pay} close-1'}}
# {Apple} {something} {0: {'label': '{pay}-1'}}
# {Apple} {patent} {0: {'label': '{seeks}-130'}, 1: {'label': '{files}-29'}, 2: {'label': 'has {filed}-3'}}
# {Apple} {peer} {0: {'label': 'might {bring}-7'}}
# {Apple} {July} 14 {0: {'label': '{lands}-1'}}
# {Apple} UK launch {date} {0: {'label': '{pay}-1'}}
# {Apple} {neff} {0: {'label': '{pay}-1'}}
# {Apple} a {lot} influence {0: {'label': '{have}-1'}}
# {Apple} {settlement} {0: {'label': '{pay}-1'}}
# {Apple} {quiz} {0: {'label': 'How does {pay}-1'}}
# {Apple} ApplePay {expansion} {0: {'label': '{eyes}-1'}}
# {Apple} a {bunch} announcements {0: {'label': '{made}-1'}}
# Eight Korean card {companies} Samsung {Pay} {0: {'label': 'are {testing}-70'}}
# Eight Korean card {companies} {SamsungPay} {0: {'label': 'are {testing}-1'}}
# {Hi} {funds} {0: {'label': 'can {deposit} directly-1'}}
# {Hi} a lloyds international GBP {acct} {0: {'label': '{have}-1'}}
# {Hi} this area {map} {0: {'label': '{see}-1'}}
# digital {wallet} {'s} hopping {0: {'label': '{creates}-1'}}
# digital {wallet} P2P {Messaging} {0: {'label': '{adds}-1'}}
# $ {ends} {advantage} {0: {'label': "'s gonna {take}-2"}}
# Another 23 financial {institutions} {support} financial {0: {'label': '{add}-1'}}
# Another 23 financial {institutions} {support} {0: {'label': '{add}-12'}}
# Barclays don {'t} Apple {Pay} {0: {'label': '{support}-1'}}
# MasterCard Tests Facial Recognition {AppMasterCard} a {smartpho} {0: {'label': 'is {testing}-5'}}
# {Sales} a {patent} {0: {'label': 'has {filed}-1'}}
# a mobile wallet {app} {use} NFC {0: {'label': 'actually {makes}-1'}}
# Squares New Wireless {Reader} Apple {Pay} {0: {'label': 'Will {Accept}-1'}}
# {Sounds} some {verification} {0: {'label': '{need}-1'}}
# {Guess} {ApplePay} {0: {'label': '{called}-2'}}
# {places} apple {pay} {0: {'label': '{accept}-1'}}
# {places} Apple {Pay} {0: {'label': '{accept}-1'}}
# {places} {Apple} {0: {'label': '{take}-1'}}
# {infographic} mobilepayments EMV tokenization {awareness} {0: {'label': '{elevates}-1'}}
# like {Christmas} card payment {system} {0: {'label': '{upgraded}-2'}}
# Barclays isn {'t} Apple {Pay} {0: {'label': '{supporting}-16'}}
# Western {Union} {services} {0: {'label': '{expands}-1'}}
# {Halifax} Apple {Pay} {0: {'label': 'when will {adopt}-1'}}
# Hello Will {Barclays} {Apple} {0: {'label': '{support}-1'}}
# {Sniip} mobile {payments} {0: {'label': '{discussing} up-1'}, 1: {'label': '{discussing}-1'}}
# {hey} {applepay} {0: {'label': 'really {want}-1'}}
# a {couple} you {t} {0: {'label': '{observed}-35'}}

# %%
2+2
# Out:
# 4

# %%
entity_versions = get_entity_versions('twitter')    
df_simp = get_simp_df(df_rels.copy(),entity_versions)  
selected_nodes = entity_versions.keys()
df_rels_selected = filter_nodes_OR(df_simp.copy(),source='arg1',target='arg2',selected_nodes = selected_nodes)

# %%
output_dir = '../../../../data/Tweets/all_tweets_with_extractions_from_spade/'
pkl_loc = output_dir + "df_simp.pkl"
CREATE_SAVE_PICKLE=False#True
if CREATE_SAVE_PICKLE:
    df_simp = get_simp_df(df_rels.copy(),entity_versions)  
    df_simp.to_pickle(pkl_loc)
else:
    df_simp = pd.read_pickle(pkl_loc)
df_simp
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-19-532be8041126> in <module>()
#       6     df_simp.to_pickle(pkl_loc)
#       7 else:
# ----> 8     df_simp = pd.read_pickle(pkl_loc)
#       9 df_simp
#
# /Library/Python/2.7/site-packages/pandas/io/pickle.pyc in read_pickle(path)
#      58
#      59     try:
# ---> 60         return try_read(path)
#      61     except:
#      62         if PY3:
#
# /Library/Python/2.7/site-packages/pandas/io/pickle.pyc in try_read(path, encoding)
#      54             # compat pickle
#      55             except:
# ---> 56                 with open(path, 'rb') as fh:
#      57                     return pc.load(fh, encoding=encoding, compat=True)
#      58
#
# IOError: [Errno 2] No such file or directory: '../../../../data/Tweets/all_tweets_with_extractions_from_spade/df_rels_selected.pkl'

# %%
df_simp.to_pickle(pkl_loc)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-5e6b30f288a2> in <module>()
# ----> 1 df_simp.to_pickle(pkl_loc)
#
# NameError: name 'pkl_loc' is not defined

# %%
df_rels_selected
# Out:
#                        tweet_id         tweet_posted_time   tweet_author_id  \
# 51      2005:616052258191577088  2015-07-01T01:14:38.000Z         566697301
# 54      2005:616053600893145088  2015-07-01T01:19:58.000Z        2247334022
# 57      2005:616057483015155712  2015-07-01T01:35:24.000Z          32439880
# 61      2005:616064196317306881  2015-07-01T02:02:04.000Z         488597347
# 69      2005:616072613857763328  2015-07-01T02:35:31.000Z          62897798
# 118     2005:616101128997093376  2015-07-01T04:28:50.000Z         270018506
# 163     2005:616108389328928769  2015-07-01T04:57:41.000Z         860947765
# 164     2005:616108389328928769  2015-07-01T04:57:41.000Z         860947765
# 211     2005:616130608700489728  2015-07-01T06:25:58.000Z          22785567
# 224     2005:616139462276419584  2015-07-01T07:01:09.000Z         381985266
# 232     2005:616142112606789632  2015-07-01T07:11:41.000Z         166138514
# 240     2005:616147236951601152  2015-07-01T07:32:03.000Z          90629673
# 241     2005:616147596495704064  2015-07-01T07:33:29.000Z         109669208
# 248     2005:616153016782192640  2015-07-01T07:55:01.000Z         156060436
# 276     2005:616163426033864704  2015-07-01T08:36:23.000Z         234683311
# 282     2005:616164117129363456  2015-07-01T08:39:07.000Z         224980710
# 314     2005:616181456306601984  2015-07-01T09:48:01.000Z         120915590
# 373     2005:616215061883940864  2015-07-01T12:01:34.000Z          44930140
# 378     2005:616219953323184129  2015-07-01T12:21:00.000Z        2364310612
# 393     2005:616225125034295296  2015-07-01T12:41:33.000Z          20556913
# 419     2005:616232678094962688  2015-07-01T13:11:34.000Z        2480884580
# 431     2005:616244360766717952  2015-07-01T13:57:59.000Z         154339533
# 432     2005:616244870080901124  2015-07-01T14:00:00.000Z        2677603136
# 440     2005:616246901722218496  2015-07-01T14:08:05.000Z         784425434
# 465     2005:616266518804987904  2015-07-01T15:26:02.000Z          15028307
# 467     2005:616267213511770112  2015-07-01T15:28:48.000Z         529107072
# 469     2005:616267523646980096  2015-07-01T15:30:01.000Z         116076509
# 474     2005:616268327443369984  2015-07-01T15:33:13.000Z         116766613
# 477     2005:616268435023097860  2015-07-01T15:33:39.000Z         224223862
# 478     2005:616268435023097860  2015-07-01T15:33:39.000Z         224223862
# ...                         ...                       ...               ...
# 153178  2005:654331229513191424  2015-10-14T16:21:36.000Z        3235321274
# 153179  2005:654331235590733824  2015-10-14T16:21:38.000Z        3235345027
# 153180  2005:654331245443178496  2015-10-14T16:21:40.000Z        3235252752
# 153195  2005:654333681029545984  2015-10-14T16:31:21.000Z         106901519
# 153201  2005:654335496647254016  2015-10-14T16:38:34.000Z        1924434625
# 153203  2005:654335547041644544  2015-10-14T16:38:46.000Z          88987464
# 153206  2005:654336021035794432  2015-10-14T16:40:39.000Z         311262156
# 153207  2005:654336128141496321  2015-10-14T16:41:04.000Z         865256425
# 153216  2005:654336367007277057  2015-10-14T16:42:01.000Z        2661644340
# 153219  2005:654338282440929280  2015-10-14T16:49:38.000Z        2716186039
# 153222  2005:654339844622057473  2015-10-14T16:55:50.000Z        2716186039
# 153223  2005:654339863567712256  2015-10-14T16:55:55.000Z        2716186039
# 153224  2005:654340015997108224  2015-10-14T16:56:31.000Z        2716186039
# 153231  2005:654341615692066816  2015-10-14T17:02:52.000Z        2853532875
# 153234  2005:654342697889624064  2015-10-14T17:07:10.000Z        2716418989
# 153240  2005:654343624658944000  2015-10-14T17:10:51.000Z          16583846
# 153241  2005:654343833124139008  2015-10-14T17:11:41.000Z        2716418989
# 153243  2005:654344061772414976  2015-10-14T17:12:36.000Z        2716418989
# 153244  2005:654344083918295040  2015-10-14T17:12:41.000Z        2716418989
# 153252  2005:654346321323671552  2015-10-14T17:21:34.000Z         930011209
# 153254  2005:654346422209409024  2015-10-14T17:21:58.000Z         261943462
# 153264  2005:654348533777199105  2015-10-14T17:30:22.000Z         164274882
# 153273  2005:654351635343388673  2015-10-14T17:42:41.000Z         197814573
# 153274  2005:654351927963164672  2015-10-14T17:43:51.000Z        2350405855
# 153275  2005:654351927963164672  2015-10-14T17:43:51.000Z        2350405855
# 153357  2005:654363359874256896  2015-10-14T18:29:17.000Z         138526255
# 153422  2005:654368099949498368  2015-10-14T18:48:07.000Z        2234854880
# 153475  2005:654374150434242560  2015-10-14T19:12:09.000Z          63636463
# 153505  2005:654377040909611008  2015-10-14T19:23:38.000Z        2661644340
# 153595  2005:654391299181776896  2015-10-14T20:20:18.000Z          14165481
#
#                  tweet_author_location  tweet_country        city  tweet_lang  \
# 51                                  NJ            NaN         NaN          en
# 54                       Wagging in MI            NaN         NaN          en
# 57                         Chicago, IL            NaN         NaN          en
# 61                                 NaN            NaN         NaN          en
# 69                     Albuquerque, NM            NaN         NaN          en
# 118                    London, England            NaN         NaN          en
# 163                                NaN            NaN         NaN          en
# 164                                NaN            NaN         NaN          en
# 211     America, China, Singapore & UK            NaN         NaN          en
# 224                                NaN            NaN         NaN          en
# 232     Here, There, Every Bloodywhere            NaN         NaN          en
# 240                             London            NaN         NaN          en
# 241                         Bolton, UK            NaN         NaN          en
# 248                             London            NaN         NaN          en
# 276                   Redditch, Worcs.            NaN         NaN          en
# 282                                NaN            NaN         NaN          en
# 314                                 UK            NaN         NaN          en
# 373                                NaN            NaN         NaN          en
# 378                 Nottingham England            NaN         NaN          en
# 393                   Hitchin, England            NaN         NaN          en
# 419                   Monroe, Georgia             NaN         NaN          en
# 431                                NaN            NaN         NaN          en
# 432                                NaN            NaN         NaN          en
# 440                Aigburth, Liverpool            NaN         NaN          en
# 465                                NaN            NaN         NaN          en
# 467                       Columbus, OH            NaN         NaN          en
# 469                Geneva, Switzerland            NaN         NaN          en
# 474              Oxford/Helsinki/Tokyo            NaN         NaN          en
# 477                             London            NaN         NaN          en
# 478                             London            NaN         NaN          en
# ...                                ...            ...         ...         ...
# 153178     United States - Los Angeles            NaN         NaN          en
# 153179                   United States            NaN         NaN          en
# 153180    United States - Los Angeles             NaN         NaN          en
# 153195                         DC, USA            NaN         NaN          en
# 153201               Greater Amsterdam            NaN         NaN          en
# 153203         T: 34.066193,-118.22897            NaN         NaN          en
# 153206                   New York, USA            NaN         NaN          en
# 153207                 chocolate river            NaN         NaN          en
# 153216                             NaN            NaN         NaN          en
# 153219                             NaN            NaN         NaN          en
# 153222                             NaN            NaN         NaN          en
# 153223                             NaN            NaN         NaN          en
# 153224                             NaN            NaN         NaN          en
# 153231                          Canada            NaN         NaN          en
# 153234                  USA - New York            NaN         NaN          en
# 153240                     Seattle, WA            NaN         NaN          en
# 153241                  USA - New York            NaN         NaN          en
# 153243                  USA - New York            NaN         NaN          en
# 153244                  USA - New York            NaN         NaN          en
# 153252               Detroit, Michigan  United States  State Fair          en
# 153254                         Chicago            NaN         NaN          en
# 153264               Fairfax, Virginia            NaN         NaN          en
# 153273                        Terrassa            NaN         NaN          en
# 153274                             USA            NaN         NaN          en
# 153275                             USA            NaN         NaN          en
# 153357                             NaN            NaN         NaN          en
# 153422                             NaN            NaN         NaN          en
# 153475                       Tennessee            NaN         NaN          en
# 153505                             NaN            NaN         NaN          en
# 153595                   Milwaukee, WI            NaN         NaN          en
#
#         lat  lon     ALTLAT  \
# 51      NaN  NaN        NaN
# 54      NaN  NaN        NaN
# 57      NaN  NaN        NaN
# 61      NaN  NaN        NaN
# 69      NaN  NaN        NaN
# 118     NaN  NaN        NaN
# 163     NaN  NaN        NaN
# 164     NaN  NaN        NaN
# 211     NaN  NaN        NaN
# 224     NaN  NaN        NaN
# 232     NaN  NaN        NaN
# 240     NaN  NaN        NaN
# 241     NaN  NaN        NaN
# 248     NaN  NaN        NaN
# 276     NaN  NaN        NaN
# 282     NaN  NaN        NaN
# 314     NaN  NaN        NaN
# 373     NaN  NaN        NaN
# 378     NaN  NaN        NaN
# 393     NaN  NaN        NaN
# 419     NaN  NaN        NaN
# 431     NaN  NaN        NaN
# 432     NaN  NaN        NaN
# 440     NaN  NaN        NaN
# 465     NaN  NaN        NaN
# 467     NaN  NaN        NaN
# 469     NaN  NaN        NaN
# 474     NaN  NaN        NaN
# 477     NaN  NaN        NaN
# 478     NaN  NaN        NaN
# ...     ...  ...        ...
# 153178  NaN  NaN        NaN
# 153179  NaN  NaN        NaN
# 153180  NaN  NaN        NaN
# 153195  NaN  NaN        NaN
# 153201  NaN  NaN        NaN
# 153203  NaN  NaN        NaN
# 153206  NaN  NaN        NaN
# 153207  NaN  NaN        NaN
# 153216  NaN  NaN        NaN
# 153219  NaN  NaN        NaN
# 153222  NaN  NaN        NaN
# 153223  NaN  NaN        NaN
# 153224  NaN  NaN        NaN
# 153231  NaN  NaN        NaN
# 153234  NaN  NaN        NaN
# 153240  NaN  NaN        NaN
# 153241  NaN  NaN        NaN
# 153243  NaN  NaN        NaN
# 153244  NaN  NaN        NaN
# 153252  NaN  NaN -83.125397
# 153254  NaN  NaN        NaN
# 153264  NaN  NaN        NaN
# 153273  NaN  NaN        NaN
# 153274  NaN  NaN        NaN
# 153275  NaN  NaN        NaN
# 153357  NaN  NaN        NaN
# 153422  NaN  NaN        NaN
# 153475  NaN  NaN        NaN
# 153505  NaN  NaN        NaN
# 153595  NaN  NaN        NaN
#
#                               ...                          \
# 51                            ...
# 54                            ...
# 57                            ...
# 61                            ...
# 69                            ...
# 118                           ...
# 163                           ...
# 164                           ...
# 211                           ...
# 224                           ...
# 232                           ...
# 240                           ...
# 241                           ...
# 248                           ...
# 276                           ...
# 282                           ...
# 314                           ...
# 373                           ...
# 378                           ...
# 393                           ...
# 419                           ...
# 431                           ...
# 432                           ...
# 440                           ...
# 465                           ...
# 467                           ...
# 469                           ...
# 474                           ...
# 477                           ...
# 478                           ...
# ...                           ...
# 153178                        ...
# 153179                        ...
# 153180                        ...
# 153195                        ...
# 153201                        ...
# 153203                        ...
# 153206                        ...
# 153207                        ...
# 153216                        ...
# 153219                        ...
# 153222                        ...
# 153223                        ...
# 153224                        ...
# 153231                        ...
# 153234                        ...
# 153240                        ...
# 153241                        ...
# 153243                        ...
# 153244                        ...
# 153252                        ...
# 153254                        ...
# 153264                        ...
# 153273                        ...
# 153274                        ...
# 153275                        ...
# 153357                        ...
# 153422                        ...
# 153475                        ...
# 153505                        ...
# 153595                        ...
#
#                                   arg2 type              pattern  \
# 51                        googlewallet  SVO  (nsubj, verb, dobj)
# 54                              PayPal  SVO  (nsubj, verb, dobj)
# 57         own mobile payment {device}  SVO  (nsubj, verb, dobj)
# 61                              PayPal  SVO  (nsubj, verb, dobj)
# 69                                {me}  SVO  (nsubj, verb, dobj)
# 118                              banks  SVO  (nsubj, verb, dobj)
# 163                 own custom {video}  SVO  (nsubj, verb, dobj)
# 164                               {ht}  SVO  (nsubj, verb, dobj)
# 211     bpay mobile {payments} compete  SVO  (nsubj, verb, dobj)
# 224                             the US  SVO  (nsubj, verb, dobj)
# 232                         the {plot}  SVO  (nsubj, verb, dobj)
# 240                           {corner}  SVO  (nsubj, verb, dobj)
# 241                             the US  SVO  (nsubj, verb, dobj)
# 248                             the US  SVO  (nsubj, verb, dobj)
# 276                             the UK  SVO  (nsubj, verb, dobj)
# 282                             the UK  SVO  (nsubj, verb, dobj)
# 314                         {applepay}  SVO  (nsubj, verb, dobj)
# 373               magento {flaw} steal  SVO  (nsubj, verb, dobj)
# 378                         {applepay}  SVO  (nsubj, verb, dobj)
# 393                         {applepay}  SVO  (nsubj, verb, dobj)
# 419                       googlewallet  SVO  (nsubj, verb, dobj)
# 431                       googlewallet  SVO  (nsubj, verb, dobj)
# 432               magento {flaw} steal  SVO  (nsubj, verb, dobj)
# 440                             the UK  SVO  (nsubj, verb, dobj)
# 465             million new {accounts}  SVO  (nsubj, verb, dobj)
# 467             million new {accounts}  SVO  (nsubj, verb, dobj)
# 469             million new {accounts}  SVO  (nsubj, verb, dobj)
# 474             million new {accounts}  SVO  (nsubj, verb, dobj)
# 477                              {it.}  SVO  (nsubj, verb, dobj)
# 478          applepay uk launch {date}  SVO  (nsubj, verb, dobj)
# ...                                ...  ...                  ...
# 153178                   the {company}  SVO  (nsubj, verb, dobj)
# 153179                   the {company}  SVO  (nsubj, verb, dobj)
# 153180                   the {company}  SVO  (nsubj, verb, dobj)
# 153195              debit card {cause}  SVO  (nsubj, verb, dobj)
# 153201              imminent {arrival}  SVO  (nsubj, verb, dobj)
# 153203                            {it}  SVO  (nsubj, verb, dobj)
# 153206                   the {company}  SVO  (nsubj, verb, dobj)
# 153207                   the {company}  SVO  (nsubj, verb, dobj)
# 153216              imminent {arrival}  SVO  (nsubj, verb, dobj)
# 153219                   the {company}  SVO  (nsubj, verb, dobj)
# 153222                   the {company}  SVO  (nsubj, verb, dobj)
# 153223                   the {company}  SVO  (nsubj, verb, dobj)
# 153224                   the {company}  SVO  (nsubj, verb, dobj)
# 153231                      {applepay}  SVO  (nsubj, verb, dobj)
# 153234                   the {company}  SVO  (nsubj, verb, dobj)
# 153240                          PayPal  SVO  (nsubj, verb, dobj)
# 153241                   the {company}  SVO  (nsubj, verb, dobj)
# 153243                   the {company}  SVO  (nsubj, verb, dobj)
# 153244                   the {company}  SVO  (nsubj, verb, dobj)
# 153252                    googlewallet  SVO  (nsubj, verb, dobj)
# 153254                    googlewallet  SVO  (nsubj, verb, dobj)
# 153264               looppay {company}  SVO  (nsubj, verb, dobj)
# 153273                           banks  SVO  (nsubj, verb, dobj)
# 153274                          PayPal  SVO  (nsubj, verb, dobj)
# 153275                    googlewallet  SVO  (nsubj, verb, dobj)
# 153357                    {samsungpay}  SVO  (nsubj, verb, dobj)
# 153422                          the US  SVO  (nsubj, verb, dobj)
# 153475                           {it.}  SVO  (nsubj, verb, dobj)
# 153505                           {it.}  SVO  (nsubj, verb, dobj)
# 153595                       {looppay}  SVO  (nsubj, verb, dobj)
#
#                                             arg1_with_pos  \
# 51                                              you-PRP-3
# 54                                                I-PRP-2
# 57                              Barclays-NNP-1 Bank-NNP-2
# 61                                                I-PRP-1
# 69                                      googlewallet-NN-1
# 118                                              I-PRP-10
# 163     Kaylawalton36yahoo-NNP-1 .com-NN-2 4-CD-3 PayP...
# 164     Kaylawalton36yahoo-NNP-1 .com-NN-2 4-CD-3 PayP...
# 211                               Barclays-NNP-1 UK-NNP-2
# 224                                               I-PRP-1
# 232                                     Barclaycard-NNP-3
# 240                                     Barclaycard-NNP-5
# 241                                               I-PRP-1
# 248                                               I-PRP-1
# 276                      an-DT-3 Apple-NNP-4 advisor-NN-5
# 282                      an-DT-3 Apple-NNP-4 advisor-NN-5
# 314                                              UK-NNP-1
# 373                                         Hackers-NNS-1
# 378                                 some-DT-5 banks-NNS-6
# 393                                          banks-NNS-10
# 419                                             you-PRP-3
# 431                                               I-PRP-2
# 432                                         Hackers-NNS-1
# 440                    any-DT-1 news-NN-2 regarding-VBG-3
# 465                                          PayPal-NNP-1
# 467                                          PayPal-NNP-1
# 469                                          PayPal-NNP-1
# 474                                          PayPal-NNP-1
# 477                                  UK-NNP-7 banks-NNS-8
# 478                                  UK-NNP-7 banks-NNS-8
# ...                                                   ...
# 153178                         Chinese-JJ-1 hackers-NNS-2
# 153179                         Chinese-JJ-1 hackers-NNS-2
# 153180                         Chinese-JJ-1 hackers-NNS-2
# 153195                                The-DT-1 Bank-NNP-2
# 153201                                         Bank-NNP-1
# 153203                                       verizon-NN-4
# 153206                         Chinese-JJ-1 hackers-NNS-2
# 153207                         Chinese-JJ-1 hackers-NNS-2
# 153216                                         Bank-NNP-3
# 153219                         Chinese-JJ-1 hackers-NNS-2
# 153222                         Chinese-JJ-1 hackers-NNS-2
# 153223                         Chinese-JJ-1 hackers-NNS-2
# 153224                         Chinese-JJ-1 hackers-NNS-2
# 153231                          Canadian-JJ-1 banks-NNS-2
# 153234                         Chinese-JJ-1 hackers-NNS-2
# 153240                                           We-PRP-1
# 153241                         Chinese-JJ-1 hackers-NNS-2
# 153243                         Chinese-JJ-1 hackers-NNS-2
# 153244                         Chinese-JJ-1 hackers-NNS-2
# 153252                                          me-PRP-11
# 153254                                          me-PRP-11
# 153264                         Chinese-JJ-1 hackers-NNS-2
# 153273                                     ApplePay-NNP-1
# 153274                                          you-PRP-3
# 153275                                            I-PRP-1
# 153357                                      Hackers-NNS-1
# 153422                                     ApplePay-NNP-1
# 153475                                        banks-NNS-7
# 153505                                        banks-NNS-7
# 153595                       Chinese-NNP-1 Hackers-NNPS-2
#
#                                        rel_with_pos  \
# 51                                        use-VBP-4
# 54                                        get-VBP-3
# 57                        is-VBZ-6 developing-VBG-7
# 61                                        got-VBD-2
# 69                             saved-VBD-3 now-RB-6
# 118                        'm-VBP-11 finding-VBG-12
# 163                                        get-VB-9
# 164                                        get-VB-9
# 211                      is-VBZ-3 relaunching-VBG-4
# 224                                   thought-VBD-2
# 232                 Also-RB-1 have-VBP-2 lost-VBN-4
# 240                                     defend-VB-6
# 241                                   thought-VBD-2
# 248                                   thought-VBD-2
# 276                                      told-VBD-7
# 282                                      told-VBD-7
# 314                                      gets-VBZ-2
# 373                      are-VBP-2 exploiting-VBG-3
# 378                                   support-VBP-7
# 393                        all-DT-12 support-VBP-13
# 419                            would-MD-2 take-VB-4
# 431                        checked-VBD-3 later-RB-6
# 432                      are-VBP-2 exploiting-VBG-3
# 440                              will-MD-8 hit-VB-9
# 465                                     added-VBD-2
# 467                                     added-VBD-2
# 469                                     added-VBD-2
# 474                                     added-VBD-2
# 477                                  support-VBP-11
# 478                                  support-VBP-11
# ...                                             ...
# 153178                               attacked-VBD-3
# 153179                               attacked-VBD-3
# 153180                               attacked-VBD-3
# 153195                                  froze-VBD-3
# 153201                                reveals-VBZ-2
# 153203  has-VBZ-5 not-RB-6 supported-VBN-7 yet-RB-9
# 153206                               attacked-VBD-3
# 153207                               attacked-VBD-3
# 153216                                reveals-VBZ-4
# 153219                               attacked-VBD-3
# 153222                               attacked-VBD-3
# 153223                               attacked-VBD-3
# 153224                               attacked-VBD-3
# 153231               finally-RB-3 advertising-VBG-4
# 153234                               attacked-VBD-3
# 153240                         do-VBP-2 accept-VB-3
# 153241                               attacked-VBD-3
# 153243                               attacked-VBD-3
# 153244                               attacked-VBD-3
# 153252                                    use-VB-12
# 153254                                    use-VB-12
# 153264                               breached-VBD-3
# 153273                                   adds-VBZ-2
# 153274      do-VB-2 not-RB-4 take-VB-5 anymore-RB-7
# 153275                            can-MD-2 use-VB-3
# 153357                               targeted-VBD-3
# 153422                                   adds-VBZ-2
# 153475                     why-WRB-6 shouldnt-VBP-8
# 153505                     why-WRB-6 shouldnt-VBP-8
# 153595                               Breached-VBD-3
#
#                                             arg2_with_pos  \
# 51                                       googlewallet-.-5
# 54                                    a-DT-4 PayPal-NNP-5
# 57       own-JJ-9 mobile-JJ-10 payment-NN-11 device-NN-12
# 61                                           PayPal-NNP-3
# 69                                               me-PRP-4
# 118                              another-DT-13 bank-NN-14
# 163                    own-JJ-11 custom-NN-12 video-NN-13
# 164                                              ht-NN-17
# 211     bPay-JJ-5 mobile-JJ-6 payments-NNS-7 compete-VB-9
# 224                                              us-PRP-3
# 232                                    the-DT-5 plot-NN-6
# 240                                           corner-NN-8
# 241                                              us-PRP-3
# 248                                              us-PRP-3
# 276                              ApplePay-NNP-9 UK-NNP-10
# 282                              ApplePay-NNP-9 UK-NNP-10
# 314                                        ApplePay-NNP-3
# 373                    Magento-NNP-4 flaw-NN-5 steal-VB-7
# 378                                        ApplePay-NNP-8
# 393                                       ApplePay-NNP-14
# 419                                     googlewallet-NN-5
# 431                                     googlewallet-NN-5
# 432                    Magento-NNP-4 flaw-NN-5 steal-VB-7
# 440                                   the-DT-10 UK-NNP-11
# 465                  million-CD-4 new-JJ-5 accounts-NNS-6
# 467                  million-CD-4 new-JJ-5 accounts-NNS-6
# 469                  million-CD-4 new-JJ-5 accounts-NNS-6
# 474                  million-CD-4 new-JJ-5 accounts-NNS-6
# 477                                              it.-.-12
# 478         ApplePay-NNP-1 UK-NNP-2 launch-NN-3 date-NN-4
# ...                                                   ...
# 153178                              the-DT-4 company-NN-5
# 153179                              the-DT-4 company-NN-5
# 153180                              the-DT-4 company-NN-5
# 153195                    debit-NN-5 card-NN-6 cause-NN-7
# 153201                         imminent-JJ-4 arrival-NN-5
# 153203                                           it-PRP-8
# 153206                              the-DT-4 company-NN-5
# 153207                              the-DT-4 company-NN-5
# 153216                         imminent-JJ-6 arrival-NN-7
# 153219                              the-DT-4 company-NN-5
# 153222                              the-DT-4 company-NN-5
# 153223                              the-DT-4 company-NN-5
# 153224                              the-DT-4 company-NN-5
# 153231                                     ApplePay-NNP-5
# 153234                              the-DT-4 company-NN-5
# 153240                                       PayPal-NNP-4
# 153241                              the-DT-4 company-NN-5
# 153243                              the-DT-4 company-NN-5
# 153244                              the-DT-4 company-NN-5
# 153252                                 googlewallet-NN-13
# 153254                                 googlewallet-NN-13
# 153264                         LoopPay-NNP-4 company-NN-6
# 153273                       29-CD-3 US-NNP-4 banks-NNS-5
# 153274                                       PayPal-NNP-6
# 153275                                  googlewallet-NN-4
# 153357                                   SamsungPay-NNP-4
# 153422                                           us-PRP-9
# 153475                                           it.-.-10
# 153505                                           it.-.-10
# 153595                                      LoopPay-NNP-4
#
#                          arg1_prepositions  \
# 51                                     NaN
# 54                                     NaN
# 57      REASON: prep_in TEXT: the {UK} --
# 61                                     NaN
# 69                                     NaN
# 118                                    NaN
# 163                                    NaN
# 164                                    NaN
# 211                                    NaN
# 224                                    NaN
# 232                                    NaN
# 240                                    NaN
# 241                                    NaN
# 248                                    NaN
# 276                                    NaN
# 282                                    NaN
# 314                                    NaN
# 373                                    NaN
# 378                                    NaN
# 393                                    NaN
# 419                                    NaN
# 431                                    NaN
# 432                                    NaN
# 440                                    NaN
# 465                                    NaN
# 467                                    NaN
# 469                                    NaN
# 474                                    NaN
# 477                                    NaN
# 478                                    NaN
# ...                                    ...
# 153178                                 NaN
# 153179                                 NaN
# 153180                                 NaN
# 153195                                 NaN
# 153201                                 NaN
# 153203                                 NaN
# 153206                                 NaN
# 153207                                 NaN
# 153216                                 NaN
# 153219                                 NaN
# 153222                                 NaN
# 153223                                 NaN
# 153224                                 NaN
# 153231                                 NaN
# 153234                                 NaN
# 153240                                 NaN
# 153241                                 NaN
# 153243                                 NaN
# 153244                                 NaN
# 153252                                 NaN
# 153254                                 NaN
# 153264                                 NaN
# 153273                                 NaN
# 153274                                 NaN
# 153275                                 NaN
# 153357                                 NaN
# 153422                                 NaN
# 153475                                 NaN
# 153505                                 NaN
# 153595                                 NaN
#
#                                          rel_prepositions  \
# 51                                                    NaN
# 54                                                    NaN
# 57                                                    NaN
# 61                                                    NaN
# 69                                                    NaN
# 118                                                   NaN
# 163                                                   NaN
# 164                                                   NaN
# 211                                                   NaN
# 224                                                   NaN
# 232                                                   NaN
# 240     REASON: prep_from TEXT: the impending {launch}...
# 241                                                   NaN
# 248                                                   NaN
# 276                                                   NaN
# 282                                                   NaN
# 314                                                   NaN
# 373                                                   NaN
# 378                                                   NaN
# 393                                                   NaN
# 419                                                   NaN
# 431                                                   NaN
# 432                                                   NaN
# 440                                                   NaN
# 465          REASON: prep_in TEXT: the last {quarter} --
# 467          REASON: prep_in TEXT: the last {quarter} --
# 469          REASON: prep_in TEXT: the last {quarter} --
# 474          REASON: prep_in TEXT: the last {quarter} --
# 477                                                   NaN
# 478                                                   NaN
# ...                                                   ...
# 153178                                                NaN
# 153179                                                NaN
# 153180                                                NaN
# 153195                                                NaN
# 153201                                                NaN
# 153203                                                NaN
# 153206                                                NaN
# 153207                                                NaN
# 153216                                                NaN
# 153219                                                NaN
# 153222                                                NaN
# 153223                                                NaN
# 153224                                                NaN
# 153231                                                NaN
# 153234                                                NaN
# 153240                                                NaN
# 153241                                                NaN
# 153243                                                NaN
# 153244                                                NaN
# 153252                                                NaN
# 153254                                                NaN
# 153264                                                NaN
# 153273                                                NaN
# 153274                                                NaN
# 153275                                                NaN
# 153357                                                NaN
# 153422                                                NaN
# 153475                                                NaN
# 153505                                                NaN
# 153595                                                NaN
#
#                                         arg2_prepositions  \
# 51                                                    NaN
# 54                                                    NaN
# 57                                                    NaN
# 61                                                    NaN
# 69                                                    NaN
# 118                                                   NaN
# 163                                                   NaN
# 164                                                   NaN
# 211                                                   NaN
# 224                                                   NaN
# 232                                                   NaN
# 240                                                   NaN
# 241                                                   NaN
# 248                                                   NaN
# 276                                                   NaN
# 282                                                   NaN
# 314                                                   NaN
# 373                                                   NaN
# 378                                                   NaN
# 393                                                   NaN
# 419                                                   NaN
# 431                                                   NaN
# 432                                                   NaN
# 440                                                   NaN
# 465                                                   NaN
# 467                                                   NaN
# 469                                                   NaN
# 474                                                   NaN
# 477                                                   NaN
# 478                                                   NaN
# ...                                                   ...
# 153178       REASON: prep_behind TEXT: SamsungPay {A} --
# 153179       REASON: prep_behind TEXT: SamsungPay {A} --
# 153180       REASON: prep_behind TEXT: SamsungPay {A} --
# 153195                                                NaN
# 153201                 REASON: prep_in TEXT: {Canada} --
# 153203                                                NaN
# 153206         REASON: prep_behind TEXT: {SamsungPay} --
# 153207         REASON: prep_behind TEXT: {SamsungPay} --
# 153216                 REASON: prep_in TEXT: {Canada} --
# 153219       REASON: prep_behind TEXT: SamsungPay {A} --
# 153222       REASON: prep_behind TEXT: SamsungPay {A} --
# 153223       REASON: prep_behind TEXT: SamsungPay {A} --
# 153224       REASON: prep_behind TEXT: SamsungPay {A} --
# 153231                                                NaN
# 153234       REASON: prep_behind TEXT: SamsungPay {A} --
# 153240                                                NaN
# 153241       REASON: prep_behind TEXT: SamsungPay {A} --
# 153243       REASON: prep_behind TEXT: SamsungPay {A} --
# 153244       REASON: prep_behind TEXT: SamsungPay {A} --
# 153252                                                NaN
# 153254                                                NaN
# 153264  REASON: prep_behind TEXT: secret sauce {Fortun...
# 153273                                                NaN
# 153274                                                NaN
# 153275                                                NaN
# 153357                                                NaN
# 153422                                                NaN
# 153475                                                NaN
# 153505                                                NaN
# 153595                                                NaN
#
#                                                annotation
# 51      {'dep_parse': 'nsubj(believe-2, i-1)\nroot(ROO...
# 54      {'dep_parse': 'advmod(will-9, once-1)\nnsubj(g...
# 57      {'dep_parse': 'nn(Bank-2, Barclays-1)\nnsubj(d...
# 61      {'dep_parse': 'nsubj(got-2, I-1)\nroot(ROOT-0,...
# 69      {'dep_parse': 'nsubj(saved-3, googlewallet-1)\...
# 118     {'dep_parse': "mark(supporting-6, as-1)\nnsubj...
# 163     {'dep_parse': 'nn(PayPal-4, Kaylawalton36yahoo...
# 164     {'dep_parse': 'nn(PayPal-4, Kaylawalton36yahoo...
# 211     {'dep_parse': 'nn(UK-2, Barclays-1)\nnsubj(rel...
# 224     {'dep_parse': 'nsubj(thought-2, I-1)\nroot(ROO...
# 232     {'dep_parse': 'advmod(lost-4, Also-1)\naux(los...
# 240     {'dep_parse': 'aux(help-4, Will-1)\ndet(innova...
# 241     {'dep_parse': 'nsubj(thought-2, I-1)\nroot(ROO...
# 248     {'dep_parse': 'nsubj(thought-2, I-1)\nroot(ROO...
# 276     {'dep_parse': "csubjpass(released-14, Spoke-1)...
# 282     {'dep_parse': 'csubjpass(released-14, Spoke-1)...
# 314     {'dep_parse': 'nsubj(gets-2, UK-1)\ncsubj(refu...
# 373     {'dep_parse': 'nsubj(exploiting-3, Hackers-1)\...
# 378     {'dep_parse': 'cop(weird-3, is-1)\nnsubj(weird...
# 393     {'dep_parse': "advmod(move-2, just-1)\nroot(RO...
# 419     {'dep_parse': 'cc(take-4, And-1)\naux(take-4, ...
# 431     {'dep_parse': 'mark(checked-3, if-1)\nnsubj(ch...
# 432     {'dep_parse': 'nsubj(exploiting-3, Hackers-1)\...
# 440     {'dep_parse': 'det(news-2, any-1)\nnsubj(hit-9...
# 465     {'dep_parse': 'nsubj(added-2, PayPal-1)\nroot(...
# 467     {'dep_parse': 'nsubj(added-2, PayPal-1)\nroot(...
# 469     {'dep_parse': 'nsubj(added-2, PayPal-1)\nroot(...
# 474     {'dep_parse': 'nsubj(added-2, PayPal-1)\nroot(...
# 477     {'dep_parse': 'nn(date-4, ApplePay-1)\nnn(date...
# 478     {'dep_parse': 'nn(date-4, ApplePay-1)\nnn(date...
# ...                                                   ...
# 153178  {'dep_parse': 'amod(hackers-2, Chinese-1)\nnsu...
# 153179  {'dep_parse': 'amod(hackers-2, Chinese-1)\nnsu...
# 153180  {'dep_parse': 'amod(hackers-2, Chinese-1)\nnsu...
# 153195  {'dep_parse': 'det(Bank-2, The-1)\nnsubj(froze...
# 153201  {'dep_parse': 'nsubj(reveals-2, Bank-1)\nroot(...
# 153203  {'dep_parse': 'nsubj(wait-2, Oh-1)\nccomp(supp...
# 153206  {'dep_parse': 'amod(hackers-2, Chinese-1)\nnsu...
# 153207  {'dep_parse': 'amod(hackers-2, Chinese-1)\nnsu...
# 153216  {'dep_parse': 'dep(reveals-4, Pjotrww-1)\nnsub...
# 153219  {'dep_parse': 'amod(hackers-2, Chinese-1)\nnsu...
# 153222  {'dep_parse': 'amod(hackers-2, Chinese-1)\nnsu...
# 153223  {'dep_parse': 'amod(hackers-2, Chinese-1)\nnsu...
# 153224  {'dep_parse': 'amod(hackers-2, Chinese-1)\nnsu...
# 153231  {'dep_parse': 'amod(banks-2, Canadian-1)\nnsub...
# 153234  {'dep_parse': 'amod(hackers-2, Chinese-1)\nnsu...
# 153240  {'dep_parse': 'nsubj(accept-3, We-1)\naux(acce...
# 153241  {'dep_parse': 'amod(hackers-2, Chinese-1)\nnsu...
# 153243  {'dep_parse': 'amod(hackers-2, Chinese-1)\nnsu...
# 153244  {'dep_parse': 'amod(hackers-2, Chinese-1)\nnsu...
# 153252  {'dep_parse': 'nsubj(sucks-2, Apple-1)\nroot(R...
# 153254  {'dep_parse': 'nsubj(sucks-2, Apple-1)\nroot(R...
# 153264  {'dep_parse': 'amod(hackers-2, Chinese-1)\nnsu...
# 153273  {'dep_parse': 'nsubj(adds-2, ApplePay-1)\nroot...
# 153274  {'dep_parse': 'cc(take-5, or-1)\naux(take-5, d...
# 153275  {'dep_parse': 'nsubj(use-3, I-1)\naux(use-3, c...
# 153357  {'dep_parse': 'nsubj(targeted-3, Hackers-1)\nd...
# 153422  {'dep_parse': 'nsubj(adds-2, ApplePay-1)\nroot...
# 153475  {'dep_parse': 'cc(see-3, But-1)\nnsubj(see-3, ...
# 153505  {'dep_parse': 'cc(see-3, But-1)\nnsubj(see-3, ...
# 153595  {'dep_parse': 'nn(Hackers-2, Chinese-1)\nnsubj...
#
# [18317 rows x 36 columns]

# %%
df = df_rels_selected[["arg1", "rel", "arg2", "arg1_prepositions","rel_prepositions","arg2_prepositions"]]

# %%
df
# Out:
#                         arg1                      rel  \
# 51                     {you}                    {use}
# 54                       {i}                    {get}
# 57                     banks          is {developing}
# 61                       {i}                    {got}
# 69              googlewallet              {saved} now
# 118                      {i}             'm {finding}
# 163                   PayPal                    {get}
# 164                   PayPal                    {get}
# 211                   the UK         is {relaunching}
# 224                      {i}                {thought}
# 232              Barclaycard         Also have {lost}
# 240              Barclaycard                 {defend}
# 241                      {i}                {thought}
# 248                      {i}                {thought}
# 276       an apple {advisor}                   {told}
# 282       an apple {advisor}                   {told}
# 314                   the UK                   {gets}
# 373          Chinese Hackers         are {exploiting}
# 378                    banks                {support}
# 393                    banks            all {support}
# 419                    {you}             would {take}
# 431                      {i}          {checked} later
# 432          Chinese Hackers         are {exploiting}
# 440     any {news} regarding               will {hit}
# 465                   PayPal                  {added}
# 467                   PayPal                  {added}
# 469                   PayPal                  {added}
# 474                   PayPal                  {added}
# 477                    banks                {support}
# 478                    banks                {support}
# ...                      ...                      ...
# 153178       Chinese Hackers               {attacked}
# 153179       Chinese Hackers               {attacked}
# 153180       Chinese Hackers               {attacked}
# 153195                 banks                  {froze}
# 153201                 banks                {reveals}
# 153203               verizon  has not {supported} yet
# 153206       Chinese Hackers               {attacked}
# 153207       Chinese Hackers               {attacked}
# 153216                 banks                {reveals}
# 153219       Chinese Hackers               {attacked}
# 153222       Chinese Hackers               {attacked}
# 153223       Chinese Hackers               {attacked}
# 153224       Chinese Hackers               {attacked}
# 153231                 banks    finally {advertising}
# 153234       Chinese Hackers               {attacked}
# 153240                  {we}              do {accept}
# 153241       Chinese Hackers               {attacked}
# 153243       Chinese Hackers               {attacked}
# 153244       Chinese Hackers               {attacked}
# 153252                  {me}                    {use}
# 153254                  {me}                    {use}
# 153264       Chinese Hackers               {breached}
# 153273            {applepay}                   {adds}
# 153274                 {you}    do not {take} anymore
# 153275                   {i}                can {use}
# 153357       Chinese Hackers               {targeted}
# 153422            {applepay}                   {adds}
# 153475                 banks           why {shouldnt}
# 153505                 banks           why {shouldnt}
# 153595       Chinese Hackers               {Breached}
#
#                                   arg2                   arg1_prepositions  \
# 51                        googlewallet                                 NaN
# 54                              PayPal                                 NaN
# 57         own mobile payment {device}  REASON: prep_in TEXT: the {UK} --
# 61                              PayPal                                 NaN
# 69                                {me}                                 NaN
# 118                              banks                                 NaN
# 163                 own custom {video}                                 NaN
# 164                               {ht}                                 NaN
# 211     bpay mobile {payments} compete                                 NaN
# 224                             the US                                 NaN
# 232                         the {plot}                                 NaN
# 240                           {corner}                                 NaN
# 241                             the US                                 NaN
# 248                             the US                                 NaN
# 276                             the UK                                 NaN
# 282                             the UK                                 NaN
# 314                         {applepay}                                 NaN
# 373               magento {flaw} steal                                 NaN
# 378                         {applepay}                                 NaN
# 393                         {applepay}                                 NaN
# 419                       googlewallet                                 NaN
# 431                       googlewallet                                 NaN
# 432               magento {flaw} steal                                 NaN
# 440                             the UK                                 NaN
# 465             million new {accounts}                                 NaN
# 467             million new {accounts}                                 NaN
# 469             million new {accounts}                                 NaN
# 474             million new {accounts}                                 NaN
# 477                              {it.}                                 NaN
# 478          applepay uk launch {date}                                 NaN
# ...                                ...                                 ...
# 153178                   the {company}                                 NaN
# 153179                   the {company}                                 NaN
# 153180                   the {company}                                 NaN
# 153195              debit card {cause}                                 NaN
# 153201              imminent {arrival}                                 NaN
# 153203                            {it}                                 NaN
# 153206                   the {company}                                 NaN
# 153207                   the {company}                                 NaN
# 153216              imminent {arrival}                                 NaN
# 153219                   the {company}                                 NaN
# 153222                   the {company}                                 NaN
# 153223                   the {company}                                 NaN
# 153224                   the {company}                                 NaN
# 153231                      {applepay}                                 NaN
# 153234                   the {company}                                 NaN
# 153240                          PayPal                                 NaN
# 153241                   the {company}                                 NaN
# 153243                   the {company}                                 NaN
# 153244                   the {company}                                 NaN
# 153252                    googlewallet                                 NaN
# 153254                    googlewallet                                 NaN
# 153264               looppay {company}                                 NaN
# 153273                           banks                                 NaN
# 153274                          PayPal                                 NaN
# 153275                    googlewallet                                 NaN
# 153357                    {samsungpay}                                 NaN
# 153422                          the US                                 NaN
# 153475                           {it.}                                 NaN
# 153505                           {it.}                                 NaN
# 153595                       {looppay}                                 NaN
#
#                                          rel_prepositions  \
# 51                                                    NaN
# 54                                                    NaN
# 57                                                    NaN
# 61                                                    NaN
# 69                                                    NaN
# 118                                                   NaN
# 163                                                   NaN
# 164                                                   NaN
# 211                                                   NaN
# 224                                                   NaN
# 232                                                   NaN
# 240     REASON: prep_from TEXT: the impending {launch}...
# 241                                                   NaN
# 248                                                   NaN
# 276                                                   NaN
# 282                                                   NaN
# 314                                                   NaN
# 373                                                   NaN
# 378                                                   NaN
# 393                                                   NaN
# 419                                                   NaN
# 431                                                   NaN
# 432                                                   NaN
# 440                                                   NaN
# 465          REASON: prep_in TEXT: the last {quarter} --
# 467          REASON: prep_in TEXT: the last {quarter} --
# 469          REASON: prep_in TEXT: the last {quarter} --
# 474          REASON: prep_in TEXT: the last {quarter} --
# 477                                                   NaN
# 478                                                   NaN
# ...                                                   ...
# 153178                                                NaN
# 153179                                                NaN
# 153180                                                NaN
# 153195                                                NaN
# 153201                                                NaN
# 153203                                                NaN
# 153206                                                NaN
# 153207                                                NaN
# 153216                                                NaN
# 153219                                                NaN
# 153222                                                NaN
# 153223                                                NaN
# 153224                                                NaN
# 153231                                                NaN
# 153234                                                NaN
# 153240                                                NaN
# 153241                                                NaN
# 153243                                                NaN
# 153244                                                NaN
# 153252                                                NaN
# 153254                                                NaN
# 153264                                                NaN
# 153273                                                NaN
# 153274                                                NaN
# 153275                                                NaN
# 153357                                                NaN
# 153422                                                NaN
# 153475                                                NaN
# 153505                                                NaN
# 153595                                                NaN
#
#                                         arg2_prepositions
# 51                                                    NaN
# 54                                                    NaN
# 57                                                    NaN
# 61                                                    NaN
# 69                                                    NaN
# 118                                                   NaN
# 163                                                   NaN
# 164                                                   NaN
# 211                                                   NaN
# 224                                                   NaN
# 232                                                   NaN
# 240                                                   NaN
# 241                                                   NaN
# 248                                                   NaN
# 276                                                   NaN
# 282                                                   NaN
# 314                                                   NaN
# 373                                                   NaN
# 378                                                   NaN
# 393                                                   NaN
# 419                                                   NaN
# 431                                                   NaN
# 432                                                   NaN
# 440                                                   NaN
# 465                                                   NaN
# 467                                                   NaN
# 469                                                   NaN
# 474                                                   NaN
# 477                                                   NaN
# 478                                                   NaN
# ...                                                   ...
# 153178       REASON: prep_behind TEXT: SamsungPay {A} --
# 153179       REASON: prep_behind TEXT: SamsungPay {A} --
# 153180       REASON: prep_behind TEXT: SamsungPay {A} --
# 153195                                                NaN
# 153201                 REASON: prep_in TEXT: {Canada} --
# 153203                                                NaN
# 153206         REASON: prep_behind TEXT: {SamsungPay} --
# 153207         REASON: prep_behind TEXT: {SamsungPay} --
# 153216                 REASON: prep_in TEXT: {Canada} --
# 153219       REASON: prep_behind TEXT: SamsungPay {A} --
# 153222       REASON: prep_behind TEXT: SamsungPay {A} --
# 153223       REASON: prep_behind TEXT: SamsungPay {A} --
# 153224       REASON: prep_behind TEXT: SamsungPay {A} --
# 153231                                                NaN
# 153234       REASON: prep_behind TEXT: SamsungPay {A} --
# 153240                                                NaN
# 153241       REASON: prep_behind TEXT: SamsungPay {A} --
# 153243       REASON: prep_behind TEXT: SamsungPay {A} --
# 153244       REASON: prep_behind TEXT: SamsungPay {A} --
# 153252                                                NaN
# 153254                                                NaN
# 153264  REASON: prep_behind TEXT: secret sauce {Fortun...
# 153273                                                NaN
# 153274                                                NaN
# 153275                                                NaN
# 153357                                                NaN
# 153422                                                NaN
# 153475                                                NaN
# 153505                                                NaN
# 153595                                                NaN
#
# [18317 rows x 6 columns]

# %%
df[np.logical_and(df['arg1'].str.contains("ApplePay"),df['arg2'].str.contains("Barclays"))]
# Out:
# Empty DataFrame
# Columns: [arg1, rel, arg2, arg1_prepositions, rel_prepositions, arg2_prepositions]
# Index: []

# %%
df[df['arg1'].str.contains("applepay")]
# Out:
#                              arg1                          rel    arg2  \
# 1702                   {applepay}                     {enters}  the UK
# 1706                   {applepay}                     {enters}  the UK
# 1710                   {applepay}                     {enters}  the UK
# 1714                   {applepay}                     {enters}  the UK
# 1718                   {applepay}                     {enters}  the UK
# 1722                   {applepay}                     {enters}  the UK
# 1727                   {applepay}                     {enters}  the UK
# 1731                   {applepay}                     {enters}  the UK
# 1736                   {applepay}                     {enters}  the UK
# 1740                   {applepay}                     {enters}  the UK
# 1747                   {applepay}                     {enters}  the UK
# 1755                   {applepay}                     {enters}  the UK
# 1761                   {applepay}                     {enters}  the UK
# 1765                   {applepay}                     {enters}  the UK
# 1769                   {applepay}                     {enters}  the UK
# 1773                   {applepay}                     {enters}  the UK
# 1777                   {applepay}                     {enters}  the UK
# 1781                   {applepay}                     {enters}  the UK
# 1785                   {applepay}                     {enters}  the UK
# 1792                   {applepay}                     {enters}  the UK
# 1796                   {applepay}                     {enters}  the UK
# 1800                   {applepay}                     {enters}  the UK
# 1804                   {applepay}                     {enters}  the UK
# 1808                   {applepay}                     {enters}  the UK
# 1812                   {applepay}                     {enters}  the UK
# 1816                   {applepay}                     {enters}  the UK
# 1824                   {applepay}                     {enters}  the UK
# 1828                   {applepay}                     {enters}  the UK
# 2490                   {applepay}                       {hits}  the UK
# 2492                   {applepay}                       {hits}  the UK
# ...                           ...                          ...     ...
# 108763                 {applepay}                       {Adds}   banks
# 110452  applepay brings {support}                      {added}   banks
# 111404                 {applepay}                 now {boasts}   banks
# 113873              no {applepay}            can {change} easy   banks
# 115036                 {applepay}                   {supports}   banks
# 115052                 {applepay}                   {supports}   banks
# 115098                 {applepay}                   {supports}   banks
# 115106                 {applepay}                So {supports}   banks
# 118305                 {applepay}                       {Adds}   banks
# 119903              no {applepay}             then 'm {moving}   banks
# 120144                 {applepay}                   {supports}   banks
# 121532                 {applepay}                   {supports}   banks
# 126537              no {applepay}  there either might {switch}   banks
# 130246                 {applepay}                       {Adds}   banks
# 148995                 {applepay}               now {supports}   banks
# 152410                 {applepay}              {brings} closer  the US
# 152417                 {applepay}              {brings} closer  the US
# 152825                 {applepay}                       {adds}   banks
# 152826                 {applepay}                       {adds}   banks
# 152828                 {applepay}                       {adds}   banks
# 152832                 {applepay}                       {adds}   banks
# 152837                 {applepay}                       {adds}   banks
# 152838                 {applepay}                       {adds}   banks
# 152842                 {applepay}                       {adds}   banks
# 152845                 {applepay}                       {adds}   banks
# 152861                 {applepay}                       {adds}   banks
# 152975                 {applepay}                       {adds}   banks
# 153130                 {applepay}                       {adds}   banks
# 153273                 {applepay}                       {adds}   banks
# 153422                 {applepay}                       {adds}  the US
#
#                               arg1_prepositions  \
# 1702                                        NaN
# 1706                                        NaN
# 1710                                        NaN
# 1714                                        NaN
# 1718                                        NaN
# 1722                                        NaN
# 1727                                        NaN
# 1731                                        NaN
# 1736                                        NaN
# 1740                                        NaN
# 1747                                        NaN
# 1755                                        NaN
# 1761                                        NaN
# 1765                                        NaN
# 1769                                        NaN
# 1773                                        NaN
# 1777                                        NaN
# 1781                                        NaN
# 1785                                        NaN
# 1792                                        NaN
# 1796                                        NaN
# 1800                                        NaN
# 1804                                        NaN
# 1808                                        NaN
# 1812                                        NaN
# 1816                                        NaN
# 1824                                        NaN
# 1828                                        NaN
# 2490                                        NaN
# 2492                                        NaN
# ...                                         ...
# 108763                                      NaN
# 110452  REASON: prep_for TEXT: More {Banks} --
# 111404                                      NaN
# 113873                                      NaN
# 115036                                      NaN
# 115052                                      NaN
# 115098                                      NaN
# 115106                                      NaN
# 118305                                      NaN
# 119903   REASON: prep_from TEXT: {Barclays} --
# 120144                                      NaN
# 121532                                      NaN
# 126537                                      NaN
# 130246                                      NaN
# 148995                                      NaN
# 152410                                      NaN
# 152417                                      NaN
# 152825                                      NaN
# 152826                                      NaN
# 152828                                      NaN
# 152832                                      NaN
# 152837                                      NaN
# 152838                                      NaN
# 152842                                      NaN
# 152845                                      NaN
# 152861                                      NaN
# 152975                                      NaN
# 153130                                      NaN
# 153273                                      NaN
# 153422                                      NaN
#
#                                          rel_prepositions  \
# 1702                                                  NaN
# 1706                                                  NaN
# 1710                                                  NaN
# 1714                                                  NaN
# 1718                                                  NaN
# 1722                                                  NaN
# 1727                                                  NaN
# 1731                                                  NaN
# 1736                                                  NaN
# 1740                                                  NaN
# 1747                                                  NaN
# 1755                                                  NaN
# 1761                                                  NaN
# 1765                                                  NaN
# 1769                                                  NaN
# 1773                                                  NaN
# 1777                                                  NaN
# 1781                                                  NaN
# 1785                                                  NaN
# 1792                                                  NaN
# 1796                                                  NaN
# 1800                                                  NaN
# 1804                                                  NaN
# 1808                                                  NaN
# 1812                                                  NaN
# 1816                                                  NaN
# 1824                                                  NaN
# 1828                                                  NaN
# 2490                                                  NaN
# 2492                                                  NaN
# ...                                                   ...
# 108763                                                NaN
# 110452                REASON: prep_on TEXT: {Tuesday} --
# 111404  REASON: prep_thanks_to TEXT: latest {round} ad...
# 113873                                                NaN
# 115036                                                NaN
# 115052                                                NaN
# 115098                                                NaN
# 115106                                                NaN
# 118305                                                NaN
# 119903                                                NaN
# 120144                                                NaN
# 121532                                                NaN
# 126537                                                NaN
# 130246                                                NaN
# 148995                                                NaN
# 152410                                                NaN
# 152417                                                NaN
# 152825                                                NaN
# 152826                                                NaN
# 152828                                                NaN
# 152832                                                NaN
# 152837                                                NaN
# 152838                                                NaN
# 152842                                                NaN
# 152845                                                NaN
# 152861                                                NaN
# 152975                                                NaN
# 153130                                                NaN
# 153273                                                NaN
# 153422                                                NaN
#
#                                     arg2_prepositions
# 1702                                              NaN
# 1706                                              NaN
# 1710                                              NaN
# 1714                                              NaN
# 1718                                              NaN
# 1722                                              NaN
# 1727                                              NaN
# 1731                                              NaN
# 1736                                              NaN
# 1740                                              NaN
# 1747                                              NaN
# 1755                                              NaN
# 1761                                              NaN
# 1765                                              NaN
# 1769                                              NaN
# 1773                                              NaN
# 1777                                              NaN
# 1781                                              NaN
# 1785                                              NaN
# 1792                                              NaN
# 1796                                              NaN
# 1800                                              NaN
# 1804                                              NaN
# 1808                                              NaN
# 1812                                              NaN
# 1816                                              NaN
# 1824                                              NaN
# 1828                                              NaN
# 2490    REASON: prep_on TEXT: July 14th {fintech} --
# 2492    REASON: prep_on TEXT: July 14th {fintech} --
# ...                                               ...
# 108763               REASON: prep_in TEXT: {U.S.} --
# 110452                                            NaN
# 111404                                            NaN
# 113873                                            NaN
# 115036                                            NaN
# 115052                                            NaN
# 115098                                            NaN
# 115106                                            NaN
# 118305               REASON: prep_in TEXT: {U.S.} --
# 119903                                            NaN
# 120144                                            NaN
# 121532                                            NaN
# 126537                                            NaN
# 130246               REASON: prep_in TEXT: {U.S.} --
# 148995                                            NaN
# 152410                                            NaN
# 152417                                            NaN
# 152825                                            NaN
# 152826                                            NaN
# 152828                                            NaN
# 152832                                            NaN
# 152837                                            NaN
# 152838                                            NaN
# 152842                                            NaN
# 152845                                            NaN
# 152861                                            NaN
# 152975                                            NaN
# 153130                                            NaN
# 153273                                            NaN
# 153422                                            NaN
#
# [1888 rows x 6 columns]
