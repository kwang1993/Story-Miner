# %%
pd.set_option('display.max_colwidth', -1)
print(len(df_filtered))
#print(df_filtered)
#import random

#random.sample(tweets, 150)
pd.reset_option('display.max_colwidth')
# Out:
# 29597

# %%
# %matplotlib inline 

import pandas as pd
from collections import defaultdict
import re
import numpy as np
import sys
import seaborn as sns
import matplotlib.pyplot as plt

pal = sns.color_palette()


sys.path.insert(0, '../../base_codes')
sys.path.insert(0, '../../data_specific_codes')
sys.path.insert(0, '../../utility_codes')


from RE_init import *
from main_functions import *
from utility_functions import *

def read_df_rel():
    #based_dir = '../../../../data/GoodReads/'
    based_dir = '../../../../data/Tweets/'
    file_input_name = 'merged.csv'
    file_input = based_dir + file_input_name    
    ff = open(file_input)
    delim=","
    df = pd.read_csv(file_input,delimiter=delim,header=0)        
    return df

df_rels = read_df_rel()

# %%
len(df_rels)
df_rels.rename(columns = {'Replaced Version of Main Tweet':'text'}, inplace = True)
df_rels.columns
# Out:
# Index([u'tweet_id', u' tweet_posted_time', u' tweet_author_id',
#        u'tweet_author_location', u' tweet_country', u'city', u' tweet_lang',
#        u'lat', u'lon', u'ALTLAT', u'ALTLON ', u'tweet_text', u'link',
#        u'Main Tweet', u'Main Entities', u'Main Hashtags',
#        u'Alternative Possibility', u'Side Tweets', u'Related to',
#        u'Retweeted From', u'Feed', u'Audience', u'text'],
#       dtype='object')

# %%
df_unique = df_rels.drop_duplicates('text', inplace = False)#.reset_index(inplace=True)

# %%
len(df_unique)
# Out:
# 202585

# %%
df_filtered = df_unique[df_unique["text"].str.contains("ApplePay")]
print len(df_filtered)
# Out:
# 126939

# %%
entity_versions = get_entity_versions("twitter")
print entity_versions
# Out:
# defaultdict(<type 'list'>, {'samsungpay': ['samsungpay'], 'googlewallet': ['googlewallet'], 'apple': ['apple'], 'looppay': ['looppay'], 'barclays': ['barclays'], 'chevron': ['chevron'], 'mcdonalds': ['mcdonalds'], 'applepay': ['applepay'], 'chilis': ['chilis'], 'tesco': ['tesco'], 'barclaycard': ['barclaycard'], 'riteaid': ['riteaid'], 'lloyds': ['lloyds'], 'verizon': ['verizon'], 'chinese hackers': ['hackers', 'hackers', 'chinese hackers'], 'the us': ['the us', 'us'], 'paypal': ['paypal'], 'the uk': ['the uk', 'uk'], 'starbucks': ['starbucks'], 'samsung': ['samsung'], 'amex': ['american express', 'express', 'amex'], 'youtube': ['youtube'], 'hsbc': ['hsbc', 'hsbc direct'], 'mastercard': ['mastercard'], 'banks': ['banks', 'bank']})

# %%
for e1 in entity_versions.keys():
    for e2 in entity_versions.keys():
        df_filtered = df_unique[np.logical_and(df_unique["text"].str.contains(e1), df_unique["text"].str.contains(e2))]
        print e1, e2, len()
# Out:
# samsungpay samsungpay
# samsungpay googlewallet
# samsungpay apple
# samsungpay looppay
# samsungpay barclays
# samsungpay chevron
# samsungpay mcdonalds
# samsungpay applepay
# samsungpay chilis
# samsungpay tesco
# samsungpay barclaycard
# samsungpay riteaid
# samsungpay lloyds
# samsungpay verizon
# samsungpay chinese hackers
# samsungpay the us
# samsungpay paypal
# samsungpay the uk
# samsungpay starbucks
# samsungpay samsung
# samsungpay amex
# samsungpay youtube
# samsungpay hsbc
# samsungpay mastercard
# samsungpay banks
# googlewallet samsungpay
# googlewallet googlewallet
# googlewallet apple
# googlewallet looppay
# googlewallet barclays
# googlewallet chevron
# googlewallet mcdonalds
# googlewallet applepay
# googlewallet chilis
# googlewallet tesco
# googlewallet barclaycard
# googlewallet riteaid
# googlewallet lloyds
# googlewallet verizon
# googlewallet chinese hackers
# googlewallet the us
# googlewallet paypal
# googlewallet the uk
# googlewallet starbucks
# googlewallet samsung
# googlewallet amex
# googlewallet youtube
# googlewallet hsbc
# googlewallet mastercard
# googlewallet banks
# apple samsungpay
# apple googlewallet
# apple apple
# apple looppay
# apple barclays
# apple chevron
# apple mcdonalds
# apple applepay
# apple chilis
# apple tesco
# apple barclaycard
# apple riteaid
# apple lloyds
# apple verizon
# apple chinese hackers
# apple the us
# apple paypal
# apple the uk
# apple starbucks
# apple samsung
# apple amex
# apple youtube
# apple hsbc
# apple mastercard
# apple banks
# looppay samsungpay
# looppay googlewallet
# looppay apple
# looppay looppay
# looppay barclays
# looppay chevron
# looppay mcdonalds
# looppay applepay
# looppay chilis
# looppay tesco
# looppay barclaycard
# looppay riteaid
# looppay lloyds
# looppay verizon
# looppay chinese hackers
# looppay the us
# looppay paypal
# looppay the uk
# looppay starbucks
# looppay samsung
# looppay amex
# looppay youtube
# looppay hsbc
# looppay mastercard
# looppay banks
# barclays samsungpay
# barclays googlewallet
# barclays apple
# barclays looppay
# barclays barclays
# barclays chevron
# barclays mcdonalds
# barclays applepay
# barclays chilis
# barclays tesco
# barclays barclaycard
# barclays riteaid
# barclays lloyds
# barclays verizon
# barclays chinese hackers
# barclays the us
# barclays paypal
# barclays the uk
# barclays starbucks
# barclays samsung
# barclays amex
# barclays youtube
# barclays hsbc
# barclays mastercard
# barclays banks
# chevron samsungpay
# chevron googlewallet
# chevron apple
# chevron looppay
# chevron barclays
# chevron chevron
# chevron mcdonalds
# chevron applepay
# chevron chilis
# chevron tesco
# chevron barclaycard
# chevron riteaid
# chevron lloyds
# chevron verizon
# chevron chinese hackers
# chevron the us
# chevron paypal
# chevron the uk
# chevron starbucks
# chevron samsung
# chevron amex
# chevron youtube
# chevron hsbc
# chevron mastercard
# chevron banks
# mcdonalds samsungpay
# mcdonalds googlewallet
# mcdonalds apple
# mcdonalds looppay
# mcdonalds barclays
# mcdonalds chevron
# mcdonalds mcdonalds
# mcdonalds applepay
# mcdonalds chilis
# mcdonalds tesco
# mcdonalds barclaycard
# mcdonalds riteaid
# mcdonalds lloyds
# mcdonalds verizon
# mcdonalds chinese hackers
# mcdonalds the us
# mcdonalds paypal
# mcdonalds the uk
# mcdonalds starbucks
# mcdonalds samsung
# mcdonalds amex
# mcdonalds youtube
# mcdonalds hsbc
# mcdonalds mastercard
# mcdonalds banks
# applepay samsungpay
# applepay googlewallet
# applepay apple
# applepay looppay
# applepay barclays
# applepay chevron
# applepay mcdonalds
# applepay applepay
# applepay chilis
# applepay tesco
# applepay barclaycard
# applepay riteaid
# applepay lloyds
# applepay verizon
# applepay chinese hackers
# applepay the us
# applepay paypal
# applepay the uk
# applepay starbucks
# applepay samsung
# applepay amex
# applepay youtube
# applepay hsbc
# applepay mastercard
# applepay banks
# chilis samsungpay
# chilis googlewallet
# chilis apple
# chilis looppay
# chilis barclays
# chilis chevron
# chilis mcdonalds
# chilis applepay
# chilis chilis
# chilis tesco
# chilis barclaycard
# chilis riteaid
# chilis lloyds
# chilis verizon
# chilis chinese hackers
# chilis the us
# chilis paypal
# chilis the uk
# chilis starbucks
# chilis samsung
# chilis amex
# chilis youtube
# chilis hsbc
# chilis mastercard
# chilis banks
# tesco samsungpay
# tesco googlewallet
# tesco apple
# tesco looppay
# tesco barclays
# tesco chevron
# tesco mcdonalds
# tesco applepay
# tesco chilis
# tesco tesco
# tesco barclaycard
# tesco riteaid
# tesco lloyds
# tesco verizon
# tesco chinese hackers
# tesco the us
# tesco paypal
# tesco the uk
# tesco starbucks
# tesco samsung
# tesco amex
# tesco youtube
# tesco hsbc
# tesco mastercard
# tesco banks
# barclaycard samsungpay
# barclaycard googlewallet
# barclaycard apple
# barclaycard looppay
# barclaycard barclays
# barclaycard chevron
# barclaycard mcdonalds
# barclaycard applepay
# barclaycard chilis
# barclaycard tesco
# barclaycard barclaycard
# barclaycard riteaid
# barclaycard lloyds
# barclaycard verizon
# barclaycard chinese hackers
# barclaycard the us
# barclaycard paypal
# barclaycard the uk
# barclaycard starbucks
# barclaycard samsung
# barclaycard amex
# barclaycard youtube
# barclaycard hsbc
# barclaycard mastercard
# barclaycard banks
# riteaid samsungpay
# riteaid googlewallet
# riteaid apple
# riteaid looppay
# riteaid barclays
# riteaid chevron
# riteaid mcdonalds
# riteaid applepay
# riteaid chilis
# riteaid tesco
# riteaid barclaycard
# riteaid riteaid
# riteaid lloyds
# riteaid verizon
# riteaid chinese hackers
# riteaid the us
# riteaid paypal
# riteaid the uk
# riteaid starbucks
# riteaid samsung
# riteaid amex
# riteaid youtube
# riteaid hsbc
# riteaid mastercard
# riteaid banks
# lloyds samsungpay
# lloyds googlewallet
# lloyds apple
# lloyds looppay
# lloyds barclays
# lloyds chevron
# lloyds mcdonalds
