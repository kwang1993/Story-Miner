# %%
import pandas as pd
from collections import defaultdict
import re
import numpy as np
import sys
sys.path.insert(0, '../../base_codes')
sys.path.insert(0, '../../data_specific_codes')
sys.path.insert(0, '../../utility_codes')

#%run -i 'parameters'
#%run -i 'main_functions'
#%run -i 'utility_functions'

from RE_init import *
from main_functions import *
from utility_functions import *


##ALL the books 
pronoun_prefix = "_raw" # no pronoun: "_raw" - with pronoun: "0601"
file_input_postfix = "_with_conjAND_relations_-1.csv" # either "_relations_-1.csv" or "_relations_with_SVP.csv" or "_with_SVP_relations_-1.csv"
svp_prefix = "_with_conjAND"
output_dir = "with_conj_and_rels/"#"improved_entity_matching/"

##MICE_AND_MEN
#based_dir = '../../../../data/GoodReads/revised_pronoun_1Jun2017/results/Mice_and_men/results_with_svp_relationships/'
#based_dir = '../../../../data/GoodReads/Raw_data_no_pronoun/mice_and_men/results_with_svp_relationships/'
#file_input_name = "mice_and_men" + pronoun_prefix + file_input_postfix
#input_name_prefix = 'mice_and_men' + pronoun_prefix + svp_prefix
#DATA_SET = 'goodreads-Mice-and-men'

##HOBBIT
#based_dir = '../../../../data/GoodReads/revised_pronoun_1Jun2017/results/Hobbit/results_with_svp_relationships/'
#based_dir = '../../../../data/GoodReads/Raw_data_no_pronoun/hobbit/results_with_svp_relationships/'
#file_input_name= 'hobbit' + pronoun_prefix + file_input_postfix
#input_name_prefix = 'hobbit' + pronoun_prefix + svp_prefix
#DATA_SET = 'goodreads-Hobbit'

##Mockingbird
#based_dir = '../../../../data/GoodReads/revised_pronoun_1Jun2017/results/Mockingbird/results_with_svp_relationships/'
#based_dir = '../../../../data/GoodReads/Raw_data_no_pronoun/mockingbird/results_with_svp_relationships/'
#file_input_name= 'mockingbird' + pronoun_prefix + file_input_postfix
#input_name_prefix = 'mockingbird' + pronoun_prefix + svp_prefix
#DATA_SET = 'goodreads-Mockingbird'

##Frankenstein
#based_dir = '../../../../data/GoodReads/revised_pronoun_1Jun2017/results/Frankenstein/results_with_svp_relationships/'
based_dir = '../../../../data/GoodReads/Raw_data_no_pronoun/frankenstein/results_with_svp_relationships/'
file_input_name= 'frankenstein' + pronoun_prefix + file_input_postfix
input_name_prefix = 'frankenstein' + pronoun_prefix + svp_prefix
DATA_SET = 'goodreads-Frankenstein'

based_dir = based_dir + output_dir

def read_df_rel(based_dir, file_input_name):
    file_input = based_dir + file_input_name    
    ff = open(file_input)
    delim=","
    df = pd.read_csv(file_input,delimiter=delim,header=0)        
    return df

df_rels = read_df_rel(based_dir, file_input_name)

# %%
'''
df_entity_rankings = get_top_entities(df_rels, 
                 #output_file='../../../../data/GoodReads/Hobbit-Pronoun_subjobj_entity_rankings.csv'
                    output_file=based_dir+ input_name_prefix+ '_subjobj_entity_rankings.csv'
                 , top_num=-1, save_to_file=True)

print_full(df_entity_rankings)
'''
# Out:
# "\ndf_entity_rankings = get_top_entities(df_rels, \n                 #output_file='../../../../data/GoodReads/Hobbit-Pronoun_subjobj_entity_rankings.csv'\n                    output_file=based_dir+ input_name_prefix+ '_subjobj_entity_rankings.csv'\n                 , top_num=-1, save_to_file=True)\n\nprint_full(df_entity_rankings)\n"

# %%
'''
def save_pairwise_relations_with_node_selection(df_rels,entity_versions,output_file):
    f = open(output_file, 'w')
    cnt = Counter()
    for entity in entity_versions:
        print >>f, "-------------------------"
        print >>f, "       ", entity
        print >>f, "-------------------------"    
        for ent_one_version in entity_versions[entity]:
            print >>f, "\n\n**** ", ent_one_version, " ****"
            df_all_versions = defaultdict(list)
            df_one_version = df_rels[np.logical_or(df_rels['arg1'].str.contains(ent_one_version),df_rels['arg2'].str.contains(ent_one_version))]
            list_one_version = df_one_version['rel'].tolist()
            for r in list_one_version:
                cnt[r] += 1
            print >>f, "Frequent relations:"
            for letter,count in cnt.most_common():
                print >>f, letter, ": ", count  
'''
# Out:
# '\ndef save_pairwise_relations_with_node_selection(df_rels,entity_versions,output_file):\n    f = open(output_file, \'w\')\n    cnt = Counter()\n    for entity in entity_versions:\n        print >>f, "-------------------------"\n        print >>f, "       ", entity\n        print >>f, "-------------------------"    \n        for ent_one_version in entity_versions[entity]:\n            print >>f, "\n\n**** ", ent_one_version, " ****"\n            df_all_versions = defaultdict(list)\n            df_one_version = df_rels[np.logical_or(df_rels[\'arg1\'].str.contains(ent_one_version),df_rels[\'arg2\'].str.contains(ent_one_version))]\n            list_one_version = df_one_version[\'rel\'].tolist()\n            for r in list_one_version:\n                cnt[r] += 1\n            print >>f, "Frequent relations:"\n            for letter,count in cnt.most_common():\n                print >>f, letter, ": ", count  \n'

# %%
entity_versions = get_entity_versions(DATA_SET)
print entity_versions
#df_simp = get_simp_df(df_rels.copy(),entity_versions)
#ent_medicals = entity_versions['medical prof']
#output_file = '../../../../data/GoodReads/Frankenstein/Frankenstein-Pronoun_selected_nodes_pairwise_rels.txt'
#save_pairwise_relations_with_node_selection(df_rels,entity_versions,output_file)
print "done"
# Out:
# defaultdict(<type 'list'>, {'gregory peck': ['gregory peck', 'peck', 'gregory'], 'dill': ['dill', 'charles baker', 'dill harris', 'charles baker dill harris'], 'people': ['people', 'townspeople', 'town'], 'mayella': ['mayella', 'mayella ewell', 'mayella ewel', 'white girl', 'ewell daughter', "ewell's daughter", "bob ewell's daughter", 'white woman'], 'judge': ['judge', 'judge taylor'], 'calpurnia': ['calpurnia'], 'children': ['children'], 'heck tate': ['heck tate', 'heck', 'tate'], 'mr walter cunningham': ['mr walter cunningham', 'cunningham', 'mr cunningham', 'walter', 'walter cunningham'], 'mrs. dubose': ['mrs. dubose', 'dubose', 'mrs dubose'], 'radley place': ['radley place', "radley's place", 'radley property', "radley's property", 'radley house'], 'tom': ['tom', 'tom robinson', 'robinson', 'black man', 'negro', 'black negro', 'mockingbird'], "tom's widow": ["tom's widow", "tom robinson's widow", 'widow', "tom's wife"], 'nathan radley': ['nathan radley', 'nathan'], 'jem': ['jem', 'jem finch', 'brother'], 'atticus': ['atticus', 'atticus finch', 'father'], 'jury': ['jury'], 'lee': ['lee', 'harper lee', 'author'], 'scout': ['scout', 'scout finch', 'sister'], 'bob ewell': ['bob ewell', 'bob', 'mr. ewell', 'mr ewell', 'bob ewel', "mayella's father", 'mayella father'], 'miss maudie': ['miss maudie', 'maudie', 'maudie atkinson'], 'mr dolphus raymond': ['mr dolphus raymond', 'raymond', 'mr raymond'], 'bluejays': ['bluejays'], 'jean louise finch': ['jean louise finch'], 'school': ['school'], 'gift': ['gift', 'gifts'], 'maycomb': ['maycomb'], 'trial': ['trial', 'court'], 'boo': ['boo', 'arthur', 'arthur radley', 'boo radley', 'arthur boo radley'], 'alexandra': ['alexandra', 'aunt alexandra', 'aunt', 'his aunt', 'her aunt', "jem's aunt"]})
# done

# %%
rels_to_network(df_rels,
                input_fname=input_name_prefix,
                output_dir_arg=based_dir,#+output_dir,
                MAX_ITERATION=-1,
                NODE_SELECTION=True,
                DATA_SET=DATA_SET,
                SAVE_GEFX=True,
                SAVE_PAIRWISE_RELS=True,
                SHOW_ARGUMENT_GRAPH=True,
                SAVE_G_JSON=True,
                SAVE_DF_SELECTED=True)
# Out:
# gregory peck atticus {0: {'label': '{gives} <<his {performance} lifetime>> as-1'}}
# atticus people {0: {'label': 'is rightly {held}-1'}, 1: {'label': '{outed} <<{him}>> in front of-1'}, 2: {'label': '{challenges}-1'}}
# atticus trial {0: {'label': '{defends} <<{him}>> in-1'}, 1: {'label': '{defends} <<a black {man}>> in-1'}, 2: {'label': '{disproves} <<Ewell {accusation}>> at-1'}, 3: {'label': 'especially when totally {embarrasses} <<Mayella {father}>> in-1'}}
# atticus scout {0: {'label': '{tells}-1'}, 1: {'label': '{named}-1'}, 2: {'label': '{gives}-1'}, 3: {'label': '{takes} on <<a {case}>> as-1'}}
# atticus bob ewell {0: {'label': 'especially when totally {embarrasses}-1'}}
# atticus tom {0: {'label': '{defends}-7'}, 1: {'label': 'is {defending}-6'}, 2: {'label': '{defended}-4'}, 3: {'label': '{defending}-1'}, 4: {'label': 'to {defend}-1'}, 5: {'label': 'will {win}-1'}, 6: {'label': 'has {taken} on-1'}, 7: {'label': 'is {representing}-1'}, 8: {'label': 'was {doing} <<{what}>> for-1'}, 9: {'label': '{takes}-1'}, 10: {'label': 'should not be {defending}-1'}, 11: {'label': 'was {helping}-1'}, 12: {'label': 'when {defends}-1'}, 13: {'label': 'has {defended}-1'}, 14: {'label': '{takes} up-1'}, 15: {'label': 'still {defended} much-1'}}
# atticus children {0: {'label': '{teaches} <<{lessons}>> to-1'}, 1: {'label': 'does not {shelter}-1'}, 2: {'label': '{lived}-1'}, 3: {'label': '{exposing}-1'}, 4: {'label': '{tells}-1'}, 5: {'label': 'always {tells}-1'}, 6: {'label': '{raised}-1'}, 7: {'label': 'is {raising}-1'}, 8: {'label': '{teaches}-1'}}
# atticus jem {0: {'label': '{patting}-1'}}
# jury tom {0: {'label': 'eventually {convicts}-1'}, 1: {'label': "'s {sent}-1"}, 2: {'label': '{convicted}-1'}}
# lee atticus {0: {'label': '{made} really-1'}, 1: {'label': '{gives} <<the {model} being>> in-1'}, 2: {'label': '{constructed}-1'}}
# lee people {0: {'label': 'Even {uses}-1'}, 1: {'label': '{captures} <<the {essence} childhood>> amidst-1'}}
# lee boo {0: {'label': 'how {built} up <<the {legend}>> behind-1'}}
# lee scout {0: {'label': 'how {described}-1'}, 1: {'label': '{created} <<{what}>> in-1'}, 2: {'label': 'masterfully {captures}-1'}, 3: {'label': 'how {wrote} <<this {book}>> in-1'}}
# lee alexandra {0: {'label': 'skillfully {captured}-1'}}
# lee children {0: {'label': 'really {understood}-1'}, 1: {'label': 'does not {patronize}-1'}}
# lee jem {0: {'label': '{captures} well <<a {child}>> such as-1'}}
# people dill {0: {'label': '{know}-1'}}
# people trial {0: {'label': '{exhibits} <<its ugly {side}>> during-1'}}
# people scout {0: {'label': 'why {name} <<their {children}>> after-1'}}
# people children {0: {'label': 'why {name}-1'}}
# people jem {0: {'label': '{know}-2'}}
# boo atticus {0: {'label': '{reveal}-1'}}
# boo scout {0: {'label': 'where {saves}-1'}, 1: {'label': 'when {asked}-1'}, 2: {'label': 'When {asks}-1'}}
# boo bob ewell {0: {'label': '{killed}-1'}, 1: {'label': 'when {saves} <<the {children}>> from-1'}, 2: {'label': 'when {saved} <<the {children}>> from-1'}}
# boo tom {0: {'label': '{has} <<an inner {goodness}>> like-1'}}
# boo children {0: {'label': 'has {saved}-1'}, 1: {'label': 'when {saved}-1'}, 2: {'label': 'when {saves}-1'}}
# boo jem {0: {'label': '{lives} <<next {store}>> to-1'}, 1: {'label': '{fell}-1'}, 2: {'label': 'When {saves}-1'}, 3: {'label': 'where {saves}-1'}, 4: {'label': '{carries} back-1'}}
# mr dolphus raymond scout {0: {'label': '{tells}-1'}}
# mayella tom {0: {'label': '{kisses}-1'}}
# trial people {0: {'label': '{bring} out-1'}, 1: {'label': '{brings}-1'}}
# trial tom {0: {'label': 'how {involving}-1'}}
# school gift {0: {'label': '{gave}-1'}}
# school scout {0: {'label': '{nicknamed}-1'}}
# scout dill {0: {'label': '{meet}-1'}}
# scout atticus {0: {'label': '{defending} <<a black {man}>> to-1'}, 1: {'label': '{lives} <<a {lawyer} named>> with-1'}, 2: {'label': '{admire} greatly-1'}, 3: {'label': 'often {asked}-1'}, 4: {'label': '{protects}-1'}, 5: {'label': 'why always {called}-1'}, 6: {'label': 'how {treat}-1'}, 7: {'label': '{lives} <<her {brother}>> with-1'}}
# scout people {0: {'label': '{describes}-1'}, 1: {'label': '{navigate}-1'}, 2: {'label': 'slowly {realizes}-1'}, 3: {'label': '{sums} up-1'}}
# scout boo {0: {'label': 'can {pet} <<{him}>> to-1'}, 1: {'label': 'when {befriend}-1'}, 2: {'label': '{have} <<their own {assumptions}>> about-1'}, 3: {'label': 'to {tell} <<{him}>> about-1'}}
# scout trial {0: {'label': 'are {seeing} <<a different {view} capable>> after-1'}}
# scout school {0: {'label': 'would {find} <<small {things} hidden>> throught-1'}, 1: {'label': '{starts}-1'}, 2: {'label': '{did} in <<{me}>> by-1'}}
# scout tom {0: {'label': '{defending}-1'}, 1: {'label': 'Also always {wondered}-1'}}
# scout alexandra {0: {'label': '{wears} <<{overalls}>> despite-1'}}
# scout children {0: {'label': '{has} <<the {ability}>> like-1'}}
# scout jem {0: {'label': '{lives}-1'}, 1: {'label': 'when {mentions}-1'}}
# bob ewell atticus {0: {'label': '{fell}-1'}}
# bob ewell boo {0: {'label': 'how had {said} <<the revenage {csme}>> by-1'}}
# bob ewell tom {0: {'label': 'when {accuses}-1'}}
# tom people {0: {'label': '{has}-1'}, 1: {'label': '{brings} <<the delightful {mannerisms} states.>> in-1'}, 2: {'label': '{brings} <<speech {patterns}>> in-1'}}
# tom mayella {0: {'label': '{raped}-1'}, 1: {'label': 'is {accused}-1'}, 2: {'label': 'not {raping}-1'}, 3: {'label': 'should not have {gotten} away-1'}}
# tom maycomb {0: {'label': '{lives} <<a typical {lifestyle}>> in-1'}}
# judge atticus {0: {'label': '{appoints}-1'}}
# judge tom {0: {'label': '{appoints} <<{Atticus}>> as-1'}}
# jean louise finch jem {0: {'label': '{has}-1'}}
# children atticus {0: {'label': '{taunt} <<{Jem}>> for-2'}, 1: {'label': '{taunt} <<{Scout}>> for-2'}, 2: {'label': '{call} <<{him}>> by-1'}, 3: {'label': '{called}-1'}}
# children people {0: {'label': 'how {see} <<{people}>> as-4'}, 1: {'label': 'how {see}-4'}}
# children boo {0: {'label': '{recognize} <<{this}>> in-1'}}
# children scout {0: {'label': '{taunt}-2'}}
# children jem {0: {'label': '{taunt}-2'}}
# jem dill {0: {'label': '{meet}-1'}}
# jem atticus {0: {'label': 'how {treat}-1'}, 1: {'label': '{admire} greatly-1'}}
# jem people {0: {'label': 'slowly {realizes}-1'}, 1: {'label': '{navigate}-1'}}
# jem boo {0: {'label': '{have} <<fictitious {stories}>> about-1'}, 1: {'label': 'is {discussing}-1'}, 2: {'label': '{have} <<their own {assumptions}>> about-1'}, 3: {'label': 'when {befriend}-1'}}
# jem trial {0: {'label': 'are {seeing} <<a different {view} capable>> after-1'}}
# jem school {0: {'label': 'would {find} <<small {things} hidden>> throught-1'}}
# jem scout {0: {'label': 'is {discussing} <<Boo {Radley}>> with-1'}}
# jem bob ewell {0: {'label': 'not {stabbed}-1'}}
# jem tom {0: {'label': '{learn}-1'}, 1: {'label': 'Also always {wondered}-1'}}
