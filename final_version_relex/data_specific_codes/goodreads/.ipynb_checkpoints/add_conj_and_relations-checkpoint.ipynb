# %%
import pandas as pd
from collections import defaultdict
import re
import numpy as np
import sys
sys.path.insert(0, '../../base_codes')
sys.path.insert(0, '../../data_specific_codes')
sys.path.insert(0, '../../utility_codes')

#%run -i 'parameters'
#%run -i 'main_functions'
#%run -i 'utility_functions'

from RE_init import *
from main_functions import *
from utility_functions import *

##ALL the books 
pronoun_prefix = "_raw" # no pronoun: "_raw" - with pronoun: "0601"
file_input_postfix = "_with_SVP_relations_-1.csv" 
file_output_postfix = "_relations_-1.csv"
svp_prefix = "_with_conjAND"#"_with_SVP"

##MICE_AND_MEN
#based_dir = '../../../../data/GoodReads/revised_pronoun_1Jun2017/results/Mice_and_men/results_with_svp_relationships/'
#based_dir = '../../../../data/GoodReads/Raw_data_no_pronoun/mice_and_men/results_with_svp_relationships/'
#file_input_name = "mice_and_men" + pronoun_prefix + file_input_postfix
#input_name_prefix = 'mice_and_men' + pronoun_prefix + svp_prefix
#DATA_SET = 'goodreads-Mice-and-men'

##HOBBIT
#based_dir = '../../../../data/GoodReads/revised_pronoun_1Jun2017/results/Hobbit/results_with_svp_relationships/'
#based_dir = '../../../../data/GoodReads/Raw_data_no_pronoun/hobbit/results_with_svp_relationships/'
#file_input_name= 'hobbit' + pronoun_prefix + file_input_postfix
#input_name_prefix = 'hobbit' + pronoun_prefix + svp_prefix
#DATA_SET = 'goodreads-Hobbit'

##Mockingbird
#based_dir = '../../../../data/GoodReads/revised_pronoun_1Jun2017/results/Mockingbird/results_with_svp_relationships/'
#based_dir = '../../../../data/GoodReads/Raw_data_no_pronoun/mockingbird/results_with_svp_relationships/'
#file_input_name= 'mockingbird' + pronoun_prefix + file_input_postfix
#input_name_prefix = 'mockingbird' + pronoun_prefix + svp_prefix
#DATA_SET = 'goodreads-Mockingbird'

##Frankenstein
#based_dir = '../../../../data/GoodReads/revised_pronoun_1Jun2017/results/Frankenstein/results_with_svp_relationships/'
based_dir = '../../../../data/GoodReads/Raw_data_no_pronoun/frankenstein/results_with_svp_relationships/'
file_input_name= 'frankenstein' + pronoun_prefix + file_input_postfix
input_name_prefix = 'frankenstein' + pronoun_prefix + svp_prefix
DATA_SET = 'goodreads-Frankenstein'

def read_df_rel(based_dir, file_input_name):
    file_input = based_dir + file_input_name    
    ff = open(file_input)
    delim=","
    df = pd.read_csv(file_input,delimiter=delim,header=0)        
    return df

df_rels = read_df_rel(based_dir, file_input_name)

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#pd.set_option('display.max_colwidth', -1)
#df_rels = df_rels.replace(np.nan, '', regex=True)
df_rels
# Out:
#       Unnamed: 0  post_num  sentence_num  \
# 0              0         3             1
# 1              1         3             1
# 2              2         3             1
# 3              3         3             1
# 4              4         3             1
# 5              5         3             7
# 6              6         3             7
# 7              7         3            11
# 8              8         3            21
# 9              9         3            21
# 10            10         3            21
# 11            11         3            22
# 12            12         3            22
# 13            13         3            22
# 14            14         3            22
# 15            15         3            23
# 16            16         3            26
# 17            17         3            26
# 18            18         3            26
# 19            19         3            28
# 20            20         3            28
# 21            21         3            28
# 22            22         3            43
# 23            23         3            43
# 24            24         3            43
# 25            25         3            51
# 26            26         3            51
# 27            27         4             1
# 28            28         4             1
# 29            29         4             1
# ...          ...       ...           ...
# 8249        8249      2751             1
# 8250        8250      2751             1
# 8251        8251      2752             1
# 8252        8252      2752             2
# 8253        8253      2753             1
# 8254        8254      2753             1
# 8255        8255      2753             1
# 8256        8256      2754             5
# 8257        8257      2754             5
# 8258        8258      2755            10
# 8259        8259      2755            10
# 8260        8260      2755            13
# 8261        8261      2755            14
# 8262        8262      2755            16
# 8263        8263      2756             1
# 8264        8264      2756             1
# 8265        8265      2757             0
# 8266        8266      2757             3
# 8267        8267      2757             3
# 8268        8268      2757             3
# 8269        8269      2770             2
# 8270        8270      2770             7
# 8271        8271      2770             7
# 8272        8272      2771             0
# 8273        8273      2771             1
# 8274        8274      2771             2
# 8275        8275      2771             2
# 8276        8276      2772             0
# 8277        8277      2774             3
# 8278        8278      2774             3
#
#                                                sentence  \
# 0     However, she did write a few articles that one...
# 1     However, she did write a few articles that one...
# 2     However, she did write a few articles that one...
# 3     However, she did write a few articles that one...
# 4     However, she did write a few articles that one...
# 5     I was able to tell in the beginning that the b...
# 6     I was able to tell in the beginning that the b...
# 7     Since they were openly drinking, Prohibition m...
# 8     I loved her way of thinking especially how she...
# 9     I loved her way of thinking especially how she...
# 10    I loved her way of thinking especially how she...
# 11    And when she wanted to write a letter to Dill ...
# 12    And when she wanted to write a letter to Dill ...
# 13    And when she wanted to write a letter to Dill ...
# 14    And when she wanted to write a letter to Dill ...
# 15    I have a feeling that Harper Lee was just like...
# 16    I'm not sure I like the fact that Atticus allo...
# 17    I'm not sure I like the fact that Atticus allo...
# 18    I'm not sure I like the fact that Atticus allo...
# 19    He firmly believed that it was important for h...
# 20    He firmly believed that it was important for h...
# 21    He firmly believed that it was important for h...
# 22    It takes a special person to admit defeat to t...
# 23    It takes a special person to admit defeat to t...
# 24    It takes a special person to admit defeat to t...
# 25    The security camera shows the tiff and it show...
# 26    The security camera shows the tiff and it show...
# 27    I smell the smoke of fireplaces and think abou...
# 28    I smell the smoke of fireplaces and think abou...
# 29    I smell the smoke of fireplaces and think abou...
# ...                                                 ...
# 8249  I read it when I was in highschool and it has ...
# 8250  I read it when I was in highschool and it has ...
# 8251  Her father was a wise lawyer who showed his tw...
# 8252  It also illustrated the girl's phobias, intere...
# 8253  As a teacher, I have taught this book to many ...
# 8254  As a teacher, I have taught this book to many ...
# 8255  As a teacher, I have taught this book to many ...
# 8256  Personal favorite quote Ladies in bunches alwa...
# 8257  Personal favorite quote Ladies in bunches alwa...
# 8258  Since Atticus is defending Tom, Mr. Ewell does...
# 8259  Since Atticus is defending Tom, Mr. Ewell does...
# 8260  I liked this book because I was eager to find ...
# 8261  I think the book explained everything well bec...
# 8262  I think people should read this book because i...
# 8263  However, this book is all the proof one needs ...
# 8264  However, this book is all the proof one needs ...
# 8265  Lawyer Atticus Finch defends the real mockingb...
# 8266  This book tells a great story with a great mes...
# 8267  This book tells a great story with a great mes...
# 8268  This book tells a great story with a great mes...
# 8269  Personally I could not connect with the storym...
# 8270         I would gladly recommend it to my friends.
# 8271         I would gladly recommend it to my friends.
# 8272  This is the first time I have read this modern...
# 8273  I had seen the film adaptation some years back...
# 8274  It proved a very rewarding experience, which d...
# 8275  It proved a very rewarding experience, which d...
# 8276  This book paints a candid picture of life in t...
# 8277  I had not picked up my copy of the book in yea...
# 8278  I had not picked up my copy of the book in yea...
#
#                                   arg1  \
# 0                                {she}
# 1                                {one}
# 2                                {one}
# 3                                {one}
# 4                                {one}
# 5                                 {he}
# 6                                 {he}
# 7                        {Prohibition}
# 8                                  {I}
# 9                                {she}
# 10                               {she}
# 11                          a {letter}
# 12                                 {I}
# 13                                 {I}
# 14                                 {I}
# 15                                 {I}
# 16                                 {I}
# 17                              {them}
# 18                              {them}
# 19                                {He}
# 20                          {children}
# 21                                {it}
# 22                                {It}
# 23                              {them}
# 24                                {he}
# 25               The security {camera}
# 26               The security {camera}
# 27                                 {I}
# 28                                 {I}
# 29                                 {I}
# ...                                ...
# 8249                               {I}
# 8250                              {it}
# 8251                   a wise {lawyer}
# 8252                              {It}
# 8253                               {I}
# 8254                               {I}
# 8255                               {I}
# 8256  Personal favorite quote {Ladies}
# 8257  Personal favorite quote {Ladies}
# 8258                         {Atticus}
# 8259                       Mr. {Ewell}
# 8260                               {I}
# 8261                        the {book}
# 8262                          {people}
# 8263                             {you}
# 8264                             {you}
# 8265            Lawyer Atticus {Finch}
# 8266                       This {book}
# 8267                       This {book}
# 8268                           {sugar}
# 8269                               {I}
# 8270                               {I}
# 8271                               {I}
# 8272                               {I}
# 8273                               {I}
# 8274                              {It}
# 8275          a rewarding {experience}
# 8276                       This {book}
# 8277                               {I}
# 8278                               {I}
#
#                                          rel                          arg2  \
# 0                        However did {write}              a few {articles}
# 1                                 can {find}              a few {articles}
# 2         can {find} <<a few {articles}>> in                 other {Words}
# 3                                 can {find}                 online {Love}
# 4            can {find} <<online {Love}>> in                 other {Words}
# 5                                      {saw}                     {Dracula}
# 6                     {saw} <<{Dracula}>> in                the {theaters}
# 7                          must have {ended}                       {1933.}
# 8                                    {loved}                {way} thinking
# 9                                {picked} up              the bad {habits}
# 10     {picked} up <<the bad {habits}>> from                      {school}
# 11                           just to {drive}                         {him}
# 12                           almost {ruined}                    the {book}
# 13                            was {drinking}                a Diet {Pepsi}
# 14      was {drinking} <<a Diet {Pepsi}>> at                   the {time.}
# 15                                    {have}                   a {feeling}
# 16                                    {like}                    the {fact}
# 17                                 to {call}                         {him}
# 18                    to {call} <<{him}>> by              first {name} not
# 19                   firmly to {respect} not                         {him}
# 20                   firmly to {respect} not                         {him}
# 21                   firmly to {respect} not                         {him}
# 22                                   {takes}      a special {person} admit
# 23                                    {join}                        {them}
# 24                     does not {understand}                      {things}
# 25                                   {shows}                    the {tiff}
# 26                                   {shows}                    the {tiff}
# 27                                   {smell}        the {smoke} fireplaces
# 28                                  {bundle}                        {coat}
# 29               {bundle} <<{coat}>> against                          {me}
# ...                                      ...                           ...
# 8249                                  {read}                          {it}
# 8250                   has always {reminded}                          {me}
# 8251                                {showed}            two children {Jem}
# 8252                      also {illustrated}           phobias {interests}
# 8253                           have {taught}                   this {book}
# 8254        have {taught} <<this {book}>> as                   a {teacher}
# 8255        have {taught} <<this {book}>> to       many {groups} teenagers
# 8256                         always {filled}                          {me}
# 8257           always {filled} <<{me}>> with          vague {apprehension}
# 8258                          is {defending}                         {Tom}
# 8259                         does not {like}                         {him}
# 8260                                 {liked}                   this {book}
# 8261                        {explained} well                  {everything}
# 8262                           should {read}                   this {book}
# 8263                              'll {hold}                          {it}
# 8264                  'll {hold} <<{it}>> in             similar {regards}
# 8265                               {defends}  the real {mockingbird} Prize
# 8266                                 {tells}               a great {story}
# 8267        {tells} <<a great {story}>> with             a great {message}
# 8268                             does {coat}           the {reality} time.
# 8269                 could have {understood}                a {lot} things
# 8270                would gladly {recommend}                          {it}
# 8271    would gladly {recommend} <<{it}>> to                     {friends}
# 8272                             have {read}         this modern {classic}
# 8273                              had {seen}         the film {adaptation}
# 8274                                {proved}      a rewarding {experience}
# 8275                        deeply {stirred}                    {emotions}
# 8276                                {paints}       a candid {picture} life
# 8277                     had not {picked} up                   {copy} book
# 8278  had not {picked} up <<{copy} book>> in                       {years}
#
#         type                 pattern  \
# 0        SVO     (nsubj, verb, dobj)
# 1        SVO     (nsubj, verb, dobj)
# 2     SV(O)P  (nsubj, verb, (O)prep)
# 3        SVO     (nsubj, verb, dobj)
# 4     SV(O)P  (nsubj, verb, (O)prep)
# 5        SVO     (nsubj, verb, dobj)
# 6     SV(O)P  (nsubj, verb, (O)prep)
# 7        SVO     (nsubj, verb, dobj)
# 8        SVO     (nsubj, verb, dobj)
# 9        SVO     (nsubj, verb, dobj)
# 10    SV(O)P  (nsubj, verb, (O)prep)
# 11       SVO     (nsubj, verb, dobj)
# 12       SVO     (nsubj, verb, dobj)
# 13       SVO     (nsubj, verb, dobj)
# 14    SV(O)P  (nsubj, verb, (O)prep)
# 15       SVO     (nsubj, verb, dobj)
# 16       SVO     (nsubj, verb, dobj)
# 17       SVO     (nsubj, verb, dobj)
# 18    SV(O)P  (nsubj, verb, (O)prep)
# 19       SVO     (nsubj, verb, dobj)
# 20       SVO     (nsubj, verb, dobj)
# 21       SVO     (nsubj, verb, dobj)
# 22       SVO     (nsubj, verb, dobj)
# 23       SVO     (nsubj, verb, dobj)
# 24       SVO     (nsubj, verb, dobj)
# 25       SVO     (nsubj, verb, dobj)
# 26       SVO     (nsubj, verb, dobj)
# 27       SVO     (nsubj, verb, dobj)
# 28       SVO     (nsubj, verb, dobj)
# 29    SV(O)P  (nsubj, verb, (O)prep)
# ...      ...                     ...
# 8249     SVO     (nsubj, verb, dobj)
# 8250     SVO     (nsubj, verb, dobj)
# 8251     SVO     (nsubj, verb, dobj)
# 8252     SVO     (nsubj, verb, dobj)
# 8253     SVO     (nsubj, verb, dobj)
# 8254  SV(O)P  (nsubj, verb, (O)prep)
# 8255  SV(O)P  (nsubj, verb, (O)prep)
# 8256     SVO     (nsubj, verb, dobj)
# 8257  SV(O)P  (nsubj, verb, (O)prep)
# 8258     SVO     (nsubj, verb, dobj)
# 8259     SVO     (nsubj, verb, dobj)
# 8260     SVO     (nsubj, verb, dobj)
# 8261     SVO     (nsubj, verb, dobj)
# 8262     SVO     (nsubj, verb, dobj)
# 8263     SVO     (nsubj, verb, dobj)
# 8264  SV(O)P  (nsubj, verb, (O)prep)
# 8265     SVO     (nsubj, verb, dobj)
# 8266     SVO     (nsubj, verb, dobj)
# 8267  SV(O)P  (nsubj, verb, (O)prep)
# 8268     SVO     (nsubj, verb, dobj)
# 8269     SVO     (nsubj, verb, dobj)
# 8270     SVO     (nsubj, verb, dobj)
# 8271  SV(O)P  (nsubj, verb, (O)prep)
# 8272     SVO     (nsubj, verb, dobj)
# 8273     SVO     (nsubj, verb, dobj)
# 8274     SVO     (nsubj, verb, dobj)
# 8275     SVO     (nsubj, verb, dobj)
# 8276     SVO     (nsubj, verb, dobj)
# 8277     SVO     (nsubj, verb, dobj)
# 8278  SV(O)P  (nsubj, verb, (O)prep)
#
#                                           arg1_with_pos  \
# 0                                             she-PRP-3
# 1                                            one-PRP-10
# 2                                            one-PRP-10
# 3                                            one-PRP-10
# 4                                            one-PRP-10
# 5                                             he-PRP-20
# 6                                             he-PRP-20
# 7                                      Prohibition-NN-7
# 8                                               I-PRP-1
# 9                                            she-PRP-22
# 10                                           she-PRP-22
# 11                                   a-DT-7 letter-NN-8
# 12                                             I-PRP-20
# 13                                             I-PRP-26
# 14                                             I-PRP-26
# 15                                              I-PRP-1
# 16                                              I-PRP-5
# 17                                          them-PRP-12
# 18                                          them-PRP-12
# 19                                             He-PRP-1
# 20                                      children-NNS-10
# 21                                             it-PRP-5
# 22                                             It-PRP-1
# 23                                          them-PRP-16
# 24                                            he-PRP-25
# 25                   The-DT-1 security-NN-2 camera-NN-3
# 26                   The-DT-1 security-NN-2 camera-NN-3
# 27                                              I-PRP-1
# 28                                             I-PRP-24
# 29                                             I-PRP-24
# ...                                                 ...
# 8249                                            I-PRP-1
# 8250                                          it-PRP-10
# 8251                       a-DT-4 wise-JJ-5 lawyer-NN-6
# 8252                                           It-PRP-1
# 8253                                            I-PRP-5
# 8254                                            I-PRP-5
# 8255                                            I-PRP-5
# 8256  Personal-JJ-1 favorite-JJ-2 quote-NN-3 Ladies-...
# 8257  Personal-JJ-1 favorite-JJ-2 quote-NN-3 Ladies-...
# 8258                                      Atticus-NNP-2
# 8259                              Mr.-NNP-7 Ewell-NNP-8
# 8260                                            I-PRP-1
# 8261                                 the-DT-3 book-NN-4
# 8262                                       people-NNS-3
# 8263                                         you-PRP-26
# 8264                                         you-PRP-26
# 8265             Lawyer-NNP-1 Atticus-NNP-2 Finch-NNP-3
# 8266                                This-DT-1 book-NN-2
# 8267                                This-DT-1 book-NN-2
# 8268                                        sugar-NN-15
# 8269                                           I-PRP-21
# 8270                                            I-PRP-1
# 8271                                            I-PRP-1
# 8272                                            I-PRP-6
# 8273                                            I-PRP-1
# 8274                                           It-PRP-1
# 8275              a-DT-3 rewarding-JJ-5 experience-NN-6
# 8276                                This-DT-1 book-NN-2
# 8277                                            I-PRP-1
# 8278                                            I-PRP-1
#
#                                       rel_with_pos  \
# 0                However-RB-1 did-VBD-4 write-VB-5
# 1                             can-MD-11 find-VB-12
# 2                             can-MD-11 find-VB-12
# 3                             can-MD-11 find-VB-12
# 4                             can-MD-11 find-VB-12
# 5                                       saw-VBD-21
# 6                                       saw-VBD-21
# 7                 must-MD-8 have-VB-9 ended-VBN-10
# 8                                      loved-VBD-2
# 9                           picked-VBD-23 up-RP-24
# 10                          picked-VBD-23 up-RP-24
# 11                 just-RB-14 to-TO-15 drive-VB-16
# 12                      almost-RB-21 ruined-VBD-22
# 13                      was-VBD-27 drinking-VBG-28
# 14                      was-VBD-27 drinking-VBG-28
# 15                                      have-VBP-2
# 16                                      like-VBP-6
# 17                             to-TO-13 call-VB-14
# 18                             to-TO-13 call-VB-14
# 19    firmly-RB-2 to-TO-11 respect-VB-12 not-RB-25
# 20    firmly-RB-2 to-TO-11 respect-VB-12 not-RB-25
# 21    firmly-RB-2 to-TO-11 respect-VB-12 not-RB-25
# 22                                     takes-VBZ-2
# 23                                      join-VB-17
# 24          does-VBZ-26 not-RB-27 understand-VB-28
# 25                                     shows-VBZ-4
# 26                                     shows-VBZ-4
# 27                                     smell-VBP-2
# 28                                   bundle-VBP-25
# 29                                   bundle-VBP-25
# ...                                            ...
# 8249                                    read-VBP-2
# 8250       has-VBZ-11 always-RB-12 reminded-VBN-13
# 8251                                  showed-VBD-8
# 8252                   also-RB-2 illustrated-VBD-3
# 8253                       have-VBP-6 taught-VBN-7
# 8254                       have-VBP-6 taught-VBN-7
# 8255                       have-VBP-6 taught-VBN-7
# 8256                      always-RB-7 filled-VBD-8
# 8257                      always-RB-7 filled-VBD-8
# 8258                      is-VBZ-3 defending-VBG-4
# 8259               does-VBZ-9 not-RB-10 like-VB-11
# 8260                                   liked-VBD-2
# 8261                     explained-VBD-5 well-RB-7
# 8262                         should-MD-4 read-VB-5
# 8263                          'll-MD-27 hold-VB-28
# 8264                          'll-MD-27 hold-VB-28
# 8265                                 defends-VBZ-4
# 8266                                   tells-VBZ-3
# 8267                                   tells-VBZ-3
# 8268                        does-VBZ-13 coat-VB-16
# 8269      could-MD-22 have-VB-23 understood-VBN-24
# 8270         would-MD-2 gladly-RB-3 recommend-VB-4
# 8271         would-MD-2 gladly-RB-3 recommend-VB-4
# 8272                         have-VBP-7 read-VBN-8
# 8273                          had-VBD-2 seen-VBN-3
# 8274                                  proved-VBD-2
# 8275                    deeply-RB-9 stirred-VBD-10
# 8276                                  paints-VBZ-3
# 8277       had-VBD-2 not-RB-3 picked-VBN-4 up-RP-5
# 8278       had-VBD-2 not-RB-3 picked-VBN-4 up-RP-5
#
#                                          arg2_with_pos  \
# 0                       a-DT-6 few-JJ-7 articles-NNS-8
# 1                       a-DT-6 few-JJ-7 articles-NNS-8
# 2                                                  NaN
# 3                             online-JJ-15 Love-NNP-16
# 4                                                  NaN
# 5                                       Dracula-NNP-22
# 6                                                  NaN
# 7                                           1933.-.-11
# 8                              way-NN-4 thinking-VBG-6
# 9                    the-DT-25 bad-JJ-26 habits-NNS-27
# 10                                                 NaN
# 11                                          him-PRP-17
# 12                                the-DT-23 book-NN-24
# 13                    a-DT-29 Diet-NNP-30 Pepsi-NNP-31
# 14                                                 NaN
# 15                                 a-DT-3 feeling-NN-4
# 16                                  the-DT-7 fact-NN-8
# 17                                          him-PRP-15
# 18                                                 NaN
# 19                                          him-PRP-13
# 20                                          him-PRP-13
# 21                                          him-PRP-13
# 22          a-DT-3 special-JJ-4 person-NN-5 admit-VB-7
# 23                                         them-PRP-18
# 24                                       things-NNS-24
# 25                                  the-DT-5 tiff-NN-6
# 26                                  the-DT-5 tiff-NN-6
# 27                the-DT-3 smoke-NN-4 fireplaces-NNS-6
# 28                                          coat-NN-27
# 29                                                 NaN
# ...                                                ...
# 8249                                          it-PRP-3
# 8250                                         me-PRP-14
# 8251              two-CD-10 children-NNS-11 Jem-NNP-12
# 8252                     phobias-NNS-7 interests-NNS-9
# 8253                               this-DT-8 book-NN-9
# 8254                                               NaN
# 8255                                               NaN
# 8256                                          me-PRP-9
# 8257                                               NaN
# 8258                                         Tom-NNP-5
# 8259                                        him-PRP-12
# 8260                               this-DT-3 book-NN-4
# 8261                                   everything-NN-6
# 8262                               this-DT-6 book-NN-7
# 8263                                         it-PRP-29
# 8264                                               NaN
# 8265  the-DT-5 real-JJ-6 mockingbird-NN-7 Prize-NNP-15
# 8266                      a-DT-4 great-JJ-5 story-NN-6
# 8267                                               NaN
# 8268               the-DT-17 reality-NN-18 time.-NN-21
# 8269                   a-DT-25 lot-NN-26 things-NNS-29
# 8270                                          it-PRP-5
# 8271                                               NaN
# 8272              this-DT-9 modern-JJ-10 classic-NN-11
# 8273                the-DT-4 film-NN-5 adaptation-NN-6
# 8274             a-DT-3 rewarding-JJ-5 experience-NN-6
# 8275                                   emotions-NNS-12
# 8276         a-DT-4 candid-JJ-5 picture-NN-6 life-NN-8
# 8277                              copy-NN-7 book-NN-10
# 8278                                               NaN
#
#                                       arg1_prepositions  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11    REASON: prep_in TEXT: invisible {ink} -- REASO...
# 12                                                  NaN
# 13                                                  NaN
# 14                                                  NaN
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# 18                                                  NaN
# 19                                                  NaN
# 20                                                  NaN
# 21                                                  NaN
# 22                                                  NaN
# 23                                                  NaN
# 24                                                  NaN
# 25                                                  NaN
# 26                                                  NaN
# 27                                                  NaN
# 28                                                  NaN
# 29                                                  NaN
# ...                                                 ...
# 8249                                                NaN
# 8250                                                NaN
# 8251                                                NaN
# 8252                                                NaN
# 8253                                                NaN
# 8254                                                NaN
# 8255                                                NaN
# 8256                REASON: prep_in TEXT: {bunches} --
# 8257                REASON: prep_in TEXT: {bunches} --
# 8258                                                NaN
# 8259                                                NaN
# 8260                                                NaN
# 8261                                                NaN
# 8262                                                NaN
# 8263                                                NaN
# 8264                                                NaN
# 8265                                                NaN
# 8266                                                NaN
# 8267                                                NaN
# 8268                                                NaN
# 8269                                                NaN
# 8270                                                NaN
# 8271                                                NaN
# 8272                                                NaN
# 8273                                                NaN
# 8274                                                NaN
# 8275                                                NaN
# 8276                                                NaN
# 8277                                                NaN
# 8278                                                NaN
#
#                                        rel_prepositions  \
# 0                                                   NaN
# 1               REASON: prep_in TEXT: other {Words} --
# 2                                                   NaN
# 3               REASON: prep_in TEXT: other {Words} --
# 4                                                   NaN
# 5              REASON: prep_in TEXT: the {theaters} --
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                  REASON: prep_from TEXT: {school} --
# 10                                                  NaN
# 11                                                  NaN
# 12                                                  NaN
# 13                REASON: prep_at TEXT: the {time.} --
# 14                                                  NaN
# 15                                                  NaN
# 16                                                  NaN
# 17           REASON: prep_by TEXT: first {name} not --
# 18                                                  NaN
# 19                                                  NaN
# 20                                                  NaN
# 21                                                  NaN
# 22                                                  NaN
# 23                                                  NaN
# 24                                                  NaN
# 25                                                  NaN
# 26                                                  NaN
# 27                                                  NaN
# 28                  REASON: prep_against TEXT: {me} --
# 29                                                  NaN
# ...                                                 ...
# 8249                                                NaN
# 8250                                                NaN
# 8251                                                NaN
# 8252                                                NaN
# 8253  REASON: prep_as TEXT: a {teacher} -- REASON: p...
# 8254                                                NaN
# 8255                                                NaN
# 8256   REASON: prep_with TEXT: vague {apprehension} --
# 8257                                                NaN
# 8258                                                NaN
# 8259                                                NaN
# 8260                                                NaN
# 8261                                                NaN
# 8262                                                NaN
# 8263        REASON: prep_in TEXT: similar {regards} --
# 8264                                                NaN
# 8265                                                NaN
# 8266      REASON: prep_with TEXT: a great {message} --
# 8267                                                NaN
# 8268                                                NaN
# 8269                                                NaN
# 8270                REASON: prep_to TEXT: {friends} --
# 8271                                                NaN
# 8272                                                NaN
# 8273                                                NaN
# 8274                                                NaN
# 8275                                                NaN
# 8276                                                NaN
# 8277                  REASON: prep_in TEXT: {years} --
# 8278                                                NaN
#
#                                       arg2_prepositions  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11                                                  NaN
# 12                                                  NaN
# 13                                                  NaN
# 14                                                  NaN
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# 18                                                  NaN
# 19                                                  NaN
# 20                                                  NaN
# 21                                                  NaN
# 22                                                  NaN
# 23                                                  NaN
# 24                                                  NaN
# 25                                                  NaN
# 26                                                  NaN
# 27                                                  NaN
# 28                                                  NaN
# 29                                                  NaN
# ...                                                 ...
# 8249                                                NaN
# 8250                                                NaN
# 8251                                                NaN
# 8252                                                NaN
# 8253                                                NaN
# 8254                                                NaN
# 8255                                                NaN
# 8256                                                NaN
# 8257                                                NaN
# 8258                                                NaN
# 8259                                                NaN
# 8260                                                NaN
# 8261                                                NaN
# 8262                                                NaN
# 8263                                                NaN
# 8264                                                NaN
# 8265                                                NaN
# 8266                                                NaN
# 8267                                                NaN
# 8268                                                NaN
# 8269                                                NaN
# 8270                                                NaN
# 8271                                                NaN
# 8272                                                NaN
# 8273                                                NaN
# 8274                                                NaN
# 8275                                                NaN
# 8276  REASON: prep_in TEXT: the {south} -- REASON: p...
# 8277                                                NaN
# 8278                                                NaN
#
#                                              annotation
# 0     {'dep_parse': 'advmod(write-5, However-1)\nnsu...
# 1     {'dep_parse': 'advmod(write-5, However-1)\nnsu...
# 2     {'dep_parse': 'advmod(write-5, However-1)\nnsu...
# 3     {'dep_parse': 'advmod(write-5, However-1)\nnsu...
# 4     {'dep_parse': 'advmod(write-5, However-1)\nnsu...
# 5     {'dep_parse': "nsubj(able-3, I-1)\nxsubj(tell-...
# 6     {'dep_parse': "nsubj(able-3, I-1)\nxsubj(tell-...
# 7     {'dep_parse': 'mark(drinking-5, Since-1)\nnsub...
# 8     {'dep_parse': 'nsubj(loved-2, I-1)\nroot(ROOT-...
# 9     {'dep_parse': 'nsubj(loved-2, I-1)\nroot(ROOT-...
# 10    {'dep_parse': 'nsubj(loved-2, I-1)\nroot(ROOT-...
# 11    {'dep_parse': 'cc(ruined-22, And-1)\nadvmod(wa...
# 12    {'dep_parse': 'cc(ruined-22, And-1)\nadvmod(wa...
# 13    {'dep_parse': 'cc(ruined-22, And-1)\nadvmod(wa...
# 14    {'dep_parse': 'cc(ruined-22, And-1)\nadvmod(wa...
# 15    {'dep_parse': 'nsubj(have-2, I-1)\nroot(ROOT-0...
# 16    {'dep_parse': "nsubj(sure-4, I-1)\ncop(sure-4,...
# 17    {'dep_parse': "nsubj(sure-4, I-1)\ncop(sure-4,...
# 18    {'dep_parse': "nsubj(sure-4, I-1)\ncop(sure-4,...
# 19    {'dep_parse': 'nsubj(respect-12, He-1)\nadvmod...
# 20    {'dep_parse': 'nsubj(respect-12, He-1)\nadvmod...
# 21    {'dep_parse': 'nsubj(respect-12, He-1)\nadvmod...
# 22    {'dep_parse': 'nsubj(takes-2, It-1)\nroot(ROOT...
# 23    {'dep_parse': 'nsubj(takes-2, It-1)\nroot(ROOT...
# 24    {'dep_parse': 'nsubj(takes-2, It-1)\nroot(ROOT...
# 25    {'dep_parse': 'det(camera-3, The-1)\nnn(camera...
# 26    {'dep_parse': 'det(camera-3, The-1)\nnn(camera...
# 27    {'dep_parse': 'nsubj(smell-2, I-1)\nroot(ROOT-...
# 28    {'dep_parse': 'nsubj(smell-2, I-1)\nroot(ROOT-...
# 29    {'dep_parse': 'nsubj(smell-2, I-1)\nroot(ROOT-...
# ...                                                 ...
# 8249  {'dep_parse': 'nsubj(read-2, I-1)\nroot(ROOT-0...
# 8250  {'dep_parse': 'nsubj(read-2, I-1)\nroot(ROOT-0...
# 8251  {'dep_parse': 'poss(father-2, Her-1)\nnsubj(la...
# 8252  {'dep_parse': "nsubj(illustrated-3, It-1)\nadv...
# 8253  {'dep_parse': 'det(teacher-3, a-2)\nprep_as(ta...
# 8254  {'dep_parse': 'det(teacher-3, a-2)\nprep_as(ta...
# 8255  {'dep_parse': 'det(teacher-3, a-2)\nprep_as(ta...
# 8256  {'dep_parse': 'amod(Ladies-4, Personal-1)\namo...
# 8257  {'dep_parse': 'amod(Ladies-4, Personal-1)\namo...
# 8258  {'dep_parse': 'mark(defending-4, Since-1)\nnsu...
# 8259  {'dep_parse': 'mark(defending-4, Since-1)\nnsu...
# 8260  {'dep_parse': 'nsubj(liked-2, I-1)\nroot(ROOT-...
# 8261  {'dep_parse': 'nsubj(think-2, I-1)\nroot(ROOT-...
# 8262  {'dep_parse': 'nsubj(think-2, I-1)\nroot(ROOT-...
# 8263  {'dep_parse': "advmod(proof-8, However-1)\ndet...
# 8264  {'dep_parse': "advmod(proof-8, However-1)\ndet...
# 8265  {'dep_parse': 'nn(Finch-3, Lawyer-1)\nnn(Finch...
# 8266  {'dep_parse': 'det(book-2, This-1)\nnsubj(tell...
# 8267  {'dep_parse': 'det(book-2, This-1)\nnsubj(tell...
# 8268  {'dep_parse': 'det(book-2, This-1)\nnsubj(tell...
# 8269  {'dep_parse': 'advmod(connect-5, Personally-1)...
# 8270  {'dep_parse': 'nsubj(recommend-4, I-1)\naux(re...
# 8271  {'dep_parse': 'nsubj(recommend-4, I-1)\naux(re...
# 8272  {'dep_parse': 'nsubj(time-5, This-1)\ncop(time...
# 8273  {'dep_parse': 'nsubj(seen-3, I-1)\naux(seen-3,...
# 8274  {'dep_parse': 'nsubj(proved-2, It-1)\nroot(ROO...
# 8275  {'dep_parse': 'nsubj(proved-2, It-1)\nroot(ROO...
# 8276  {'dep_parse': 'det(book-2, This-1)\nnsubj(pain...
# 8277  {'dep_parse': 'nsubj(picked-4, I-1)\naux(picke...
# 8278  {'dep_parse': 'nsubj(picked-4, I-1)\naux(picke...
#
# [8279 rows x 16 columns]

# %%
rels_final = []
rels_simp_final = []


'''
Post o sentence o 2 bar naram : check with prev post & index
baghie mokhalafato ham ezafe konam.
'''
prev_post_num = 0
prev_sentence_num = 0
for ind, row in df_rels.iterrows():
    current_post_num = row["post_num"]
    current_sentence_num = row["sentence_num"]   
    if ind > 0:
        if prev_post_num == current_post_num and prev_sentence_num == current_sentence_num:
            #we already extracted the relations of this sentence. Skip it
            continue
        
    #list_rels_final.append(row.tolist())
    try:
        t_annotated = df_rels.iloc[ind]["annotation"]
        t_annotated = ast.literal_eval(t_annotated)
        g_dir = create_dep_graph(t_annotated)
        if g_dir is None:
            print "No extraction found"
            continue
        #g_undir = g_dir.to_undirected()
    except:
        print "Unexpected error while extracting relations:", sys.exc_info()[0]
        continue    
    
    rels_pure, rels_simp = get_relations(g_dir, t_annotated, EXTRACT_NESTED_PREPOSITIONS_RELS=True, option="SVO") 
    #print len(rels_pure)
    for r in rels_pure:
        new_row = row.copy()
        for key in r:
            new_row[key] = r[key]

        #new_row["type"] = "SVO-conjAND"
        #new_row["pattern"] = "(nsubj, verb, object) with conj_and"
        #new_row["arg1"] = r["arg1"]
        #new_row["rel"] = r["rel"]
        #new_row["arg2"] = r["arg2"]
        rels_final.append(new_row.tolist())    

    
    prev_post_num = current_post_num
    prev_sentence_num = current_sentence_num
    
df = pd.DataFrame(rels_final,columns = df_rels.columns.tolist())
#df
df.to_csv(based_dir + "with_conj_and_rels/" + input_name_prefix + file_output_postfix,
          sep=',', encoding='utf-8',header=True, columns=df.columns.tolist(), index=False)
# Out:
# conveying-VBG-19  does not appeared as a separate node in parsing tree.
# using-VBG-23  does not appeared as a separate node in parsing tree.
# like-IN-7  does not appeared as a separate node in parsing tree.
# based-VBN-18  does not appeared as a separate node in parsing tree.
# including-VBG-18  does not appeared as a separate node in parsing tree.
# including-VBG-9  does not appeared as a separate node in parsing tree.
# including-VBG-10  does not appeared as a separate node in parsing tree.
# based-VBN-17  does not appeared as a separate node in parsing tree.
# based-VBN-14  does not appeared as a separate node in parsing tree.
# makes-VBZ-4  does not appeared as a separate node in parsing tree.
# leave-VB-18  does not appeared as a separate node in parsing tree.
# play-VB-23  does not appeared as a separate node in parsing tree.
# scratch-VB-28  does not appeared as a separate node in parsing tree.
# come-VBN-33  does not appeared as a separate node in parsing tree.
# came-VBD-38  does not appeared as a separate node in parsing tree.
# based-VBN-5  does not appeared as a separate node in parsing tree.
# based-VBN-18  does not appeared as a separate node in parsing tree.
# based-VBN-18  does not appeared as a separate node in parsing tree.
# based-VBN-29  does not appeared as a separate node in parsing tree.
# had-VBD-11  does not appeared as a separate node in parsing tree.
# understanding-VBG-15  does not appeared as a separate node in parsing tree.
# meant-VBD-22  does not appeared as a separate node in parsing tree.
# reading-VBG-26  does not appeared as a separate node in parsing tree.
# learned-VBD-34  does not appeared as a separate node in parsing tree.
# referring-VBG-41  does not appeared as a separate node in parsing tree.
# defended-VBD-49  does not appeared as a separate node in parsing tree.
# decided-VBD-2  does not appeared as a separate node in parsing tree.
# going-VBG-6  does not appeared as a separate node in parsing tree.
# got-VBD-13  does not appeared as a separate node in parsing tree.
# including-VBG-12  does not appeared as a separate node in parsing tree.
# including-VBG-21  does not appeared as a separate node in parsing tree.
# running-VBG-7  does not appeared as a separate node in parsing tree.
# walking-VBG-12  does not appeared as a separate node in parsing tree.
# seen-VBN-18  does not appeared as a separate node in parsing tree.
# wanted-VBD-35  does not appeared as a separate node in parsing tree.
# do-VB-38  does not appeared as a separate node in parsing tree.
# enjoying-VBG-4  does not appeared as a separate node in parsing tree.
# aspired-VBN-13  does not appeared as a separate node in parsing tree.

# %%
df2 = df[df["type"].str.contains("conj")]

# %%
df2
# Out:
#       Unnamed: 0  post_num  sentence_num  \
# 2              0         3             1
# 5              0         3             1
# 12             8         3            21
# 23            19         3            28
# 25            19         3            28
# 27            19         3            28
# 34            27         4             1
# 37            27         4             1
# 42            27         4             1
# 43            27         4             1
# 44            27         4             1
# 45            27         4             1
# 48            32         4             5
# 67            50        10             6
# 78            60        12             3
# 82            63        15             7
# 96            74        19            33
# 113           90        24             7
# 125          100        28             9
# 139          114        31             8
# 150          124        34            13
# 163          136        36             9
# 173          145        38             9
# 177          148        38            11
# 216          185        47            35
# 218          186        47            40
# 219          186        47            40
# 230          195        48            11
# 242          207        50            42
# 243          207        50            42
# ...          ...       ...           ...
# 9117        8001      2631             3
# 9119        8002      2632             3
# 9121        8003      2633             4
# 9140        8021      2641             1
# 9151        8031      2644             2
# 9155        8033      2644             4
# 9161        8038      2650             3
# 9178        8054      2664             5
# 9195        8070      2677             1
# 9214        8088      2681            45
# 9216        8088      2681            45
# 9236        8108      2688             1
# 9240        8111      2688            13
# 9285        8154      2704             1
# 9289        8158      2704             6
# 9296        8164      2708             2
# 9304        8171      2712             3
# 9307        8173      2714             1
# 9313        8178      2714             8
# 9323        8187      2728             4
# 9327        8190      2730             1
# 9331        8193      2732             1
# 9352        8212      2741             5
# 9354        8213      2742             5
# 9358        8215      2743             2
# 9386        8241      2745            24
# 9397        8251      2752             1
# 9399        8252      2752             2
# 9401        8253      2753             1
# 9428        8277      2774             3
#
#                                                sentence  \
# 2     However, she did write a few articles that one...
# 5     However, she did write a few articles that one...
# 12    I loved her way of thinking especially how she...
# 23    He firmly believed that it was important for h...
# 25    He firmly believed that it was important for h...
# 27    He firmly believed that it was important for h...
# 34    I smell the smoke of fireplaces and think abou...
# 37    I smell the smoke of fireplaces and think abou...
# 42    I smell the smoke of fireplaces and think abou...
# 43    I smell the smoke of fireplaces and think abou...
# 44    I smell the smoke of fireplaces and think abou...
# 45    I smell the smoke of fireplaces and think abou...
# 48    It must be the school thing, my daughter just ...
# 67    I love this book and could not tell you how ma...
# 78    It also shows the love between a father and hi...
# 82    For those who were not around then I think thi...
# 96    Whenever you take an extreme view and I know I...
# 113   Or that entire sequence at the end when Boo Ra...
# 125   It takes him a few seconds to recover but he g...
# 139   I'd carry it with me in between classes and ho...
# 150   It shows us how the people in the book see the...
# 163   So, I stopped reading for a while and watched ...
# 173   Mr. Finch shocks Scout and Jem when he shoots ...
# 177   But he does not even have a gun and is never s...
# 216   He and his children were continually reminding...
# 218                  And I love Scout and Jem and Dill.
# 219                  And I love Scout and Jem and Dill.
# 230   Even though I might have seen other books as m...
# 242   By taking this case, Atticus knowingly risks h...
# 243   By taking this case, Atticus knowingly risks h...
# ...                                                 ...
# 9117                  This time I read it and loved it.
# 9119  Scout, his brother, and their friend Dill has ...
# 9121  It's not a perfect novel, as its critics will ...
# 9140  When I was in junior high school, I bought the...
# 9151  I read it as required reading in 9th grade and...
# 9155  read every few years and I always find some ot...
# 9161  I liked the book because it taught me that peo...
# 9178  This is one of those rare books that you can e...
# 9195  the language used and the description excels e...
# 9214  The racist bitties and crackers that view spoi...
# 9216  The racist bitties and crackers that view spoi...
# 9236  I avoided Mockingbird all through high school ...
# 9240  The jury and town knows the truth, but the def...
# 9285  Because I have been busy lately I read it much...
# 9289  This book discusses tolerance and compassion b...
# 9296  There is a reason it had won a Purlitzer prize...
# 9304  I also like how they invitioned the life of th...
# 9307  I picked it up and set it down again after rea...
# 9313  This shows us valuable morals and I enjoyed re...
# 9323  Yet, it also contains the purity of a child an...
# 9327  I finally found time to read it, and I was exc...
# 9331  This book takes a child's innocence and applie...
# 9352  I found that Ms. Dubose was a great character ...
# 9354  It was like she spent so much time on irreleva...
# 9358  I also learned a lot about myself and even cha...
# 9386  It was quite engaging, especially the last 3 c...
# 9397  Her father was a wise lawyer who showed his tw...
# 9399  It also illustrated the girl's phobias, intere...
# 9401  As a teacher, I have taught this book to many ...
# 9428  I had not picked up my copy of the book in yea...
#
#                        arg1                           rel  \
# 2                     {one}                        {read}
# 5                     {one}                        {read}
# 12                    {she}                        {pull}
# 23                     {He}               NOT {following}
# 25           his {children}               NOT {following}
# 27                     {it}               NOT {following}
# 34                      {I}                       {think}
# 37                      {I}                        {lift}
# 42    another deep {breath}                        {have}
# 43                      {I}                        {have}
# 44        a stunning {blue}                        {have}
# 45              no {clouds}                    is {taken}
# 48                     {me}                     {pretend}
# 67                      {I}              could not {tell}
# 78                     {It}                  also {shows}
# 82                    {one}    might otherwise only {get}
# 96                    {you}                        {know}
# 113            Boo {Radley}                 when {brings}
# 125                    {he}                       {grabs}
# 139                     {I}                     {hold} up
# 150                    {It}                 do not {stop}
# 163                     {I}                     {watched}
# 173             Mr. {Finch}                      {shocks}
# 177                    {he}               is never {seen}
# 216          his {children}  were continually {reminding}
# 218                     {I}                        {love}
# 219                     {I}                        {love}
# 230             few {books}                        {made}
# 242               {Atticus}             knowingly {risks}
# 243               {Atticus}             knowingly {risks}
# ...                     ...                           ...
# 9117                    {I}                       {loved}
# 9119    their friend {Dill}                   has {faced}
# 9121                  {you}                 still {enjoy}
# 9140                    {I}                         {let}
# 9151                    {I}                       {loved}
# 9155                    {I}                 always {find}
# 9161                    {I}              then will {come}
# 9178                  {you}                  still {find}
# 9195      the {description}                      {excels}
# 9214             {crackers}                        {view}
# 9216             {crackers}                       {voted}
# 9236                    {I}                     {thought}
# 9240                 {town}                       {knows}
# 9285                    {I}                       {enjoy}
# 9289            This {book}                   {discusses}
# 9296                   {it}                        {sold}
# 9304                 {they}                    {explains}
# 9307                    {I}              {set} down again
# 9313                 {This}                     {enjoyed}
# 9323                   {it}           Yet also {contains}
# 9327                    {I}      was {excited} beforehand
# 9331            This {book}                     {applies}
# 9352                    {I}                was {starting}
# 9354                  {she}                     {crammed}
# 9358                    {I}                even {changed}
# 9386                {Scout}         finally {understands}
# 9397        a wise {lawyer}                      {showed}
# 9399                   {It}            also {illustrated}
# 9401                    {I}                        {fall}
# 9428                    {I}                        {read}
#
#                             arg2                   type              pattern  \
# 2               a few {articles}       SVO_conj_and_rel  (nsubj, verb, dobj)
# 5                  online {Love}       SVO_conj_and_rel  (nsubj, verb, dobj)
# 12                         {her}  SVO_conj_and_rel_dobj  (nsubj, verb, dobj)
# 23                         {him}       SVO_conj_and_rel  (nsubj, verb, dobj)
# 25                         {him}       SVO_conj_and_rel  (nsubj, verb, dobj)
# 27                         {him}       SVO_conj_and_rel  (nsubj, verb, dobj)
# 34        the {smoke} fireplaces       SVO_conj_and_rel  (nsubj, verb, dobj)
# 37                     my {head}  SVO_conj_and_rel_dobj  (nsubj, verb, dobj)
# 42                this {feeling}      SVO_conj_and_arg1  (nsubj, verb, dobj)
# 43                this {feeling}      SVO_conj_and_arg1  (nsubj, verb, dobj)
# 44                this {feeling}      SVO_conj_and_arg1  (nsubj, verb, dobj)
# 45                this {feeling}       SVO_conj_and_rel  (nsubj, verb, dobj)
# 48                  another {go}       SVO_conj_and_rel  (nsubj, verb, dobj)
# 67                         {you}  SVO_conj_and_rel_dobj  (nsubj, verb, dobj)
# 78    the true {meaning} courage      SVO_conj_and_arg2  (nsubj, verb, dobj)
# 82                     {sorrows}      SVO_conj_and_arg2  (nsubj, verb, dobj)
# 96             an extreme {view}       SVO_conj_and_rel  (nsubj, verb, dobj)
# 113                     shy {ol}      SVO_conj_and_arg2  (nsubj, verb, dobj)
# 125                   {proceeds}      SVO_conj_and_arg2  (nsubj, verb, dobj)
# 139                         {it}  SVO_conj_and_rel_dobj  (nsubj, verb, dobj)
# 150                         {us}       SVO_conj_and_rel  (nsubj, verb, dobj)
# 163    Nikita American TV {Show}  SVO_conj_and_rel_dobj  (nsubj, verb, dobj)
# 173                        {Jem}      SVO_conj_and_arg2  (nsubj, verb, dobj)
# 177                      a {gun}       SVO_conj_and_rel  (nsubj, verb, dobj)
# 216                 each {other}      SVO_conj_and_arg1  (nsubj, verb, dobj)
# 218                        {Jem}      SVO_conj_and_arg2  (nsubj, verb, dobj)
# 219                       {Dill}      SVO_conj_and_arg2  (nsubj, verb, dobj)
# 230                my {behavior}       SVO_conj_and_rel  (nsubj, verb, dobj)
# 242                 his {safety}      SVO_conj_and_arg2  (nsubj, verb, dobj)
# 243               {those} family      SVO_conj_and_arg2  (nsubj, verb, dobj)
# ...                          ...                    ...                  ...
# 9117                       {it.}  SVO_conj_and_rel_dobj  (nsubj, verb, dobj)
# 9119        racial {segregation}      SVO_conj_and_arg2  (nsubj, verb, dobj)
# 9121                  {the} read  SVO_conj_and_rel_dobj  (nsubj, verb, dobj)
# 9140                  the {book}       SVO_conj_and_rel  (nsubj, verb, dobj)
# 9151                        {it}  SVO_conj_and_rel_dobj  (nsubj, verb, dobj)
# 9155     some other {part} story      SVO_conj_and_arg1  (nsubj, verb, dobj)
# 9161                  the {book}       SVO_conj_and_rel  (nsubj, verb, dobj)
# 9178           new {things} love  SVO_conj_and_rel_dobj  (nsubj, verb, dobj)
# 9195         every single {book}      SVO_conj_and_arg1  (nsubj, verb, dobj)
# 9214                   {spoiler}      SVO_conj_and_arg1  (nsubj, verb, dobj)
# 9216       Tom {Robinson} guilty      SVO_conj_and_arg1  (nsubj, verb, dobj)
# 9236               {Mockingbird}       SVO_conj_and_rel  (nsubj, verb, dobj)
# 9240                 the {truth}      SVO_conj_and_arg1  (nsubj, verb, dobj)
# 9285                 the {story}  SVO_conj_and_rel_dobj  (nsubj, verb, dobj)
# 9289                {compassion}      SVO_conj_and_arg2  (nsubj, verb, dobj)
# 9296         a Purlitzer {prize}       SVO_conj_and_rel  (nsubj, verb, dobj)
# 9304               the {trouble}  SVO_conj_and_rel_dobj  (nsubj, verb, dobj)
# 9307                        {it}  SVO_conj_and_rel_dobj  (nsubj, verb, dobj)
# 9313           valuable {morals}       SVO_conj_and_rel  (nsubj, verb, dobj)
# 9323              the {kindness}      SVO_conj_and_arg2  (nsubj, verb, dobj)
# 9327                      {time}       SVO_conj_and_rel  (nsubj, verb, dobj)
# 9331                        {it}  SVO_conj_and_rel_dobj  (nsubj, verb, dobj)
# 9352                 the {scene}       SVO_conj_and_rel  (nsubj, verb, dobj)
# 9354             the {rest} plot  SVO_conj_and_rel_dobj  (nsubj, verb, dobj)
# 9358               my {attitude}  SVO_conj_and_rel_dobj  (nsubj, verb, dobj)
# 9386               the {lessons}      SVO_conj_and_arg1  (nsubj, verb, dobj)
# 9397                     {Scout}      SVO_conj_and_arg2  (nsubj, verb, dobj)
# 9399          her {frustrations}      SVO_conj_and_arg2  (nsubj, verb, dobj)
# 9401                 this {book}       SVO_conj_and_rel  (nsubj, verb, dobj)
# 9428                        {it}  SVO_conj_and_rel_dobj  (nsubj, verb, dobj)
#
#                             arg1_with_pos  \
# 2                              one-PRP-10
# 5                              one-PRP-10
# 12                             she-PRP-22
# 23                               He-PRP-1
# 25             his-PRP$-9 children-NNS-10
# 27                               it-PRP-5
# 34                                I-PRP-1
# 37                               I-PRP-24
# 42                 no-DT-39 clouds-NNS-40
# 43                 no-DT-39 clouds-NNS-40
# 44                 no-DT-39 clouds-NNS-40
# 45                 no-DT-39 clouds-NNS-40
# 48                              me-PRP-16
# 67                                I-PRP-1
# 78                               It-PRP-1
# 82                             one-PRP-31
# 96                              you-PRP-2
# 113               Boo-NNP-9 Radley-NNP-10
# 125                             he-PRP-10
# 139                               I-PRP-1
# 150                              It-PRP-1
# 163                               I-PRP-3
# 173                 Mr.-NNP-1 Finch-NNP-2
# 177                              he-PRP-2
# 216                              He-PRP-1
# 218                               I-PRP-2
# 219                               I-PRP-2
# 230                few-JJ-16 books-NNS-17
# 242                         Atticus-NNP-6
# 243                         Atticus-NNP-6
# ...                                   ...
# 9117                              I-PRP-3
# 9119  their-PRP$-7 friend-NN-8 Dill-NNP-9
# 9121                           you-PRP-19
# 9140                              I-PRP-9
# 9151                              I-PRP-1
# 9155      every-DT-2 few-JJ-3 years-NNS-4
# 9161                              I-PRP-1
# 9178                            you-PRP-9
# 9195    the-DT-1 language-NN-2 used-VBN-3
# 9214   The-DT-1 racist-JJ-2 bitties-NNS-3
# 9216   The-DT-1 racist-JJ-2 bitties-NNS-3
# 9236                              I-PRP-1
# 9240                   The-DT-1 jury-NN-2
# 9285                             I-PRP-27
# 9289                  This-DT-1 book-NN-2
# 9296                             it-PRP-5
# 9304                           they-PRP-5
# 9307                              I-PRP-1
# 9313                            This-DT-1
# 9323                             it-PRP-3
# 9327                              I-PRP-1
# 9331                  This-DT-1 book-NN-2
# 9352                             I-PRP-14
# 9354                            she-PRP-4
# 9358                              I-PRP-1
# 9386                           Boo-NNP-16
# 9397         a-DT-4 wise-JJ-5 lawyer-NN-6
# 9399                             It-PRP-1
# 9401                              I-PRP-5
# 9428                              I-PRP-1
#
#                                           rel_with_pos  \
# 2                                 can-MD-11 find-VB-12
# 5                                 can-MD-11 find-VB-12
# 12                              picked-VBD-23 up-RP-24
# 23        firmly-RB-2 to-TO-11 respect-VB-12 not-RB-25
# 25        firmly-RB-2 to-TO-11 respect-VB-12 not-RB-25
# 27        firmly-RB-2 to-TO-11 respect-VB-12 not-RB-25
# 34                                         smell-VBP-2
# 37                                       bundle-VBP-25
# 42                                         have-VBP-56
# 43                                         have-VBP-56
# 44                                         have-VBP-56
# 45                                         have-VBP-56
# 48                                 to-TO-17 give-VB-18
# 67                                          love-VBP-2
# 78                               also-RB-2 shows-VBZ-3
# 82    might-MD-32 otherwise-RB-33 only-RB-34 get-VB-35
# 96                           Whenever-WRB-1 take-VBP-3
# 113                           when-WRB-8 brings-VBZ-11
# 125                                       grabs-VBZ-11
# 139                                 'd-MD-2 carry-VB-3
# 150                                        shows-VBZ-2
# 163                              So-RB-1 stopped-VBD-4
# 173                                       shocks-VBZ-3
# 177            does-VBZ-3 not-RB-4 even-RB-5 have-VB-6
# 216        were-VBD-5 continually-RB-6 reminding-VBG-7
# 218                                         love-VBP-3
# 219                                         love-VBP-3
# 230                        have-VBP-18 modified-VBN-19
# 242                         knowingly-RB-7 risks-VBZ-8
# 243                         knowingly-RB-7 risks-VBZ-8
# ...                                                ...
# 9117                                        read-VBP-4
# 9119                           has-VBZ-10 faced-VBN-11
# 9121                              can-MD-20 keep-VB-21
# 9140                                     bought-VBD-10
# 9151                                        read-VBP-2
# 9155                            always-RB-7 find-VBP-8
# 9161                                       liked-VBD-2
# 9178                             can-MD-10 enjoy-VB-11
# 9195                                      excels-VBZ-7
# 9214                                        view-VBP-7
# 9216                                       voted-VBD-9
# 9236                                     avoided-VBD-2
# 9240                                       knows-VBZ-5
# 9285                         was-VBD-28 reading-VBG-29
# 9289                                   discusses-VBZ-3
# 9296                               had-VBD-6 won-VBN-7
# 9304                        how-WRB-4 invitioned-VBD-6
# 9307                              picked-VBD-2 up-RP-4
# 9313                                       shows-VBZ-2
# 9323                 Yet-RB-1 also-RB-4 contains-VBZ-5
# 9327                          finally-RB-2 found-VBD-3
# 9331                                       takes-VBZ-3
# 9352                                    thought-VBD-15
# 9354                                       spent-VBD-5
# 9358                           also-RB-2 learned-VBD-3
# 9386                  finally-RB-19 understands-VBZ-20
# 9397                                      showed-VBD-8
# 9399                       also-RB-2 illustrated-VBD-3
# 9401                           have-VBP-6 taught-VBN-7
# 9428           had-VBD-2 not-RB-3 picked-VBN-4 up-RP-5
#
#                                           arg2_with_pos arg1_prepositions  \
# 2                        a-DT-6 few-JJ-7 articles-NNS-8
# 5                              online-JJ-15 Love-NNP-16
# 12                                           her-PRP-32
# 23                                           him-PRP-13
# 25                                           him-PRP-13
# 27                                           him-PRP-13
# 34                 the-DT-3 smoke-NN-4 fireplaces-NNS-6
# 37                                my-PRP$-33 head-NN-34
# 42                             this-DT-57 feeling-NN-58
# 43                             this-DT-57 feeling-NN-58
# 44                             this-DT-57 feeling-NN-58
# 45                             this-DT-57 feeling-NN-58
# 48                               another-DT-20 go-NN-21
# 67                                            you-PRP-9
# 78                                   the-DT-4 love-NN-5
# 82                   the-DT-22 tenor-NN-23 years-NNS-28
# 96                       an-DT-4 extreme-JJ-5 view-NN-6
# 113   his-PRP$-12 awkward-JJ-13 self-NN-18 created-V...
# 125                             Scout-NNP-12 head-NN-14
# 139                                           it-PRP-12
# 150                                            us-PRP-3
# 163   Nikita-NNP-11 American-NNP-12 TV-NNP-13 Show-N...
# 173                                         Scout-NNP-4
# 177                                     a-DT-7 gun-NN-8
# 216                                each-DT-8 other-JJ-9
# 218                                         Scout-NNP-4
# 219                                         Scout-NNP-4
# 230                           my-PRP$-20 behavior-NN-21
# 242                         his-PRP$-9 reputation-NN-10
# 243                         his-PRP$-9 reputation-NN-10
# ...                                                 ...               ...
# 9117                                          it.-PRP-8
# 9119                                      abuses-NNS-12
# 9121                              the-DT-29 read-VBN-30
# 9140                               the-DT-11 book-NN-12
# 9151                                          it-PRP-12
# 9155       some-DT-9 other-JJ-10 part-NN-11 story-NN-14
# 9161                                 the-DT-3 book-NN-4
# 9178                 new-JJ-19 things-NNS-20 love-VB-22
# 9195                  every-DT-8 single-JJ-9 book-NN-10
# 9214                                       spoiler-NN-8
# 9216            Tom-NNP-10 Robinson-NNP-11 guilty-JJ-12
# 9236                                  Mockingbird-NNP-3
# 9240                                the-DT-6 truth-NN-7
# 9285                              the-DT-32 story-NN-33
# 9289                                     tolerance-NN-4
# 9296                 a-DT-8 Purlitzer-NNP-9 prize-NN-10
# 9304                            the-DT-14 trouble-NN-15
# 9307                                           it-PRP-7
# 9313                         valuable-JJ-4 morals-NNS-5
# 9323                   the-DT-6 purity-NN-7 child-NN-10
# 9327                                          time-NN-4
# 9331                                          it-PRP-10
# 9352                              the-DT-16 scene-NN-17
# 9354                    the-DT-23 rest-NN-24 plot-NN-27
# 9358                          my-PRP$-11 attitude-NN-12
# 9386                           the-DT-21 lessons-NNS-22
# 9397    his-PRP$-9 two-CD-10 children-NNS-11 Jem-NNP-12
# 9399                      phobias-NNS-7 interests-NNS-9
# 9401                                this-DT-8 book-NN-9
# 9428                                          it-PRP-16
#
#                                        rel_prepositions  \
# 2
# 5
# 12
# 23
# 25
# 27
# 34             REASON: prep_about TEXT: hot {cider} --
# 37                  REASON: prep_to TEXT: the {sky} --
# 42
# 43
# 44
# 45                     REASON: prep_from TEXT: {me} --
# 48
# 67
# 78
# 82    REASON: prep_from TEXT: the 2,800 {pages} Amer...
# 96
# 113
# 125
# 139
# 150
# 163
# 173
# 177                  REASON: prep_with TEXT: {one.} --
# 216
# 218
# 219
# 230
# 242
# 243
# ...                                                 ...
# 9117
# 9119
# 9121
# 9140
# 9151            REASON: prep_from TEXT: the {start} --
# 9155
# 9161
# 9178
# 9195
# 9214
# 9216
# 9236
# 9240
# 9285
# 9289
# 9296
# 9304
# 9307
# 9313
# 9323
# 9327
# 9331  REASON: prep_to TEXT: real world {situations} --
# 9352
# 9354  REASON: prep_into TEXT: the last couple {chapt...
# 9358  REASON: prep_to TEXT: certain modern {problems...
# 9386
# 9397
# 9399
# 9401  REASON: prep_with TEXT: the {text} -- REASON: ...
# 9428                REASON: prep_from TEXT: {cover} --
#
#                                  arg2_prepositions  \
# 2
# 5
# 12
# 23
# 25
# 27
# 34
# 37
# 42
# 43
# 44
# 45
# 48
# 67
# 78
# 82
# 96
# 113
# 125
# 139
# 150
# 163
# 173
# 177
# 216
# 218
# 219
# 230
# 242
# 243
# ...                                            ...
# 9117
# 9119
# 9121
# 9140
# 9151
# 9155
# 9161
# 9178
# 9195
# 9214
# 9216
# 9236
# 9240
# 9285
# 9289
# 9296
# 9304
# 9307
# 9313
# 9323  REASON: prep_from TEXT: the {unexpected} --
# 9327
# 9331
# 9352
# 9354
# 9358
# 9386
# 9397
# 9399
# 9401
# 9428
#
#                                              annotation
# 2     {'dep_parse': 'advmod(write-5, However-1)\nnsu...
# 5     {'dep_parse': 'advmod(write-5, However-1)\nnsu...
# 12    {'dep_parse': 'nsubj(loved-2, I-1)\nroot(ROOT-...
# 23    {'dep_parse': 'nsubj(respect-12, He-1)\nadvmod...
# 25    {'dep_parse': 'nsubj(respect-12, He-1)\nadvmod...
# 27    {'dep_parse': 'nsubj(respect-12, He-1)\nadvmod...
# 34    {'dep_parse': 'nsubj(smell-2, I-1)\nroot(ROOT-...
# 37    {'dep_parse': 'nsubj(smell-2, I-1)\nroot(ROOT-...
# 42    {'dep_parse': 'nsubj(smell-2, I-1)\nroot(ROOT-...
# 43    {'dep_parse': 'nsubj(smell-2, I-1)\nroot(ROOT-...
# 44    {'dep_parse': 'nsubj(smell-2, I-1)\nroot(ROOT-...
# 45    {'dep_parse': 'nsubj(smell-2, I-1)\nroot(ROOT-...
# 48    {'dep_parse': 'nsubj(thing-6, It-1)\naux(thing...
# 67    {'dep_parse': 'nsubj(love-2, I-1)\nroot(ROOT-0...
# 78    {'dep_parse': 'nsubj(shows-3, It-1)\nadvmod(sh...
# 82    {'dep_parse': 'dep(think-9, For-1)\nnsubj(thin...
# 96    {'dep_parse': 'advmod(take-3, Whenever-1)\nnsu...
# 113   {'dep_parse': "det(sequence-4, that-2)\namod(s...
# 125   {'dep_parse': 'nsubj(takes-2, It-1)\nroot(ROOT...
# 139   {'dep_parse': "nsubj(carry-3, I-1)\naux(carry-...
# 150   {'dep_parse': 'nsubj(shows-2, It-1)\nroot(ROOT...
# 163   {'dep_parse': 'advmod(stopped-4, So-1)\nnsubj(...
# 173   {'dep_parse': 'nn(Finch-2, Mr.-1)\nnsubj(shock...
# 177   {'dep_parse': 'nsubj(have-6, he-2)\naux(have-6...
# 216   {'dep_parse': 'nsubj(reminding-7, He-1)\nposs(...
# 218   {'dep_parse': 'cc(love-3, And-1)\nnsubj(love-3...
# 219   {'dep_parse': 'cc(love-3, And-1)\nnsubj(love-3...
# 230   {'dep_parse': 'advmod(seen-6, Even-1)\nmark(se...
# 242   {'dep_parse': 'prepc_by(risks-8, taking-2)\nde...
# 243   {'dep_parse': 'prepc_by(risks-8, taking-2)\nde...
# ...                                                 ...
# 9117  {'dep_parse': 'det(time-2, This-1)\nroot(ROOT-...
# 9119  {'dep_parse': 'root(ROOT-0, Scout-1)\nposs(bro...
# 9121  {'dep_parse': "nsubj(novel-6, It-1)\ncop(novel...
# 9140  {'dep_parse': 'advmod(was-3, When-1)\nnsubj(wa...
# 9151  {'dep_parse': 'nsubj(read-2, I-1)\nroot(ROOT-0...
# 9155  {'dep_parse': 'root(ROOT-0, read-1)\ndet(years...
# 9161  {'dep_parse': 'nsubj(liked-2, I-1)\nroot(ROOT-...
# 9178  {'dep_parse': 'nsubj(one-3, This-1)\ncop(one-3...
# 9195  {'dep_parse': 'det(language-2, the-1)\nnsubj(e...
# 9214  {'dep_parse': 'det(bitties-3, The-1)\namod(bit...
# 9216  {'dep_parse': 'det(bitties-3, The-1)\namod(bit...
# 9236  {'dep_parse': 'nsubj(avoided-2, I-1)\nroot(ROO...
# 9240  {'dep_parse': 'det(jury-2, The-1)\nnsubj(knows...
# 9285  {'dep_parse': 'mark(busy-5, Because-1)\nnsubj(...
# 9289  {'dep_parse': 'det(book-2, This-1)\nnsubj(disc...
# 9296  {'dep_parse': 'expl(is-2, There-1)\nroot(ROOT-...
# 9304  {'dep_parse': 'nsubj(like-3, I-1)\nadvmod(like...
# 9307  {'dep_parse': 'nsubj(picked-2, I-1)\nroot(ROOT...
# 9313  {'dep_parse': 'nsubj(shows-2, This-1)\nroot(RO...
# 9323  {'dep_parse': 'advmod(contains-5, Yet-1)\nnsub...
# 9327  {'dep_parse': 'nsubj(found-3, I-1)\nxsubj(read...
# 9331  {'dep_parse': 'det(book-2, This-1)\nnsubj(take...
# 9352  {'dep_parse': 'nsubj(found-2, I-1)\nroot(ROOT-...
# 9354  {'dep_parse': 'nsubj(was-2, It-1)\nroot(ROOT-0...
# 9358  {'dep_parse': 'nsubj(learned-3, I-1)\nadvmod(l...
# 9386  {'dep_parse': 'nsubj(engaging-4, It-1)\ncop(en...
# 9397  {'dep_parse': 'poss(father-2, Her-1)\nnsubj(la...
# 9399  {'dep_parse': "nsubj(illustrated-3, It-1)\nadv...
# 9401  {'dep_parse': 'det(teacher-3, a-2)\nprep_as(ta...
# 9428  {'dep_parse': 'nsubj(picked-4, I-1)\naux(picke...
#
# [935 rows x 16 columns]
